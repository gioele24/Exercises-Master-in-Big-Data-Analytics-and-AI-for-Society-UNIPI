# %%
import pandas as pd
import numpy as np
import re
import html

# %%
df = pd.read_csv('steam_games_enhanced.csv', low_memory=False)

# %%
# Normalize the column names
df.columns = df.columns.str.lower().str.replace(' ', '_')

# %%
df.head()
# Out:
#      appid     normalized_name                    name release_date  \
# 0  1026420              warsaw                  WARSAW   2019-10-01
# 1    22670  alienbreed3descent  Alien Breed 3: Descent   2010-11-01
# 2   231330  deadfalladventures     Deadfall Adventures   2013-11-01
# 3   552520             farcry5              Far Cry® 5   2018-03-01
# 4  1293830       forzahorizon4         Forza Horizon 4   2021-03-01
#
#     estimated_owners  peak_ccu  required_age launch_price  price  dlc_count  \
# 0      20000 - 50000         5             0       $23,99  23.99          0
# 1    200000 - 500000         3             0        $9,99   9.99          0
# 2    100000 - 200000         4             0       $19,99  19.99          0
# 3  2000000 - 5000000      2164            17       $59,99  59.99          5
# 4  2000000 - 5000000      7571             0       $59,99  59.99         15
#
#    ...               new_owners new_average_forever new_median_forever  \
# 0  ...         20,000 .. 50,000               572.0              496.0
# 1  ...       200,000 .. 500,000               161.0              223.0
# 2  ...       200,000 .. 500,000               671.0              821.0
# 3  ...   2,000,000 .. 5,000,000              1700.0             1341.0
# 4  ...  5,000,000 .. 10,000,000              2487.0              770.0
#
#   new_price new_initialprice new_discount  new_ccu  \
# 0       0.0              0.0          0.0      3.0
# 1     999.0            999.0          0.0      1.0
# 2    1999.0           1999.0          0.0      4.0
# 3    5999.0           5999.0          0.0   4336.0
# 4       0.0              0.0          0.0   6019.0
#
#                                        new_languages  \
# 0           English, French, German, Polish, Russian
# 1  English, French, German, Italian, Japanese, Sp...
# 2           English, German, Polish, French, Russian
# 3  English, French, Italian, German, Spanish - Sp...
# 4  English, French, Italian, German, Spanish - Sp...
#
#                   new_genre                                           new_tags
# 0  Indie, RPG, Free To Play  {'Tactical RPG': 255, 'Wargame': 251, 'Turn-Ba...
# 1                    Action  {'Action': 111, 'Shooter': 93, 'Isometric': 89...
# 2         Action, Adventure  {'Adventure': 143, 'Action': 127, 'FPS': 104, ...
# 3         Action, Adventure  {'Open World': 1711, 'Action-Adventure': 1707,...
# 4                    Racing  {'Racing': 790, 'Open World': 669, 'Driving': ...
#
# [5 rows x 69 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5129 entries, 0 to 5128
# Data columns (total 69 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   appid                       5129 non-null   int64
#  1   normalized_name             5129 non-null   object
#  2   name                        5129 non-null   object
#  3   release_date                5129 non-null   object
#  4   estimated_owners            5129 non-null   object
#  5   peak_ccu                    5129 non-null   int64
#  6   required_age                5129 non-null   int64
#  7   launch_price                4610 non-null   object
#  8   price                       5129 non-null   float64
#  9   dlc_count                   5129 non-null   int64
#  10  about_the_game              5112 non-null   object
#  11  summary                     3051 non-null   object
#  12  supported_languages         5129 non-null   object
#  13  full_audio_languages        5129 non-null   object
#  14  some_reviews                2260 non-null   object
#  15  number_of_reviews           3055 non-null   object
#  16  reviews_total               4610 non-null   float64
#  17  reviews_score_fancy         4610 non-null   object
#  18  header_image                5129 non-null   object
#  19  website                     4249 non-null   object
#  20  support_url                 3762 non-null   object
#  21  support_email               3232 non-null   object
#  22  windows                     5129 non-null   bool
#  23  mac                         5129 non-null   bool
#  24  linux                       5129 non-null   bool
#  25  metacritic_score            5129 non-null   int64
#  26  metacritic_url              2744 non-null   object
#  27  user_score                  5129 non-null   int64
#  28  positive                    5129 non-null   int64
#  29  negative                    5129 non-null   int64
#  30  score_rank                  1 non-null      float64
#  31  rating                      2793 non-null   float64
#  32  achievements                5129 non-null   int64
#  33  recommendations             5129 non-null   int64
#  34  notes                       601 non-null    object
#  35  average_playtime_forever    5129 non-null   int64
#  36  average_playtime_two_weeks  5129 non-null   int64
#  37  median_playtime_forever     5129 non-null   int64
#  38  median_playtime_two_weeks   5129 non-null   int64
#  39  developers                  5119 non-null   object
#  40  publishers                  5105 non-null   object
#  41  categories                  5127 non-null   object
#  42  genres                      5124 non-null   object
#  43  tags                        5018 non-null   object
#  44  screenshots                 5129 non-null   object
#  45  movies                      4562 non-null   object
#  46  plays                       3055 non-null   object
#  47  playing                     3055 non-null   object
#  48  backlogs                    3055 non-null   object
#  49  wishlist                    3055 non-null   object
#  50  lists                       3055 non-null   object
#  51  steam_page                  4610 non-null   object
#  52  platforms                   3055 non-null   object
#  53  platforms_2                 3422 non-null   object
#  54  infos_per_platform          3422 non-null   object
#  55  revenue_estimated           4610 non-null   object
#  56  meta_critic_score           5129 non-null   float64
#  57  new_positive                4583 non-null   float64
#  58  new_negative                4583 non-null   float64
#  59  new_owners                  4583 non-null   object
#  60  new_average_forever         4583 non-null   float64
#  61  new_median_forever          4583 non-null   float64
#  62  new_price                   4583 non-null   float64
#  63  new_initialprice            4583 non-null   float64
#  64  new_discount                4583 non-null   float64
#  65  new_ccu                     4583 non-null   float64
#  66  new_languages               4583 non-null   object
#  67  new_genre                   4575 non-null   object
#  68  new_tags                    4583 non-null   object
# dtypes: bool(3), float64(13), int64(14), object(39)
# memory usage: 2.6+ MB

# %% [markdown]
# ### Data type cleaning

# %%
# Transform the 'release_date' column to datetime
df['release_date'] = pd.to_datetime(df['release_date'])

# %%
df['estimated_owners'].unique()
# Out:
# array(['20000 - 50000', '200000 - 500000', '100000 - 200000',
#        '2000000 - 5000000', '500000 - 1000000', '1000000 - 2000000',
#        '50000 - 100000', '0 - 20000', '20000000 - 50000000',
#        '5000000 - 10000000', '0 - 0', '10000000 - 20000000',
#        '50000000 - 100000000', '100000000 - 200000000'], dtype=object)

# %%
df['new_owners'].unique()
# Out:
# array(['20,000 .. 50,000', '200,000 .. 500,000', '2,000,000 .. 5,000,000',
#        '5,000,000 .. 10,000,000', '1,000,000 .. 2,000,000',
#        '500,000 .. 1,000,000', '100,000 .. 200,000', '0 .. 20,000',
#        '50,000 .. 100,000', nan, '20,000,000 .. 50,000,000',
#        '50,000,000 .. 100,000,000', '10,000,000 .. 20,000,000',
#        '200,000,000 .. 500,000,000', '100,000,000 .. 200,000,000'],
#       dtype=object)

# %%
df.insert(5, 'min_estimated_owners', df['estimated_owners'].str.split(' - ').str[0].values.astype('int64'))
df.insert(6, 'max_estimated_owners', df['estimated_owners'].str.split(' - ').str[1].values.astype('int64'))

# %%
df.drop(columns='estimated_owners', inplace=True)

# %%
df.insert(60, 'new_min_estimated_owners', df['new_owners'].str.split(' .. ').str[0].str.replace(',' , '').astype('float'))
df.insert(61, 'new_max_estimated_owners', df['new_owners'].str.split(' .. ').str[1].str.replace(',' , '').astype('float'))

# %%
df.drop(columns='new_owners', inplace=True)

# %%
(df['max_estimated_owners'] == 0).value_counts()
# Out:
# max_estimated_owners
# False    5061
# True       68
# Name: count, dtype: int64

# %%
(df['new_max_estimated_owners'].isna()).value_counts()
# Out:
# new_max_estimated_owners
# False    4583
# True      546
# Name: count, dtype: int64

# %%
((df['max_estimated_owners'] == 0) & (df['new_max_estimated_owners'].isna())).value_counts()
# Out:
# False    5061
# True       68
# Name: count, dtype: int64

# %%
df.drop(df[df['max_estimated_owners'] == 0].index, inplace=True)
df.reset_index(drop=True, inplace=True)

# %%
(df['new_max_estimated_owners'].isna()).value_counts()
# Out:
# new_max_estimated_owners
# False    4583
# True      478
# Name: count, dtype: int64

# %%
df['new_max_estimated_owners'] = df['new_max_estimated_owners'].fillna(df['max_estimated_owners'])

# %%
(df['new_max_estimated_owners'].isna()).value_counts()
# Out:
# new_max_estimated_owners
# False    5061
# Name: count, dtype: int64

# %%
(df['new_max_estimated_owners'] < df['max_estimated_owners']).value_counts()
# Out:
# False    4865
# True      196
# Name: count, dtype: int64

# %%
for i, row in df.iterrows():
    df.at[i, 'new_max_estimated_owners'] = max(row['new_max_estimated_owners'], row['max_estimated_owners'])

# %% [markdown]
# Now the `max_estimated_owners` is useless and can be dropped

# %%
df.drop(columns='max_estimated_owners', inplace=True)

# %% [markdown]
# Let's do the same analysis with `min_estiamted_owners` and `new_min_estimated_owners`

# %%
(df['min_estimated_owners'] == 0).value_counts()
# Out:
# min_estimated_owners
# False    3880
# True     1181
# Name: count, dtype: int64

# %%
(df['new_min_estimated_owners'] == 0).value_counts()
# Out:
# new_min_estimated_owners
# False    4414
# True      647
# Name: count, dtype: int64

# %%
df['new_min_estimated_owners'].isna().value_counts()
# Out:
# new_min_estimated_owners
# False    4583
# True      478
# Name: count, dtype: int64

# %%
((df['min_estimated_owners'] == 0) & df['new_min_estimated_owners'].isna()).value_counts()
# Out:
# False    4848
# True      213
# Name: count, dtype: int64

# %%
df['new_min_estimated_owners'] = df['new_min_estimated_owners'].fillna(df['min_estimated_owners'])

# %%
(df['new_min_estimated_owners'] == 0).value_counts()
# Out:
# new_min_estimated_owners
# False    4201
# True      860
# Name: count, dtype: int64

# %%
(df['new_min_estimated_owners'] < df['min_estimated_owners']).value_counts()
# Out:
# False    4865
# True      196
# Name: count, dtype: int64

# %%
for i, row in df.iterrows():
    df.at[i, 'new_min_estimated_owners'] = max(row['new_min_estimated_owners'], row['min_estimated_owners'])

# %% [markdown]
# `min_estimated_owners` can now be dropped as completely useless

# %%
df.drop(columns='min_estimated_owners', inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5061 entries, 0 to 5060
# Data columns (total 69 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   appid                       5061 non-null   int64
#  1   normalized_name             5061 non-null   object
#  2   name                        5061 non-null   object
#  3   release_date                5061 non-null   datetime64[ns]
#  4   peak_ccu                    5061 non-null   int64
#  5   required_age                5061 non-null   int64
#  6   launch_price                4583 non-null   object
#  7   price                       5061 non-null   float64
#  8   dlc_count                   5061 non-null   int64
#  9   about_the_game              5045 non-null   object
#  10  summary                     3021 non-null   object
#  11  supported_languages         5061 non-null   object
#  12  full_audio_languages        5061 non-null   object
#  13  some_reviews                2248 non-null   object
#  14  number_of_reviews           3024 non-null   object
#  15  reviews_total               4583 non-null   float64
#  16  reviews_score_fancy         4583 non-null   object
#  17  header_image                5061 non-null   object
#  18  website                     4201 non-null   object
#  19  support_url                 3707 non-null   object
#  20  support_email               3196 non-null   object
#  21  windows                     5061 non-null   bool
#  22  mac                         5061 non-null   bool
#  23  linux                       5061 non-null   bool
#  24  metacritic_score            5061 non-null   int64
#  25  metacritic_url              2736 non-null   object
#  26  user_score                  5061 non-null   int64
#  27  positive                    5061 non-null   int64
#  28  negative                    5061 non-null   int64
#  29  score_rank                  1 non-null      float64
#  30  rating                      2768 non-null   float64
#  31  achievements                5061 non-null   int64
#  32  recommendations             5061 non-null   int64
#  33  notes                       591 non-null    object
#  34  average_playtime_forever    5061 non-null   int64
#  35  average_playtime_two_weeks  5061 non-null   int64
#  36  median_playtime_forever     5061 non-null   int64
#  37  median_playtime_two_weeks   5061 non-null   int64
#  38  developers                  5061 non-null   object
#  39  publishers                  5037 non-null   object
#  40  categories                  5059 non-null   object
#  41  genres                      5057 non-null   object
#  42  tags                        5018 non-null   object
#  43  screenshots                 5061 non-null   object
#  44  movies                      4500 non-null   object
#  45  plays                       3024 non-null   object
#  46  playing                     3024 non-null   object
#  47  backlogs                    3024 non-null   object
#  48  wishlist                    3024 non-null   object
#  49  lists                       3024 non-null   object
#  50  steam_page                  4583 non-null   object
#  51  platforms                   3024 non-null   object
#  52  platforms_2                 3384 non-null   object
#  53  infos_per_platform          3384 non-null   object
#  54  revenue_estimated           4583 non-null   object
#  55  meta_critic_score           5061 non-null   float64
#  56  new_positive                4583 non-null   float64
#  57  new_negative                4583 non-null   float64
#  58  new_min_estimated_owners    5061 non-null   float64
#  59  new_max_estimated_owners    5061 non-null   float64
#  60  new_average_forever         4583 non-null   float64
#  61  new_median_forever          4583 non-null   float64
#  62  new_price                   4583 non-null   float64
#  63  new_initialprice            4583 non-null   float64
#  64  new_discount                4583 non-null   float64
#  65  new_ccu                     4583 non-null   float64
#  66  new_languages               4583 non-null   object
#  67  new_genre                   4575 non-null   object
#  68  new_tags                    4583 non-null   object
# dtypes: bool(3), datetime64[ns](1), float64(15), int64(14), object(36)
# memory usage: 2.6+ MB

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5061 entries, 0 to 5060
# Data columns (total 69 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   appid                       5061 non-null   int64
#  1   normalized_name             5061 non-null   object
#  2   name                        5061 non-null   object
#  3   release_date                5061 non-null   datetime64[ns]
#  4   peak_ccu                    5061 non-null   int64
#  5   required_age                5061 non-null   int64
#  6   launch_price                4583 non-null   object
#  7   price                       5061 non-null   float64
#  8   dlc_count                   5061 non-null   int64
#  9   about_the_game              5045 non-null   object
#  10  summary                     3021 non-null   object
#  11  supported_languages         5061 non-null   object
#  12  full_audio_languages        5061 non-null   object
#  13  some_reviews                2248 non-null   object
#  14  number_of_reviews           3024 non-null   object
#  15  reviews_total               4583 non-null   float64
#  16  reviews_score_fancy         4583 non-null   object
#  17  header_image                5061 non-null   object
#  18  website                     4201 non-null   object
#  19  support_url                 3707 non-null   object
#  20  support_email               3196 non-null   object
#  21  windows                     5061 non-null   bool
#  22  mac                         5061 non-null   bool
#  23  linux                       5061 non-null   bool
#  24  metacritic_score            5061 non-null   int64
#  25  metacritic_url              2736 non-null   object
#  26  user_score                  5061 non-null   int64
#  27  positive                    5061 non-null   int64
#  28  negative                    5061 non-null   int64
#  29  score_rank                  1 non-null      float64
#  30  rating                      2768 non-null   float64
#  31  achievements                5061 non-null   int64
#  32  recommendations             5061 non-null   int64
#  33  notes                       591 non-null    object
#  34  average_playtime_forever    5061 non-null   int64
#  35  average_playtime_two_weeks  5061 non-null   int64
#  36  median_playtime_forever     5061 non-null   int64
#  37  median_playtime_two_weeks   5061 non-null   int64
#  38  developers                  5061 non-null   object
#  39  publishers                  5037 non-null   object
#  40  categories                  5059 non-null   object
#  41  genres                      5057 non-null   object
#  42  tags                        5018 non-null   object
#  43  screenshots                 5061 non-null   object
#  44  movies                      4500 non-null   object
#  45  plays                       3024 non-null   object
#  46  playing                     3024 non-null   object
#  47  backlogs                    3024 non-null   object
#  48  wishlist                    3024 non-null   object
#  49  lists                       3024 non-null   object
#  50  steam_page                  4583 non-null   object
#  51  platforms                   3024 non-null   object
#  52  platforms_2                 3384 non-null   object
#  53  infos_per_platform          3384 non-null   object
#  54  revenue_estimated           4583 non-null   object
#  55  meta_critic_score           5061 non-null   float64
#  56  new_positive                4583 non-null   float64
#  57  new_negative                4583 non-null   float64
#  58  new_min_estimated_owners    5061 non-null   float64
#  59  new_max_estimated_owners    5061 non-null   float64
#  60  new_average_forever         4583 non-null   float64
#  61  new_median_forever          4583 non-null   float64
#  62  new_price                   4583 non-null   float64
#  63  new_initialprice            4583 non-null   float64
#  64  new_discount                4583 non-null   float64
#  65  new_ccu                     4583 non-null   float64
#  66  new_languages               4583 non-null   object
#  67  new_genre                   4575 non-null   object
#  68  new_tags                    4583 non-null   object
# dtypes: bool(3), datetime64[ns](1), float64(15), int64(14), object(36)
# memory usage: 2.6+ MB

# %%
df['launch_price'] = df['launch_price'].str.replace('\xa0', '', regex=True).str.replace('$' , '').str.replace(',' , '.').values.astype(float)

# %%
(df['price'] == 0).value_counts()
# Out:
# price
# False    4814
# True      247
# Name: count, dtype: int64

# %%
df['new_price'] = df['new_price']/100
df['new_initialprice'] = df['new_initialprice']/100

# %%
((df['price'] != 0) & (df['new_price'].isna())).value_counts()
# Out:
# False    4708
# True      353
# Name: count, dtype: int64

# %%
for i, row in df.iterrows():
    if (row['price'] != 0) & (pd.isna(row['new_price'])):
        df.at[i, 'new_price'] = row['price']

# %%
(df['new_price'].isna()).value_counts()
# Out:
# new_price
# False    4936
# True      125
# Name: count, dtype: int64

# %%
((df['price'] == 0) & (df['new_price'].isna())).value_counts()
# Out:
# False    4936
# True      125
# Name: count, dtype: int64

# %% [markdown]
# Now the `price` feature is useless:

# %%
df.drop(columns='price', inplace=True)

# %%
(df['new_initialprice'].isna()).value_counts()
# Out:
# new_initialprice
# False    4583
# True      478
# Name: count, dtype: int64

# %%
(df['launch_price'].isna()).value_counts()
# Out:
# launch_price
# False    4583
# True      478
# Name: count, dtype: int64

# %%
((df['launch_price'].notna()) & (df['new_initialprice'].isna())).value_counts()
# Out:
# False    5061
# Name: count, dtype: int64

# %%
(df['launch_price'] - df['new_initialprice'] > 0).value_counts()
# Out:
# False    3898
# True     1163
# Name: count, dtype: int64

# %%
df[['name', 'launch_price', 'new_initialprice']]
# Out:
#                              name  launch_price  new_initialprice
# 0                          WARSAW         23.99              0.00
# 1          Alien Breed 3: Descent          9.99              9.99
# 2             Deadfall Adventures         19.99             19.99
# 3                      Far Cry® 5         59.99             59.99
# 4                 Forza Horizon 4         59.99              0.00
# ...                           ...           ...               ...
# 5056                   Deathbound           NaN               NaN
# 5057             F1® Manager 2024           NaN               NaN
# 5058          SteamWorld Heist II           NaN               NaN
# 5059                Cat Quest III           NaN               NaN
# 5060  Thank Goodness You're Here!           NaN               NaN
#
# [5061 rows x 3 columns]

# %%
for i, row in df.iterrows():
    if (row['launch_price'] != 0) & (pd.notna(row['launch_price'])) & (row['new_initialprice'] == 0.):
        df.at[i, 'new_initialprice'] = row['launch_price']

# %%
df[['name', 'launch_price', 'new_initialprice']].iloc[0:10]
# Out:
#                               name  launch_price  new_initialprice
# 0                           WARSAW         23.99             23.99
# 1           Alien Breed 3: Descent          9.99              9.99
# 2              Deadfall Adventures         19.99             19.99
# 3                       Far Cry® 5         59.99             59.99
# 4                  Forza Horizon 4         59.99             59.99
# 5                        Max Payne          9.99              9.99
# 6  Aurion: Legacy of the Kori-Odan         14.99              4.99
# 7              Oxygen Not Included         24.99             24.99
# 8                Puyo Puyo™Tetris®         19.99             19.99
# 9               DYNASTY WARRIORS 9         59.99             44.99

# %% [markdown]
# The column `launch_price` is useless and can be dropped

# %%
df.drop(columns='launch_price', inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5061 entries, 0 to 5060
# Data columns (total 67 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   appid                       5061 non-null   int64
#  1   normalized_name             5061 non-null   object
#  2   name                        5061 non-null   object
#  3   release_date                5061 non-null   datetime64[ns]
#  4   peak_ccu                    5061 non-null   int64
#  5   required_age                5061 non-null   int64
#  6   dlc_count                   5061 non-null   int64
#  7   about_the_game              5045 non-null   object
#  8   summary                     3021 non-null   object
#  9   supported_languages         5061 non-null   object
#  10  full_audio_languages        5061 non-null   object
#  11  some_reviews                2248 non-null   object
#  12  number_of_reviews           3024 non-null   object
#  13  reviews_total               4583 non-null   float64
#  14  reviews_score_fancy         4583 non-null   object
#  15  header_image                5061 non-null   object
#  16  website                     4201 non-null   object
#  17  support_url                 3707 non-null   object
#  18  support_email               3196 non-null   object
#  19  windows                     5061 non-null   bool
#  20  mac                         5061 non-null   bool
#  21  linux                       5061 non-null   bool
#  22  metacritic_score            5061 non-null   int64
#  23  metacritic_url              2736 non-null   object
#  24  user_score                  5061 non-null   int64
#  25  positive                    5061 non-null   int64
#  26  negative                    5061 non-null   int64
#  27  score_rank                  1 non-null      float64
#  28  rating                      2768 non-null   float64
#  29  achievements                5061 non-null   int64
#  30  recommendations             5061 non-null   int64
#  31  notes                       591 non-null    object
#  32  average_playtime_forever    5061 non-null   int64
#  33  average_playtime_two_weeks  5061 non-null   int64
#  34  median_playtime_forever     5061 non-null   int64
#  35  median_playtime_two_weeks   5061 non-null   int64
#  36  developers                  5061 non-null   object
#  37  publishers                  5037 non-null   object
#  38  categories                  5059 non-null   object
#  39  genres                      5057 non-null   object
#  40  tags                        5018 non-null   object
#  41  screenshots                 5061 non-null   object
#  42  movies                      4500 non-null   object
#  43  plays                       3024 non-null   object
#  44  playing                     3024 non-null   object
#  45  backlogs                    3024 non-null   object
#  46  wishlist                    3024 non-null   object
#  47  lists                       3024 non-null   object
#  48  steam_page                  4583 non-null   object
#  49  platforms                   3024 non-null   object
#  50  platforms_2                 3384 non-null   object
#  51  infos_per_platform          3384 non-null   object
#  52  revenue_estimated           4583 non-null   object
#  53  meta_critic_score           5061 non-null   float64
#  54  new_positive                4583 non-null   float64
#  55  new_negative                4583 non-null   float64
#  56  new_min_estimated_owners    5061 non-null   float64
#  57  new_max_estimated_owners    5061 non-null   float64
#  58  new_average_forever         4583 non-null   float64
#  59  new_median_forever          4583 non-null   float64
#  60  new_price                   4936 non-null   float64
#  61  new_initialprice            4583 non-null   float64
#  62  new_discount                4583 non-null   float64
#  63  new_ccu                     4583 non-null   float64
#  64  new_languages               4583 non-null   object
#  65  new_genre                   4575 non-null   object
#  66  new_tags                    4583 non-null   object
# dtypes: bool(3), datetime64[ns](1), float64(14), int64(14), object(35)
# memory usage: 2.5+ MB

# %%
df.head()
# Out:
#      appid     normalized_name                    name release_date  peak_ccu  \
# 0  1026420              warsaw                  WARSAW   2019-10-01         5
# 1    22670  alienbreed3descent  Alien Breed 3: Descent   2010-11-01         3
# 2   231330  deadfalladventures     Deadfall Adventures   2013-11-01         4
# 3   552520             farcry5              Far Cry® 5   2018-03-01      2164
# 4  1293830       forzahorizon4         Forza Horizon 4   2021-03-01      7571
#
#    required_age  dlc_count                                     about_the_game  \
# 0             0          0  Use everything at your disposal to help a team...
# 1             0          0  Alien Breed™ 3: Descent is the final explosive...
# 2             0          0  Deadfall Adventures is an action-driven first-...
# 3            17          5  Far Cry comes to America in the latest install...
# 4             0         15  Dynamic seasons change everything at the world...
#
#                                              summary  \
# 0                                                NaN
# 1  Alien Breed 3: Descent is the final explosive ...
# 2                                                NaN
# 3  Welcome to Hope County, Montana, land of the f...
# 4  Dynamic seasons change everything at the world...
#
#                                  supported_languages  ...  \
# 0  ['English', 'French', 'German', 'Polish', 'Rus...  ...
# 1  ['English', 'French', 'German', 'Italian', 'Ja...  ...
# 2  ['English', 'German', 'Polish', 'French', 'Rus...  ...
# 3  ['English', 'French', 'Italian', 'German', 'Sp...  ...
# 4  ['English', 'French', 'Italian', 'German', 'Sp...  ...
#
#   new_max_estimated_owners new_average_forever new_median_forever  new_price  \
# 0                  50000.0               572.0              496.0       0.00
# 1                 500000.0               161.0              223.0       9.99
# 2                 500000.0               671.0              821.0      19.99
# 3                5000000.0              1700.0             1341.0      59.99
# 4               10000000.0              2487.0              770.0       0.00
#
#   new_initialprice new_discount new_ccu  \
# 0            23.99          0.0     3.0
# 1             9.99          0.0     1.0
# 2            19.99          0.0     4.0
# 3            59.99          0.0  4336.0
# 4            59.99          0.0  6019.0
#
#                                        new_languages  \
# 0           English, French, German, Polish, Russian
# 1  English, French, German, Italian, Japanese, Sp...
# 2           English, German, Polish, French, Russian
# 3  English, French, Italian, German, Spanish - Sp...
# 4  English, French, Italian, German, Spanish - Sp...
#
#                   new_genre                                           new_tags
# 0  Indie, RPG, Free To Play  {'Tactical RPG': 255, 'Wargame': 251, 'Turn-Ba...
# 1                    Action  {'Action': 111, 'Shooter': 93, 'Isometric': 89...
# 2         Action, Adventure  {'Adventure': 143, 'Action': 127, 'FPS': 104, ...
# 3         Action, Adventure  {'Open World': 1711, 'Action-Adventure': 1707,...
# 4                    Racing  {'Racing': 790, 'Open World': 669, 'Driving': ...
#
# [5 rows x 67 columns]

# %%
df['peak_ccu']
# Out:
# 0          5
# 1          3
# 2          4
# 3       2164
# 4       7571
#         ...
# 5056       0
# 5057    4578
# 5058     707
# 5059     180
# 5060     216
# Name: peak_ccu, Length: 5061, dtype: int64

# %%
df['new_ccu']
# Out:
# 0          3.0
# 1          1.0
# 2          4.0
# 3       4336.0
# 4       6019.0
#          ...
# 5056       NaN
# 5057       NaN
# 5058       NaN
# 5059       NaN
# 5060       NaN
# Name: new_ccu, Length: 5061, dtype: float64

# %%
max(0, np.nan)
# Out:
# 0

# %%
df['new_ccu'].isna().value_counts()
# Out:
# new_ccu
# False    4583
# True      478
# Name: count, dtype: int64

# %%
(df['new_ccu'] == 0).value_counts()
# Out:
# new_ccu
# False    3966
# True     1095
# Name: count, dtype: int64

# %%
(df['peak_ccu'] == 0).value_counts()
# Out:
# peak_ccu
# False    4100
# True      961
# Name: count, dtype: int64

# %%
((df['peak_ccu'] == 0) & (df['new_ccu'].isna())).value_counts()
# Out:
# False    4963
# True       98
# Name: count, dtype: int64

# %%
((df['peak_ccu'] != 0) & (df['new_ccu'].isna())).value_counts()
# Out:
# False    4681
# True      380
# Name: count, dtype: int64

# %%
df['peak_ccu'] = df[['peak_ccu', 'new_ccu']].max(axis=1)

# %% [markdown]
# Now the `new_ccu` is useless and can be dropped

# %%
df.drop(columns='new_ccu', inplace = True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5061 entries, 0 to 5060
# Data columns (total 66 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   appid                       5061 non-null   int64
#  1   normalized_name             5061 non-null   object
#  2   name                        5061 non-null   object
#  3   release_date                5061 non-null   datetime64[ns]
#  4   peak_ccu                    5061 non-null   float64
#  5   required_age                5061 non-null   int64
#  6   dlc_count                   5061 non-null   int64
#  7   about_the_game              5045 non-null   object
#  8   summary                     3021 non-null   object
#  9   supported_languages         5061 non-null   object
#  10  full_audio_languages        5061 non-null   object
#  11  some_reviews                2248 non-null   object
#  12  number_of_reviews           3024 non-null   object
#  13  reviews_total               4583 non-null   float64
#  14  reviews_score_fancy         4583 non-null   object
#  15  header_image                5061 non-null   object
#  16  website                     4201 non-null   object
#  17  support_url                 3707 non-null   object
#  18  support_email               3196 non-null   object
#  19  windows                     5061 non-null   bool
#  20  mac                         5061 non-null   bool
#  21  linux                       5061 non-null   bool
#  22  metacritic_score            5061 non-null   int64
#  23  metacritic_url              2736 non-null   object
#  24  user_score                  5061 non-null   int64
#  25  positive                    5061 non-null   int64
#  26  negative                    5061 non-null   int64
#  27  score_rank                  1 non-null      float64
#  28  rating                      2768 non-null   float64
#  29  achievements                5061 non-null   int64
#  30  recommendations             5061 non-null   int64
#  31  notes                       591 non-null    object
#  32  average_playtime_forever    5061 non-null   int64
#  33  average_playtime_two_weeks  5061 non-null   int64
#  34  median_playtime_forever     5061 non-null   int64
#  35  median_playtime_two_weeks   5061 non-null   int64
#  36  developers                  5061 non-null   object
#  37  publishers                  5037 non-null   object
#  38  categories                  5059 non-null   object
#  39  genres                      5057 non-null   object
#  40  tags                        5018 non-null   object
#  41  screenshots                 5061 non-null   object
#  42  movies                      4500 non-null   object
#  43  plays                       3024 non-null   object
#  44  playing                     3024 non-null   object
#  45  backlogs                    3024 non-null   object
#  46  wishlist                    3024 non-null   object
#  47  lists                       3024 non-null   object
#  48  steam_page                  4583 non-null   object
#  49  platforms                   3024 non-null   object
#  50  platforms_2                 3384 non-null   object
#  51  infos_per_platform          3384 non-null   object
#  52  revenue_estimated           4583 non-null   object
#  53  meta_critic_score           5061 non-null   float64
#  54  new_positive                4583 non-null   float64
#  55  new_negative                4583 non-null   float64
#  56  new_min_estimated_owners    5061 non-null   float64
#  57  new_max_estimated_owners    5061 non-null   float64
#  58  new_average_forever         4583 non-null   float64
#  59  new_median_forever          4583 non-null   float64
#  60  new_price                   4936 non-null   float64
#  61  new_initialprice            4583 non-null   float64
#  62  new_discount                4583 non-null   float64
#  63  new_languages               4583 non-null   object
#  64  new_genre                   4575 non-null   object
#  65  new_tags                    4583 non-null   object
# dtypes: bool(3), datetime64[ns](1), float64(14), int64(13), object(35)
# memory usage: 2.4+ MB

# %%
df['supported_languages'] = df['supported_languages'].str.replace('[', '').str.replace(']', '').str.replace("'", '').str.split(', ')

# %%
df['full_audio_languages'] = df['full_audio_languages'].str.replace('[', '').str.replace(']', '').str.replace("'", '').str.split(', ')

# %%
df['new_languages'] = df['new_languages'].str.split(', ')

# %%
df['supported_languages']
# Out:
# 0              [English, French, German, Polish, Russian]
# 1       [English, French, German, Italian, Japanese, S...
# 2              [English, German, Polish, French, Russian]
# 3       [English, French, Italian, German, Spanish - S...
# 4       [English, French, Italian, German, Spanish - S...
#                               ...
# 5056    [English, Portuguese - Brazil, French, Italian...
# 5057    [English, French, Italian, German, Spanish - S...
# 5058    [English, French, Italian, German, Spanish - S...
# 5059    [English, French, Italian, German, Spanish - S...
# 5060    [English, French, German, Spanish - Spain, Jap...
# Name: supported_languages, Length: 5061, dtype: object

# %%
df['supported_languages'].isna().value_counts()
# Out:
# supported_languages
# False    5061
# Name: count, dtype: int64

# %%
def clean_language_string(text):
    # Decode HTML entities twice
    text = html.unescape(html.unescape(text.strip()))

    # Remove malformed HTML tags
    text = re.sub(r'<.*?>', '', text)

    # Fix broken tag fragments like b/b, B/B, etc., even with spacing
    text = re.sub(r'[bB]\s*/\s*[bB]', '', text)

    # Replace escaped line breaks with commas
    text = text.replace('\\r\\n', ',').replace('\\n', ',').replace('\\r', ',')

    # Remove trailing punctuation and whitespace
    text = re.sub(r'[;:.,\s]+$', '', text)

    return text.strip()

def clean_language_list(lang_list):
    cleaned = []
    for item in lang_list:
        cleaned_str = clean_language_string(item)
        split_parts = [p.strip() for p in cleaned_str.split(',') if p.strip()]
        cleaned.extend(split_parts)
    return list(dict.fromkeys(cleaned))  # Removes duplicates while preserving order

# %%
df['supported_languages'] = df['supported_languages'].apply(clean_language_list)

# %%
for i, row in df.iterrows():
    if len(row['supported_languages']) == 0:
        print(row['supported_languages'])

# %%
df['full_audio_languages'].isna().value_counts()
# Out:
# full_audio_languages
# False    5061
# Name: count, dtype: int64

# %%
df['full_audio_languages'] = df['full_audio_languages'].apply(clean_language_list)

# %%
for i, row in df.iterrows():
    if len(row['full_audio_languages']) == 0:
        print(row['full_audio_languages'])
# Out:
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []

# %%
df['new_languages'].isna().value_counts()
# Out:
# new_languages
# False    4583
# True      478
# Name: count, dtype: int64

# %% [markdown]
# Since the are no missing values in both the `supported_languages` and the `full_audio_languages` features we can take them as they are and drop the `new_languages` column

# %%
df.drop(columns='new_languages', inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5061 entries, 0 to 5060
# Data columns (total 65 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   appid                       5061 non-null   int64
#  1   normalized_name             5061 non-null   object
#  2   name                        5061 non-null   object
#  3   release_date                5061 non-null   datetime64[ns]
#  4   peak_ccu                    5061 non-null   float64
#  5   required_age                5061 non-null   int64
#  6   dlc_count                   5061 non-null   int64
#  7   about_the_game              5045 non-null   object
#  8   summary                     3021 non-null   object
#  9   supported_languages         5061 non-null   object
#  10  full_audio_languages        5061 non-null   object
#  11  some_reviews                2248 non-null   object
#  12  number_of_reviews           3024 non-null   object
#  13  reviews_total               4583 non-null   float64
#  14  reviews_score_fancy         4583 non-null   object
#  15  header_image                5061 non-null   object
#  16  website                     4201 non-null   object
#  17  support_url                 3707 non-null   object
#  18  support_email               3196 non-null   object
#  19  windows                     5061 non-null   bool
#  20  mac                         5061 non-null   bool
#  21  linux                       5061 non-null   bool
#  22  metacritic_score            5061 non-null   int64
#  23  metacritic_url              2736 non-null   object
#  24  user_score                  5061 non-null   int64
#  25  positive                    5061 non-null   int64
#  26  negative                    5061 non-null   int64
#  27  score_rank                  1 non-null      float64
#  28  rating                      2768 non-null   float64
#  29  achievements                5061 non-null   int64
#  30  recommendations             5061 non-null   int64
#  31  notes                       591 non-null    object
#  32  average_playtime_forever    5061 non-null   int64
#  33  average_playtime_two_weeks  5061 non-null   int64
#  34  median_playtime_forever     5061 non-null   int64
#  35  median_playtime_two_weeks   5061 non-null   int64
#  36  developers                  5061 non-null   object
#  37  publishers                  5037 non-null   object
#  38  categories                  5059 non-null   object
#  39  genres                      5057 non-null   object
#  40  tags                        5018 non-null   object
#  41  screenshots                 5061 non-null   object
#  42  movies                      4500 non-null   object
#  43  plays                       3024 non-null   object
#  44  playing                     3024 non-null   object
#  45  backlogs                    3024 non-null   object
#  46  wishlist                    3024 non-null   object
#  47  lists                       3024 non-null   object
#  48  steam_page                  4583 non-null   object
#  49  platforms                   3024 non-null   object
#  50  platforms_2                 3384 non-null   object
#  51  infos_per_platform          3384 non-null   object
#  52  revenue_estimated           4583 non-null   object
#  53  meta_critic_score           5061 non-null   float64
#  54  new_positive                4583 non-null   float64
#  55  new_negative                4583 non-null   float64
#  56  new_min_estimated_owners    5061 non-null   float64
#  57  new_max_estimated_owners    5061 non-null   float64
#  58  new_average_forever         4583 non-null   float64
#  59  new_median_forever          4583 non-null   float64
#  60  new_price                   4936 non-null   float64
#  61  new_initialprice            4583 non-null   float64
#  62  new_discount                4583 non-null   float64
#  63  new_genre                   4575 non-null   object
#  64  new_tags                    4583 non-null   object
# dtypes: bool(3), datetime64[ns](1), float64(14), int64(13), object(34)
# memory usage: 2.4+ MB

# %% [markdown]
# It's now time to manage `number_of_reviews`, `reviews_total`, `positive`, `negative`, `new_positive`, `new_negative`

# %%
df['number_of_reviews'].isna().value_counts()
# Out:
# number_of_reviews
# False    3024
# True     2037
# Name: count, dtype: int64

# %%
(df['number_of_reviews'] == 0).value_counts()
# Out:
# number_of_reviews
# False    5061
# Name: count, dtype: int64

# %%
df['reviews_total'].isna().value_counts()
# Out:
# reviews_total
# False    4583
# True      478
# Name: count, dtype: int64

# %%
(df['reviews_total'] == 0).value_counts()
# Out:
# reviews_total
# False    5028
# True       33
# Name: count, dtype: int64

# %%
df['positive'].isna().value_counts()
# Out:
# positive
# False    5061
# Name: count, dtype: int64

# %%
(df['positive'] == 0).value_counts()
# Out:
# positive
# False    5014
# True       47
# Name: count, dtype: int64

# %%
df['negative'].isna().value_counts()
# Out:
# negative
# False    5061
# Name: count, dtype: int64

# %%
(df['negative'] == 0).value_counts()
# Out:
# negative
# False    4963
# True       98
# Name: count, dtype: int64

# %%
df['new_positive'].isna().value_counts()
# Out:
# new_positive
# False    4583
# True      478
# Name: count, dtype: int64

# %%
(df['new_positive'] == 0).value_counts()
# Out:
# new_positive
# False    5058
# True        3
# Name: count, dtype: int64

# %%
df['new_negative'].isna().value_counts()
# Out:
# new_negative
# False    4583
# True      478
# Name: count, dtype: int64

# %%
(df['new_negative'] == 0).value_counts()
# Out:
# new_negative
# False    5047
# True       14
# Name: count, dtype: int64

# %%
((df['new_positive'].isna()) & (df['new_negative'].isna())).value_counts()
# Out:
# False    4583
# True      478
# Name: count, dtype: int64

# %%
((df['new_positive'].isna()) & (df['new_negative'].isna()) & (df['reviews_total'].isna())).value_counts()
# Out:
# False    4583
# True      478
# Name: count, dtype: int64

# %%
df['new_positive'] = df['new_positive'].fillna(df['positive'])

# %%
(df['new_positive'] == 0).value_counts()
# Out:
# new_positive
# False    5027
# True       34
# Name: count, dtype: int64

# %%
df['new_negative'] = df['new_negative'].fillna(df['negative'])

# %%
(df['new_negative'] == 0).value_counts()
# Out:
# new_negative
# False    5003
# True       58
# Name: count, dtype: int64

# %%
((df['new_positive'] == 0) & (df['new_negative'] == 0)).value_counts()
# Out:
# False    5028
# True       33
# Name: count, dtype: int64

# %%
df[(df['new_positive'] == 0) & (df['new_negative'] == 0)][['name', 'meta_critic_score']]
# Out:
#                                                    name  meta_critic_score
# 45                          Wasteland 2: Director's Cut               80.0
# 205                                            F.E.A.R.               88.0
# 762                                            ElecHead               84.0
# 1338                              Guild Wars Nightfall®               84.0
# 1647                                              SCARF               69.0
# 2465                                            RACE On               73.0
# 2637                                   Best Month Ever!               65.0
# 2876  Beijing 2008™ - The Official Video Game of the...               60.0
# 3213                               Guild Wars Factions®               84.0
# 3566                                   Lust from Beyond               61.0
# 4635                                              Venba               79.0
# 4764                                   EA SPORTS FC™ 24               75.0
# 4786                                           Observer               78.0
# 4795                                  Gangs of Sherwood               55.0
# 4879                               Rails Across America               81.0
# 4888                                      Go Mecha Ball               70.0
# 4899                                             Ultros               81.0
# 4900                              DRAGON QUEST BUILDERS               83.0
# 4913                                          Promenade               80.0
# 4967                               TriggerHeart EXELICA               63.0
# 4969                                 Rusty's Retirement               81.0
# 4972                            Another Crab's Treasure               78.0
# 4982                                         MADiSON VR               76.0
# 4989                                        Cryptmaster               77.0
# 5008                                        Pine Hearts               83.0
# 5019       KINGDOM HEARTS HD 2.8 Final Chapter Prologue               76.0
# 5020                    Shin Megami Tensei V: Vengeance               87.0
# 5021                             Monster Hunter Stories               76.0
# 5026                                          Dystopika               79.0
# 5028                                        Tavern Talk               80.0
# 5036                Arranger: A Role-Puzzling Adventure               80.0
# 5047                                Closer the Distance               86.0
# 5048                        Thalassa: Edge of the Abyss               76.0

# %% [markdown]
# This $0$ values needs to be filled

# %% [markdown]
# In any case the `positive` and `negative` columns can be dropped.

# %%
df.drop(columns=['positive', 'negative'], inplace=True)

# %%
df['number_of_reviews']
# Out:
# 0       NaN
# 1         0
# 2       NaN
# 3       402
# 4       223
#        ...
# 5056      0
# 5057    NaN
# 5058    NaN
# 5059    NaN
# 5060    NaN
# Name: number_of_reviews, Length: 5061, dtype: object

# %%
df['number_of_reviews'].isna().value_counts()
# Out:
# number_of_reviews
# False    3024
# True     2037
# Name: count, dtype: int64

# %%
def dealing_with_Ks(val):
    if isinstance(val, str):
        val = val.replace(',', '')
        if 'K' in val:
            return float(val.replace('K', '')) * 1000
        return float(val)
    return val  # Keep as-is if not a string

# %%
df['number_of_reviews'] = df['number_of_reviews'].apply(dealing_with_Ks)

# %%
df['number_of_reviews']
# Out:
# 0         NaN
# 1         0.0
# 2         NaN
# 3       402.0
# 4       223.0
#         ...
# 5056      0.0
# 5057      NaN
# 5058      NaN
# 5059      NaN
# 5060      NaN
# Name: number_of_reviews, Length: 5061, dtype: float64

# %%
df['reviews_total'].isna().value_counts()
# Out:
# reviews_total
# False    4583
# True      478
# Name: count, dtype: int64

# %%
df['reviews_total'] = df['reviews_total'].values.astype(float)

# %%
((df['reviews_total'].isna()) & (df['number_of_reviews'].isna())).value_counts()
# Out:
# False    4804
# True      257
# Name: count, dtype: int64

# %%
((df['reviews_total'].isna()) & (df['number_of_reviews'].notna()) & (df['number_of_reviews'] != 0)).value_counts()
# Out:
# False    4928
# True      133
# Name: count, dtype: int64

# %%
((df['reviews_total'].isna()) & (df['number_of_reviews'].notna()) & (df['number_of_reviews'] == 0)).value_counts()
# Out:
# False    4973
# True       88
# Name: count, dtype: int64

# %%
((df['reviews_total'] == 0) & (df['number_of_reviews'].notna()) & (df['number_of_reviews'] != 0)).value_counts()
# Out:
# False    5056
# True        5
# Name: count, dtype: int64

# %%
df['reviews_total'] = df['reviews_total'].fillna(df['number_of_reviews'])

# %%
for i, row in df.iterrows():
    if (row['reviews_total'] == 0) & (pd.notna(row['number_of_reviews'])) & (row['number_of_reviews'] != 0):
        df.at[i, 'reviews_total'] = row['number_of_reviews']

# %%
df['reviews_total'].isna().value_counts()
# Out:
# reviews_total
# False    4804
# True      257
# Name: count, dtype: int64

# %% [markdown]
# Let's drop the number of reviews column

# %%
df.drop(columns='number_of_reviews', inplace=True)

# %% [markdown]
# Now in the `reviews_total` column there are both $0$ and NaN. We have to deal with that.

# %%
((df['reviews_total'].isna()) & ((df['new_positive'] + df['new_negative']) != 0)).value_counts()
# Out:
# False    4825
# True      236
# Name: count, dtype: int64

# %%
((df['reviews_total'] == 0) & ((df['new_positive'] + df['new_negative']) != 0)).value_counts()
# Out:
# False    4948
# True      113
# Name: count, dtype: int64

# %%
((df['reviews_total'].isna()) & ((df['new_positive'] + df['new_negative']) == 0)).value_counts()
# Out:
# False    5040
# True       21
# Name: count, dtype: int64

# %%
((df['reviews_total'] == 0) & ((df['new_positive'] + df['new_negative']) == 0)).value_counts()
# Out:
# False    5058
# True        3
# Name: count, dtype: int64

# %%
df['reviews_total'] = df['reviews_total'].fillna(df['new_positive'] + df['new_negative'])

# %%
for i, row in df.iterrows():
    if (row['reviews_total'] == 0) & ((row['new_positive'] + row['new_negative']) != 0):
        df.at[i, 'reviews_total'] = row['new_positive'] + row['new_negative']

# %%
(df['reviews_total'] < df['new_positive'] + df['new_negative']).value_counts()
# Out:
# True     4661
# False     400
# Name: count, dtype: int64

# %%
for i, row in df.iterrows():
    if row['reviews_total'] < row['new_positive'] + row['new_negative']:
        df.at[i, 'reviews_total'] = row['new_positive'] + row['new_negative']

# %%
df['reviews_total'].isna().value_counts()
# Out:
# reviews_total
# False    5061
# Name: count, dtype: int64

# %%
(df['reviews_total'] == 0).value_counts()
# Out:
# reviews_total
# False    5037
# True       24
# Name: count, dtype: int64

# %%
df['reviews_score_fancy'] = df['reviews_score_fancy'].str.replace('%' , '').str.replace(',' , '.').values.astype(float)

# %%
df['reviews_score_fancy'].isna().value_counts()
# Out:
# reviews_score_fancy
# False    4583
# True      478
# Name: count, dtype: int64

# %%
(df['new_positive'] + df['new_negative']).isna().value_counts()
# Out:
# False    5061
# Name: count, dtype: int64

# %%
(df['new_positive'] + df['new_negative'] == 0).value_counts()
# Out:
# False    5028
# True       33
# Name: count, dtype: int64

# %%
(100*df['new_positive']*1/(df['new_positive'] + df['new_negative'])).isna().value_counts()
# Out:
# False    5028
# True       33
# Name: count, dtype: int64

# %%
((df['reviews_score_fancy'].notna()) & (round(100*df['new_positive']*1/(df['new_positive'] + df['new_negative']))).isna()).value_counts()
# Out:
# False    5058
# True        3
# Name: count, dtype: int64

# %%
round(100*df['new_positive']*1/(df['new_positive'] + df['new_negative']))
# Out:
# 0       65.0
# 1       75.0
# 2       74.0
# 3       81.0
# 4       91.0
#         ...
# 5056    75.0
# 5057    66.0
# 5058    96.0
# 5059    95.0
# 5060    97.0
# Length: 5061, dtype: float64

# %%
df['new_reviews_score_fancy'] = round(100*df['new_positive']*1/(df['new_positive'] + df['new_negative']))

# %%
df['new_reviews_score_fancy'] = df['new_reviews_score_fancy'].fillna('reviews_score_fancy')

# %%
df['reviews_score_fancy'] = df['new_reviews_score_fancy']

# %%
df['reviews_score_fancy']
# Out:
# 0       65.0
# 1       75.0
# 2       74.0
# 3       81.0
# 4       91.0
#         ...
# 5056    75.0
# 5057    66.0
# 5058    96.0
# 5059    95.0
# 5060    97.0
# Name: reviews_score_fancy, Length: 5061, dtype: object

# %% [markdown]
# The column `new_reviews_score_fancy` can now be dropped

# %%
df.drop(columns='new_reviews_score_fancy', inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5061 entries, 0 to 5060
# Data columns (total 62 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   appid                       5061 non-null   int64
#  1   normalized_name             5061 non-null   object
#  2   name                        5061 non-null   object
#  3   release_date                5061 non-null   datetime64[ns]
#  4   peak_ccu                    5061 non-null   float64
#  5   required_age                5061 non-null   int64
#  6   dlc_count                   5061 non-null   int64
#  7   about_the_game              5045 non-null   object
#  8   summary                     3021 non-null   object
#  9   supported_languages         5061 non-null   object
#  10  full_audio_languages        5061 non-null   object
#  11  some_reviews                2248 non-null   object
#  12  reviews_total               5061 non-null   float64
#  13  reviews_score_fancy         5061 non-null   object
#  14  header_image                5061 non-null   object
#  15  website                     4201 non-null   object
#  16  support_url                 3707 non-null   object
#  17  support_email               3196 non-null   object
#  18  windows                     5061 non-null   bool
#  19  mac                         5061 non-null   bool
#  20  linux                       5061 non-null   bool
#  21  metacritic_score            5061 non-null   int64
#  22  metacritic_url              2736 non-null   object
#  23  user_score                  5061 non-null   int64
#  24  score_rank                  1 non-null      float64
#  25  rating                      2768 non-null   float64
#  26  achievements                5061 non-null   int64
#  27  recommendations             5061 non-null   int64
#  28  notes                       591 non-null    object
#  29  average_playtime_forever    5061 non-null   int64
#  30  average_playtime_two_weeks  5061 non-null   int64
#  31  median_playtime_forever     5061 non-null   int64
#  32  median_playtime_two_weeks   5061 non-null   int64
#  33  developers                  5061 non-null   object
#  34  publishers                  5037 non-null   object
#  35  categories                  5059 non-null   object
#  36  genres                      5057 non-null   object
#  37  tags                        5018 non-null   object
#  38  screenshots                 5061 non-null   object
#  39  movies                      4500 non-null   object
#  40  plays                       3024 non-null   object
#  41  playing                     3024 non-null   object
#  42  backlogs                    3024 non-null   object
#  43  wishlist                    3024 non-null   object
#  44  lists                       3024 non-null   object
#  45  steam_page                  4583 non-null   object
#  46  platforms                   3024 non-null   object
#  47  platforms_2                 3384 non-null   object
#  48  infos_per_platform          3384 non-null   object
#  49  revenue_estimated           4583 non-null   object
#  50  meta_critic_score           5061 non-null   float64
#  51  new_positive                5061 non-null   float64
#  52  new_negative                5061 non-null   float64
#  53  new_min_estimated_owners    5061 non-null   float64
#  54  new_max_estimated_owners    5061 non-null   float64
#  55  new_average_forever         4583 non-null   float64
#  56  new_median_forever          4583 non-null   float64
#  57  new_price                   4936 non-null   float64
#  58  new_initialprice            4583 non-null   float64
#  59  new_discount                4583 non-null   float64
#  60  new_genre                   4575 non-null   object
#  61  new_tags                    4583 non-null   object
# dtypes: bool(3), datetime64[ns](1), float64(14), int64(11), object(33)
# memory usage: 2.3+ MB

# %% [markdown]
# The columns `website`, `support_url` and `support_email` are quite useless and can be dropped

# %%
df.drop(columns=['website','support_url', 'support_email'], inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5061 entries, 0 to 5060
# Data columns (total 59 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   appid                       5061 non-null   int64
#  1   normalized_name             5061 non-null   object
#  2   name                        5061 non-null   object
#  3   release_date                5061 non-null   datetime64[ns]
#  4   peak_ccu                    5061 non-null   float64
#  5   required_age                5061 non-null   int64
#  6   dlc_count                   5061 non-null   int64
#  7   about_the_game              5045 non-null   object
#  8   summary                     3021 non-null   object
#  9   supported_languages         5061 non-null   object
#  10  full_audio_languages        5061 non-null   object
#  11  some_reviews                2248 non-null   object
#  12  reviews_total               5061 non-null   float64
#  13  reviews_score_fancy         5061 non-null   object
#  14  header_image                5061 non-null   object
#  15  windows                     5061 non-null   bool
#  16  mac                         5061 non-null   bool
#  17  linux                       5061 non-null   bool
#  18  metacritic_score            5061 non-null   int64
#  19  metacritic_url              2736 non-null   object
#  20  user_score                  5061 non-null   int64
#  21  score_rank                  1 non-null      float64
#  22  rating                      2768 non-null   float64
#  23  achievements                5061 non-null   int64
#  24  recommendations             5061 non-null   int64
#  25  notes                       591 non-null    object
#  26  average_playtime_forever    5061 non-null   int64
#  27  average_playtime_two_weeks  5061 non-null   int64
#  28  median_playtime_forever     5061 non-null   int64
#  29  median_playtime_two_weeks   5061 non-null   int64
#  30  developers                  5061 non-null   object
#  31  publishers                  5037 non-null   object
#  32  categories                  5059 non-null   object
#  33  genres                      5057 non-null   object
#  34  tags                        5018 non-null   object
#  35  screenshots                 5061 non-null   object
#  36  movies                      4500 non-null   object
#  37  plays                       3024 non-null   object
#  38  playing                     3024 non-null   object
#  39  backlogs                    3024 non-null   object
#  40  wishlist                    3024 non-null   object
#  41  lists                       3024 non-null   object
#  42  steam_page                  4583 non-null   object
#  43  platforms                   3024 non-null   object
#  44  platforms_2                 3384 non-null   object
#  45  infos_per_platform          3384 non-null   object
#  46  revenue_estimated           4583 non-null   object
#  47  meta_critic_score           5061 non-null   float64
#  48  new_positive                5061 non-null   float64
#  49  new_negative                5061 non-null   float64
#  50  new_min_estimated_owners    5061 non-null   float64
#  51  new_max_estimated_owners    5061 non-null   float64
#  52  new_average_forever         4583 non-null   float64
#  53  new_median_forever          4583 non-null   float64
#  54  new_price                   4936 non-null   float64
#  55  new_initialprice            4583 non-null   float64
#  56  new_discount                4583 non-null   float64
#  57  new_genre                   4575 non-null   object
#  58  new_tags                    4583 non-null   object
# dtypes: bool(3), datetime64[ns](1), float64(14), int64(11), object(30)
# memory usage: 2.2+ MB

# %%
df['header_image'].values
# Out:
# array(['https://cdn.akamai.steamstatic.com/steam/apps/1026420/header.jpg?t=1657716289',
#        'https://cdn.akamai.steamstatic.com/steam/apps/22670/header.jpg?t=1655730869',
#        'https://cdn.akamai.steamstatic.com/steam/apps/231330/header.jpg?t=1561964976',
#        ...,
#        'https://shared.akamai.steamstatic.com/store_item_assets/steam/apps/2396240/header.jpg?t=1723132341',
#        'https://shared.akamai.steamstatic.com/store_item_assets/steam/apps/2305840/header.jpg?t=1723195692',
#        'https://shared.akamai.steamstatic.com/store_item_assets/steam/apps/2366980/header.jpg?t=1722529446'],
#       dtype=object)

# %%
(df['metacritic_score'] == 0).value_counts()
# Out:
# metacritic_score
# False    2736
# True     2325
# Name: count, dtype: int64

# %% [markdown]
# Since we have added the `meta_critic_score` column the `metacritic_score` one can be dropped

# %%
df.drop(columns='metacritic_score', inplace=True)

# %%
df['metacritic_url']
# Out:
# 0       https://www.metacritic.com/game/pc/warsaw?ftag...
# 1       https://www.metacritic.com/game/pc/alien-breed...
# 2       https://www.metacritic.com/game/pc/deadfall-ad...
# 3                                                     NaN
# 4                                                     NaN
#                               ...
# 5056                                                  NaN
# 5057                                                  NaN
# 5058    https://www.metacritic.com/game/pc/steamworld-...
# 5059    https://www.metacritic.com/game/pc/cat-quest-i...
# 5060    https://www.metacritic.com/game/pc/thank-goodn...
# Name: metacritic_url, Length: 5061, dtype: object

# %%
import re

# Function to normalize game names to the metacritic standard
def metacritic_name(name):
    # Convert to lowercase
    name = name.lower()
    # Remove trademarks (e.g., ™, ®)
    name = re.sub(r'[™®]', '', name)
    # Remove other symbols (e.g., punctuation)
    name = re.sub(r'[^\w\s]', '', name)
    # Replace spaces with '-'
    name = name.replace(' ', '-')
    return name

# %%
metacritic_url_list = []
for i, row in df.iterrows():
    if pd.isna(row['metacritic_url']):
        metacritic_url_list.append('https://www.metacritic.com/game/pc/' + metacritic_name(row['name']) + '?ftag=MCD-06-10aaa1f')
    else:
        metacritic_url_list.append(row['metacritic_url'])

# %%
df['metacritic_url'] = metacritic_url_list

# %%
df['metacritic_url'].values
# Out:
# array(['https://www.metacritic.com/game/pc/warsaw?ftag=MCD-06-10aaa1f',
#        'https://www.metacritic.com/game/pc/alien-breed-3-descent?ftag=MCD-06-10aaa1f',
#        'https://www.metacritic.com/game/pc/deadfall-adventures?ftag=MCD-06-10aaa1f',
#        ...,
#        'https://www.metacritic.com/game/pc/steamworld-heist-ii?ftag=MCD-06-10aaa1f',
#        'https://www.metacritic.com/game/pc/cat-quest-iii?ftag=MCD-06-10aaa1f',
#        'https://www.metacritic.com/game/pc/thank-goodness-youre-here!?ftag=MCD-06-10aaa1f'],
#       dtype=object)

# %%
df['metacritic_url'].isna().value_counts()
# Out:
# metacritic_url
# False    5061
# Name: count, dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5061 entries, 0 to 5060
# Data columns (total 58 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   appid                       5061 non-null   int64
#  1   normalized_name             5061 non-null   object
#  2   name                        5061 non-null   object
#  3   release_date                5061 non-null   datetime64[ns]
#  4   peak_ccu                    5061 non-null   float64
#  5   required_age                5061 non-null   int64
#  6   dlc_count                   5061 non-null   int64
#  7   about_the_game              5045 non-null   object
#  8   summary                     3021 non-null   object
#  9   supported_languages         5061 non-null   object
#  10  full_audio_languages        5061 non-null   object
#  11  some_reviews                2248 non-null   object
#  12  reviews_total               5061 non-null   float64
#  13  reviews_score_fancy         5061 non-null   object
#  14  header_image                5061 non-null   object
#  15  windows                     5061 non-null   bool
#  16  mac                         5061 non-null   bool
#  17  linux                       5061 non-null   bool
#  18  metacritic_url              5061 non-null   object
#  19  user_score                  5061 non-null   int64
#  20  score_rank                  1 non-null      float64
#  21  rating                      2768 non-null   float64
#  22  achievements                5061 non-null   int64
#  23  recommendations             5061 non-null   int64
#  24  notes                       591 non-null    object
#  25  average_playtime_forever    5061 non-null   int64
#  26  average_playtime_two_weeks  5061 non-null   int64
#  27  median_playtime_forever     5061 non-null   int64
#  28  median_playtime_two_weeks   5061 non-null   int64
#  29  developers                  5061 non-null   object
#  30  publishers                  5037 non-null   object
#  31  categories                  5059 non-null   object
#  32  genres                      5057 non-null   object
#  33  tags                        5018 non-null   object
#  34  screenshots                 5061 non-null   object
#  35  movies                      4500 non-null   object
#  36  plays                       3024 non-null   object
#  37  playing                     3024 non-null   object
#  38  backlogs                    3024 non-null   object
#  39  wishlist                    3024 non-null   object
#  40  lists                       3024 non-null   object
#  41  steam_page                  4583 non-null   object
#  42  platforms                   3024 non-null   object
#  43  platforms_2                 3384 non-null   object
#  44  infos_per_platform          3384 non-null   object
#  45  revenue_estimated           4583 non-null   object
#  46  meta_critic_score           5061 non-null   float64
#  47  new_positive                5061 non-null   float64
#  48  new_negative                5061 non-null   float64
#  49  new_min_estimated_owners    5061 non-null   float64
#  50  new_max_estimated_owners    5061 non-null   float64
#  51  new_average_forever         4583 non-null   float64
#  52  new_median_forever          4583 non-null   float64
#  53  new_price                   4936 non-null   float64
#  54  new_initialprice            4583 non-null   float64
#  55  new_discount                4583 non-null   float64
#  56  new_genre                   4575 non-null   object
#  57  new_tags                    4583 non-null   object
# dtypes: bool(3), datetime64[ns](1), float64(14), int64(10), object(30)
# memory usage: 2.1+ MB

# %%
(df['user_score'] == 0).value_counts()
# Out:
# user_score
# True     5060
# False       1
# Name: count, dtype: int64

# %% [markdown]
# The columns `user_score` and `score_rank` can both be dropped since they have only 1 non null value

# %%
df.drop(columns=['user_score', 'score_rank'], inplace=True)

# %%
metacritic_user_score = pd.read_csv('user_score_updated.csv')
df = df.merge(metacritic_user_score, left_on='appid', right_on='appid', how='left')

# %%
df.rename(columns={'user_score': 'metacritic_user_score'}, inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5061 entries, 0 to 5060
# Data columns (total 57 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   appid                       5061 non-null   int64
#  1   normalized_name             5061 non-null   object
#  2   name                        5061 non-null   object
#  3   release_date                5061 non-null   datetime64[ns]
#  4   peak_ccu                    5061 non-null   float64
#  5   required_age                5061 non-null   int64
#  6   dlc_count                   5061 non-null   int64
#  7   about_the_game              5045 non-null   object
#  8   summary                     3021 non-null   object
#  9   supported_languages         5061 non-null   object
#  10  full_audio_languages        5061 non-null   object
#  11  some_reviews                2248 non-null   object
#  12  reviews_total               5061 non-null   float64
#  13  reviews_score_fancy         5061 non-null   object
#  14  header_image                5061 non-null   object
#  15  windows                     5061 non-null   bool
#  16  mac                         5061 non-null   bool
#  17  linux                       5061 non-null   bool
#  18  metacritic_url              5061 non-null   object
#  19  rating                      2768 non-null   float64
#  20  achievements                5061 non-null   int64
#  21  recommendations             5061 non-null   int64
#  22  notes                       591 non-null    object
#  23  average_playtime_forever    5061 non-null   int64
#  24  average_playtime_two_weeks  5061 non-null   int64
#  25  median_playtime_forever     5061 non-null   int64
#  26  median_playtime_two_weeks   5061 non-null   int64
#  27  developers                  5061 non-null   object
#  28  publishers                  5037 non-null   object
#  29  categories                  5059 non-null   object
#  30  genres                      5057 non-null   object
#  31  tags                        5018 non-null   object
#  32  screenshots                 5061 non-null   object
#  33  movies                      4500 non-null   object
#  34  plays                       3024 non-null   object
#  35  playing                     3024 non-null   object
#  36  backlogs                    3024 non-null   object
#  37  wishlist                    3024 non-null   object
#  38  lists                       3024 non-null   object
#  39  steam_page                  4583 non-null   object
#  40  platforms                   3024 non-null   object
#  41  platforms_2                 3384 non-null   object
#  42  infos_per_platform          3384 non-null   object
#  43  revenue_estimated           4583 non-null   object
#  44  meta_critic_score           5061 non-null   float64
#  45  new_positive                5061 non-null   float64
#  46  new_negative                5061 non-null   float64
#  47  new_min_estimated_owners    5061 non-null   float64
#  48  new_max_estimated_owners    5061 non-null   float64
#  49  new_average_forever         4583 non-null   float64
#  50  new_median_forever          4583 non-null   float64
#  51  new_price                   4936 non-null   float64
#  52  new_initialprice            4583 non-null   float64
#  53  new_discount                4583 non-null   float64
#  54  new_genre                   4575 non-null   object
#  55  new_tags                    4583 non-null   object
#  56  metacritic_user_score       5061 non-null   object
# dtypes: bool(3), datetime64[ns](1), float64(13), int64(9), object(31)
# memory usage: 2.1+ MB

# %%
df[(df['meta_critic_score'].notna()) & (df['metacritic_user_score'] == '-1')][['appid', 'name', 'meta_critic_score', 'metacritic_user_score']]
# Out:
#         appid                               name  meta_critic_score  \
# 91     378750            Sayonara Umihara Kawase               76.0
# 786    236450  PAC-MAN™ Championship Edition DX+               93.0
# 970    331750                Disney•Pixar WALL-E               50.0
# 3479   469820                   Genital Jousting               68.0
# 3566  1035120                   Lust from Beyond               61.0
#
#      metacritic_user_score
# 91                      -1
# 786                     -1
# 970                     -1
# 3479                    -1
# 3566                    -1

# %%
df.at[91, 'metacritic_user_score'] = '8.3'

# %%
df.at[786, 'metacritic_user_score'] = '7.6'

# %%
df.at[970, 'metacritic_user_score'] = '6.6'

# %%
df.at[3479, 'metacritic_user_score'] = '5.3'

# %%
df[(df['meta_critic_score'].notna()) & (df['metacritic_user_score'] == 'tbd')][['appid', 'name', 'meta_critic_score', 'metacritic_user_score']]
# Out:
#         appid                            name  meta_critic_score  \
# 25    1495860                  What The Dub?!               78.0
# 27      16130                     Fish Tycoon               46.0
# 34    1095120                  Helheim Hassle               79.0
# 37    1228870         Bartlow's Dread Machine               73.0
# 56    1275660                Sanity of Morris               35.0
# ...       ...                             ...                ...
# 4981  2104880                     Undead Inc.               59.0
# 4984  2739830          King Arthur: Legion IX               72.0
# 4990  1293910  Read Only Memories: NEURODIVER               77.0
# 4997  2719200           SAMURAI WARRIORS 4 DX               82.0
# 5045  1619230              The Star Named EOS               79.0
#
#      metacritic_user_score
# 25                     tbd
# 27                     tbd
# 34                     tbd
# 37                     tbd
# 56                     tbd
# ...                    ...
# 4981                   tbd
# 4984                   tbd
# 4990                   tbd
# 4997                   tbd
# 5045                   tbd
#
# [317 rows x 4 columns]

# %%
for idx, row in df.iterrows():
    if (row['metacritic_user_score'] == '-1') or (row['metacritic_user_score'] == 'tbd'):
        df.at[idx, 'metacritic_user_score'] = np.nan

df['metacritic_user_score'] = df['metacritic_user_score'].astype(float)

# %%
df['metacritic_user_score']
# Out:
# 0       7.1
# 1       6.7
# 2       6.8
# 3       6.9
# 4       8.4
#        ...
# 5056    6.6
# 5057    7.5
# 5058    7.6
# 5059    8.1
# 5060    7.7
# Name: metacritic_user_score, Length: 5061, dtype: float64

# %%
df['rating'].isna().value_counts()
# Out:
# rating
# False    2768
# True     2293
# Name: count, dtype: int64

# %%
(df['rating'] == 0).value_counts()
# Out:
# rating
# False    5061
# Name: count, dtype: int64

# %%
((df['rating'].notna()) & (df['reviews_score_fancy'] == 0)).value_counts()
# Out:
# False    5061
# Name: count, dtype: int64

# %% [markdown]
# The column rating is completely useless and can be dropped

# %%
df.drop(columns='rating', inplace=True)

# %%
df['achievements']
# Out:
# 0        34
# 1        13
# 2        50
# 3         0
# 4       178
#        ...
# 5056     35
# 5057     30
# 5058     34
# 5059     30
# 5060     32
# Name: achievements, Length: 5061, dtype: int64

# %%
(df['achievements'] == 0).value_counts()
# Out:
# achievements
# False    4182
# True      879
# Name: count, dtype: int64

# %%
df['recommendations']
# Out:
# 0          427
# 1          285
# 2         1140
# 3       114588
# 4       126316
#          ...
# 5056         0
# 5057      1205
# 5058       469
# 5059      1294
# 5060      2222
# Name: recommendations, Length: 5061, dtype: int64

# %%
(df['recommendations'] == 0).value_counts()
# Out:
# recommendations
# False    4129
# True      932
# Name: count, dtype: int64

# %%
df[df['notes'].notna()]['notes']
# Out:
# 15      This game contains content that might not be s...
# 19      This product features frequent violence and ba...
# 35      Phoenix Point contains depictions of science-f...
# 36      This Game may contain content not appropriate ...
# 56      Sanity of Morris is a horror adventure game. S...
#                               ...
# 5048    The game talks about death and loss, while not...
# 5049    The game contains some video depicting murders...
# 5050                     Volgarr kills evil in all forms!
# 5055    Light sexual themes and occasional references ...
# 5056                          Excessive Blood Dead Bodies
# Name: notes, Length: 591, dtype: object

# %% [markdown]
# `average_playtime_two_weeks`, `median_playtime_two_weeks` are not relevant and can be dropped

# %%
df.drop(columns=['average_playtime_two_weeks', 'median_playtime_two_weeks'], inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5061 entries, 0 to 5060
# Data columns (total 54 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   appid                     5061 non-null   int64
#  1   normalized_name           5061 non-null   object
#  2   name                      5061 non-null   object
#  3   release_date              5061 non-null   datetime64[ns]
#  4   peak_ccu                  5061 non-null   float64
#  5   required_age              5061 non-null   int64
#  6   dlc_count                 5061 non-null   int64
#  7   about_the_game            5045 non-null   object
#  8   summary                   3021 non-null   object
#  9   supported_languages       5061 non-null   object
#  10  full_audio_languages      5061 non-null   object
#  11  some_reviews              2248 non-null   object
#  12  reviews_total             5061 non-null   float64
#  13  reviews_score_fancy       5061 non-null   object
#  14  header_image              5061 non-null   object
#  15  windows                   5061 non-null   bool
#  16  mac                       5061 non-null   bool
#  17  linux                     5061 non-null   bool
#  18  metacritic_url            5061 non-null   object
#  19  achievements              5061 non-null   int64
#  20  recommendations           5061 non-null   int64
#  21  notes                     591 non-null    object
#  22  average_playtime_forever  5061 non-null   int64
#  23  median_playtime_forever   5061 non-null   int64
#  24  developers                5061 non-null   object
#  25  publishers                5037 non-null   object
#  26  categories                5059 non-null   object
#  27  genres                    5057 non-null   object
#  28  tags                      5018 non-null   object
#  29  screenshots               5061 non-null   object
#  30  movies                    4500 non-null   object
#  31  plays                     3024 non-null   object
#  32  playing                   3024 non-null   object
#  33  backlogs                  3024 non-null   object
#  34  wishlist                  3024 non-null   object
#  35  lists                     3024 non-null   object
#  36  steam_page                4583 non-null   object
#  37  platforms                 3024 non-null   object
#  38  platforms_2               3384 non-null   object
#  39  infos_per_platform        3384 non-null   object
#  40  revenue_estimated         4583 non-null   object
#  41  meta_critic_score         5061 non-null   float64
#  42  new_positive              5061 non-null   float64
#  43  new_negative              5061 non-null   float64
#  44  new_min_estimated_owners  5061 non-null   float64
#  45  new_max_estimated_owners  5061 non-null   float64
#  46  new_average_forever       4583 non-null   float64
#  47  new_median_forever        4583 non-null   float64
#  48  new_price                 4936 non-null   float64
#  49  new_initialprice          4583 non-null   float64
#  50  new_discount              4583 non-null   float64
#  51  new_genre                 4575 non-null   object
#  52  new_tags                  4583 non-null   object
#  53  metacritic_user_score     4743 non-null   float64
# dtypes: bool(3), datetime64[ns](1), float64(13), int64(7), object(30)
# memory usage: 2.0+ MB

# %%
(df['average_playtime_forever'] == 0).value_counts()
# Out:
# average_playtime_forever
# False    3710
# True     1351
# Name: count, dtype: int64

# %%
df['new_average_forever'].isna().value_counts()
# Out:
# new_average_forever
# False    4583
# True      478
# Name: count, dtype: int64

# %%
(df['new_average_forever'] == 0).value_counts()
# Out:
# new_average_forever
# False    4072
# True      989
# Name: count, dtype: int64

# %%
df[['average_playtime_forever', 'new_average_forever']]
# Out:
#       average_playtime_forever  new_average_forever
# 0                           67                572.0
# 1                           44                161.0
# 2                          324                671.0
# 3                         1756               1700.0
# 4                         2518               2487.0
# ...                        ...                  ...
# 5056                         0                  NaN
# 5057                         0                  NaN
# 5058                        50                  NaN
# 5059                         0                  NaN
# 5060                       265                  NaN
#
# [5061 rows x 2 columns]

# %%
((df['average_playtime_forever'] != 0) & (df['new_average_forever'].isna())).value_counts()
# Out:
# False    4868
# True      193
# Name: count, dtype: int64

# %%
((df['average_playtime_forever'] != 0) & (df['new_average_forever'] == 0)).value_counts()
# Out:
# False    4728
# True      333
# Name: count, dtype: int64

# %%
df['new_average_forever'] = df['new_average_forever'].fillna(df['average_playtime_forever'])

# %%
((df['average_playtime_forever'] != 0) & (df['new_average_forever'] == 0)).value_counts()
# Out:
# False    4728
# True      333
# Name: count, dtype: int64

# %%
for i, row in df.iterrows():
    if (row['average_playtime_forever'] != 0) & (row['new_average_forever'] == 0):
        df.at[i, 'new_average_forever'] = row['average_playtime_forever']

# %%
(df['new_average_forever'] == 0).value_counts()
# Out:
# new_average_forever
# False    4120
# True      941
# Name: count, dtype: int64

# %%
df[['average_playtime_forever', 'new_average_forever']]
# Out:
#       average_playtime_forever  new_average_forever
# 0                           67                572.0
# 1                           44                161.0
# 2                          324                671.0
# 3                         1756               1700.0
# 4                         2518               2487.0
# ...                        ...                  ...
# 5056                         0                  0.0
# 5057                         0                  0.0
# 5058                        50                 50.0
# 5059                         0                  0.0
# 5060                       265                265.0
#
# [5061 rows x 2 columns]

# %% [markdown]
# `average_playtime_forever` is now useless and can be dropped

# %%
df.drop(columns='average_playtime_forever', inplace=True)

# %% [markdown]
# The same type of analysis now needs to be done on `median_playtime_forever` and `new_median_forever`

# %%
(df['median_playtime_forever'] == 0).value_counts()
# Out:
# median_playtime_forever
# False    3710
# True     1351
# Name: count, dtype: int64

# %%
df['new_median_forever'].isna().value_counts()
# Out:
# new_median_forever
# False    4583
# True      478
# Name: count, dtype: int64

# %%
df[['median_playtime_forever', 'new_median_forever']]
# Out:
#       median_playtime_forever  new_median_forever
# 0                          93               496.0
# 1                          24               223.0
# 2                         431               821.0
# 3                        1258              1341.0
# 4                        1021               770.0
# ...                       ...                 ...
# 5056                        0                 NaN
# 5057                        0                 NaN
# 5058                       50                 NaN
# 5059                        0                 NaN
# 5060                      265                 NaN
#
# [5061 rows x 2 columns]

# %%
((df['median_playtime_forever'] != 0) & (df['new_median_forever'].isna())).value_counts()
# Out:
# False    4868
# True      193
# Name: count, dtype: int64

# %%
((df['median_playtime_forever'] != 0) & (df['new_median_forever'] == 0)).value_counts()
# Out:
# False    4728
# True      333
# Name: count, dtype: int64

# %%
df['new_median_forever'] = df['new_median_forever'].fillna(df['median_playtime_forever'])

# %%
for i, row in df.iterrows():
    if (row['median_playtime_forever'] != 0) & (row['new_median_forever'] == 0):
        df.at[i, 'new_median_forever'] = row['median_playtime_forever']

# %%
(df['new_median_forever'] == 0).value_counts()
# Out:
# new_median_forever
# False    4120
# True      941
# Name: count, dtype: int64

# %%
df[['median_playtime_forever', 'new_median_forever']]
# Out:
#       median_playtime_forever  new_median_forever
# 0                          93               496.0
# 1                          24               223.0
# 2                         431               821.0
# 3                        1258              1341.0
# 4                        1021               770.0
# ...                       ...                 ...
# 5056                        0                 0.0
# 5057                        0                 0.0
# 5058                       50                50.0
# 5059                        0                 0.0
# 5060                      265               265.0
#
# [5061 rows x 2 columns]

# %% [markdown]
# `median_playtime_forever` is now useless and can be dropped

# %%
df.drop(columns='median_playtime_forever', inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5061 entries, 0 to 5060
# Data columns (total 52 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   appid                     5061 non-null   int64
#  1   normalized_name           5061 non-null   object
#  2   name                      5061 non-null   object
#  3   release_date              5061 non-null   datetime64[ns]
#  4   peak_ccu                  5061 non-null   float64
#  5   required_age              5061 non-null   int64
#  6   dlc_count                 5061 non-null   int64
#  7   about_the_game            5045 non-null   object
#  8   summary                   3021 non-null   object
#  9   supported_languages       5061 non-null   object
#  10  full_audio_languages      5061 non-null   object
#  11  some_reviews              2248 non-null   object
#  12  reviews_total             5061 non-null   float64
#  13  reviews_score_fancy       5061 non-null   object
#  14  header_image              5061 non-null   object
#  15  windows                   5061 non-null   bool
#  16  mac                       5061 non-null   bool
#  17  linux                     5061 non-null   bool
#  18  metacritic_url            5061 non-null   object
#  19  achievements              5061 non-null   int64
#  20  recommendations           5061 non-null   int64
#  21  notes                     591 non-null    object
#  22  developers                5061 non-null   object
#  23  publishers                5037 non-null   object
#  24  categories                5059 non-null   object
#  25  genres                    5057 non-null   object
#  26  tags                      5018 non-null   object
#  27  screenshots               5061 non-null   object
#  28  movies                    4500 non-null   object
#  29  plays                     3024 non-null   object
#  30  playing                   3024 non-null   object
#  31  backlogs                  3024 non-null   object
#  32  wishlist                  3024 non-null   object
#  33  lists                     3024 non-null   object
#  34  steam_page                4583 non-null   object
#  35  platforms                 3024 non-null   object
#  36  platforms_2               3384 non-null   object
#  37  infos_per_platform        3384 non-null   object
#  38  revenue_estimated         4583 non-null   object
#  39  meta_critic_score         5061 non-null   float64
#  40  new_positive              5061 non-null   float64
#  41  new_negative              5061 non-null   float64
#  42  new_min_estimated_owners  5061 non-null   float64
#  43  new_max_estimated_owners  5061 non-null   float64
#  44  new_average_forever       5061 non-null   float64
#  45  new_median_forever        5061 non-null   float64
#  46  new_price                 4936 non-null   float64
#  47  new_initialprice          4583 non-null   float64
#  48  new_discount              4583 non-null   float64
#  49  new_genre                 4575 non-null   object
#  50  new_tags                  4583 non-null   object
#  51  metacritic_user_score     4743 non-null   float64
# dtypes: bool(3), datetime64[ns](1), float64(13), int64(5), object(30)
# memory usage: 1.9+ MB

# %%
df['developers']
# Out:
# 0                                          Pixelated Milk
# 1                                      Team17 Digital Ltd
# 2                                             The Farm 51
# 3       Ubisoft Montreal,Red Storm,Ubisoft Shanghai,Ub...
# 4                                        Playground Games
#                               ...
# 5056                                    Trialforge Studio
# 5057                                Frontier Developments
# 5058                               Thunderful Development
# 5059                                       The Gentlebros
# 5060                                          Coal Supper
# Name: developers, Length: 5061, dtype: object

# %%
df['developers'] = df['developers'].str.split(',')

# %%
def merge_suffixes(companies):
    # Normalize suffixes (no leading/trailing spaces)
    suffixes = {'Inc.', 'Ltd.', 'LTD.'}
    result = []

    for item in companies:
        stripped = item.strip()  # Remove leading/trailing spaces
        if stripped in suffixes and result:
            # Merge with previous, preserving original spacing
            result[-1] += ' ' + stripped
        else:
            result.append(item.strip())

    return result

# %%
df['developers'] = df['developers'].apply(merge_suffixes)

# %%
df['publishers']
# Out:
# 0       Pixelated Milk,gaming company
# 1                  Team17 Digital Ltd
# 2                          THQ Nordic
# 3                             Ubisoft
# 4                   Xbox Game Studios
#                     ...
# 5056                  Tate Multimedia
# 5057            Frontier Developments
# 5058            Thunderful Publishing
# 5059               Kepler Interactive
# 5060                            Panic
# Name: publishers, Length: 5061, dtype: object

# %%
df['publishers'] = df['publishers'].str.split(',')

# %%
for idx, row in df.iterrows():
    if not isinstance(row['publishers'], float):
        df.at[idx, 'publishers'] = merge_suffixes(row['publishers'])

# %%
df['publishers']
# Out:
# 0       [Pixelated Milk, gaming company]
# 1                   [Team17 Digital Ltd]
# 2                           [THQ Nordic]
# 3                              [Ubisoft]
# 4                    [Xbox Game Studios]
#                       ...
# 5056                   [Tate Multimedia]
# 5057             [Frontier Developments]
# 5058             [Thunderful Publishing]
# 5059                [Kepler Interactive]
# 5060                             [Panic]
# Name: publishers, Length: 5061, dtype: object

# %%
df['categories']
# Out:
# 0       Single-player,Steam Achievements,Steam Trading...
# 1       Single-player,Multi-player,Co-op,Steam Achieve...
# 2       Single-player,Multi-player,Co-op,Steam Achieve...
# 3       Single-player,Multi-player,Co-op,Online Co-op,...
# 4       Single-player,Multi-player,PvP,Online PvP,Co-o...
#                               ...
# 5056    Single-player,Steam Achievements,Full controll...
# 5057    Single-player,Steam Achievements,Steam Trading...
# 5058    Single-player,Steam Achievements,Full controll...
# 5059    Single-player,Multi-player,Co-op,Shared/Split ...
# 5060    Single-player,Steam Achievements,Full controll...
# Name: categories, Length: 5061, dtype: object

# %%
df['categories'] = df['categories'].str.split(',').values

# %%
df['categories']
# Out:
# 0       [Single-player, Steam Achievements, Steam Trad...
# 1       [Single-player, Multi-player, Co-op, Steam Ach...
# 2       [Single-player, Multi-player, Co-op, Steam Ach...
# 3       [Single-player, Multi-player, Co-op, Online Co...
# 4       [Single-player, Multi-player, PvP, Online PvP,...
#                               ...
# 5056    [Single-player, Steam Achievements, Full contr...
# 5057    [Single-player, Steam Achievements, Steam Trad...
# 5058    [Single-player, Steam Achievements, Full contr...
# 5059    [Single-player, Multi-player, Co-op, Shared/Sp...
# 5060    [Single-player, Steam Achievements, Full contr...
# Name: categories, Length: 5061, dtype: object

# %% [markdown]
# It's now the moment to compare `genres` and `tags` with `new_genre` and `new_tags`

# %%
df['genres']
# Out:
# 0                                 Indie,RPG
# 1                                    Action
# 2                          Action,Adventure
# 3                          Action,Adventure
# 4                                    Racing
#                        ...
# 5056             Action,Adventure,Indie,RPG
# 5057                    Simulation,Strategy
# 5058    Action,Adventure,Indie,RPG,Strategy
# 5059             Action,Adventure,Indie,RPG
# 5060                 Adventure,Casual,Indie
# Name: genres, Length: 5061, dtype: object

# %%
df['genres'] = df['genres'].str.split(',')

# %%
df['genres']
# Out:
# 0                                    [Indie, RPG]
# 1                                        [Action]
# 2                             [Action, Adventure]
# 3                             [Action, Adventure]
# 4                                        [Racing]
#                           ...
# 5056              [Action, Adventure, Indie, RPG]
# 5057                       [Simulation, Strategy]
# 5058    [Action, Adventure, Indie, RPG, Strategy]
# 5059              [Action, Adventure, Indie, RPG]
# 5060                   [Adventure, Casual, Indie]
# Name: genres, Length: 5061, dtype: object

# %%
df['new_genre']
# Out:
# 0       Indie, RPG, Free To Play
# 1                         Action
# 2              Action, Adventure
# 3              Action, Adventure
# 4                         Racing
#                   ...
# 5056                         NaN
# 5057                         NaN
# 5058                         NaN
# 5059                         NaN
# 5060                         NaN
# Name: new_genre, Length: 5061, dtype: object

# %%
df['new_genre'] = df['new_genre'].str.split(', ')

# %%
df['new_genre']
# Out:
# 0       [Indie, RPG, Free To Play]
# 1                         [Action]
# 2              [Action, Adventure]
# 3              [Action, Adventure]
# 4                         [Racing]
#                    ...
# 5056                           NaN
# 5057                           NaN
# 5058                           NaN
# 5059                           NaN
# 5060                           NaN
# Name: new_genre, Length: 5061, dtype: object

# %%
df.iloc[10]
# Out:
# appid                                                                 1345820
# normalized_name                                                     ragnarock
# name                                                                Ragnarock
# release_date                                              2021-07-01 00:00:00
# peak_ccu                                                                 44.0
# required_age                                                                0
# dlc_count                                                                  17
# about_the_game              Are you ready to rock? Ragnarock is a solo/mul...
# summary                     Ragnarock is a VR game of rhythm and skill. Yo...
# supported_languages         [English, French, Italian, German, Spanish - S...
# full_audio_languages                                                       []
# some_reviews                “You know that scene in 'Mad Max: Fury Road' w...
# reviews_total                                                          2977.0
# reviews_score_fancy                                                      95.0
# header_image                https://cdn.akamai.steamstatic.com/steam/apps/...
# windows                                                                  True
# mac                                                                     False
# linux                                                                   False
# metacritic_url              https://www.metacritic.com/game/pc/ragnarock?f...
# achievements                                                               11
# recommendations                                                          1996
# notes                                                                     NaN
# developers                                                    [WanadevStudio]
# publishers                                                    [WanadevStudio]
# categories                  [Single-player, Multi-player, PvP, Online PvP,...
# genres                                        [Casual, Indie, Racing, Sports]
# tags                        Rhythm,VR,Multiplayer,Music,Racing,PvP,Casual,...
# screenshots                 https://cdn.akamai.steamstatic.com/steam/apps/...
# movies                      http://cdn.akamai.steamstatic.com/steam/apps/2...
# plays                                                                      50
# playing                                                                     5
# backlogs                                                                   19
# wishlist                                                                    9
# lists                                                                      11
# steam_page                         https://store.steampowered.com/app/1345820
# platforms                   ['Oculus VR', 'SteamVR', 'Oculus Quest', 'Ocul...
# platforms_2                                                            ['PC']
# infos_per_platform          {'PC': {'critic_score': nan, 'total_sales': na...
# revenue_estimated                                                  $57 826,86
# meta_critic_score                                                        79.0
# new_positive                                                           2820.0
# new_negative                                                            157.0
# new_min_estimated_owners                                             100000.0
# new_max_estimated_owners                                             200000.0
# new_average_forever                                                     220.0
# new_median_forever                                                      178.0
# new_price                                                               12.49
# new_initialprice                                                        24.99
# new_discount                                                             50.0
# new_genre                                             [Action, Casual, Indie]
# new_tags                    {'VR': 323, 'Action': 320, 'Rhythm': 317, 'Mus...
# metacritic_user_score                                                     6.1
# Name: 10, dtype: object

# %%
for genres, new_genres in zip(df['genres'].values, df['new_genre'].values):
    if isinstance(genres, list) and isinstance(new_genres, float):
        print(genres, new_genres)
# Out:
# ['Adventure', 'Indie', 'RPG'] nan
# ['Action', 'Adventure', 'Free to Play'] nan
# ['Adventure', 'Indie', 'RPG', 'Strategy'] nan
# ['Adventure', 'Indie'] nan
# ['Adventure'] nan
# ['Free to Play', 'Massively Multiplayer', 'RPG'] nan
# ['Simulation', 'Sports'] nan
# ['Massively Multiplayer', 'RPG'] nan
# ['Action'] nan
# ['Action'] nan
# ['Action'] nan
# ['Action'] nan
# ['Action', 'Free to Play'] nan
# ['Action', 'Indie', 'Strategy'] nan
# ['Action', 'Adventure', 'Casual', 'Indie'] nan
# ['Action', 'Adventure', 'Indie'] nan
# ['Action', 'Free to Play'] nan
# ['Simulation', 'Sports'] nan
# ['Adventure', 'Massively Multiplayer', 'RPG', 'Strategy'] nan
# ['RPG'] nan
# ['Action'] nan
# ['Casual', 'Indie', 'Strategy'] nan
# ['Free to Play', 'Massively Multiplayer', 'RPG'] nan
# ['Indie', 'Strategy'] nan
# ['Adventure'] nan
# ['Action', 'RPG'] nan
# ['Action'] nan
# ['RPG'] nan
# ['Adventure'] nan
# ['Action', 'Free to Play', 'Massively Multiplayer', 'Simulation'] nan
# ['Action', 'Adventure'] nan
# ['Action', 'Free to Play', 'Massively Multiplayer', 'RPG', 'Strategy'] nan
# ['Action', 'Adventure', 'Free to Play', 'RPG'] nan
# ['Simulation'] nan
# ['Casual', 'Free to Play', 'Indie'] nan
# ['Action', 'Indie', 'Strategy'] nan
# ['Action', 'Free to Play', 'Strategy'] nan
# ['Action', 'Adventure', 'Free to Play', 'Massively Multiplayer', 'RPG'] nan
# ['Action', 'Free to Play', 'Massively Multiplayer', 'Simulation'] nan
# ['Action', 'Strategy', 'Indie', 'Sports'] nan
# ['Action', 'Casual', 'Indie'] nan
# ['Action', 'Free to Play', 'Massively Multiplayer', 'Simulation'] nan
# ['Action', 'Free to Play', 'Massively Multiplayer'] nan
# ['Action', 'Adventure', 'Indie', 'RPG', 'Strategy'] nan
# ['Free to Play', 'Massively Multiplayer', 'RPG'] nan
# ['Massively Multiplayer', 'RPG'] nan
# ['Adventure'] nan
# ['Design & Illustration', 'Web Publishing'] nan
# ['Sports'] nan
# ['Action', 'Simulation'] nan
# ['Action', 'Free to Play', 'Massively Multiplayer', 'Simulation'] nan
# ['Action'] nan
# ['Action', 'Free to Play', 'Simulation'] nan
# ['RPG'] nan
# ['Action'] nan
# ['Casual', 'Sports'] nan
# ['Action', 'Free to Play', 'Massively Multiplayer'] nan
# ['RPG', 'Strategy', 'Early Access'] nan
# ['Free to Play', 'RPG', 'Simulation', 'Strategy'] nan
# ['Action', 'RPG'] nan
# ['Racing', 'Simulation', 'Sports'] nan
# ['Casual', 'Indie', 'Simulation'] nan
# ['Action', 'Free to Play', 'Indie'] nan
# ['Action'] nan
# ['Action', 'Free to Play'] nan
# ['Action', 'Casual', 'Free to Play', 'Strategy'] nan
# ['Adventure', 'Casual', 'Free to Play', 'Massively Multiplayer', 'Strategy'] nan
# ['Adventure', 'Free to Play'] nan
# ['Action', 'Free to Play'] nan
# ['Action', 'Adventure', 'Free to Play', 'Massively Multiplayer', 'RPG', 'Simulation', 'Strategy'] nan
# ['Casual', 'Simulation'] nan
# ['Action', 'Indie', 'RPG'] nan
# ['Action'] nan
# ['Action', 'RPG'] nan
# ['Action', 'Free to Play'] nan
# ['Action', 'Indie', 'Massively Multiplayer', 'RPG'] nan
# ['Adventure'] nan
# ['Free to Play', 'Massively Multiplayer', 'RPG'] nan
# ['Action', 'RPG'] nan
# ['Action', 'Free to Play', 'RPG'] nan
# ['Action', 'Adventure'] nan
# ['Casual', 'Sports'] nan
# ['Free to Play', 'Massively Multiplayer', 'RPG'] nan
# ['Sports'] nan
# ['Free to Play', 'Massively Multiplayer', 'RPG'] nan
# ['Action'] nan
# ['Free to Play', 'Massively Multiplayer', 'RPG'] nan
# ['Simulation'] nan
# ['Indie', 'Simulation', 'Strategy'] nan
# ['Action', 'Free to Play', 'Indie', 'Strategy'] nan
# ['Simulation', 'Strategy'] nan
# ['Sports'] nan
# ['Racing'] nan
# ['Free to Play', 'Massively Multiplayer', 'Sports'] nan
# ['Action', 'Free to Play', 'Massively Multiplayer', 'Simulation'] nan
# ['Action', 'Indie'] nan
# ['Strategy'] nan
# ['Action'] nan
# ['Sports'] nan
# ['Casual', 'Indie', 'Strategy', 'Early Access'] nan
# ['Action', 'Free to Play', 'Indie'] nan
# ['Adventure', 'Casual', 'Free to Play', 'Indie'] nan
# ['Action', 'Adventure', 'Free to Play', 'Massively Multiplayer', 'RPG'] nan
# ['Adventure', 'Indie'] nan
# ['Action', 'Adventure', 'Indie'] nan
# ['Adventure'] nan
# ['Action', 'Adventure', 'Indie'] nan
# ['Sports'] nan
# ['Action', 'RPG', 'Simulation'] nan
# ['Free to Play'] nan
# ['Action', 'Adventure', 'RPG'] nan
# ['Strategy'] nan
# ['Massively Multiplayer', 'RPG'] nan
# ['Action', 'Adventure'] nan
# ['Simulation', 'Sports'] nan
# ['Action', 'Adventure', 'RPG'] nan
# ['Action', 'Casual', 'Free to Play', 'Massively Multiplayer'] nan
# ['Action', 'Adventure', 'Free to Play', 'Massively Multiplayer', 'RPG'] nan
# ['Action', 'Adventure', 'Indie'] nan
# ['RPG', 'Casual'] nan
# ['Casual', 'Free to Play', 'Indie', 'Strategy'] nan
# ['Simulation', 'Sports'] nan
# ['Adventure'] nan
# ['Action', 'Adventure', 'Free to Play', 'Massively Multiplayer', 'RPG'] nan
# ['Action', 'Adventure', 'Free to Play', 'Massively Multiplayer', 'RPG', 'Strategy'] nan
# ['Action', 'Free to Play'] nan
# ['Action', 'Free to Play', 'Massively Multiplayer'] nan
# ['Action', 'Free to Play'] nan
# ['Casual'] nan
# ['Action', 'Adventure'] nan
# ['Action', 'Free to Play'] nan
# ['Action', 'Strategy'] nan
# ['Strategy'] nan
# ['Action', 'Indie', 'Massively Multiplayer'] nan
# ['Free to Play', 'Strategy'] nan
# ['Action', 'Adventure'] nan
# ['Action', 'Free to Play', 'Indie'] nan
# ['Casual', 'Strategy'] nan
# ['Action', 'Adventure', 'Free to Play', 'Massively Multiplayer', 'RPG'] nan
# ['Action', 'Free to Play'] nan
# ['Free to Play', 'Massively Multiplayer', 'RPG'] nan
# ['Action', 'Free to Play'] nan
# ['Action', 'Adventure', 'Free to Play', 'Indie', 'Massively Multiplayer', 'RPG'] nan
# ['Action', 'Adventure', 'Indie'] nan
# ['RPG', 'Strategy'] nan
# ['Adventure', 'Free to Play', 'Massively Multiplayer', 'RPG'] nan
# ['Strategy'] nan
# ['Adventure', 'Casual', 'Indie', 'Simulation'] nan
# ['Action'] nan
# ['Action', 'Adventure', 'Indie', 'RPG'] nan
# ['Adventure'] nan
# ['Adventure', 'Free to Play', 'RPG', 'Strategy'] nan
# ['Free to Play', 'Indie', 'Strategy'] nan
# ['Free to Play', 'Indie', 'Strategy'] nan
# ['Free to Play', 'Strategy'] nan
# ['Action', 'Indie'] nan
# ['Action'] nan
# ['Simulation', 'Sports'] nan
# ['Action'] nan
# ['Action', 'Indie'] nan
# ['Racing', 'Sports'] nan
# ['Indie'] nan
# ['Action', 'Casual', 'Racing'] nan
# ['Action', 'Free to Play', 'Massively Multiplayer', 'RPG'] nan
# ['Action', 'Indie'] nan
# ['Action'] nan
# ['Adventure', 'Indie', 'RPG', 'Strategy'] nan
# ['Adventure', 'Indie', 'Simulation', 'Strategy'] nan
# ['Adventure', 'RPG', 'Strategy'] nan
# ['Action'] nan
# ['Action', 'Adventure', 'Indie'] nan
# ['Adventure', 'Indie'] nan
# ['Racing'] nan
# ['Action', 'Adventure', 'Indie', 'RPG'] nan
# ['Adventure', 'Casual', 'Indie', 'Simulation'] nan
# ['Adventure'] nan
# ['Action', 'Adventure', 'Indie'] nan
# ['Action', 'Adventure', 'Indie'] nan
# ['Action', 'Adventure', 'Simulation'] nan
# ['Action', 'Indie'] nan
# ['Adventure', 'Indie'] nan
# ['Adventure', 'Indie', 'RPG'] nan
# ['Adventure', 'Indie', 'RPG'] nan
# ['Action', 'Adventure', 'Indie', 'RPG'] nan
# ['Adventure'] nan
# ['Racing', 'Simulation', 'Sports'] nan
# ['Indie', 'Racing', 'Sports', 'Early Access'] nan
# ['Strategy'] nan
# ['Racing'] nan
# ['Action'] nan
# ['Adventure', 'Indie', 'RPG'] nan
# ['Action'] nan
# ['Action', 'Adventure'] nan
# ['Action', 'RPG'] nan
# ['Casual', 'Indie', 'Strategy'] nan
# ['Action'] nan
# ['Action', 'RPG'] nan
# ['Adventure', 'RPG', 'Simulation'] nan
# ['Adventure', 'Indie', 'Strategy'] nan
# ['Adventure', 'Indie', 'RPG', 'Strategy'] nan
# ['Adventure', 'Casual', 'Indie'] nan
# ['Simulation', 'Sports'] nan
# ['Adventure', 'Indie'] nan
# ['Adventure', 'Casual', 'Indie', 'Simulation'] nan
# ['Action'] nan
# ['Adventure', 'RPG'] nan
# ['Adventure', 'Simulation', 'Strategy'] nan
# ['Adventure'] nan
# ['Action', 'Adventure', 'Indie', 'RPG'] nan
# ['Action', 'Casual', 'Indie'] nan
# ['Racing'] nan
# ['Casual', 'RPG', 'Simulation'] nan
# ['Simulation', 'Sports'] nan
# ['Action', 'Adventure', 'Casual', 'Indie', 'RPG', 'Simulation'] nan
# ['Adventure'] nan
# ['Action', 'Adventure'] nan
# ['RPG'] nan
# ['Action', 'Adventure'] nan
# ['Indie', 'Simulation', 'Strategy'] nan
# ['Adventure', 'Casual', 'Indie', 'RPG', 'Early Access'] nan
# ['Action', 'Adventure'] nan
# ['Action', 'Strategy'] nan
# ['Action', 'Adventure', 'Racing', 'Simulation', 'Sports'] nan
# ['Adventure', 'Indie'] nan
# ['Action', 'Adventure'] nan
# ['RPG', 'Strategy'] nan
# ['Adventure', 'Casual', 'Indie', 'RPG', 'Simulation'] nan
# ['Action', 'Adventure'] nan
# ['Action', 'Casual', 'RPG', 'Strategy'] nan
# ['Adventure'] nan
# ['Action', 'Indie'] nan
# ['Action', 'Casual'] nan
# ['Action', 'Adventure', 'Strategy'] nan
# ['Action', 'Adventure'] nan
# ['Adventure', 'Indie'] nan
# ['Adventure', 'RPG'] nan
# ['RPG', 'Strategy'] nan
# ['Action', 'Adventure', 'Simulation'] nan
# ['Action', 'Adventure'] nan
# ['Action', 'Adventure', 'RPG', 'Strategy'] nan
# ['Action', 'Adventure', 'Indie'] nan
# ['Adventure', 'Indie', 'RPG', 'Simulation'] nan
# ['Adventure', 'Casual', 'Indie'] nan
# ['Action', 'Adventure'] nan
# ['Action', 'Adventure', 'Casual', 'Indie'] nan
# ['Strategy'] nan
# ['Action'] nan
# ['Adventure', 'Casual', 'Indie', 'RPG', 'Simulation'] nan
# ['Action', 'RPG'] nan
# ['Action'] nan
# ['Casual', 'Indie', 'Simulation', 'Strategy'] nan
# ['Action', 'Casual'] nan
# ['Simulation', 'Strategy'] nan
# ['Action', 'Adventure', 'Indie'] nan
# ['Sports'] nan
# ['Action', 'Adventure'] nan
# ['Action', 'Adventure'] nan
# ['Action', 'Adventure', 'Indie', 'Early Access'] nan
# ['Casual'] nan
# ['Action'] nan
# ['Action', 'Adventure', 'Indie'] nan
# ['Adventure'] nan
# ['Action'] nan
# ['Action', 'Adventure', 'Indie'] nan
# ['Action'] nan
# ['Action', 'Indie'] nan
# ['RPG', 'Simulation', 'Strategy'] nan
# ['Adventure'] nan
# ['Adventure', 'Indie', 'RPG', 'Strategy'] nan
# ['Action', 'Adventure', 'Indie', 'RPG'] nan
# ['Action', 'Adventure', 'RPG'] nan
# ['Action', 'Adventure', 'Casual', 'Massively Multiplayer', 'RPG'] nan
# ['Adventure'] nan
# ['Adventure', 'Indie', 'RPG'] nan
# ['Action', 'Adventure', 'RPG', 'Strategy'] nan
# ['Adventure', 'Casual', 'Indie'] nan
# ['Action', 'Adventure'] nan
# ['Simulation', 'Strategy'] nan
# ['Action', 'Adventure', 'Indie'] nan
# ['Action', 'Adventure'] nan
# ['Action', 'Adventure', 'Indie'] nan
# ['Simulation', 'Sports', 'Strategy'] nan
# ['Adventure', 'Indie'] nan
# ['RPG'] nan
# ['Action'] nan
# ['Adventure', 'Indie'] nan
# ['Simulation', 'Strategy'] nan
# ['Action', 'Adventure', 'Indie'] nan
# ['Action', 'Adventure'] nan
# ['Simulation', 'Strategy'] nan
# ['Action', 'Adventure'] nan
# ['Adventure', 'Indie', 'RPG', 'Strategy'] nan
# ['Adventure', 'Indie'] nan
# ['Action'] nan
# ['Casual', 'Indie', 'Simulation'] nan
# ['Action', 'Adventure', 'Indie', 'RPG'] nan
# ['Action'] nan
# ['RPG'] nan
# ['Adventure', 'Indie'] nan
# ['RPG', 'Strategy'] nan
# ['Simulation', 'Strategy'] nan
# ['Strategy'] nan
# ['Action', 'Adventure', 'Indie'] nan
# ['RPG'] nan
# ['Action', 'Indie'] nan
# ['Action'] nan
# ['Strategy'] nan
# ['Adventure'] nan
# ['Action', 'Adventure', 'RPG'] nan
# ['Action'] nan
# ['Action'] nan
# ['Adventure', 'Casual', 'Indie'] nan
# ['Action', 'Adventure', 'Indie'] nan
# ['Adventure', 'RPG', 'Strategy'] nan
# ['Action', 'Adventure', 'RPG', 'Free to Play'] nan
# ['Adventure', 'Indie'] nan
# ['Action'] nan
# ['Action'] nan
# ['Action'] nan
# ['Action', 'Adventure'] nan
# ['Adventure', 'Indie'] nan
# ['Action', 'Adventure', 'RPG'] nan
# ['Adventure'] nan
# ['Adventure', 'Casual', 'Simulation'] nan
# ['Action', 'Adventure'] nan
# ['Action', 'Adventure'] nan
# ['Indie', 'Strategy'] nan
# ['RPG', 'Simulation'] nan
# ['Strategy'] nan
# ['Action'] nan
# ['Adventure', 'Indie'] nan
# ['Casual', 'Indie', 'Strategy'] nan
# ['Action', 'Adventure', 'Indie'] nan
# ['Action', 'Adventure', 'Indie', 'Racing', 'Simulation'] nan
# ['Adventure', 'Indie'] nan
# ['Action'] nan
# ['Action'] nan
# ['Casual'] nan
# ['Adventure', 'Casual'] nan
# ['Casual', 'Indie', 'Strategy'] nan
# ['Action', 'Adventure', 'RPG'] nan
# ['Action', 'Adventure', 'Indie'] nan
# ['Casual', 'Indie', 'Simulation', 'Strategy'] nan
# ['Action'] nan
# ['Indie', 'RPG', 'Strategy'] nan
# ['Strategy'] nan
# ['Action', 'Adventure'] nan
# ['Casual', 'Indie', 'Simulation'] nan
# ['Action', 'Casual', 'Indie', 'Racing'] nan
# ['Action', 'Adventure', 'Casual'] nan
# ['Action'] nan
# ['Adventure', 'Indie', 'RPG'] nan
# ['Adventure', 'Indie'] nan
# ['Adventure', 'RPG'] nan
# ['Simulation', 'Sports'] nan
# ['Simulation'] nan
# ['Action'] nan
# ['Adventure', 'Racing', 'Simulation'] nan
# ['Casual', 'Simulation', 'Strategy'] nan
# ['Action', 'RPG'] nan
# ['Action', 'RPG'] nan
# ['Action', 'Adventure', 'Indie'] nan
# ['Action', 'Adventure', 'Indie'] nan
# ['Action', 'Indie'] nan
# ['Simulation', 'Strategy'] nan
# ['Adventure', 'Indie'] nan
# ['Casual', 'Indie', 'Simulation', 'Strategy'] nan
# ['Action', 'Adventure'] nan
# ['Strategy'] nan
# ['Action', 'Adventure'] nan
# ['Action', 'RPG', 'Simulation', 'Strategy'] nan
# ['Action', 'Indie', 'Simulation'] nan
# ['Strategy'] nan
# ['Action', 'Adventure', 'Casual', 'RPG'] nan
# ['Action', 'Adventure', 'Indie'] nan
# ['Action', 'Adventure', 'Indie'] nan
# ['RPG'] nan
# ['Action', 'Adventure', 'Indie'] nan
# ['Simulation', 'Strategy'] nan
# ['Casual', 'Indie', 'Simulation'] nan
# ['Action', 'Indie', 'Strategy'] nan
# ['Adventure'] nan
# ['Adventure', 'Casual', 'Indie'] nan
# ['Indie', 'RPG', 'Simulation', 'Strategy'] nan
# ['Racing'] nan
# ['Action', 'RPG'] nan
# ['Sports'] nan
# ['RPG'] nan
# ['Action'] nan
# ['Action', 'Adventure', 'Indie', 'RPG', 'Strategy'] nan
# ['Simulation', 'Strategy'] nan
# ['Action'] nan
# ['Action', 'RPG'] nan
# ['Action', 'Adventure', 'Indie'] nan
# ['Action', 'Adventure', 'Indie'] nan
# ['Indie', 'RPG', 'Simulation'] nan
# ['Action', 'Adventure'] nan
# ['Action', 'Indie'] nan
# ['Action', 'Adventure'] nan
# ['Strategy'] nan
# ['Adventure'] nan
# ['Racing', 'Sports'] nan
# ['Action', 'Simulation', 'Strategy'] nan
# ['Action', 'Adventure', 'Indie', 'Simulation'] nan
# ['Adventure', 'Casual', 'Indie', 'Simulation'] nan
# ['RPG', 'Strategy'] nan
# ['Action', 'Indie'] nan
# ['Adventure', 'Indie', 'Racing', 'Strategy'] nan
# ['Action', 'Adventure', 'Indie'] nan
# ['Casual'] nan
# ['Adventure', 'Indie', 'RPG'] nan
# ['Adventure', 'Casual', 'Indie'] nan
# ['Action', 'Simulation', 'Strategy'] nan
# ['Simulation', 'Strategy'] nan
# ['Action', 'Adventure', 'Indie'] nan
# ['Adventure', 'Indie'] nan
# ['Action', 'Indie'] nan
# ['Action', 'Adventure', 'Early Access'] nan
# ['Action'] nan
# ['Action', 'Adventure', 'Indie'] nan
# ['Action', 'Adventure'] nan
# ['Action', 'Casual', 'Indie'] nan
# ['Action', 'Adventure'] nan
# ['Action', 'Adventure', 'Indie'] nan
# ['Adventure', 'RPG', 'Strategy'] nan
# ['Adventure', 'Casual', 'Indie'] nan
# ['Adventure'] nan
# ['Strategy'] nan
# ['Adventure', 'Casual', 'Indie', 'Strategy'] nan
# ['Adventure', 'Casual'] nan
# ['Action', 'Adventure', 'Indie'] nan
# ['Casual', 'Indie', 'Simulation'] nan
# ['Adventure', 'Casual', 'Indie', 'RPG'] nan
# ['Action', 'Adventure', 'Indie'] nan
# ['Indie', 'Strategy'] nan
# ['Racing', 'Sports'] nan
# ['Action'] nan
# ['Adventure', 'Casual', 'Indie', 'RPG', 'Simulation'] nan
# ['Indie', 'Simulation'] nan
# ['Action', 'Adventure', 'Massively Multiplayer', 'RPG'] nan
# ['Action', 'Adventure', 'RPG'] nan
# ['Adventure', 'RPG'] nan
# ['RPG'] nan
# ['RPG'] nan
# ['Action', 'Adventure', 'Indie', 'RPG'] nan
# ['Action'] nan
# ['Action'] nan
# ['Casual', 'Indie', 'Simulation', 'Strategy'] nan
# ['Action', 'Adventure'] nan
# ['Adventure', 'Casual', 'Indie'] nan
# ['Adventure'] nan
# ['Action', 'Adventure'] nan
# ['Action', 'Adventure', 'Indie', 'RPG'] nan
# ['Action', 'Indie'] nan
# ['Adventure', 'Casual', 'Indie'] nan
# ['Action', 'Adventure', 'RPG'] nan
# ['Adventure', 'Casual', 'Indie'] nan
# ['Adventure', 'Indie', 'RPG'] nan
# ['Action'] nan
# ['Action', 'Casual', 'Simulation'] nan
# ['Indie', 'Simulation'] nan
# ['Action', 'Adventure', 'RPG'] nan
# ['RPG'] nan
# ['Adventure'] nan
# ['Adventure', 'Casual', 'Indie'] nan
# ['Action', 'Adventure', 'Indie'] nan
# ['Adventure', 'Indie'] nan
# ['Action', 'Adventure'] nan
# ['Casual', 'Indie', 'Simulation'] nan
# ['Adventure', 'Indie', 'RPG'] nan
# ['Adventure', 'Indie', 'Simulation'] nan
# ['Action', 'Adventure', 'Indie'] nan
# ['Adventure', 'Indie', 'RPG'] nan
# ['Action', 'Strategy'] nan
# ['Adventure', 'Indie'] nan
# ['Action', 'Adventure'] nan
# ['Adventure', 'Simulation'] nan
# ['Action', 'Adventure', 'Indie', 'RPG'] nan
# ['Simulation', 'Strategy'] nan
# ['Action', 'Adventure', 'Indie', 'RPG', 'Strategy'] nan
# ['Action', 'Adventure', 'Indie', 'RPG'] nan
# ['Adventure', 'Casual', 'Indie'] nan

# %%
for genres, new_genres in zip(df['genres'].values, df['new_genre'].values):
    if isinstance(genres, float) and isinstance(new_genres, list):
        print(genres, new_genres)

# %% [markdown]
# The above cell tell us that the missing values in the `genres` column doesn't correspond to non null values in `new_genre` that is now quite useless and can be dropped

# %%
df.drop(columns='new_genre', inplace = True)

# %%
df['tags']
# Out:
# 0       Tactical RPG,Turn-Based Strategy,Wargame,Histo...
# 1       Action,Shooter,Sci-fi,Aliens,Third Person,Isom...
# 2       Adventure,Action,FPS,Shooter,Multiplayer,First...
# 3       Open World,Co-op,Action,Multiplayer,FPS,Shoote...
# 4       Racing,Open World,Driving,Multiplayer,Online C...
#                               ...
# 5056    Souls-like,RPG,Difficult,Action RPG,Violent,St...
# 5057    Simulation,Strategy,Racing,Automobile Sim,Imme...
# 5058    Comedy,Steampunk,Turn-Based Combat,Strategy,Tu...
# 5059    Action,Adventure,Cats,Action RPG,Exploration,L...
# 5060    Adventure,Comedy,Hand-drawn,Funny,Exploration,...
# Name: tags, Length: 5061, dtype: object

# %%
df['tags'] = df['tags'].str.split(',')

# %%
df['tags']
# Out:
# 0       [Tactical RPG, Turn-Based Strategy, Wargame, H...
# 1       [Action, Shooter, Sci-fi, Aliens, Third Person...
# 2       [Adventure, Action, FPS, Shooter, Multiplayer,...
# 3       [Open World, Co-op, Action, Multiplayer, FPS, ...
# 4       [Racing, Open World, Driving, Multiplayer, Onl...
#                               ...
# 5056    [Souls-like, RPG, Difficult, Action RPG, Viole...
# 5057    [Simulation, Strategy, Racing, Automobile Sim,...
# 5058    [Comedy, Steampunk, Turn-Based Combat, Strateg...
# 5059    [Action, Adventure, Cats, Action RPG, Explorat...
# 5060    [Adventure, Comedy, Hand-drawn, Funny, Explora...
# Name: tags, Length: 5061, dtype: object

# %%
df['new_tags']
# Out:
# 0       {'Tactical RPG': 255, 'Wargame': 251, 'Turn-Ba...
# 1       {'Action': 111, 'Shooter': 93, 'Isometric': 89...
# 2       {'Adventure': 143, 'Action': 127, 'FPS': 104, ...
# 3       {'Open World': 1711, 'Action-Adventure': 1707,...
# 4       {'Racing': 790, 'Open World': 669, 'Driving': ...
#                               ...
# 5056                                                  NaN
# 5057                                                  NaN
# 5058                                                  NaN
# 5059                                                  NaN
# 5060                                                  NaN
# Name: new_tags, Length: 5061, dtype: object

# %%
for i, row in df.iterrows():
    if isinstance(row['new_tags'], str):
       if isinstance(eval(row['new_tags']), list):
           print(eval(row['new_tags']))
# Out:
# []

# %%
new_tags_list = []
for i, row in df.iterrows():
    if isinstance(row['new_tags'], str):
        if isinstance(eval(row['new_tags']), dict):
            new_tags_list.append(eval(row['new_tags']).keys())
        else:
            df.at[i, 'new_tags'] = np.nan
            new_tags_list.append(row['new_tags'])
    else:
        new_tags_list.append(row['new_tags'])

for i, elem in enumerate(new_tags_list):
    if not isinstance(elem, float):
        new_tags_list[i] = list(elem)

# %%
df['new_tags'] = new_tags_list

# %%
df['new_tags']
# Out:
# 0       [Tactical RPG, Wargame, Turn-Based Strategy, H...
# 1       [Action, Shooter, Isometric, Aliens, Sci-fi, T...
# 2       [Adventure, Action, FPS, Shooter, First-Person...
# 3       [Open World, Action-Adventure, Multiplayer, Co...
# 4       [Racing, Open World, Driving, Multiplayer, Aut...
#                               ...
# 5056                                                  NaN
# 5057                                                  NaN
# 5058                                                  NaN
# 5059                                                  NaN
# 5060                                                  NaN
# Name: new_tags, Length: 5061, dtype: object

# %%
df[['tags', 'new_tags']]
# Out:
#                                                    tags  \
# 0     [Tactical RPG, Turn-Based Strategy, Wargame, H...
# 1     [Action, Shooter, Sci-fi, Aliens, Third Person...
# 2     [Adventure, Action, FPS, Shooter, Multiplayer,...
# 3     [Open World, Co-op, Action, Multiplayer, FPS, ...
# 4     [Racing, Open World, Driving, Multiplayer, Onl...
# ...                                                 ...
# 5056  [Souls-like, RPG, Difficult, Action RPG, Viole...
# 5057  [Simulation, Strategy, Racing, Automobile Sim,...
# 5058  [Comedy, Steampunk, Turn-Based Combat, Strateg...
# 5059  [Action, Adventure, Cats, Action RPG, Explorat...
# 5060  [Adventure, Comedy, Hand-drawn, Funny, Explora...
#
#                                                new_tags
# 0     [Tactical RPG, Wargame, Turn-Based Strategy, H...
# 1     [Action, Shooter, Isometric, Aliens, Sci-fi, T...
# 2     [Adventure, Action, FPS, Shooter, First-Person...
# 3     [Open World, Action-Adventure, Multiplayer, Co...
# 4     [Racing, Open World, Driving, Multiplayer, Aut...
# ...                                                 ...
# 5056                                                NaN
# 5057                                                NaN
# 5058                                                NaN
# 5059                                                NaN
# 5060                                                NaN
#
# [5061 rows x 2 columns]

# %%
for tags, new_tags in zip(df['tags'].values, df['new_tags'].values):
    if isinstance(tags, float) and isinstance(new_tags, list):
        print(tags, new_tags)
# Out:
# nan ['Casual', 'Arcade', 'Puzzle-Platformer', '2D', 'Score Attack', 'Singleplayer', 'Indie']
# nan ['Adventure', 'Action', 'Strategy', 'Turn-Based Tactics', '4X', 'Arcade', 'Grand Strategy', 'Turn-Based Strategy', 'Visual Novel', 'Wargame', 'Tactical RPG', '3D', 'Cartoony', 'Old School', 'Investigation', 'Historical', 'Lore-Rich', 'War', 'Military', 'Combat']
# nan ['[', ']']
# nan ['Adventure', 'Exploration', 'Puzzle', '2D', 'Hidden Object', 'Colorful', 'Cute', 'Indie', 'Relaxing', 'Casual', 'Family Friendly', 'Controller', 'Singleplayer']
# nan ['Strategy', 'Wargame', 'Historical', 'Turn-Based Tactics', 'Singleplayer', 'War']
# nan ['Adventure', 'RPG', 'Point & Click', 'Puzzle', 'Turn-Based Strategy', 'Choose Your Own Adventure', 'Comedy', '2D', 'Funny', 'Lovecraftian', 'CRPG', 'Investigation', 'Character Customization', 'Choices Matter', 'Controller', 'Multiple Endings', 'Open World', 'Story Rich', 'Turn-Based Combat', 'Singleplayer']
# nan ['Casual', 'Retro', 'Singleplayer', 'Multiplayer', 'RPG', 'Family Friendly', '2D', 'Action', 'Strategy', 'Card Game', 'Sports', 'JRPG', 'Puzzle', 'Strategy RPG', "1990's", 'Pixel Graphics', 'Colorful', 'Turn-Based Strategy', 'Card Battler', 'Turn-Based Tactics']
# nan ['Soundtrack', 'Precision Platformer', 'Vikings', '2D Platformer', 'Pixel Graphics', 'Collectathon', 'Old School', 'Unforgiving', 'Linear', 'Platformer', 'Side Scroller', '1980s', 'Retro', 'Arcade', '2D', 'Character Action Game', 'Comic Book', 'Action', 'Mythology', 'Minimalist']
# nan ['RPG', 'Action', 'Adventure', 'Massively Multiplayer', 'Open World', 'Fantasy', 'MMORPG', 'Exploration', 'Supernatural', 'Multiplayer', 'Singleplayer', 'Character Customization', 'Story Rich', 'PvP', 'PvE', 'Choose Your Own Adventure', 'Lore-Rich', 'Action RPG', 'Class-Based', 'Dark Fantasy']
# nan ['RPG', 'First-Person', 'Fantasy', 'Action', 'Action-Adventure', 'Adventure', 'Singleplayer', 'Action RPG', 'Swordplay', 'Magic', 'Archery', 'Metroidvania', 'Medieval', 'Dark Fantasy', 'Lore-Rich', 'Story Rich', 'Post-apocalyptic', 'Atmospheric', 'Indie', 'Puzzle-Platformer']
# nan ['VR', 'Action', 'Shooter', 'FPS', 'First-Person', '1980s', 'Military', 'On-Rails Shooter', 'Combat', 'Violent', 'Singleplayer', 'Arcade', 'Multiplayer']
# nan ['Party-Based RPG', 'Hidden Object', 'JRPG', 'Action RPG', 'RPG', 'Character Action Game', 'Cute', 'Action', 'Relaxing', 'Story Rich', 'Casual', 'Family Friendly', 'Fantasy', 'Loot', 'Atmospheric', 'Emotional', 'Singleplayer', 'Soundtrack', 'Creature Collector', 'Anime']
# nan ['Simulation', 'Strategy', 'Sports', 'Automobile Sim', 'Immersive Sim', 'Time Management', '3D', 'Management', 'Realistic', 'Driving', 'Economy', 'Racing', 'Family Friendly', 'Tactical', 'Base-Building', 'Choices Matter', 'PvE', 'Resource Management', 'Team-Based', 'Singleplayer']

# %%
for i, row in df.iterrows():
    if isinstance(row['tags'], float) and isinstance(row['new_tags'], list): 
        df.at[i, 'tags'] = row['new_tags']

# %%
df['tags'].isna().value_counts()
# Out:
# tags
# False    5031
# True       30
# Name: count, dtype: int64

# %% [markdown]
# The `new_tags` feature is now not that useful and can be dropped

# %%
df.drop(columns='new_tags', inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5061 entries, 0 to 5060
# Data columns (total 50 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   appid                     5061 non-null   int64
#  1   normalized_name           5061 non-null   object
#  2   name                      5061 non-null   object
#  3   release_date              5061 non-null   datetime64[ns]
#  4   peak_ccu                  5061 non-null   float64
#  5   required_age              5061 non-null   int64
#  6   dlc_count                 5061 non-null   int64
#  7   about_the_game            5045 non-null   object
#  8   summary                   3021 non-null   object
#  9   supported_languages       5061 non-null   object
#  10  full_audio_languages      5061 non-null   object
#  11  some_reviews              2248 non-null   object
#  12  reviews_total             5061 non-null   float64
#  13  reviews_score_fancy       5061 non-null   object
#  14  header_image              5061 non-null   object
#  15  windows                   5061 non-null   bool
#  16  mac                       5061 non-null   bool
#  17  linux                     5061 non-null   bool
#  18  metacritic_url            5061 non-null   object
#  19  achievements              5061 non-null   int64
#  20  recommendations           5061 non-null   int64
#  21  notes                     591 non-null    object
#  22  developers                5061 non-null   object
#  23  publishers                5037 non-null   object
#  24  categories                5059 non-null   object
#  25  genres                    5057 non-null   object
#  26  tags                      5031 non-null   object
#  27  screenshots               5061 non-null   object
#  28  movies                    4500 non-null   object
#  29  plays                     3024 non-null   object
#  30  playing                   3024 non-null   object
#  31  backlogs                  3024 non-null   object
#  32  wishlist                  3024 non-null   object
#  33  lists                     3024 non-null   object
#  34  steam_page                4583 non-null   object
#  35  platforms                 3024 non-null   object
#  36  platforms_2               3384 non-null   object
#  37  infos_per_platform        3384 non-null   object
#  38  revenue_estimated         4583 non-null   object
#  39  meta_critic_score         5061 non-null   float64
#  40  new_positive              5061 non-null   float64
#  41  new_negative              5061 non-null   float64
#  42  new_min_estimated_owners  5061 non-null   float64
#  43  new_max_estimated_owners  5061 non-null   float64
#  44  new_average_forever       5061 non-null   float64
#  45  new_median_forever        5061 non-null   float64
#  46  new_price                 4936 non-null   float64
#  47  new_initialprice          4583 non-null   float64
#  48  new_discount              4583 non-null   float64
#  49  metacritic_user_score     4743 non-null   float64
# dtypes: bool(3), datetime64[ns](1), float64(13), int64(5), object(28)
# memory usage: 1.8+ MB

# %%
df['screenshots'].values
# Out:
# array(['https://cdn.akamai.steamstatic.com/steam/apps/1026420/ss_6a8fc6b2c001cf47ee616159e0b9038ec7bc5866.1920x1080.jpg?t=1657716289,https://cdn.akamai.steamstatic.com/steam/apps/1026420/ss_df4fa138bce054ecf5b5364f425a5883f3d2a14d.1920x1080.jpg?t=1657716289,https://cdn.akamai.steamstatic.com/steam/apps/1026420/ss_a2b404c25b07dd62106c14e7db330e5af778564e.1920x1080.jpg?t=1657716289,https://cdn.akamai.steamstatic.com/steam/apps/1026420/ss_68564ec1bb8081be3d2cc89e36a00694370b6f6a.1920x1080.jpg?t=1657716289,https://cdn.akamai.steamstatic.com/steam/apps/1026420/ss_d53b8acaaa4fdc3af645c644c3be2cffcd2620bf.1920x1080.jpg?t=1657716289,https://cdn.akamai.steamstatic.com/steam/apps/1026420/ss_976f0a68b1c4511162e59732014e69afb3680655.1920x1080.jpg?t=1657716289,https://cdn.akamai.steamstatic.com/steam/apps/1026420/ss_f0424f82e2023ce101e6e04530d895169a300095.1920x1080.jpg?t=1657716289,https://cdn.akamai.steamstatic.com/steam/apps/1026420/ss_dd10c156c29304af6ec37f06923e023b7a3eec57.1920x1080.jpg?t=1657716289',
#        'https://cdn.akamai.steamstatic.com/steam/apps/22670/ss_12bdbc7f444c7e99c2132f05d1945b9036e999cb.1920x1080.jpg?t=1655730869,https://cdn.akamai.steamstatic.com/steam/apps/22670/ss_7a6d2e8c4866940f5f1571f36eba50c1b4341149.1920x1080.jpg?t=1655730869,https://cdn.akamai.steamstatic.com/steam/apps/22670/ss_76aac22003177dc2e9136f95bb8908931807040c.1920x1080.jpg?t=1655730869,https://cdn.akamai.steamstatic.com/steam/apps/22670/ss_2d4bdc8ed2a931aad47964cce85e5301fb4a4dea.1920x1080.jpg?t=1655730869,https://cdn.akamai.steamstatic.com/steam/apps/22670/ss_290e7da46439abfbd196924daf9f7b51155a043b.1920x1080.jpg?t=1655730869,https://cdn.akamai.steamstatic.com/steam/apps/22670/ss_86fe862196b13c922889b9a13eb3b0ba39d914c3.1920x1080.jpg?t=1655730869,https://cdn.akamai.steamstatic.com/steam/apps/22670/ss_386f1b537acf9102c8896f5fa1ad4f91a3a3af1b.1920x1080.jpg?t=1655730869,https://cdn.akamai.steamstatic.com/steam/apps/22670/ss_9ce9bb8f24a8d6205d417097cbcc9cf084a4b5b2.1920x1080.jpg?t=1655730869,https://cdn.akamai.steamstatic.com/steam/apps/22670/ss_7b201de1cef3b955a2d3236fb56f342e4ffdcc06.1920x1080.jpg?t=1655730869,https://cdn.akamai.steamstatic.com/steam/apps/22670/ss_940cd02b37f6a9ae8ea8ff93f3c16b39bf89743a.1920x1080.jpg?t=1655730869',
#        'https://cdn.akamai.steamstatic.com/steam/apps/231330/ss_e53512c37c3b4927efec4ef2dccec62084af5a57.1920x1080.jpg?t=1561964976,https://cdn.akamai.steamstatic.com/steam/apps/231330/ss_e5660e00480523bab71e5758c6606de0abf9bebf.1920x1080.jpg?t=1561964976,https://cdn.akamai.steamstatic.com/steam/apps/231330/ss_eb71d7cb42e05f68b50d14a3d2a8bd60145acb98.1920x1080.jpg?t=1561964976,https://cdn.akamai.steamstatic.com/steam/apps/231330/ss_6ce7d35e3e24b9f5d35d8ebb27a0ca793ad08361.1920x1080.jpg?t=1561964976,https://cdn.akamai.steamstatic.com/steam/apps/231330/ss_8b3791b17d55df0461262b23192a725f80de2593.1920x1080.jpg?t=1561964976,https://cdn.akamai.steamstatic.com/steam/apps/231330/ss_d30c427a0ce9d8b04ca0809ae71f5356e0204e73.1920x1080.jpg?t=1561964976,https://cdn.akamai.steamstatic.com/steam/apps/231330/ss_3109f03c94c404b51e5775ad86a60e81e132ad19.1920x1080.jpg?t=1561964976,https://cdn.akamai.steamstatic.com/steam/apps/231330/ss_0ae6376d1947a3907690ed0a725e81d589cf5760.1920x1080.jpg?t=1561964976,https://cdn.akamai.steamstatic.com/steam/apps/231330/ss_d4e66c6d44b80b5835acabad30cb60292267e922.1920x1080.jpg?t=1561964976,https://cdn.akamai.steamstatic.com/steam/apps/231330/ss_ccc8d733e5f5e565ceaa4be6d8edcf6bdab95079.1920x1080.jpg?t=1561964976,https://cdn.akamai.steamstatic.com/steam/apps/231330/ss_b6ef227c36746b589e96d57eb3b09fba2d2c1cc6.1920x1080.jpg?t=1561964976,https://cdn.akamai.steamstatic.com/steam/apps/231330/ss_18bb9893a8c153b743417f8ada5526d7e172170b.1920x1080.jpg?t=1561964976,https://cdn.akamai.steamstatic.com/steam/apps/231330/ss_5b3342439c4a7fcb93ab253be906817f849da3e7.1920x1080.jpg?t=1561964976,https://cdn.akamai.steamstatic.com/steam/apps/231330/ss_6338aab220eabdf66b1137d0ad71278b255ce39f.1920x1080.jpg?t=1561964976,https://cdn.akamai.steamstatic.com/steam/apps/231330/ss_8292d4dd3ea71a927d2b8b09c41a4856e72b59fd.1920x1080.jpg?t=1561964976,https://cdn.akamai.steamstatic.com/steam/apps/231330/ss_27bd5bdb26ed53217bf31d013e795d0d5376e880.1920x1080.jpg?t=1561964976,https://cdn.akamai.steamstatic.com/steam/apps/231330/ss_aac2586e6d2a200f246c11f399216576bad38dc1.1920x1080.jpg?t=1561964976,https://cdn.akamai.steamstatic.com/steam/apps/231330/ss_aac19564f29ac14d3b70f1bbae5d6233284530cc.1920x1080.jpg?t=1561964976,https://cdn.akamai.steamstatic.com/steam/apps/231330/ss_763fee337f9ec69f6c6724460264e7c92d09c1ba.1920x1080.jpg?t=1561964976,https://cdn.akamai.steamstatic.com/steam/apps/231330/ss_f70a0c7cc773129ef12bd9ebcaf9bfcba74c637c.1920x1080.jpg?t=1561964976',
#        ...,
#        'https://shared.akamai.steamstatic.com/store_item_assets/steam/apps/2396240/ss_19c1be291bc0e198b7d6199f536e699399977c3c.1920x1080.jpg?t=1723132341,https://shared.akamai.steamstatic.com/store_item_assets/steam/apps/2396240/ss_11b2e0326139aea79fb34abe300fbe729fd5a174.1920x1080.jpg?t=1723132341,https://shared.akamai.steamstatic.com/store_item_assets/steam/apps/2396240/ss_49005bce3e915a90065465407a6fc998fa0f1011.1920x1080.jpg?t=1723132341,https://shared.akamai.steamstatic.com/store_item_assets/steam/apps/2396240/ss_ccc6348ac31bd2f05df67f442145ef4b490bb57e.1920x1080.jpg?t=1723132341,https://shared.akamai.steamstatic.com/store_item_assets/steam/apps/2396240/ss_6d4152271981dc43a6a9d6dafb08ff86e6f43086.1920x1080.jpg?t=1723132341,https://shared.akamai.steamstatic.com/store_item_assets/steam/apps/2396240/ss_17fa4e68061c35d1448a9c212e444ce6b237b007.1920x1080.jpg?t=1723132341,https://shared.akamai.steamstatic.com/store_item_assets/steam/apps/2396240/ss_cad1ccc375ff5f280af980321ee5454b586bfd7a.1920x1080.jpg?t=1723132341,https://shared.akamai.steamstatic.com/store_item_assets/steam/apps/2396240/ss_b2a14c2cf7dfe2ffad612bf20e2cbae1373838ef.1920x1080.jpg?t=1723132341,https://shared.akamai.steamstatic.com/store_item_assets/steam/apps/2396240/ss_6f576e9a8e81c1c642c241047dea62e331bf1690.1920x1080.jpg?t=1723132341,https://shared.akamai.steamstatic.com/store_item_assets/steam/apps/2396240/ss_912376105c6e7d74a736e718a1d0017fa3a97c1d.1920x1080.jpg?t=1723132341,https://shared.akamai.steamstatic.com/store_item_assets/steam/apps/2396240/ss_87ed389d79d249624d385eb3a7ccf1719a77ee4d.1920x1080.jpg?t=1723132341',
#        'https://shared.akamai.steamstatic.com/store_item_assets/steam/apps/2305840/ss_d3ee13457298398719023fcbc8276cc0c0d17d72.1920x1080.jpg?t=1723195692,https://shared.akamai.steamstatic.com/store_item_assets/steam/apps/2305840/ss_d4714cf64cf250d843157129ed318565619124de.1920x1080.jpg?t=1723195692,https://shared.akamai.steamstatic.com/store_item_assets/steam/apps/2305840/ss_b0fa2769d024f88bb5036ede0d911b3a3e2c2c6b.1920x1080.jpg?t=1723195692,https://shared.akamai.steamstatic.com/store_item_assets/steam/apps/2305840/ss_a1de47564302f566afb760c0cfa1eb61eec52496.1920x1080.jpg?t=1723195692,https://shared.akamai.steamstatic.com/store_item_assets/steam/apps/2305840/ss_5854d4cab322d403c2e6017d280e5bd1d9526f31.1920x1080.jpg?t=1723195692,https://shared.akamai.steamstatic.com/store_item_assets/steam/apps/2305840/ss_9934cb3e03cba2440f6eac8631fa69b3ce6b4d7d.1920x1080.jpg?t=1723195692,https://shared.akamai.steamstatic.com/store_item_assets/steam/apps/2305840/ss_c7a9554db2af32872f381dbfbf294b6f0e7082d0.1920x1080.jpg?t=1723195692,https://shared.akamai.steamstatic.com/store_item_assets/steam/apps/2305840/ss_461f0794e63768bb991735c69b6ba7c10d741b5b.1920x1080.jpg?t=1723195692,https://shared.akamai.steamstatic.com/store_item_assets/steam/apps/2305840/ss_57492ca963e4c9878cf704a411b9f12aedc85b24.1920x1080.jpg?t=1723195692,https://shared.akamai.steamstatic.com/store_item_assets/steam/apps/2305840/ss_f4ca7ab12d6a784cca9a6aaf1cfbefb7c8a586a3.1920x1080.jpg?t=1723195692',
#        'https://shared.akamai.steamstatic.com/store_item_assets/steam/apps/2366980/ss_928c3226d2a3723e29e63cc19c13f47bd88faa86.1920x1080.jpg?t=1722529446,https://shared.akamai.steamstatic.com/store_item_assets/steam/apps/2366980/ss_c624fda9191859781cf9b34a6563c1953d977800.1920x1080.jpg?t=1722529446,https://shared.akamai.steamstatic.com/store_item_assets/steam/apps/2366980/ss_179e32f0cddfa678a826750968325810bf83e6b3.1920x1080.jpg?t=1722529446,https://shared.akamai.steamstatic.com/store_item_assets/steam/apps/2366980/ss_dfd24b8c643032dea42919d1584b94f100dccd2b.1920x1080.jpg?t=1722529446,https://shared.akamai.steamstatic.com/store_item_assets/steam/apps/2366980/ss_d9dc1ea31fae0bbe198885ef23ed9a6348190a5f.1920x1080.jpg?t=1722529446,https://shared.akamai.steamstatic.com/store_item_assets/steam/apps/2366980/ss_21e18c4d8f5e892281a5f6877abb878812379141.1920x1080.jpg?t=1722529446,https://shared.akamai.steamstatic.com/store_item_assets/steam/apps/2366980/ss_e421026db9d4c7243bd50a10286dd91fbe73b66c.1920x1080.jpg?t=1722529446,https://shared.akamai.steamstatic.com/store_item_assets/steam/apps/2366980/ss_5b30e20935577fce25ecbbc5de88de4e90360ba1.1920x1080.jpg?t=1722529446,https://shared.akamai.steamstatic.com/store_item_assets/steam/apps/2366980/ss_7ab5b787a84dda59e58652ececd904a6ea391fe3.1920x1080.jpg?t=1722529446'],
#       dtype=object)

# %%
df['screenshots'] = df['screenshots'].str.split(',').values

# %%
df['screenshots'].values
# Out:
# array([list(['https://cdn.akamai.steamstatic.com/steam/apps/1026420/ss_6a8fc6b2c001cf47ee616159e0b9038ec7bc5866.1920x1080.jpg?t=1657716289', 'https://cdn.akamai.steamstatic.com/steam/apps/1026420/ss_df4fa138bce054ecf5b5364f425a5883f3d2a14d.1920x1080.jpg?t=1657716289', 'https://cdn.akamai.steamstatic.com/steam/apps/1026420/ss_a2b404c25b07dd62106c14e7db330e5af778564e.1920x1080.jpg?t=1657716289', 'https://cdn.akamai.steamstatic.com/steam/apps/1026420/ss_68564ec1bb8081be3d2cc89e36a00694370b6f6a.1920x1080.jpg?t=1657716289', 'https://cdn.akamai.steamstatic.com/steam/apps/1026420/ss_d53b8acaaa4fdc3af645c644c3be2cffcd2620bf.1920x1080.jpg?t=1657716289', 'https://cdn.akamai.steamstatic.com/steam/apps/1026420/ss_976f0a68b1c4511162e59732014e69afb3680655.1920x1080.jpg?t=1657716289', 'https://cdn.akamai.steamstatic.com/steam/apps/1026420/ss_f0424f82e2023ce101e6e04530d895169a300095.1920x1080.jpg?t=1657716289', 'https://cdn.akamai.steamstatic.com/steam/apps/1026420/ss_dd10c156c29304af6ec37f06923e023b7a3eec57.1920x1080.jpg?t=1657716289']),
#        list(['https://cdn.akamai.steamstatic.com/steam/apps/22670/ss_12bdbc7f444c7e99c2132f05d1945b9036e999cb.1920x1080.jpg?t=1655730869', 'https://cdn.akamai.steamstatic.com/steam/apps/22670/ss_7a6d2e8c4866940f5f1571f36eba50c1b4341149.1920x1080.jpg?t=1655730869', 'https://cdn.akamai.steamstatic.com/steam/apps/22670/ss_76aac22003177dc2e9136f95bb8908931807040c.1920x1080.jpg?t=1655730869', 'https://cdn.akamai.steamstatic.com/steam/apps/22670/ss_2d4bdc8ed2a931aad47964cce85e5301fb4a4dea.1920x1080.jpg?t=1655730869', 'https://cdn.akamai.steamstatic.com/steam/apps/22670/ss_290e7da46439abfbd196924daf9f7b51155a043b.1920x1080.jpg?t=1655730869', 'https://cdn.akamai.steamstatic.com/steam/apps/22670/ss_86fe862196b13c922889b9a13eb3b0ba39d914c3.1920x1080.jpg?t=1655730869', 'https://cdn.akamai.steamstatic.com/steam/apps/22670/ss_386f1b537acf9102c8896f5fa1ad4f91a3a3af1b.1920x1080.jpg?t=1655730869', 'https://cdn.akamai.steamstatic.com/steam/apps/22670/ss_9ce9bb8f24a8d6205d417097cbcc9cf084a4b5b2.1920x1080.jpg?t=1655730869', 'https://cdn.akamai.steamstatic.com/steam/apps/22670/ss_7b201de1cef3b955a2d3236fb56f342e4ffdcc06.1920x1080.jpg?t=1655730869', 'https://cdn.akamai.steamstatic.com/steam/apps/22670/ss_940cd02b37f6a9ae8ea8ff93f3c16b39bf89743a.1920x1080.jpg?t=1655730869']),
#        list(['https://cdn.akamai.steamstatic.com/steam/apps/231330/ss_e53512c37c3b4927efec4ef2dccec62084af5a57.1920x1080.jpg?t=1561964976', 'https://cdn.akamai.steamstatic.com/steam/apps/231330/ss_e5660e00480523bab71e5758c6606de0abf9bebf.1920x1080.jpg?t=1561964976', 'https://cdn.akamai.steamstatic.com/steam/apps/231330/ss_eb71d7cb42e05f68b50d14a3d2a8bd60145acb98.1920x1080.jpg?t=1561964976', 'https://cdn.akamai.steamstatic.com/steam/apps/231330/ss_6ce7d35e3e24b9f5d35d8ebb27a0ca793ad08361.1920x1080.jpg?t=1561964976', 'https://cdn.akamai.steamstatic.com/steam/apps/231330/ss_8b3791b17d55df0461262b23192a725f80de2593.1920x1080.jpg?t=1561964976', 'https://cdn.akamai.steamstatic.com/steam/apps/231330/ss_d30c427a0ce9d8b04ca0809ae71f5356e0204e73.1920x1080.jpg?t=1561964976', 'https://cdn.akamai.steamstatic.com/steam/apps/231330/ss_3109f03c94c404b51e5775ad86a60e81e132ad19.1920x1080.jpg?t=1561964976', 'https://cdn.akamai.steamstatic.com/steam/apps/231330/ss_0ae6376d1947a3907690ed0a725e81d589cf5760.1920x1080.jpg?t=1561964976', 'https://cdn.akamai.steamstatic.com/steam/apps/231330/ss_d4e66c6d44b80b5835acabad30cb60292267e922.1920x1080.jpg?t=1561964976', 'https://cdn.akamai.steamstatic.com/steam/apps/231330/ss_ccc8d733e5f5e565ceaa4be6d8edcf6bdab95079.1920x1080.jpg?t=1561964976', 'https://cdn.akamai.steamstatic.com/steam/apps/231330/ss_b6ef227c36746b589e96d57eb3b09fba2d2c1cc6.1920x1080.jpg?t=1561964976', 'https://cdn.akamai.steamstatic.com/steam/apps/231330/ss_18bb9893a8c153b743417f8ada5526d7e172170b.1920x1080.jpg?t=1561964976', 'https://cdn.akamai.steamstatic.com/steam/apps/231330/ss_5b3342439c4a7fcb93ab253be906817f849da3e7.1920x1080.jpg?t=1561964976', 'https://cdn.akamai.steamstatic.com/steam/apps/231330/ss_6338aab220eabdf66b1137d0ad71278b255ce39f.1920x1080.jpg?t=1561964976', 'https://cdn.akamai.steamstatic.com/steam/apps/231330/ss_8292d4dd3ea71a927d2b8b09c41a4856e72b59fd.1920x1080.jpg?t=1561964976', 'https://cdn.akamai.steamstatic.com/steam/apps/231330/ss_27bd5bdb26ed53217bf31d013e795d0d5376e880.1920x1080.jpg?t=1561964976', 'https://cdn.akamai.steamstatic.com/steam/apps/231330/ss_aac2586e6d2a200f246c11f399216576bad38dc1.1920x1080.jpg?t=1561964976', 'https://cdn.akamai.steamstatic.com/steam/apps/231330/ss_aac19564f29ac14d3b70f1bbae5d6233284530cc.1920x1080.jpg?t=1561964976', 'https://cdn.akamai.steamstatic.com/steam/apps/231330/ss_763fee337f9ec69f6c6724460264e7c92d09c1ba.1920x1080.jpg?t=1561964976', 'https://cdn.akamai.steamstatic.com/steam/apps/231330/ss_f70a0c7cc773129ef12bd9ebcaf9bfcba74c637c.1920x1080.jpg?t=1561964976']),
#        ...,
#        list(['https://shared.akamai.steamstatic.com/store_item_assets/steam/apps/2396240/ss_19c1be291bc0e198b7d6199f536e699399977c3c.1920x1080.jpg?t=1723132341', 'https://shared.akamai.steamstatic.com/store_item_assets/steam/apps/2396240/ss_11b2e0326139aea79fb34abe300fbe729fd5a174.1920x1080.jpg?t=1723132341', 'https://shared.akamai.steamstatic.com/store_item_assets/steam/apps/2396240/ss_49005bce3e915a90065465407a6fc998fa0f1011.1920x1080.jpg?t=1723132341', 'https://shared.akamai.steamstatic.com/store_item_assets/steam/apps/2396240/ss_ccc6348ac31bd2f05df67f442145ef4b490bb57e.1920x1080.jpg?t=1723132341', 'https://shared.akamai.steamstatic.com/store_item_assets/steam/apps/2396240/ss_6d4152271981dc43a6a9d6dafb08ff86e6f43086.1920x1080.jpg?t=1723132341', 'https://shared.akamai.steamstatic.com/store_item_assets/steam/apps/2396240/ss_17fa4e68061c35d1448a9c212e444ce6b237b007.1920x1080.jpg?t=1723132341', 'https://shared.akamai.steamstatic.com/store_item_assets/steam/apps/2396240/ss_cad1ccc375ff5f280af980321ee5454b586bfd7a.1920x1080.jpg?t=1723132341', 'https://shared.akamai.steamstatic.com/store_item_assets/steam/apps/2396240/ss_b2a14c2cf7dfe2ffad612bf20e2cbae1373838ef.1920x1080.jpg?t=1723132341', 'https://shared.akamai.steamstatic.com/store_item_assets/steam/apps/2396240/ss_6f576e9a8e81c1c642c241047dea62e331bf1690.1920x1080.jpg?t=1723132341', 'https://shared.akamai.steamstatic.com/store_item_assets/steam/apps/2396240/ss_912376105c6e7d74a736e718a1d0017fa3a97c1d.1920x1080.jpg?t=1723132341', 'https://shared.akamai.steamstatic.com/store_item_assets/steam/apps/2396240/ss_87ed389d79d249624d385eb3a7ccf1719a77ee4d.1920x1080.jpg?t=1723132341']),
#        list(['https://shared.akamai.steamstatic.com/store_item_assets/steam/apps/2305840/ss_d3ee13457298398719023fcbc8276cc0c0d17d72.1920x1080.jpg?t=1723195692', 'https://shared.akamai.steamstatic.com/store_item_assets/steam/apps/2305840/ss_d4714cf64cf250d843157129ed318565619124de.1920x1080.jpg?t=1723195692', 'https://shared.akamai.steamstatic.com/store_item_assets/steam/apps/2305840/ss_b0fa2769d024f88bb5036ede0d911b3a3e2c2c6b.1920x1080.jpg?t=1723195692', 'https://shared.akamai.steamstatic.com/store_item_assets/steam/apps/2305840/ss_a1de47564302f566afb760c0cfa1eb61eec52496.1920x1080.jpg?t=1723195692', 'https://shared.akamai.steamstatic.com/store_item_assets/steam/apps/2305840/ss_5854d4cab322d403c2e6017d280e5bd1d9526f31.1920x1080.jpg?t=1723195692', 'https://shared.akamai.steamstatic.com/store_item_assets/steam/apps/2305840/ss_9934cb3e03cba2440f6eac8631fa69b3ce6b4d7d.1920x1080.jpg?t=1723195692', 'https://shared.akamai.steamstatic.com/store_item_assets/steam/apps/2305840/ss_c7a9554db2af32872f381dbfbf294b6f0e7082d0.1920x1080.jpg?t=1723195692', 'https://shared.akamai.steamstatic.com/store_item_assets/steam/apps/2305840/ss_461f0794e63768bb991735c69b6ba7c10d741b5b.1920x1080.jpg?t=1723195692', 'https://shared.akamai.steamstatic.com/store_item_assets/steam/apps/2305840/ss_57492ca963e4c9878cf704a411b9f12aedc85b24.1920x1080.jpg?t=1723195692', 'https://shared.akamai.steamstatic.com/store_item_assets/steam/apps/2305840/ss_f4ca7ab12d6a784cca9a6aaf1cfbefb7c8a586a3.1920x1080.jpg?t=1723195692']),
#        list(['https://shared.akamai.steamstatic.com/store_item_assets/steam/apps/2366980/ss_928c3226d2a3723e29e63cc19c13f47bd88faa86.1920x1080.jpg?t=1722529446', 'https://shared.akamai.steamstatic.com/store_item_assets/steam/apps/2366980/ss_c624fda9191859781cf9b34a6563c1953d977800.1920x1080.jpg?t=1722529446', 'https://shared.akamai.steamstatic.com/store_item_assets/steam/apps/2366980/ss_179e32f0cddfa678a826750968325810bf83e6b3.1920x1080.jpg?t=1722529446', 'https://shared.akamai.steamstatic.com/store_item_assets/steam/apps/2366980/ss_dfd24b8c643032dea42919d1584b94f100dccd2b.1920x1080.jpg?t=1722529446', 'https://shared.akamai.steamstatic.com/store_item_assets/steam/apps/2366980/ss_d9dc1ea31fae0bbe198885ef23ed9a6348190a5f.1920x1080.jpg?t=1722529446', 'https://shared.akamai.steamstatic.com/store_item_assets/steam/apps/2366980/ss_21e18c4d8f5e892281a5f6877abb878812379141.1920x1080.jpg?t=1722529446', 'https://shared.akamai.steamstatic.com/store_item_assets/steam/apps/2366980/ss_e421026db9d4c7243bd50a10286dd91fbe73b66c.1920x1080.jpg?t=1722529446', 'https://shared.akamai.steamstatic.com/store_item_assets/steam/apps/2366980/ss_5b30e20935577fce25ecbbc5de88de4e90360ba1.1920x1080.jpg?t=1722529446', 'https://shared.akamai.steamstatic.com/store_item_assets/steam/apps/2366980/ss_7ab5b787a84dda59e58652ececd904a6ea391fe3.1920x1080.jpg?t=1722529446'])],
#       dtype=object)

# %%
df['movies'].values
# Out:
# array(['http://cdn.akamai.steamstatic.com/steam/apps/256763461/movie_max.mp4?t=1573634285,http://cdn.akamai.steamstatic.com/steam/apps/256743901/movie_max.mp4?t=1551209280',
#        nan,
#        'http://cdn.akamai.steamstatic.com/steam/apps/2029553/movie_max.mp4?t=1490862566,http://cdn.akamai.steamstatic.com/steam/apps/2030185/movie_max.mp4?t=1490862575,http://cdn.akamai.steamstatic.com/steam/apps/2028438/movie_max.mp4?t=1490862584,http://cdn.akamai.steamstatic.com/steam/apps/2030143/movie_max.mp4?t=1493809128,http://cdn.akamai.steamstatic.com/steam/apps/2030092/movie_max.mp4?t=1493809135',
#        ...,
#        'http://video.akamai.steamstatic.com/store_trailers/257043794/movie_max.mp4?t=1723129231,http://video.akamai.steamstatic.com/store_trailers/257028248/movie_max.mp4?t=1717518619,http://video.akamai.steamstatic.com/store_trailers/257016381/movie_max.mp4?t=1713363951,http://video.akamai.steamstatic.com/store_trailers/257023127/movie_max.mp4?t=1716068557,http://video.akamai.steamstatic.com/store_trailers/257019542/movie_max.mp4?t=1714749493',
#        'http://video.akamai.steamstatic.com/store_trailers/257043804/movie_max.mp4?t=1723126060,http://video.akamai.steamstatic.com/store_trailers/257040209/movie_max.mp4?t=1721915988,http://video.akamai.steamstatic.com/store_trailers/257015301/movie_max.mp4?t=1713364264',
#        'http://video.akamai.steamstatic.com/store_trailers/257040308/movie_max.mp4?t=1722528754,http://video.akamai.steamstatic.com/store_trailers/256964057/movie_max.mp4?t=1704989969,http://video.akamai.steamstatic.com/store_trailers/257026995/movie_max.mp4?t=1717790760'],
#       dtype=object)

# %%
df['movies'] = df['movies'].str.split(',').values

# %%
df['movies'].values
# Out:
# array([list(['http://cdn.akamai.steamstatic.com/steam/apps/256763461/movie_max.mp4?t=1573634285', 'http://cdn.akamai.steamstatic.com/steam/apps/256743901/movie_max.mp4?t=1551209280']),
#        nan,
#        list(['http://cdn.akamai.steamstatic.com/steam/apps/2029553/movie_max.mp4?t=1490862566', 'http://cdn.akamai.steamstatic.com/steam/apps/2030185/movie_max.mp4?t=1490862575', 'http://cdn.akamai.steamstatic.com/steam/apps/2028438/movie_max.mp4?t=1490862584', 'http://cdn.akamai.steamstatic.com/steam/apps/2030143/movie_max.mp4?t=1493809128', 'http://cdn.akamai.steamstatic.com/steam/apps/2030092/movie_max.mp4?t=1493809135']),
#        ...,
#        list(['http://video.akamai.steamstatic.com/store_trailers/257043794/movie_max.mp4?t=1723129231', 'http://video.akamai.steamstatic.com/store_trailers/257028248/movie_max.mp4?t=1717518619', 'http://video.akamai.steamstatic.com/store_trailers/257016381/movie_max.mp4?t=1713363951', 'http://video.akamai.steamstatic.com/store_trailers/257023127/movie_max.mp4?t=1716068557', 'http://video.akamai.steamstatic.com/store_trailers/257019542/movie_max.mp4?t=1714749493']),
#        list(['http://video.akamai.steamstatic.com/store_trailers/257043804/movie_max.mp4?t=1723126060', 'http://video.akamai.steamstatic.com/store_trailers/257040209/movie_max.mp4?t=1721915988', 'http://video.akamai.steamstatic.com/store_trailers/257015301/movie_max.mp4?t=1713364264']),
#        list(['http://video.akamai.steamstatic.com/store_trailers/257040308/movie_max.mp4?t=1722528754', 'http://video.akamai.steamstatic.com/store_trailers/256964057/movie_max.mp4?t=1704989969', 'http://video.akamai.steamstatic.com/store_trailers/257026995/movie_max.mp4?t=1717790760'])],
#       dtype=object)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5061 entries, 0 to 5060
# Data columns (total 50 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   appid                     5061 non-null   int64
#  1   normalized_name           5061 non-null   object
#  2   name                      5061 non-null   object
#  3   release_date              5061 non-null   datetime64[ns]
#  4   peak_ccu                  5061 non-null   float64
#  5   required_age              5061 non-null   int64
#  6   dlc_count                 5061 non-null   int64
#  7   about_the_game            5045 non-null   object
#  8   summary                   3021 non-null   object
#  9   supported_languages       5061 non-null   object
#  10  full_audio_languages      5061 non-null   object
#  11  some_reviews              2248 non-null   object
#  12  reviews_total             5061 non-null   float64
#  13  reviews_score_fancy       5061 non-null   object
#  14  header_image              5061 non-null   object
#  15  windows                   5061 non-null   bool
#  16  mac                       5061 non-null   bool
#  17  linux                     5061 non-null   bool
#  18  metacritic_url            5061 non-null   object
#  19  achievements              5061 non-null   int64
#  20  recommendations           5061 non-null   int64
#  21  notes                     591 non-null    object
#  22  developers                5061 non-null   object
#  23  publishers                5037 non-null   object
#  24  categories                5059 non-null   object
#  25  genres                    5057 non-null   object
#  26  tags                      5031 non-null   object
#  27  screenshots               5061 non-null   object
#  28  movies                    4500 non-null   object
#  29  plays                     3024 non-null   object
#  30  playing                   3024 non-null   object
#  31  backlogs                  3024 non-null   object
#  32  wishlist                  3024 non-null   object
#  33  lists                     3024 non-null   object
#  34  steam_page                4583 non-null   object
#  35  platforms                 3024 non-null   object
#  36  platforms_2               3384 non-null   object
#  37  infos_per_platform        3384 non-null   object
#  38  revenue_estimated         4583 non-null   object
#  39  meta_critic_score         5061 non-null   float64
#  40  new_positive              5061 non-null   float64
#  41  new_negative              5061 non-null   float64
#  42  new_min_estimated_owners  5061 non-null   float64
#  43  new_max_estimated_owners  5061 non-null   float64
#  44  new_average_forever       5061 non-null   float64
#  45  new_median_forever        5061 non-null   float64
#  46  new_price                 4936 non-null   float64
#  47  new_initialprice          4583 non-null   float64
#  48  new_discount              4583 non-null   float64
#  49  metacritic_user_score     4743 non-null   float64
# dtypes: bool(3), datetime64[ns](1), float64(13), int64(5), object(28)
# memory usage: 1.8+ MB

# %%
df['plays']
# Out:
# 0        NaN
# 1         34
# 2        NaN
# 3       7.8K
# 4       5.1K
#         ...
# 5056       0
# 5057     NaN
# 5058     NaN
# 5059     NaN
# 5060     NaN
# Name: plays, Length: 5061, dtype: object

# %%
df['plays'] = df['plays'].apply(dealing_with_Ks)

# %%
df['plays']
# Out:
# 0          NaN
# 1         34.0
# 2          NaN
# 3       7800.0
# 4       5100.0
#          ...
# 5056       0.0
# 5057       NaN
# 5058       NaN
# 5059       NaN
# 5060       NaN
# Name: plays, Length: 5061, dtype: float64

# %%
df['plays'].isna().value_counts()
# Out:
# plays
# False    3024
# True     2037
# Name: count, dtype: int64

# %%
(df['plays'] == 0).value_counts()
# Out:
# plays
# False    4999
# True       62
# Name: count, dtype: int64

# %%
df['playing']
# Out:
# 0       NaN
# 1         1
# 2       NaN
# 3       203
# 4       191
#        ...
# 5056      0
# 5057    NaN
# 5058    NaN
# 5059    NaN
# 5060    NaN
# Name: playing, Length: 5061, dtype: object

# %%
df['playing'] = df['playing'].apply(dealing_with_Ks)

# %%
df['playing'].isna().value_counts()
# Out:
# playing
# False    3024
# True     2037
# Name: count, dtype: int64

# %%
(df['playing'] == 0).value_counts()
# Out:
# playing
# False    4449
# True      612
# Name: count, dtype: int64

# %%
df['backlogs']
# Out:
# 0        NaN
# 1         58
# 2        NaN
# 3       1.5K
# 4        461
#         ...
# 5056       0
# 5057     NaN
# 5058     NaN
# 5059     NaN
# 5060     NaN
# Name: backlogs, Length: 5061, dtype: object

# %%
df['backlogs'] = df['backlogs'].apply(dealing_with_Ks)

# %%
df['backlogs']
# Out:
# 0          NaN
# 1         58.0
# 2          NaN
# 3       1500.0
# 4        461.0
#          ...
# 5056       0.0
# 5057       NaN
# 5058       NaN
# 5059       NaN
# 5060       NaN
# Name: backlogs, Length: 5061, dtype: float64

# %%
df['backlogs'].isna().value_counts()
# Out:
# backlogs
# False    3024
# True     2037
# Name: count, dtype: int64

# %%
(df['backlogs'] == 0).value_counts()
# Out:
# backlogs
# False    5025
# True       36
# Name: count, dtype: int64

# %%
df['wishlist']
# Out:
# 0       NaN
# 1         5
# 2       NaN
# 3       542
# 4       233
#        ...
# 5056      0
# 5057    NaN
# 5058    NaN
# 5059    NaN
# 5060    NaN
# Name: wishlist, Length: 5061, dtype: object

# %%
df['wishlist'] = df['wishlist'].apply(dealing_with_Ks)

# %%
df['wishlist'].isna().value_counts()
# Out:
# wishlist
# False    3024
# True     2037
# Name: count, dtype: int64

# %%
(df['wishlist'] == 0).value_counts()
# Out:
# wishlist
# False    4971
# True       90
# Name: count, dtype: int64

# %%
df['lists']
# Out:
# 0       NaN
# 1        26
# 2       NaN
# 3       649
# 4       487
#        ...
# 5056      2
# 5057    NaN
# 5058    NaN
# 5059    NaN
# 5060    NaN
# Name: lists, Length: 5061, dtype: object

# %%
df['lists'] = df['lists'].apply(dealing_with_Ks)

# %%
df['lists'].isna().value_counts()
# Out:
# lists
# False    3024
# True     2037
# Name: count, dtype: int64

# %%
(df['lists'] == 0).value_counts()
# Out:
# lists
# False    4994
# True       67
# Name: count, dtype: int64

# %%
backloggd = pd.read_csv('backloggd_contatori.csv')

# %%
df = df.merge(backloggd, left_on='appid', right_on='appid', how='left')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5061 entries, 0 to 5060
# Data columns (total 58 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   appid                     5061 non-null   int64
#  1   normalized_name           5061 non-null   object
#  2   name                      5061 non-null   object
#  3   release_date              5061 non-null   datetime64[ns]
#  4   peak_ccu                  5061 non-null   float64
#  5   required_age              5061 non-null   int64
#  6   dlc_count                 5061 non-null   int64
#  7   about_the_game            5045 non-null   object
#  8   summary                   3021 non-null   object
#  9   supported_languages       5061 non-null   object
#  10  full_audio_languages      5061 non-null   object
#  11  some_reviews              2248 non-null   object
#  12  reviews_total             5061 non-null   float64
#  13  reviews_score_fancy       5061 non-null   object
#  14  header_image              5061 non-null   object
#  15  windows                   5061 non-null   bool
#  16  mac                       5061 non-null   bool
#  17  linux                     5061 non-null   bool
#  18  metacritic_url            5061 non-null   object
#  19  achievements              5061 non-null   int64
#  20  recommendations           5061 non-null   int64
#  21  notes                     591 non-null    object
#  22  developers                5061 non-null   object
#  23  publishers                5037 non-null   object
#  24  categories                5059 non-null   object
#  25  genres                    5057 non-null   object
#  26  tags                      5031 non-null   object
#  27  screenshots               5061 non-null   object
#  28  movies                    4500 non-null   object
#  29  plays                     3024 non-null   float64
#  30  playing                   3024 non-null   float64
#  31  backlogs                  3024 non-null   float64
#  32  wishlist                  3024 non-null   float64
#  33  lists                     3024 non-null   float64
#  34  steam_page                4583 non-null   object
#  35  platforms                 3024 non-null   object
#  36  platforms_2               3384 non-null   object
#  37  infos_per_platform        3384 non-null   object
#  38  revenue_estimated         4583 non-null   object
#  39  meta_critic_score         5061 non-null   float64
#  40  new_positive              5061 non-null   float64
#  41  new_negative              5061 non-null   float64
#  42  new_min_estimated_owners  5061 non-null   float64
#  43  new_max_estimated_owners  5061 non-null   float64
#  44  new_average_forever       5061 non-null   float64
#  45  new_median_forever        5061 non-null   float64
#  46  new_price                 4936 non-null   float64
#  47  new_initialprice          4583 non-null   float64
#  48  new_discount              4583 non-null   float64
#  49  metacritic_user_score     4743 non-null   float64
#  50  game                      5061 non-null   object
#  51  Plays                     5058 non-null   float64
#  52  Playing                   5058 non-null   float64
#  53  Backlogs                  5058 non-null   float64
#  54  Wishlist                  5058 non-null   float64
#  55  Lists                     5058 non-null   float64
#  56  Reviews                   5058 non-null   float64
#  57  Likes                     4525 non-null   float64
# dtypes: bool(3), datetime64[ns](1), float64(25), int64(5), object(24)
# memory usage: 2.1+ MB

# %%
df.drop(columns=['plays','playing','backlogs','wishlist','lists','game'],inplace=True)
df.rename(columns={'Plays':'plays_backloggd', 'Playing':'playing_backloggd', 'Backlogs':'backlogs_backloggd','Wishlist':'wishlist_backloggd',
                   'Lists':'lists_backloggd','Reviews':'reviews_backloggd','Likes':'likes_backloggd'}, inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5061 entries, 0 to 5060
# Data columns (total 52 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   appid                     5061 non-null   int64
#  1   normalized_name           5061 non-null   object
#  2   name                      5061 non-null   object
#  3   release_date              5061 non-null   datetime64[ns]
#  4   peak_ccu                  5061 non-null   float64
#  5   required_age              5061 non-null   int64
#  6   dlc_count                 5061 non-null   int64
#  7   about_the_game            5045 non-null   object
#  8   summary                   3021 non-null   object
#  9   supported_languages       5061 non-null   object
#  10  full_audio_languages      5061 non-null   object
#  11  some_reviews              2248 non-null   object
#  12  reviews_total             5061 non-null   float64
#  13  reviews_score_fancy       5061 non-null   object
#  14  header_image              5061 non-null   object
#  15  windows                   5061 non-null   bool
#  16  mac                       5061 non-null   bool
#  17  linux                     5061 non-null   bool
#  18  metacritic_url            5061 non-null   object
#  19  achievements              5061 non-null   int64
#  20  recommendations           5061 non-null   int64
#  21  notes                     591 non-null    object
#  22  developers                5061 non-null   object
#  23  publishers                5037 non-null   object
#  24  categories                5059 non-null   object
#  25  genres                    5057 non-null   object
#  26  tags                      5031 non-null   object
#  27  screenshots               5061 non-null   object
#  28  movies                    4500 non-null   object
#  29  steam_page                4583 non-null   object
#  30  platforms                 3024 non-null   object
#  31  platforms_2               3384 non-null   object
#  32  infos_per_platform        3384 non-null   object
#  33  revenue_estimated         4583 non-null   object
#  34  meta_critic_score         5061 non-null   float64
#  35  new_positive              5061 non-null   float64
#  36  new_negative              5061 non-null   float64
#  37  new_min_estimated_owners  5061 non-null   float64
#  38  new_max_estimated_owners  5061 non-null   float64
#  39  new_average_forever       5061 non-null   float64
#  40  new_median_forever        5061 non-null   float64
#  41  new_price                 4936 non-null   float64
#  42  new_initialprice          4583 non-null   float64
#  43  new_discount              4583 non-null   float64
#  44  metacritic_user_score     4743 non-null   float64
#  45  plays_backloggd           5058 non-null   float64
#  46  playing_backloggd         5058 non-null   float64
#  47  backlogs_backloggd        5058 non-null   float64
#  48  wishlist_backloggd        5058 non-null   float64
#  49  lists_backloggd           5058 non-null   float64
#  50  reviews_backloggd         5058 non-null   float64
#  51  likes_backloggd           4525 non-null   float64
# dtypes: bool(3), datetime64[ns](1), float64(20), int64(5), object(23)
# memory usage: 1.9+ MB

# %%
df['steam_page'].values
# Out:
# array(['https://store.steampowered.com/app/1026420',
#        'https://store.steampowered.com/app/22670',
#        'https://store.steampowered.com/app/231330', ..., nan, nan, nan],
#       dtype=object)

# %%
def steam_url_getter(appid : str) -> str:
    return 'https://store.steampowered.com/app/' + str(appid)

# %%
for i, row in df.iterrows():
    if pd.isna(row['steam_page']):
        df.at[i, 'steam_page'] = steam_url_getter(row['appid'])

# %%
df['steam_page'].values
# Out:
# array(['https://store.steampowered.com/app/1026420',
#        'https://store.steampowered.com/app/22670',
#        'https://store.steampowered.com/app/231330', ...,
#        'https://store.steampowered.com/app/2396240',
#        'https://store.steampowered.com/app/2305840',
#        'https://store.steampowered.com/app/2366980'], dtype=object)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5061 entries, 0 to 5060
# Data columns (total 52 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   appid                     5061 non-null   int64
#  1   normalized_name           5061 non-null   object
#  2   name                      5061 non-null   object
#  3   release_date              5061 non-null   datetime64[ns]
#  4   peak_ccu                  5061 non-null   float64
#  5   required_age              5061 non-null   int64
#  6   dlc_count                 5061 non-null   int64
#  7   about_the_game            5045 non-null   object
#  8   summary                   3021 non-null   object
#  9   supported_languages       5061 non-null   object
#  10  full_audio_languages      5061 non-null   object
#  11  some_reviews              2248 non-null   object
#  12  reviews_total             5061 non-null   float64
#  13  reviews_score_fancy       5061 non-null   object
#  14  header_image              5061 non-null   object
#  15  windows                   5061 non-null   bool
#  16  mac                       5061 non-null   bool
#  17  linux                     5061 non-null   bool
#  18  metacritic_url            5061 non-null   object
#  19  achievements              5061 non-null   int64
#  20  recommendations           5061 non-null   int64
#  21  notes                     591 non-null    object
#  22  developers                5061 non-null   object
#  23  publishers                5037 non-null   object
#  24  categories                5059 non-null   object
#  25  genres                    5057 non-null   object
#  26  tags                      5031 non-null   object
#  27  screenshots               5061 non-null   object
#  28  movies                    4500 non-null   object
#  29  steam_page                5061 non-null   object
#  30  platforms                 3024 non-null   object
#  31  platforms_2               3384 non-null   object
#  32  infos_per_platform        3384 non-null   object
#  33  revenue_estimated         4583 non-null   object
#  34  meta_critic_score         5061 non-null   float64
#  35  new_positive              5061 non-null   float64
#  36  new_negative              5061 non-null   float64
#  37  new_min_estimated_owners  5061 non-null   float64
#  38  new_max_estimated_owners  5061 non-null   float64
#  39  new_average_forever       5061 non-null   float64
#  40  new_median_forever        5061 non-null   float64
#  41  new_price                 4936 non-null   float64
#  42  new_initialprice          4583 non-null   float64
#  43  new_discount              4583 non-null   float64
#  44  metacritic_user_score     4743 non-null   float64
#  45  plays_backloggd           5058 non-null   float64
#  46  playing_backloggd         5058 non-null   float64
#  47  backlogs_backloggd        5058 non-null   float64
#  48  wishlist_backloggd        5058 non-null   float64
#  49  lists_backloggd           5058 non-null   float64
#  50  reviews_backloggd         5058 non-null   float64
#  51  likes_backloggd           4525 non-null   float64
# dtypes: bool(3), datetime64[ns](1), float64(20), int64(5), object(23)
# memory usage: 1.9+ MB

# %%
df['platforms']
# Out:
# 0                                                     NaN
# 1       ['Windows PC', 'Xbox 360', 'Linux', 'PlayStati...
# 2                                                     NaN
# 3       ['Windows PC', 'PlayStation 4', 'Xbox One', 'G...
# 4               ['Windows PC', 'Xbox One', 'Xbox Series']
#                               ...
# 5056                                       ['Windows PC']
# 5057                                                  NaN
# 5058                                                  NaN
# 5059                                                  NaN
# 5060                                                  NaN
# Name: platforms, Length: 5061, dtype: object

# %%
for i, row in df.iterrows():
    if isinstance(row['platforms'], str):
        df.at[i, 'platforms'] = eval(row['platforms'])

# %%
df['platforms'].values
# Out:
# array([nan, list(['Windows PC', 'Xbox 360', 'Linux', 'PlayStation 3']),
#        nan, ..., nan, nan, nan], dtype=object)

# %%
temp_list = list()
for sublist in df['platforms'].values:
    if isinstance(sublist, list):
        for item in sublist:
            temp_list.append(item)

unique_platforms = list(set(temp_list))

# %%
unique_platforms
# Out:
# ['Mobile',
#  'Daydream',
#  'PC DOS',
#  'Game Boy Color',
#  'Family Computer (FAMICOM)',
#  'Sega Game Gear',
#  'NES',
#  'Neo Geo CD',
#  'Philips CD-i',
#  'SNES',
#  'Windows Phone',
#  'Atari Jaguar CD',
#  'Neo Geo AES',
#  'Sega Mega Drive/Genesis',
#  'Nintendo GameCube',
#  'New Nintendo 3DS',
#  'Game Boy Advance',
#  'Google Stadia',
#  'Game Boy',
#  'Playstation VR2',
#  'Dreamcast',
#  'Oculus Quest 2',
#  'PlayStation Network',
#  'Oculus Rift',
#  'Nintendo Switch',
#  'Xbox Series',
#  'BlackBerry OS',
#  'Gear VR',
#  'Xbox One',
#  'PlayStation Vita',
#  'Mac',
#  'Wii U',
#  'Nintendo DS',
#  'Zeebo',
#  'Oculus Quest',
#  'Tapwave Zodiac',
#  'Linux',
#  'PlayStation 2',
#  'SteamVR',
#  'Sega Saturn',
#  'Amazon Fire TV',
#  'PlayStation 3',
#  'PlayStation 4',
#  'Oculus VR',
#  'Arcade',
#  'Web browser',
#  'Sega CD',
#  'PlayStation VR',
#  '3DO Interactive Multiplayer',
#  'Xbox 360',
#  'Xbox',
#  'Nintendo DSi',
#  'Android',
#  'Satellaview',
#  'Atari Jaguar',
#  'Atari ST/STE',
#  'Super Famicom',
#  'iOS',
#  'Windows PC',
#  'Amiga CD32',
#  'Nintendo 64',
#  'Neo Geo MVS',
#  'Ouya',
#  'PlayStation 5',
#  'Nintendo 3DS',
#  'Wii',
#  'Amiga',
#  'WonderSwan',
#  'PlayStation Portable',
#  'PlayStation',
#  'Windows Mixed Reality',
#  'OnLive Game System',
#  'WonderSwan Color',
#  'N-Gage']

# %%
for i, row in df.iterrows():
    if isinstance(row['platforms_2'], str):
        df.at[i, 'platforms_2'] = eval(row['platforms_2'])

# %%
df['platforms_2'].values
# Out:
# array([list(['XOne', 'NS', 'PC', 'PS4']), list(['PSN', 'XBL', 'PC']),
#        list(['X360', 'PC', 'PS3']), ..., nan, nan, nan], dtype=object)

# %%
temp_list = list()
for sublist in df['platforms_2'].values:
    if isinstance(sublist, list):
        for item in sublist:
            temp_list.append(item)

unique_platforms_2 = list(set(temp_list))

# %%
unique_platforms_2
# Out:
# ['GBA',
#  'OSX',
#  'PS5',
#  'OR',
#  'NES',
#  'GBC',
#  'ACPC',
#  'And',
#  'SNES',
#  'PS2',
#  'N64',
#  '2600',
#  'X360',
#  'ApII',
#  'Series',
#  'SCD',
#  'PS3',
#  'WiiU',
#  'GC',
#  'PSN',
#  'XS',
#  'GEN',
#  'DC',
#  'Linux',
#  'SAT',
#  'GG',
#  'Mob',
#  'AJ',
#  'DS',
#  'GB',
#  'XBL',
#  'NGage',
#  'NG',
#  'MSX',
#  'XB',
#  'PC',
#  'WS',
#  'WW',
#  'MS',
#  '3DS',
#  'TG16',
#  'PSV',
#  'DSiW',
#  'iOS',
#  'PCFX',
#  'WinP',
#  'Lynx',
#  'C64',
#  'Ouya',
#  'PS',
#  'PS4',
#  'Wii',
#  'NS',
#  'VC',
#  '3DO',
#  'PSP',
#  'S32X',
#  'XOne',
#  'Arc']

# %%
sorted(unique_platforms)
# Out:
# ['3DO Interactive Multiplayer',
#  'Amazon Fire TV',
#  'Amiga',
#  'Amiga CD32',
#  'Android',
#  'Arcade',
#  'Atari Jaguar',
#  'Atari Jaguar CD',
#  'Atari ST/STE',
#  'BlackBerry OS',
#  'Daydream',
#  'Dreamcast',
#  'Family Computer (FAMICOM)',
#  'Game Boy',
#  'Game Boy Advance',
#  'Game Boy Color',
#  'Gear VR',
#  'Google Stadia',
#  'Linux',
#  'Mac',
#  'Mobile',
#  'N-Gage',
#  'NES',
#  'Neo Geo AES',
#  'Neo Geo CD',
#  'Neo Geo MVS',
#  'New Nintendo 3DS',
#  'Nintendo 3DS',
#  'Nintendo 64',
#  'Nintendo DS',
#  'Nintendo DSi',
#  'Nintendo GameCube',
#  'Nintendo Switch',
#  'Oculus Quest',
#  'Oculus Quest 2',
#  'Oculus Rift',
#  'Oculus VR',
#  'OnLive Game System',
#  'Ouya',
#  'PC DOS',
#  'Philips CD-i',
#  'PlayStation',
#  'PlayStation 2',
#  'PlayStation 3',
#  'PlayStation 4',
#  'PlayStation 5',
#  'PlayStation Network',
#  'PlayStation Portable',
#  'PlayStation VR',
#  'PlayStation Vita',
#  'Playstation VR2',
#  'SNES',
#  'Satellaview',
#  'Sega CD',
#  'Sega Game Gear',
#  'Sega Mega Drive/Genesis',
#  'Sega Saturn',
#  'SteamVR',
#  'Super Famicom',
#  'Tapwave Zodiac',
#  'Web browser',
#  'Wii',
#  'Wii U',
#  'Windows Mixed Reality',
#  'Windows PC',
#  'Windows Phone',
#  'WonderSwan',
#  'WonderSwan Color',
#  'Xbox',
#  'Xbox 360',
#  'Xbox One',
#  'Xbox Series',
#  'Zeebo',
#  'iOS']

# %%
platforms_2_mapping = {
    'PS2': 'PlayStation 2',
    'PS5': 'PlayStation 5',
    'WiiU': 'Wii U',
    'X360': 'Xbox 360',
    'N64': 'Nintendo 64',
    'Series': 'Xbox Series',
    'GB': 'Game Boy',
    'WW': 'WiiWare', # Check V
    'GC': 'Nintendo GameCube',
    'NG': 'Neo Geo AES', # Check V
    'DC': 'Dreamcast',
    'S32X': 'Sega 32X', # Check X
    'GEN': 'Sega Mega Drive/Genesis',
    'XS': 'Xbox Series',
    'TG16': 'TurboGrafx-16', # Check X
    'VC': 'Virtual Console', # Check V
    'Linux': 'Linux',
    'OSX': 'Mac',
    'SAT': 'Sega Saturn',
    'GBC': 'Game Boy Color',
    'NES': 'NES',
    'SCD': 'Sega CD',
    'MS': 'Sega Master System', # Check V
    'Lynx': 'Atari Lynx', # Check V
    'ACPC': 'Amstrad CPC', # Check V
    'PS3': 'PlayStation 3',
    'PSP': 'PlayStation Portable',
    'PSV': 'PlayStation Vita',
    'NGage': 'N-Gage',
    'GBA': 'Game Boy Advance',
    'NS': 'Nintendo Switch',
    'XBL': 'Xbox Live', # Check V
    'XOne': 'Xbox One',
    'Arc': 'Arcade',
    'MSX': 'MSX', # Check V
    'SNES': 'SNES',
    'XB': 'Xbox',
    '3DO': '3DO Interactive Multiplayer',
    '3DS': 'Nintendo 3DS',
    'PCFX': 'NEC PC-FX', # Check X
    'Ouya': 'Ouya',
    'PC': 'Windows PC',
    'ApII': 'Apple II', # Check V
    'DS': 'Nintendo DS',
    'Wii': 'Wii',
    'iOS': 'iOS',
    'WinP': 'Windows Phone',
    'PS': 'PlayStation',
    'And': 'Android',
    'Mob': 'Mobile',
    '2600': 'Atari 2600', # Check V
    'DSiW': 'Nintendo DSi',
    'PSN': 'PlayStation Network',
    'C64': 'Commodore 64', # Check V
    'GG': 'Sega Game Gear',
    'PS4': 'PlayStation 4',
    'OR': 'Oculus Rift',
    'AJ': 'Atari Jaguar', # Check V
    'WS': 'WonderSwan'
}

# %%
platform_2_code = 'AJ'
for i, row in df.iterrows():
    if isinstance(row['platforms_2'], list) and platform_2_code in row['platforms_2']:
        print(row['appid'], row['name'], row['platforms'], row['platforms_2'])
# Out:
# 227380 Dragon's Lair ['Android', 'Mac', 'Xbox 360', 'iOS', 'PlayStation 3', 'Atari ST/STE', 'Arcade', 'Sega CD', 'Amiga', 'Game Boy Color', 'Philips CD-i', 'PC DOS', '3DO Interactive Multiplayer', 'Atari Jaguar', 'Atari Jaguar CD'] ['DS', 'PSN', 'NES', 'SCD', 'DSiW', 'AJ', 'SNES', '3DO']
# 379720 DOOM ['Windows PC', 'PlayStation 4', 'Xbox One'] ['PS', 'GBA', 'PC', 'XBL', 'SAT', 'AJ', 'SNES', '3DO', 'PS4', 'XOne', 'And', 'NS', 'iOS']
# 2270 Wolfenstein 3D ['Windows PC', 'Mac', 'Xbox 360', 'iOS', 'PlayStation 3', 'Super Famicom', 'SNES', 'PC DOS', 'Web browser', 'Xbox One', 'Game Boy Advance', '3DO Interactive Multiplayer', 'Atari Jaguar'] ['GBA', 'SNES', 'XBL', 'PC', '3DO', 'AJ', 'PSN']

# %%
new_platforms_2_list = list()
for i, row in df.iterrows():
    if isinstance(row['platforms_2'], list):
        temp_list = list()
        for console in row['platforms_2']:
            temp_list.append(platforms_2_mapping.get(console, console))
        new_platforms_2_list.append(temp_list)
    else:
        new_platforms_2_list.append(row['platforms_2'])

# %%
new_platforms_2_list
# Out:
# [['Xbox One', 'Nintendo Switch', 'Windows PC', 'PlayStation 4'],
#  ['PlayStation Network', 'Xbox Live', 'Windows PC'],
#  ['Xbox 360', 'Windows PC', 'PlayStation 3'],
#  ['PlayStation 4', 'Xbox One', 'Windows PC'],
#  ['Xbox One', 'Windows PC', 'Xbox Series'],
#  ['PlayStation 2',
#   'Xbox',
#   'Game Boy Advance',
#   'Windows PC',
#   'Xbox Series',
#   'Xbox Live'],
#  nan,
#  ['Windows PC'],
#  ['Nintendo 3DS',
#   'PlayStation 4',
#   'PlayStation Vita',
#   'PlayStation 3',
#   'Wii U',
#   'Nintendo Switch',
#   'Xbox One'],
#  ['PlayStation 4', 'Xbox One', 'Windows PC'],
#  ['Windows PC'],
#  nan,
#  ['Xbox 360',
#   'PlayStation 3',
#   'Windows PC',
#   'Nintendo DS',
#   'PlayStation Network',
#   'Xbox Live'],
#  ['Xbox Live'],
#  ['PlayStation Network', 'Windows PC', 'PlayStation 4'],
#  nan,
#  ['PlayStation Vita', 'PlayStation 3'],
#  ['Windows PC'],
#  ['Nintendo Switch', 'PlayStation 4', 'Xbox One', 'Windows PC'],
#  ['Nintendo Switch',
#   'Windows PC',
#   'PlayStation 4',
#   'PlayStation 5',
#   'Xbox One',
#   'Xbox Series'],
#  ['PlayStation 4', 'Xbox One', 'Nintendo Switch', 'Windows PC'],
#  ['Nintendo Switch', 'PlayStation 4', 'Xbox One', 'Windows PC'],
#  ['Windows PC', 'Nintendo Switch'],
#  ['Windows PC'],
#  ['PlayStation Vita', 'Windows PC'],
#  nan,
#  ['Windows PC'],
#  ['Nintendo DS'],
#  ['Windows PC'],
#  nan,
#  ['PlayStation 4', 'Windows PC'],
#  nan,
#  ['Nintendo Switch'],
#  nan,
#  nan,
#  ['PlayStation 4', 'Windows PC', 'Xbox One'],
#  ['Windows PC', 'PlayStation 4', 'Xbox One'],
#  nan,
#  [],
#  nan,
#  ['Wii', 'PlayStation 3', 'Xbox 360', 'Windows PC'],
#  nan,
#  ['PlayStation 4',
#   'Windows PC',
#   'Xbox Live',
#   'WiiWare',
#   'Nintendo Switch',
#   'Xbox Series'],
#  ['Windows PC'],
#  ['Nintendo Switch', 'PlayStation 4', 'Windows PC', 'Xbox One'],
#  ['Nintendo Switch'],
#  nan,
#  nan,
#  ['PlayStation Vita', 'PlayStation 4', 'Windows PC'],
#  ['Windows PC'],
#  ['PlayStation 3', 'Xbox 360', 'Windows PC'],
#  ['Windows PC', 'PlayStation 4', 'Nintendo Switch'],
#  nan,
#  ['Windows PC'],
#  ['Nintendo Switch'],
#  nan,
#  nan,
#  nan,
#  ['Xbox 360', 'PlayStation 3', 'Windows PC'],
#  ['Nintendo Switch', 'Windows PC', 'Xbox One', 'PlayStation 4'],
#  ['Nintendo Switch', 'Windows PC'],
#  nan,
#  ['Nintendo Switch'],
#  nan,
#  ['PlayStation Vita', 'Nintendo 3DS', 'Windows PC'],
#  ['PlayStation 4', 'Xbox One', 'Windows PC'],
#  nan,
#  ['Nintendo Switch'],
#  nan,
#  nan,
#  nan,
#  ['Xbox One', 'PlayStation 4', 'Windows PC'],
#  ['iOS',
#   'Windows PC',
#   'PlayStation 4',
#   'PlayStation 5',
#   'Nintendo Switch',
#   'Xbox One',
#   'Xbox Series'],
#  nan,
#  nan,
#  ['Xbox Live', 'Windows PC', 'PlayStation Network'],
#  ['Xbox One', 'PlayStation 4'],
#  ['Windows PC', 'PlayStation 3', 'Xbox 360'],
#  nan,
#  ['Windows PC'],
#  ['Nintendo Switch', 'Windows PC', 'PlayStation 4'],
#  ['Nintendo Switch',
#   'Xbox Live',
#   'Game Boy',
#   'Nintendo DSi',
#   'WiiWare',
#   'PlayStation Network',
#   'PlayStation',
#   'PlayStation 2',
#   'Windows PC'],
#  nan,
#  nan,
#  ['Windows PC'],
#  ['Windows PC'],
#  nan,
#  ['Windows PC'],
#  ['Windows PC'],
#  ['PlayStation 3', 'Xbox Series'],
#  ['Windows PC', 'PlayStation 4', 'Xbox One'],
#  ['Nintendo 3DS', 'Windows PC', 'PlayStation Vita'],
#  ['PlayStation 4',
#   'Xbox One',
#   'PlayStation 3',
#   'PlayStation Vita',
#   'Windows PC'],
#  ['Windows PC'],
#  ['PlayStation Vita', 'PlayStation 4', 'Windows PC'],
#  ['PlayStation Vita', 'Android', 'Mac', 'Windows PC'],
#  nan,
#  ['SNES', 'Game Boy'],
#  nan,
#  ['Sega Mega Drive/Genesis',
#   'Sega Game Gear',
#   'Virtual Console',
#   'Xbox Live',
#   'Windows PC'],
#  nan,
#  ['Nintendo Switch'],
#  ['Windows PC'],
#  nan,
#  ['Xbox Series'],
#  ['PlayStation 4', 'Nintendo Switch'],
#  ['Windows PC', 'Android', 'PlayStation 4', 'Xbox One', 'Nintendo Switch'],
#  ['Windows PC'],
#  ['PlayStation 4',
#   'PlayStation 3',
#   'Wii',
#   'Xbox 360',
#   'Xbox One',
#   'Windows PC',
#   'PlayStation Network'],
#  ['PlayStation 4', 'PlayStation Vita'],
#  nan,
#  ['Windows PC', 'Xbox One'],
#  ['Xbox Live', 'Windows PC', 'PlayStation Network'],
#  nan,
#  ['Windows PC'],
#  ['Wii',
#   'Xbox 360',
#   'PlayStation 3',
#   'Nintendo DS',
#   'Nintendo 3DS',
#   'PlayStation Portable',
#   'Windows PC',
#   'PlayStation Vita',
#   'Mac'],
#  nan,
#  ['Windows PC', 'PlayStation 4'],
#  ['PlayStation 4',
#   'Nintendo Switch',
#   'PlayStation 2',
#   'Xbox One',
#   'Windows PC'],
#  nan,
#  ['Xbox Series', 'Windows PC', 'Xbox One', 'Nintendo Switch'],
#  ['Windows PC'],
#  ['PlayStation Network'],
#  ['PlayStation 3', 'Xbox 360', 'Xbox Live', 'Windows PC'],
#  nan,
#  nan,
#  nan,
#  nan,
#  ['PlayStation 4', 'Windows PC'],
#  nan,
#  ['Windows PC'],
#  ['PlayStation 4', 'Windows PC', 'Nintendo Switch'],
#  ['Windows PC', 'N-Gage'],
#  ['Windows PC', 'Xbox One', 'PlayStation 4'],
#  ['Windows PC', 'Xbox 360'],
#  ['Windows PC'],
#  ['PlayStation 3',
#   'Xbox 360',
#   'Windows PC',
#   'PlayStation Network',
#   'Xbox Series',
#   'Xbox Live'],
#  ['Xbox 360', 'Windows PC'],
#  nan,
#  nan,
#  ['PlayStation 4', 'Nintendo Switch', 'PlayStation Vita', 'Windows PC'],
#  nan,
#  ['PlayStation 4',
#   'PlayStation Vita',
#   'PlayStation 3',
#   'Windows PC',
#   'Nintendo Switch',
#   'Xbox One'],
#  ['PlayStation 4'],
#  ['PlayStation 4'],
#  ['PlayStation 4', 'Xbox One', 'Windows PC'],
#  ['PlayStation 4'],
#  [],
#  ['Windows PC'],
#  ['Windows PC'],
#  nan,
#  ['Windows PC', 'Mac', 'iOS', 'PlayStation 4', 'Xbox One'],
#  ['Windows PC'],
#  ['Xbox One', 'Nintendo Switch', 'Windows PC', 'PlayStation 4'],
#  nan,
#  ['NEC PC-FX', 'Mac', 'Windows PC'],
#  ['Windows PC', 'Linux', 'Mac'],
#  ['Nintendo Switch'],
#  ['PlayStation 4', 'Xbox One', 'Nintendo Switch', 'Windows PC'],
#  ['Xbox One', 'PlayStation 4', 'Nintendo Switch', 'Windows PC'],
#  nan,
#  ['Windows PC'],
#  nan,
#  ['Windows PC', 'Nintendo Switch'],
#  ['PlayStation 4', 'Nintendo Switch', 'Windows PC', 'Linux', 'Xbox One'],
#  nan,
#  ['Linux', 'Windows PC'],
#  ['Nintendo Switch', 'Windows PC'],
#  ['PlayStation 4', 'Windows PC', 'Xbox One'],
#  nan,
#  ['Windows PC', 'Mac'],
#  nan,
#  nan,
#  nan,
#  ['Windows PC', 'Xbox Live', 'PlayStation Network'],
#  ['Linux', 'Mac', 'Windows PC', 'PlayStation 4', 'Xbox One'],
#  ['Windows PC'],
#  ['PlayStation 4', 'Xbox One', 'PlayStation 3', 'Xbox 360', 'Windows PC'],
#  ['PlayStation 2',
#   'Nintendo DS',
#   'PlayStation Portable',
#   'Wii',
#   'Windows PC',
#   'PlayStation Network',
#   'NES'],
#  ['Windows PC'],
#  ['PlayStation 2', 'Xbox', 'Nintendo GameCube', 'Xbox Live', 'Windows PC'],
#  ['Xbox One', 'PlayStation 4', 'Windows PC'],
#  ['Nintendo Switch', 'Windows PC', 'PlayStation 4'],
#  nan,
#  nan,
#  ['Nintendo Switch', 'Windows PC', 'PlayStation 4'],
#  ['Windows PC'],
#  ['PlayStation 4',
#   'Xbox Series',
#   'Xbox One',
#   'Nintendo Switch',
#   'Windows PC',
#   'PlayStation 5'],
#  nan,
#  nan,
#  ['Windows PC', 'Xbox One', 'PlayStation 4', 'Nintendo Switch'],
#  nan,
#  nan,
#  ['Windows PC', 'PlayStation Network', 'Xbox Live'],
#  ['PlayStation 4', 'Xbox One', 'Windows PC'],
#  ['Windows PC'],
#  ['Mac', 'Windows PC'],
#  ['Windows PC'],
#  ['Xbox Series', 'Nintendo Switch', 'Windows PC'],
#  ['PlayStation 4', 'Xbox One', 'Windows PC', 'iOS', 'Nintendo Switch'],
#  nan,
#  ['Nintendo Switch'],
#  ['PlayStation Vita', 'Windows PC', 'Nintendo Switch'],
#  ['PlayStation 4', 'Xbox One', 'Windows PC', 'PlayStation 5', 'Xbox Series'],
#  nan,
#  ['PlayStation 3', 'Xbox 360', 'Windows PC'],
#  ['Nintendo Switch'],
#  nan,
#  ['Nintendo Switch', 'PlayStation Vita', 'PlayStation 4', 'Windows PC'],
#  nan,
#  ['Windows PC'],
#  nan,
#  ['Xbox One', 'Nintendo Switch', 'Windows PC'],
#  ['Windows PC', 'Xbox One', 'PlayStation 4', 'Xbox Series'],
#  nan,
#  ['Xbox 360',
#   'PlayStation 3',
#   'Windows PC',
#   'Wii',
#   'Nintendo DS',
#   'PlayStation Network',
#   'Xbox Live'],
#  ['Windows PC', 'Xbox Live'],
#  nan,
#  ['Windows PC',
#   'Mac',
#   'PlayStation Vita',
#   'PlayStation 3',
#   'Linux',
#   'PlayStation 4'],
#  nan,
#  nan,
#  nan,
#  ['PlayStation 5', 'Xbox Series', 'Windows PC', 'PlayStation 4'],
#  nan,
#  nan,
#  ['Windows PC', 'Xbox 360', 'PlayStation 3'],
#  nan,
#  nan,
#  ['Windows PC', 'Linux', 'Mac'],
#  nan,
#  ['PlayStation 4', 'PlayStation 3', 'Linux', 'Mac', 'Windows PC'],
#  ['Xbox 360', 'Xbox Live', 'Windows PC'],
#  ['Xbox 360', 'PlayStation 3', 'Windows PC'],
#  ['Nintendo Switch', 'Windows PC'],
#  ['Xbox 360', 'PlayStation 3', 'Windows PC'],
#  ['Xbox One', 'PlayStation 4', 'Windows PC'],
#  nan,
#  nan,
#  ['Sega Mega Drive/Genesis',
#   'Virtual Console',
#   'Windows PC',
#   'Xbox 360',
#   'Xbox Live'],
#  nan,
#  ['Windows PC', 'PlayStation 4'],
#  nan,
#  ['Windows PC', 'PlayStation 4', 'Xbox One'],
#  nan,
#  nan,
#  ['Windows PC'],
#  nan,
#  ['Windows PC'],
#  ['Xbox', 'Windows PC'],
#  ['Windows PC'],
#  ['Windows PC'],
#  ['Windows PC'],
#  nan,
#  ['PlayStation Vita', 'PlayStation 4', 'Windows PC'],
#  ['Windows PC'],
#  ['Xbox One', 'Nintendo Switch', 'Windows PC', 'PlayStation 4'],
#  ['PlayStation 4', 'Nintendo Switch'],
#  nan,
#  nan,
#  ['Nintendo Switch', 'Windows PC', 'PlayStation 4', 'Xbox One'],
#  ['Nintendo Switch', 'Windows PC'],
#  ['Windows PC'],
#  ['PlayStation 4', 'Windows PC'],
#  ['Windows PC',
#   'PlayStation Vita',
#   'PlayStation 4',
#   'Xbox One',
#   'Nintendo Switch'],
#  ['Xbox One', 'Windows PC', 'PlayStation 4'],
#  ['Windows PC'],
#  ['Windows PC'],
#  nan,
#  ['Windows PC'],
#  ['Windows PC'],
#  ['PlayStation Vita', 'PlayStation 4'],
#  ['Xbox One', 'PlayStation 4', 'Windows PC', 'Nintendo Switch'],
#  ['Windows PC'],
#  ['Windows PC'],
#  ['PlayStation 4', 'Nintendo Switch', 'Windows PC', 'Linux', 'Mac'],
#  nan,
#  ['Windows PC', 'PlayStation 4'],
#  ['Xbox 360', 'Windows PC', 'NES'],
#  ['Windows PC', 'Xbox One', 'Nintendo Switch', 'PlayStation 4', 'Xbox Series'],
#  ['PlayStation Portable', 'PlayStation Network'],
#  ['Windows PC'],
#  ['Wii U'],
#  ['Windows PC', 'PlayStation 5', 'Xbox Series'],
#  ['PlayStation 2', 'Xbox', 'Windows PC'],
#  ['iOS',
#   'Windows PC',
#   'PlayStation 4',
#   'Nintendo Switch',
#   'Xbox One',
#   'Android'],
#  ['Xbox 360', 'PlayStation 3', 'Windows PC'],
#  ['Wii U', 'Windows PC', 'Mac'],
#  ['Wii U'],
#  nan,
#  ['Windows PC'],
#  ['PlayStation 5'],
#  ['Windows PC'],
#  ['Xbox Series',
#   'Xbox One',
#   'PlayStation 5',
#   'PlayStation 4',
#   'Windows PC',
#   'Nintendo Switch'],
#  ['PlayStation 4', 'Windows PC', 'PlayStation 5'],
#  ['Windows PC'],
#  ['Windows PC'],
#  ['N-Gage'],
#  nan,
#  ['PlayStation 4', 'Xbox One', 'Windows PC'],
#  ['Windows PC', 'PlayStation Network'],
#  nan,
#  ['PlayStation 4', 'Nintendo Switch'],
#  ['Nintendo Switch'],
#  ['Windows PC', 'PlayStation 4', 'Xbox One'],
#  ['Windows PC', 'Xbox Live', 'Linux'],
#  ['Nintendo DS',
#   'PlayStation Network',
#   'NES',
#   'Sega CD',
#   'Nintendo DSi',
#   'Atari Jaguar',
#   'SNES',
#   '3DO Interactive Multiplayer'],
#  nan,
#  ['Wii U', 'Mac', 'Windows PC', 'PlayStation 3'],
#  ['PlayStation Portable',
#   'Wii',
#   'Xbox',
#   'Windows PC',
#   'Xbox Live',
#   'PlayStation Network'],
#  ['PlayStation Network'],
#  ['Xbox One', 'PlayStation 4', 'Windows PC', 'Nintendo Switch'],
#  nan,
#  ['Windows PC'],
#  ['Xbox Live', 'Windows PC'],
#  ['Nintendo Switch'],
#  nan,
#  ['Windows PC'],
#  ['Windows PC'],
#  ['Windows PC'],
#  ['Windows PC'],
#  ['PlayStation 4', 'Xbox One', 'Windows PC'],
#  ['Nintendo Switch', 'Windows PC'],
#  ['Windows PC', 'Xbox One', 'Nintendo Switch', 'PlayStation 4'],
#  ['PlayStation 4'],
#  nan,
#  ['Nintendo GameCube', 'PlayStation 2'],
#  nan,
#  ['Mac', 'Windows PC'],
#  ['Nintendo Switch'],
#  nan,
#  ['PlayStation 4', 'Xbox One', 'Nintendo Switch', 'Windows PC'],
#  ['Windows PC', 'Dreamcast'],
#  ['PlayStation Vita'],
#  nan,
#  ['PlayStation 4',
#   'PlayStation 5',
#   'Xbox One',
#   'Xbox Series',
#   'Windows PC',
#   'Nintendo Switch'],
#  ['Xbox 360', 'PlayStation 3', 'Windows PC', 'PlayStation Network'],
#  ['Windows PC'],
#  nan,
#  nan,
#  ['Nintendo Switch', 'PlayStation 4', 'Xbox One'],
#  ['Windows PC', 'Nintendo Switch', 'Xbox One', 'PlayStation 4'],
#  ['PlayStation 4', 'Xbox One'],
#  nan,
#  ['Windows PC'],
#  ['Wii U', 'Windows PC', 'Xbox One', 'PlayStation 4'],
#  nan,
#  ['PlayStation 3', 'Xbox 360', 'Windows PC'],
#  ['Nintendo Switch'],
#  nan,
#  ['Windows PC', 'Wii U'],
#  ['PlayStation 3', 'Xbox 360', 'Windows PC'],
#  nan,
#  ['PlayStation 3', 'Xbox 360', 'Windows PC'],
#  ['Nintendo Switch', 'PlayStation 4', 'Xbox One'],
#  ['PlayStation 3', 'Xbox 360', 'Windows PC'],
#  nan,
#  ['PlayStation 4', 'Windows PC'],
#  ['Windows PC', 'Xbox One'],
#  ['Windows PC'],
#  nan,
#  nan,
#  ['Wii', 'PlayStation Network', 'Windows PC', 'Xbox Live'],
#  ['PlayStation Network'],
#  ['PlayStation 3',
#   'Xbox 360',
#   'PlayStation Portable',
#   'Wii',
#   'Nintendo DS',
#   'Windows PC',
#   'PlayStation Network',
#   'Xbox Live'],
#  ['Xbox One', 'PlayStation 4', 'Windows PC'],
#  ['Windows PC'],
#  nan,
#  ['PlayStation 4', 'Nintendo Switch'],
#  ['Windows PC'],
#  nan,
#  ['Windows PC'],
#  ['PlayStation 4', 'Nintendo Switch', 'Xbox One', 'Windows PC'],
#  ['Xbox One', 'PlayStation 4', 'Windows PC', 'Nintendo Switch'],
#  nan,
#  ['PlayStation 4', 'Xbox One', 'Windows PC'],
#  ['Xbox One', 'PlayStation 4', 'Windows PC', 'Nintendo Switch'],
#  ['Windows PC',
#   'PlayStation 4',
#   'PlayStation 5',
#   'Xbox Series',
#   'Xbox One',
#   'Nintendo Switch'],
#  ['PlayStation Vita', 'Windows PC'],
#  ['PlayStation 3', 'Windows PC'],
#  ['PlayStation 4', 'Windows PC', 'Oculus Rift'],
#  nan,
#  ['PlayStation 4', 'Xbox One', 'PlayStation 3', 'Xbox 360', 'Windows PC'],
#  ['Windows PC'],
#  ['PlayStation 2',
#   'Xbox',
#   'Nintendo GameCube',
#   'Game Boy Advance',
#   'Windows PC'],
#  nan,
#  ['Windows PC', 'Xbox Live'],
#  ['Windows PC'],
#  ['Xbox One', 'PlayStation 4', 'Nintendo Switch', 'Windows PC'],
#  ['Windows PC', 'PlayStation 4', 'Xbox One', 'Nintendo Switch'],
#  nan,
#  ['Xbox One',
#   'Xbox Series',
#   'Nintendo Switch',
#   'Windows PC',
#   'PlayStation 4',
#   'PlayStation 5'],
#  nan,
#  ['PlayStation 4', 'Xbox One', 'Windows PC'],
#  ['Nintendo DS'],
#  ['Windows PC'],
#  ['Windows PC'],
#  ['Windows PC', 'PlayStation 4', 'PlayStation 5'],
#  ['Nintendo Switch'],
#  ['Windows PC'],
#  nan,
#  nan,
#  ['PlayStation 4', 'Windows PC', 'PlayStation 3', 'Xbox 360'],
#  ['Wii U', 'Windows PC', 'Android', 'Mac'],
#  ['Windows PC', 'Xbox Series', 'Xbox Live'],
#  nan,
#  ['Windows PC', 'PlayStation Vita', 'PlayStation 3', 'Mac', 'Linux'],
#  nan,
#  ['PlayStation Network', 'Windows PC', 'Xbox Live'],
#  ['Windows PC', 'PlayStation 4'],
#  nan,
#  ['Nintendo Switch'],
#  nan,
#  nan,
#  ['Xbox',
#   'Game Boy Advance',
#   'Windows PC',
#   'PlayStation Vita',
#   'PlayStation Network'],
#  ['PlayStation 4'],
#  ['Windows PC'],
#  ['Windows PC', 'PlayStation 4', 'Xbox One'],
#  ['PlayStation 2', 'Xbox', 'Windows PC', 'Xbox Live'],
#  ['PlayStation 4', 'Xbox One', 'Windows PC'],
#  ['PlayStation Network', 'Xbox Live', 'Windows PC'],
#  nan,
#  ['PlayStation 4', 'Windows PC', 'Xbox One'],
#  ['Windows PC'],
#  ['Nintendo Switch', 'Windows PC', 'PlayStation 4', 'Xbox One'],
#  nan,
#  ['Nintendo Switch', 'PlayStation 4', 'Windows PC', 'Xbox One'],
#  ['Nintendo Switch', 'Windows PC', 'PlayStation 4', 'Xbox One'],
#  ['Nintendo Switch', 'Windows PC', 'Xbox One', 'PlayStation 4'],
#  ['PlayStation Vita', 'PlayStation 4', 'PlayStation 3', 'Windows PC'],
#  ['Xbox Live', 'Windows PC'],
#  ['Windows PC', 'PlayStation 4', 'Xbox One'],
#  ['PlayStation 4',
#   'Nintendo Switch',
#   'Windows PC',
#   'Xbox Series',
#   'Xbox One',
#   'PlayStation 5'],
#  ['Xbox One',
#   'PlayStation 4',
#   'PlayStation 5',
#   'Nintendo Switch',
#   'Windows PC',
#   'Xbox Series'],
#  ['Windows PC', 'PlayStation 4', 'Xbox One', 'Nintendo Switch'],
#  ['PlayStation 3', 'Xbox 360', 'Wii', 'Windows PC'],
#  ['PlayStation Network', 'Windows PC'],
#  ['Nintendo Switch', 'Windows PC'],
#  ['WiiWare'],
#  ['PlayStation 4'],
#  ['PlayStation 4'],
#  nan,
#  ['PlayStation 4'],
#  nan,
#  ['Windows PC', 'Mac', 'Nintendo Switch', 'Linux', 'PlayStation 4', 'Wii U'],
#  nan,
#  nan,
#  ['Nintendo Switch'],
#  ['Windows PC', 'Xbox 360', 'PlayStation 3'],
#  nan,
#  ['Windows PC'],
#  ['Windows PC'],
#  ['Windows PC', 'Xbox One', 'PlayStation 4', 'Nintendo Switch'],
#  ['Windows PC', 'Mac'],
#  ['Xbox',
#   'Windows PC',
#   'iOS',
#   'Android',
#   'Xbox One',
#   'PlayStation 4',
#   'Nintendo Switch'],
#  nan,
#  ['Windows PC'],
#  ['Nintendo Switch'],
#  nan,
#  nan,
#  ['Nintendo Switch',
#   'Game Boy',
#   'Atari 2600',
#   'NES',
#   'Nintendo DSi',
#   'WiiWare',
#   'PlayStation Network',
#   'PlayStation 2'],
#  ['Xbox', 'Windows PC'],
#  ['Windows PC', 'PlayStation 4', 'Xbox One', 'Mac', 'Linux'],
#  nan,
#  nan,
#  nan,
#  ['Xbox', 'Windows PC'],
#  ['Windows PC'],
#  ['PlayStation 4', 'Xbox One', 'Nintendo Switch', 'Windows PC'],
#  ['Windows PC', 'Mac', 'Linux'],
#  nan,
#  nan,
#  nan,
#  nan,
#  ['Xbox One', 'Nintendo Switch', 'Windows PC', 'PlayStation 4'],
#  nan,
#  ['Nintendo Switch', 'Windows PC'],
#  ['Windows PC', 'Nintendo Switch'],
#  ['Windows PC'],
#  nan,
#  ['PlayStation 4', 'Xbox One', 'Windows PC', 'PlayStation 5', 'Xbox Series'],
#  ['Windows PC'],
#  ['Windows PC'],
#  nan,
#  ['Xbox Live', 'PlayStation Network', 'Windows PC'],
#  nan,
#  ['Windows PC'],
#  ['Windows PC'],
#  ['PlayStation 4', 'Nintendo Switch', 'Xbox One', 'Windows PC'],
#  ['PlayStation Vita', 'PlayStation 3'],
#  nan,
#  ['Windows PC', 'PlayStation 4', 'Xbox One'],
#  ['Xbox Live', 'Windows PC', 'PlayStation Network'],
#  ['Xbox', 'Windows PC', 'PlayStation 2'],
#  ['Windows PC'],
#  ['Nintendo Switch',
#   'Nintendo 3DS',
#   'PlayStation 4',
#   'Xbox One',
#   'Windows PC',
#   'Xbox Series'],
#  ['Windows PC'],
#  ['PlayStation 4', 'Windows PC', 'Xbox One'],
#  nan,
#  ['Nintendo Switch'],
#  ['PlayStation 4'],
#  ['PlayStation 5', 'PlayStation 4', 'Windows PC', 'Xbox Series', 'Xbox One'],
#  ['Windows PC'],
#  ['Xbox 360',
#   'Wii',
#   'Nintendo DS',
#   'PlayStation 2',
#   'PlayStation Portable',
#   'PlayStation 3',
#   'Windows PC',
#   'PlayStation Network',
#   'Mac'],
#  ['Nintendo Switch', 'Xbox One', 'Windows PC'],
#  ['PlayStation 2', 'Xbox', 'Windows PC', 'Xbox Series'],
#  nan,
#  ['Windows PC'],
#  nan,
#  nan,
#  ['Xbox Live', 'Windows PC'],
#  ['Xbox One', 'Nintendo Switch', 'Windows PC', 'PlayStation 4'],
#  ['PlayStation 4', 'Windows PC'],
#  ['Windows PC'],
#  nan,
#  ['PlayStation Vita', 'PlayStation 3', 'Windows PC'],
#  ['Xbox One', 'PlayStation 4', 'Windows PC'],
#  nan,
#  ['Windows PC'],
#  ['Windows PC'],
#  ['PlayStation 3', 'Xbox 360', 'Windows PC', 'Wii U'],
#  ['Xbox One',
#   'PlayStation 4',
#   'Xbox Series',
#   'Nintendo Switch',
#   'PlayStation 5',
#   'Windows PC',
#   'Wii U',
#   'Xbox 360',
#   'PlayStation 3',
#   'Mac'],
#  ['PlayStation 4', 'Xbox One', 'Windows PC'],
#  ['Windows PC', 'PlayStation 4', 'Nintendo Switch', 'Xbox One', 'Xbox Series'],
#  ['Nintendo Switch', 'Xbox One', 'PlayStation 4', 'Windows PC'],
#  ['PlayStation 4', 'Xbox One', 'Windows PC'],
#  ['Nintendo Switch'],
#  ['PlayStation Network', 'Xbox Live', 'Windows PC'],
#  ['Wii',
#   'Xbox 360',
#   'PlayStation 3',
#   'Nintendo DS',
#   'Nintendo 3DS',
#   'PlayStation Portable',
#   'Windows PC',
#   'PlayStation Network'],
#  ['PlayStation 4',
#   'PlayStation 5',
#   'Xbox One',
#   'Xbox Series',
#   'Nintendo Switch',
#   'Windows PC'],
#  ['Windows PC'],
#  ['Windows PC'],
#  ['Windows PC'],
#  ['PlayStation 4', 'Windows PC', 'Xbox One'],
#  nan,
#  nan,
#  ['Nintendo Switch', 'Windows PC', 'PlayStation 4'],
#  ['PlayStation 4'],
#  ['Windows PC'],
#  ['Windows PC', 'PlayStation 4', 'Xbox One', 'Mac'],
#  ['Xbox 360', 'Windows PC', 'Xbox Live', 'Nintendo Switch'],
#  nan,
#  nan,
#  ['PlayStation 4'],
#  nan,
#  ['Windows PC', 'Windows Phone'],
#  nan,
#  nan,
#  ['Windows PC', 'PlayStation 4', 'Xbox One', 'PlayStation 5', 'Xbox Series'],
#  ['Nintendo Switch'],
#  ['PlayStation 4', 'Windows PC'],
#  ['Xbox One',
#   'Xbox Series',
#   'Nintendo Switch',
#   'Windows PC',
#   'PlayStation 4',
#   'PlayStation 5'],
#  ['Windows PC', 'Xbox One', 'Xbox Series'],
#  nan,
#  nan,
#  ['PlayStation 4', 'Nintendo Switch', 'Windows PC'],
#  nan,
#  ['Xbox 360', 'PlayStation 3', 'Windows PC', 'Wii U'],
#  ['Windows PC', 'Xbox One', 'PlayStation 4', 'Nintendo Switch'],
#  ['Xbox 360', 'PlayStation 2', 'Windows PC', 'Xbox', 'Xbox Series'],
#  ['PlayStation 4'],
#  nan,
#  nan,
#  ['Nintendo Switch'],
#  ['Game Boy Advance', 'Nintendo GameCube', 'PlayStation 2', 'Windows PC'],
#  nan,
#  ['Xbox One', 'PlayStation 4', 'Windows PC', 'Nintendo Switch'],
#  nan,
#  ['Windows PC', 'Xbox Live'],
#  nan,
#  nan,
#  ['PlayStation 2', 'Xbox', 'Windows PC', 'Xbox Series'],
#  ['Windows PC', 'Linux', 'Mac'],
#  nan,
#  ['Windows PC',
#   'Xbox One',
#   'Linux',
#   'Mac',
#   'PlayStation 4',
#   'Wii U',
#   'Nintendo 3DS',
#   'PlayStation Vita'],
#  nan,
#  nan,
#  ['PlayStation 3', 'Xbox 360', 'Windows PC'],
#  nan,
#  nan,
#  nan,
#  ['PlayStation 4', 'PlayStation 3', 'Windows PC', 'Nintendo Switch'],
#  ['Windows PC', 'Nintendo Switch'],
#  ['Nintendo Switch', 'Windows PC', 'PlayStation 5', 'Xbox One', 'Xbox Series'],
#  ['Nintendo Switch', 'Windows PC'],
#  ['Windows PC'],
#  ['PlayStation 5',
#   'Xbox Series',
#   'Xbox One',
#   'Nintendo Switch',
#   'Windows PC',
#   'PlayStation 4'],
#  ['PlayStation 2', 'Xbox', 'Nintendo GameCube', 'Windows PC'],
#  ['PlayStation 4', 'Xbox One', 'Windows PC'],
#  ['Nintendo Switch'],
#  nan,
#  ['Windows PC', 'Xbox One', 'PlayStation 4'],
#  ['PlayStation 4', 'Windows PC', 'Xbox One'],
#  ['Windows PC', 'PlayStation 4', 'Nintendo Switch'],
#  ['PlayStation 5', 'Xbox One', 'Xbox Series', 'Windows PC', 'PlayStation 4'],
#  ['PlayStation 5', 'Windows PC'],
#  ['Windows PC'],
#  [],
#  ['PlayStation 4', 'Xbox One', 'Windows PC'],
#  ['Nintendo Switch'],
#  ['Windows PC', 'Xbox One', 'PlayStation 4'],
#  nan,
#  ['Windows PC', 'Mac'],
#  ['Xbox 360', 'Windows PC', 'Nintendo DS'],
#  ['PlayStation 2', 'Xbox', 'Wii', 'Windows PC'],
#  nan,
#  ['PlayStation 4', 'Windows PC', 'Xbox 360', 'Xbox One', 'Mac', 'Linux'],
#  ['PlayStation 3', 'Xbox 360'],
#  ['PlayStation',
#   'Game Boy Advance',
#   'Windows PC',
#   'Xbox Live',
#   'Sega Saturn',
#   'Atari Jaguar',
#   'SNES',
#   '3DO Interactive Multiplayer',
#   'PlayStation 4',
#   'Xbox One',
#   'Android',
#   'Nintendo Switch',
#   'iOS'],
#  ['Xbox 360', 'PlayStation 3', 'Windows PC'],
#  ['Windows PC'],
#  ['PlayStation 3', 'Xbox 360', 'Windows PC'],
#  nan,
#  nan,
#  nan,
#  ['Nintendo DS',
#   'PlayStation Portable',
#   'Windows PC',
#   'PlayStation Network',
#   'PlayStation 2'],
#  ['PlayStation 4', 'Windows PC', 'Xbox One', 'Nintendo Switch'],
#  nan,
#  nan,
#  ['Xbox One', 'PlayStation 4', 'Windows PC'],
#  ['Windows PC'],
#  nan,
#  nan,
#  nan,
#  ['Windows PC', 'Xbox One', 'PlayStation 4'],
#  ['Windows PC', 'PlayStation 4', 'Xbox One'],
#  ['WiiWare'],
#  ['PlayStation 4'],
#  nan,
#  ['PlayStation Network'],
#  nan,
#  ['Xbox Series',
#   'Nintendo Switch',
#   'PlayStation 4',
#   'PlayStation 5',
#   'Windows PC',
#   'Xbox One'],
#  nan,
#  ['PlayStation 4', 'Xbox One', 'Wii U', 'Windows PC', 'Nintendo Switch'],
#  nan,
#  ['Windows PC'],
#  nan,
#  ['Windows PC', 'Xbox Live'],
#  ['PlayStation 4', 'Xbox One', 'Xbox 360', 'Windows PC', 'PlayStation 3'],
#  ['Xbox One', 'Nintendo Switch', 'PlayStation 4', 'Windows PC'],
#  ['PlayStation 2', 'Xbox'],
#  ['Xbox One', 'Nintendo Switch', 'Windows PC', 'PlayStation 4'],
#  nan,
#  ['PlayStation 4',
#   'Nintendo Switch',
#   'PlayStation 5',
#   'Xbox Series',
#   'Windows PC',
#   'Xbox One'],
#  ['PlayStation 2'],
#  ['Windows PC'],
#  ['Windows PC', 'Nintendo Switch'],
#  ['PlayStation 3',
#   'Xbox 360',
#   'Wii',
#   'Windows PC',
#   'Xbox Live',
#   'PlayStation Network'],
#  ['PlayStation Vita', 'Windows PC'],
#  ['Nintendo Switch'],
#  ['Windows PC', 'Mac', 'PlayStation 4', 'Xbox One'],
#  ['Wii',
#   'PlayStation Portable',
#   'PlayStation 2',
#   'Xbox 360',
#   'Windows PC',
#   'PlayStation Network',
#   'Xbox Live'],
#  nan,
#  ['Xbox One', 'PlayStation 4', 'Nintendo Switch', 'Windows PC'],
#  ['Nintendo Switch', 'PlayStation 4', 'Xbox One', 'Windows PC'],
#  ['Nintendo Switch', 'Wii U', 'Windows PC'],
#  ['Windows PC'],
#  ['PlayStation Vita', 'PlayStation 4'],
#  ['Windows PC'],
#  ['PlayStation 4',
#   'Xbox One',
#   'Windows PC',
#   'Xbox Series',
#   'Nintendo Switch',
#   'PlayStation 5'],
#  ['Windows PC', 'PlayStation 4', 'PlayStation 5', 'Xbox One', 'Xbox Series'],
#  ['Xbox One', 'PlayStation 4', 'Windows PC'],
#  ['PlayStation 4', 'Xbox One', 'Windows PC'],
#  ['Windows PC', 'Nintendo DS'],
#  ['PlayStation 3', 'Xbox 360', 'Windows PC'],
#  ['Windows PC', 'PlayStation 4'],
#  ['PlayStation 4', 'Xbox One', 'Windows PC'],
#  ['Xbox One', 'Xbox Series', 'Windows PC', 'PlayStation 4', 'PlayStation 5'],
#  ['PlayStation 3',
#   'Xbox 360',
#   'PlayStation Portable',
#   'Nintendo DS',
#   'Windows PC'],
#  nan,
#  ['PlayStation 4', 'Windows PC'],
#  ['Windows PC'],
#  ['Nintendo Switch'],
#  nan,
#  nan,
#  ['Windows PC', 'Xbox Live'],
#  ['PlayStation 4'],
#  ['Windows PC'],
#  nan,
#  ['Windows PC'],
#  ['Windows PC', 'Linux'],
#  ['Windows PC', 'PlayStation 4'],
#  ['Xbox',
#   'PlayStation 2',
#   'Nintendo GameCube',
#   'Game Boy Advance',
#   'Windows PC',
#   'Xbox Series'],
#  ['Game Boy Advance'],
#  ['Windows PC'],
#  ['PlayStation 2', 'Xbox', 'Windows PC'],
#  nan,
#  ['Mac', 'Windows PC'],
#  ['Windows PC', 'Linux', 'Mac', 'Xbox One'],
#  nan,
#  ['PlayStation 4', 'Nintendo Switch', 'Windows PC'],
#  ['PlayStation Network'],
#  ['Windows PC', 'PlayStation 4', 'Nintendo Switch'],
#  ['PlayStation 4', 'Xbox One', 'Windows PC'],
#  ['PlayStation 4', 'Windows PC', 'Xbox One', 'Nintendo Switch'],
#  ['Windows PC'],
#  nan,
#  ['Nintendo Switch', 'Windows PC', 'PlayStation 4', 'Xbox One'],
#  ['Mac', 'Linux', 'Windows PC'],
#  ['Windows PC', 'PlayStation 4', 'Xbox One', 'PlayStation 5', 'Xbox Series'],
#  ['Windows PC',
#   'Linux',
#   'Mac',
#   'Xbox Live',
#   'PlayStation 4',
#   'Nintendo Switch'],
#  nan,
#  nan,
#  ['Xbox One', 'Nintendo Switch', 'Windows PC', 'PlayStation 4'],
#  ['Xbox One', 'Nintendo Switch', 'Windows PC', 'PlayStation 4'],
#  ['Nintendo Switch', 'Windows PC', 'PlayStation 4', 'Xbox One'],
#  ['PlayStation 3', 'Xbox 360', 'Windows PC'],
#  nan,
#  nan,
#  nan,
#  ['Nintendo Switch'],
#  ['PlayStation 3', 'Xbox 360', 'Windows PC'],
#  ['Xbox One', 'Nintendo Switch', 'PlayStation 4'],
#  nan,
#  ['Windows PC', 'Xbox 360', 'PlayStation 3'],
#  ['Xbox Live'],
#  ['Windows PC'],
#  ['Nintendo Switch'],
#  nan,
#  ['PlayStation 5', 'Xbox One', 'Xbox Series', 'Windows PC', 'PlayStation 4'],
#  ['Windows PC'],
#  nan,
#  ['PlayStation 3',
#   'Wii',
#   'Xbox 360',
#   'Nintendo DS',
#   'Nintendo Switch',
#   'PlayStation 4'],
#  ['Windows PC'],
#  nan,
#  ['PlayStation 4', 'PlayStation Vita'],
#  nan,
#  ['Windows PC', 'Mac'],
#  ['Windows PC', 'PlayStation 4'],
#  ['Xbox 360', 'PlayStation 3', 'Windows PC', 'Xbox Series'],
#  ['PlayStation 4', 'Windows PC'],
#  ['Windows PC'],
#  nan,
#  ['Windows PC', 'Mac', 'Xbox One', 'Linux', 'Ouya'],
#  nan,
#  nan,
#  ['Windows PC'],
#  nan,
#  ['PlayStation 4', 'Xbox One', 'Windows PC', 'Nintendo Switch'],
#  ['PlayStation 4',
#   'Wii U',
#   'Windows PC',
#   'Xbox One',
#   'Linux',
#   'Mac',
#   'PlayStation 3',
#   'Nintendo Switch',
#   'Xbox 360'],
#  ['Xbox Series', 'Nintendo Switch', 'PlayStation 4', 'Windows PC', 'Xbox One'],
#  nan,
#  nan,
#  nan,
#  ['Nintendo Switch'],
#  ['Xbox Series', 'Nintendo Switch', 'Xbox One', 'Windows PC'],
#  ['Xbox Series', 'PlayStation 5', 'Windows PC', 'Xbox One', 'PlayStation 4'],
#  nan,
#  nan,
#  ['Windows PC'],
#  nan,
#  ['Xbox 360', 'PlayStation 3', 'Windows PC', 'Nintendo Switch'],
#  ['Windows PC', 'PlayStation Vita', 'PlayStation 3', 'Mac', 'Linux'],
#  nan,
#  nan,
#  ['Windows PC'],
#  ['Windows PC', 'PlayStation 4', 'Xbox One'],
#  ['Windows PC'],
#  ['Nintendo Switch'],
#  ['Linux', 'Windows PC', 'Mac'],
#  ['PlayStation 4', 'Xbox One', 'Nintendo Switch', 'Windows PC'],
#  ['PlayStation 4', 'Xbox One', 'PlayStation Vita', 'Windows PC'],
#  ['Windows PC', 'PlayStation 4', 'Xbox One', 'Nintendo Switch'],
#  nan,
#  ['PlayStation 4', 'Xbox One', 'Nintendo Switch', 'Windows PC'],
#  ['Xbox Live'],
#  ['Wii',
#   'PlayStation 3',
#   'Nintendo DS',
#   'Xbox 360',
#   'Windows PC',
#   'Xbox Live'],
#  nan,
#  ['PlayStation Portable', 'PlayStation 3', 'Windows PC'],
#  ['PlayStation 4', 'Xbox One', 'Nintendo Switch'],
#  ['PlayStation 4'],
#  ['PlayStation Vita', 'Windows PC'],
#  ['PlayStation 4', 'Nintendo Switch'],
#  nan,
#  nan,
#  ['Wii',
#   'Nintendo DS',
#   'Windows PC',
#   'PlayStation 4',
#   'Xbox One',
#   'Nintendo 3DS'],
#  ['PlayStation 4', 'Windows PC'],
#  ['PlayStation 5', 'Windows PC'],
#  ['Windows PC'],
#  nan,
#  ['PlayStation 5', 'PlayStation 4', 'Windows PC'],
#  ['Windows PC'],
#  ['Windows PC'],
#  ['Nintendo Switch', 'PlayStation 4'],
#  nan,
#  nan,
#  nan,
#  ['PlayStation Network', 'Xbox Live'],
#  ['Windows PC', 'PlayStation 4', 'Nintendo Switch', 'Xbox One'],
#  nan,
#  nan,
#  ['Windows PC'],
#  ['Windows PC', 'PlayStation 4', 'Nintendo Switch'],
#  nan,
#  ['PlayStation Vita', 'Windows PC', 'Wii'],
#  nan,
#  ['Nintendo Switch', 'Wii U', 'Windows PC', 'PlayStation 4', 'Mac', 'Linux'],
#  nan,
#  ['Nintendo Switch'],
#  ['PlayStation 3'],
#  nan,
#  ['Windows PC'],
#  ['Windows PC', 'Nintendo Switch'],
#  nan,
#  nan,
#  nan,
#  ['PlayStation 4', 'PlayStation', 'Windows PC'],
#  nan,
#  nan,
#  ['PlayStation 4', 'Nintendo Switch', 'Windows PC', 'Xbox One'],
#  nan,
#  ['Nintendo 3DS', 'Wii U', 'PlayStation 4', 'PlayStation Vita', 'Windows PC'],
#  ['PlayStation 4', 'Windows PC'],
#  nan,
#  ['Nintendo Switch'],
#  nan,
#  nan,
#  ['Mac',
#   'PlayStation Vita',
#   'PlayStation 4',
#   'PlayStation 3',
#   'Linux',
#   'Windows PC'],
#  ['Oculus Rift'],
#  nan,
#  ['PlayStation', 'Windows PC', 'Sega Saturn'],
#  ['Windows PC', 'Xbox One', 'Nintendo Switch', 'PlayStation 4'],
#  nan,
#  ['PlayStation 4', 'Windows PC', 'Xbox One'],
#  nan,
#  ['Windows PC'],
#  ['Xbox One', 'Nintendo Switch', 'Windows PC', 'PlayStation 4'],
#  ['PlayStation Vita', 'Windows PC'],
#  ['Xbox 360',
#   'PlayStation 3',
#   'PlayStation Portable',
#   'Windows PC',
#   'Xbox Live',
#   'PlayStation Network'],
#  ['Nintendo Switch'],
#  nan,
#  ['Windows PC', 'Linux'],
#  ['Windows PC', 'PlayStation 4', 'PlayStation 5', 'Xbox One', 'Xbox Series'],
#  ['Windows PC'],
#  ['Windows PC'],
#  ['Xbox One', 'PlayStation 4', 'Windows PC'],
#  ['Xbox 360', 'PlayStation 3', 'Windows PC'],
#  ['PlayStation 2', 'Xbox', 'Windows PC', 'Xbox Series'],
#  nan,
#  ['Windows PC', 'Xbox 360'],
#  ['Windows PC'],
#  nan,
#  ['PlayStation 4', 'Xbox One', 'Windows PC', 'Xbox 360'],
#  ['Wii',
#   'Nintendo DS',
#   'Xbox 360',
#   'PlayStation 3',
#   'Xbox Live',
#   'Mac',
#   'Windows PC'],
#  ['PlayStation 4', 'Xbox One', 'Windows PC'],
#  nan,
#  ['Windows PC', 'Xbox One', 'Xbox Series'],
#  nan,
#  ['Windows PC', 'Xbox Live'],
#  nan,
#  ['Windows PC',
#   'PlayStation Vita',
#   'PlayStation 4',
#   'PlayStation 3',
#   'Wii U',
#   'Mac',
#   'Linux'],
#  ['Windows PC'],
#  ['PlayStation 4',
#   'Xbox One',
#   'Windows PC',
#   'Xbox 360',
#   'PlayStation 3',
#   'Xbox Series'],
#  ['Windows PC', 'Xbox One', 'PlayStation 4'],
#  ['Xbox', 'Windows PC', 'Android', 'iOS'],
#  nan,
#  ['Windows PC'],
#  ['PlayStation',
#   'Windows PC',
#   'PlayStation Network',
#   'iOS',
#   'Android',
#   'Nintendo Switch',
#   'PlayStation 4',
#   'Xbox One'],
#  nan,
#  ['Windows PC', 'PlayStation 4', 'Xbox One'],
#  ['Windows PC', 'PlayStation Network', 'Xbox One'],
#  ['Windows PC', 'Linux', 'Mac'],
#  nan,
#  ['PlayStation 5'],
#  nan,
#  nan,
#  ['PlayStation Portable', 'PlayStation Network', 'Windows PC', 'Xbox Live'],
#  ['Xbox One', 'Xbox Series', 'Windows PC', 'PlayStation 4', 'PlayStation 5'],
#  ['PlayStation 2', 'Xbox', 'Windows PC'],
#  nan,
#  ['Windows PC'],
#  nan,
#  ['Windows PC', 'PlayStation 4'],
#  nan,
#  ['PlayStation 3', 'Xbox 360', 'Windows PC'],
#  ['Windows PC',
#   'Wii U',
#   'Xbox 360',
#   'PlayStation 3',
#   'Xbox One',
#   'PlayStation 4',
#   'Linux',
#   'Mac'],
#  ['Nintendo Switch',
#   'Windows PC',
#   'PlayStation Vita',
#   'PlayStation 4',
#   'Xbox One'],
#  nan,
#  ['Windows PC'],
#  ['PlayStation 4', 'Xbox One', 'Nintendo Switch', 'Windows PC'],
#  ['Xbox One', 'Windows PC', 'Nintendo Switch', 'PlayStation 4'],
#  ['PlayStation 4'],
#  nan,
#  ['PlayStation 4', 'Xbox One', 'Nintendo Switch', 'Windows PC'],
#  ['Windows PC'],
#  ['PlayStation 5',
#   'PlayStation 4',
#   'Xbox One',
#   'Nintendo Switch',
#   'Windows PC',
#   'Xbox Series'],
#  ['PlayStation 3',
#   'PlayStation 4',
#   'PlayStation Vita',
#   'Xbox One',
#   'Windows PC',
#   'Linux',
#   'Mac'],
#  ['Windows PC', 'PlayStation 4', 'Xbox One'],
#  ['Windows PC', 'Xbox One', 'PlayStation 4'],
#  ['PlayStation 3', 'Xbox 360', 'Windows PC'],
#  nan,
#  ['Windows PC'],
#  ['Windows PC'],
#  ['Windows PC'],
#  nan,
#  nan,
#  ['Windows PC', 'PlayStation 4', 'Xbox One'],
#  ['Windows PC', 'PlayStation Network', 'Xbox Live'],
#  ['Xbox 360', 'Windows PC', 'Xbox Live'],
#  nan,
#  ['Windows PC', 'Nintendo Switch'],
#  nan,
#  ['Windows PC', 'PlayStation 4', 'Xbox One', 'Nintendo Switch'],
#  ['Windows PC'],
#  nan,
#  nan,
#  ['PlayStation 4', 'PlayStation Vita', 'Windows PC'],
#  ['PlayStation Vita', 'PlayStation 4', 'PlayStation 3', 'Windows PC'],
#  ['Nintendo 3DS', 'Nintendo Switch', 'Windows PC', 'Wii U', 'PlayStation 5'],
#  nan,
#  nan,
#  nan,
#  nan,
#  ['PlayStation 3', 'Xbox 360', 'Windows PC'],
#  nan,
#  nan,
#  ['Windows PC'],
#  ['PlayStation 4', 'Xbox One', 'Nintendo Switch', 'Windows PC'],
#  ['Xbox One', 'PlayStation 4', 'Windows PC', 'Nintendo Switch'],
#  nan,
#  ['Windows PC'],
#  ['Windows PC'],
#  ['PlayStation 3', 'Xbox 360', 'Windows PC'],
#  ['PlayStation 4', 'PlayStation Vita', 'Windows PC'],
#  ['Xbox One', 'PlayStation 4', 'Nintendo Switch', 'Windows PC'],
#  ['Nintendo Switch', 'PlayStation 4', 'Xbox One', 'Windows PC'],
#  nan,
#  ['Windows PC'],
#  nan,
#  ['PlayStation Vita', 'PlayStation 3', 'Xbox 360', 'Windows PC'],
#  nan,
#  ['PlayStation 4', 'Windows PC', 'Xbox One', 'Nintendo Switch'],
#  nan,
#  nan,
#  ['PlayStation 3', 'Xbox 360', 'Windows PC'],
#  nan,
#  ['Nintendo Switch'],
#  ['Windows PC'],
#  nan,
#  ['Windows PC', 'Nintendo Switch'],
#  ['Nintendo Switch'],
#  nan,
#  ['Nintendo Switch', 'Xbox One', 'PlayStation 4', 'Windows PC'],
#  ['Nintendo Switch', 'Windows PC', 'Xbox One'],
#  ['Xbox One'],
#  ['Windows PC', 'Mac'],
#  ['Windows PC'],
#  ['PlayStation', 'Game Boy', 'Windows PC', 'PlayStation Network'],
#  ['Windows PC'],
#  nan,
#  nan,
#  ['PlayStation 3', 'Xbox 360', 'PlayStation Vita', 'Windows PC'],
#  ['Xbox', 'PlayStation 2', 'Windows PC', 'Xbox Live'],
#  ['PlayStation 4', 'Windows PC', 'Nintendo Switch', 'Xbox One'],
#  ['Windows PC', 'PlayStation 4'],
#  ['Windows PC'],
#  ['Nintendo Switch', 'Windows PC'],
#  ['PlayStation Network',
#   'PlayStation 4',
#   'PlayStation Portable',
#   'PlayStation Vita'],
#  nan,
#  nan,
#  ['PlayStation 4', 'Xbox 360', 'Windows PC', 'Xbox One'],
#  ['Nintendo Switch', 'iOS', 'Windows PC', 'PlayStation 4'],
#  ['Nintendo Switch'],
#  nan,
#  ['PlayStation 4', 'Windows PC', 'PlayStation 5'],
#  ['Nintendo Switch', 'PlayStation 4', 'Xbox One', 'Windows PC'],
#  nan,
#  ['Windows PC', 'Linux', 'Mac', 'PlayStation 4', 'Wii U', 'Xbox One'],
#  nan,
#  ['PlayStation 4', 'Nintendo Switch', 'Xbox One', 'Wii U'],
#  ['Nintendo Switch', 'Windows PC', 'PlayStation 4', 'Xbox One'],
#  nan,
#  ['Nintendo Switch'],
#  ['Xbox One', 'Windows PC', 'Nintendo Switch', 'PlayStation 4'],
#  ['Windows PC', 'Nintendo Switch'],
#  ['PlayStation', 'Windows PC', 'PlayStation 3', 'PlayStation Portable'],
#  ['PlayStation 5', 'Windows PC'],
#  nan,
#  ['Windows PC'],
#  ['PlayStation Network', 'Windows PC'],
#  nan,
#  ['PlayStation Vita'],
#  nan,
#  nan,
#  nan,
#  nan,
#  ['Xbox', 'Windows PC'],
#  ['PlayStation 4', 'Xbox One', 'Nintendo Switch', 'Windows PC'],
#  ['PlayStation Portable',
#   'Nintendo DS',
#   'Windows PC',
#   'Xbox Live',
#   'Nintendo DSi',
#   'PlayStation Network'],
#  ['PlayStation 4', 'Windows PC'],
#  ['Nintendo Switch', 'PlayStation 4', 'Xbox One'],
#  ['Xbox One', 'PlayStation 4', 'Windows PC'],
#  ['PlayStation', 'Windows PC', 'Android'],
#  nan,
#  nan,
#  ['Nintendo Switch', 'Windows PC', 'Xbox One', 'PlayStation 4'],
#  nan,
#  nan,
#  ['Xbox Series', 'Windows PC'],
#  nan,
#  nan,
#  ...]

# %%
count = 0
for elem in new_platforms_2_list:
    if isinstance(elem, list):
        for console in elem:
            if console in ['Sega 32X', 'TurboGrafx-16', 'NEC PC-FX']:
                count += 1

print(count)
# Out:
# 3

# %%
for elem in new_platforms_2_list:
    if isinstance(elem, list):
        for console in elem:
            if console in ['Sega 32X', 'TurboGrafx-16', 'NEC PC-FX']:
                elem.remove(console)

# %%
count = 0
for elem in new_platforms_2_list:
    if isinstance(elem, list):
        for console in elem:
            if console in ['Sega 32X', 'TurboGrafx-16', 'NEC PC-FX']:
                count += 1

print(count)
# Out:
# 0

# %%
df['platforms_2'] = new_platforms_2_list

# %%
df[['platforms', 'platforms_2']]
# Out:
#                                               platforms  \
# 0                                                   NaN
# 1          [Windows PC, Xbox 360, Linux, PlayStation 3]
# 2                                                   NaN
# 3     [Windows PC, PlayStation 4, Xbox One, Google S...
# 4                   [Windows PC, Xbox One, Xbox Series]
# ...                                                 ...
# 5056                                       [Windows PC]
# 5057                                                NaN
# 5058                                                NaN
# 5059                                                NaN
# 5060                                                NaN
#
#                                             platforms_2
# 0     [Xbox One, Nintendo Switch, Windows PC, PlaySt...
# 1          [PlayStation Network, Xbox Live, Windows PC]
# 2                 [Xbox 360, Windows PC, PlayStation 3]
# 3                 [PlayStation 4, Xbox One, Windows PC]
# 4                   [Xbox One, Windows PC, Xbox Series]
# ...                                                 ...
# 5056                                                NaN
# 5057                                                NaN
# 5058                                                NaN
# 5059                                                NaN
# 5060                                                NaN
#
# [5061 rows x 2 columns]

# %% [markdown]
# The next step is to fill the NaN values of `platforms` with the non null values of `platforms_2`. When both have non missing value we have to compare the two lists

# %%
((df['platforms'].isna()) & (df['platforms_2'].notna())).value_counts()
# Out:
# False    3997
# True     1064
# Name: count, dtype: int64

# %%
df['platforms'].isna().value_counts()
# Out:
# platforms
# False    3024
# True     2037
# Name: count, dtype: int64

# %%
df['platforms_2'].isna().value_counts()
# Out:
# platforms_2
# False    3384
# True     1677
# Name: count, dtype: int64

# %%
df['platforms'] = df['platforms'].fillna(df['platforms_2'])

# %%
df['platforms'].isna().value_counts()
# Out:
# platforms
# False    4088
# True      973
# Name: count, dtype: int64

# %%
df['platforms_2'].values
# Out:
# array([list(['Xbox One', 'Nintendo Switch', 'Windows PC', 'PlayStation 4']),
#        list(['PlayStation Network', 'Xbox Live', 'Windows PC']),
#        list(['Xbox 360', 'Windows PC', 'PlayStation 3']), ..., nan, nan,
#        nan], dtype=object)

# %%
for elem, elem_2 in zip(df['platforms'].values, df['platforms_2'].values):
    if isinstance(elem, list) and isinstance(elem_2, list):
        print(elem, elem_2)
# Out:
# ['Xbox One', 'Nintendo Switch', 'Windows PC', 'PlayStation 4'] ['Xbox One', 'Nintendo Switch', 'Windows PC', 'PlayStation 4']
# ['Windows PC', 'Xbox 360', 'Linux', 'PlayStation 3'] ['PlayStation Network', 'Xbox Live', 'Windows PC']
# ['Xbox 360', 'Windows PC', 'PlayStation 3'] ['Xbox 360', 'Windows PC', 'PlayStation 3']
# ['Windows PC', 'PlayStation 4', 'Xbox One', 'Google Stadia'] ['PlayStation 4', 'Xbox One', 'Windows PC']
# ['Windows PC', 'Xbox One', 'Xbox Series'] ['Xbox One', 'Windows PC', 'Xbox Series']
# ['Windows PC', 'Android', 'Mac', 'Xbox', 'Xbox 360', 'PlayStation 4', 'iOS', 'PlayStation 3', 'PlayStation 2'] ['PlayStation 2', 'Xbox', 'Game Boy Advance', 'Windows PC', 'Xbox Series', 'Xbox Live']
# ['Windows PC', 'Mac', 'Linux'] ['Windows PC']
# ['Windows PC', 'Wii U', 'PlayStation 4', 'PlayStation 3', 'Nintendo 3DS', 'Xbox One', 'PlayStation Vita', 'Nintendo Switch'] ['Nintendo 3DS', 'PlayStation 4', 'PlayStation Vita', 'PlayStation 3', 'Wii U', 'Nintendo Switch', 'Xbox One']
# ['Windows PC', 'PlayStation 4', 'Xbox One'] ['PlayStation 4', 'Xbox One', 'Windows PC']
# ['Oculus VR', 'SteamVR', 'Oculus Quest', 'Oculus Quest 2', 'Playstation VR2'] ['Windows PC']
# ['Windows PC', 'Mac', 'Xbox 360', 'PlayStation 3', 'Nintendo DS', 'Wii'] ['Xbox 360', 'PlayStation 3', 'Windows PC', 'Nintendo DS', 'PlayStation Network', 'Xbox Live']
# ['Xbox Live'] ['Xbox Live']
# ['Windows PC', 'PlayStation 4', 'iOS', 'PlayStation 3'] ['PlayStation Network', 'Windows PC', 'PlayStation 4']
# ['Windows PC', 'PlayStation 4', 'PlayStation 3', 'PlayStation Vita'] ['PlayStation Vita', 'PlayStation 3']
# ['Windows PC'] ['Windows PC']
# ['Windows PC', 'PlayStation 4', 'Xbox One', 'Nintendo Switch', 'Google Stadia'] ['Nintendo Switch', 'PlayStation 4', 'Xbox One', 'Windows PC']
# ['Windows PC', 'PlayStation 4', 'Xbox One', 'PlayStation 5', 'Nintendo Switch', 'Google Stadia', 'Xbox Series'] ['Nintendo Switch', 'Windows PC', 'PlayStation 4', 'PlayStation 5', 'Xbox One', 'Xbox Series']
# ['Windows PC', 'Mac', 'Linux', 'PlayStation 4', 'Xbox One', 'PlayStation 5', 'Nintendo Switch'] ['PlayStation 4', 'Xbox One', 'Nintendo Switch', 'Windows PC']
# ['Windows PC', 'PlayStation 4', 'Xbox One', 'Nintendo Switch'] ['Nintendo Switch', 'PlayStation 4', 'Xbox One', 'Windows PC']
# ['Windows PC', 'Mac', 'Linux', 'PlayStation 4', 'Nintendo Switch'] ['Windows PC', 'Nintendo Switch']
# ['Windows PC'] ['Windows PC']
# ['Windows PC', 'PlayStation Vita'] ['PlayStation Vita', 'Windows PC']
# ['Windows PC'] ['Windows PC']
# ['Windows PC', 'Mac', 'iOS', 'Nintendo DS', 'Windows Phone', 'Tapwave Zodiac'] ['Nintendo DS']
# ['Windows PC'] ['Windows PC']
# ['Windows PC', 'PlayStation 4'] ['PlayStation 4', 'Windows PC']
# ['Windows PC', 'Android', 'Mac', 'Linux', 'iOS', 'Nintendo Switch'] ['Nintendo Switch']
# ['Windows PC', 'Xbox One', 'PlayStation 5', 'Google Stadia'] ['PlayStation 4', 'Windows PC', 'Xbox One']
# ['Windows PC', 'PlayStation 4', 'Xbox One'] ['Windows PC', 'PlayStation 4', 'Xbox One']
# [] []
# ['Wii', 'PlayStation 3', 'Xbox 360', 'Windows PC'] ['Wii', 'PlayStation 3', 'Xbox 360', 'Windows PC']
# ['Windows PC', 'Mac', 'Wii U', 'Xbox 360', 'Linux', 'PlayStation 4', 'PlayStation Vita', 'Nintendo Switch'] ['PlayStation 4', 'Windows PC', 'Xbox Live', 'WiiWare', 'Nintendo Switch', 'Xbox Series']
# ['Windows PC', 'Mac', 'Linux'] ['Windows PC']
# ['Windows PC', 'PlayStation 4', 'Xbox One', 'PlayStation 5', 'Nintendo Switch', 'Xbox Series'] ['Nintendo Switch', 'PlayStation 4', 'Windows PC', 'Xbox One']
# ['Nintendo Switch'] ['Nintendo Switch']
# ['Windows PC', 'PlayStation 4', 'PlayStation Vita'] ['PlayStation Vita', 'PlayStation 4', 'Windows PC']
# ['Windows PC', 'Mac', 'Linux'] ['Windows PC']
# ['Windows PC', 'Xbox 360', 'Linux', 'PlayStation 3'] ['PlayStation 3', 'Xbox 360', 'Windows PC']
# ['Windows PC', 'PlayStation 4', 'Nintendo Switch'] ['Windows PC', 'PlayStation 4', 'Nintendo Switch']
# ['Windows PC'] ['Windows PC']
# ['Nintendo Switch'] ['Nintendo Switch']
# ['Windows PC', 'Xbox 360', 'PlayStation 3'] ['Xbox 360', 'PlayStation 3', 'Windows PC']
# ['Nintendo Switch', 'Windows PC', 'Xbox One', 'PlayStation 4'] ['Nintendo Switch', 'Windows PC', 'Xbox One', 'PlayStation 4']
# ['Windows PC', 'Nintendo Switch'] ['Nintendo Switch', 'Windows PC']
# ['Windows PC', 'Android', 'Mac', 'PlayStation 4', 'iOS', 'Xbox One', 'Nintendo Switch'] ['Nintendo Switch']
# ['Windows PC', 'Nintendo 3DS', 'PlayStation Vita'] ['PlayStation Vita', 'Nintendo 3DS', 'Windows PC']
# ['Windows PC', 'PlayStation 4', 'Xbox One'] ['PlayStation 4', 'Xbox One', 'Windows PC']
# ['Windows PC', 'PlayStation 4', 'Xbox One', 'Nintendo Switch'] ['Nintendo Switch']
# ['Windows PC', 'PlayStation 4', 'Xbox One'] ['Xbox One', 'PlayStation 4', 'Windows PC']
# ['Windows PC', 'PlayStation 4', 'iOS', 'Xbox One', 'PlayStation 5', 'Nintendo Switch', 'Xbox Series'] ['iOS', 'Windows PC', 'PlayStation 4', 'PlayStation 5', 'Nintendo Switch', 'Xbox One', 'Xbox Series']
# ['Windows PC', 'Xbox 360', 'PlayStation 3'] ['Xbox Live', 'Windows PC', 'PlayStation Network']
# ['Windows PC', 'PlayStation 4', 'Xbox One'] ['Xbox One', 'PlayStation 4']
# ['Windows PC', 'Xbox 360', 'PlayStation 3'] ['Windows PC', 'PlayStation 3', 'Xbox 360']
# ['Windows PC', 'PlayStation 4', 'Nintendo Switch'] ['Windows PC']
# ['Windows PC', 'PlayStation 4', 'Nintendo Switch'] ['Nintendo Switch', 'Windows PC', 'PlayStation 4']
# ['Windows PC', 'Nintendo Switch'] ['Nintendo Switch', 'Xbox Live', 'Game Boy', 'Nintendo DSi', 'WiiWare', 'PlayStation Network', 'PlayStation', 'PlayStation 2', 'Windows PC']
# ['Windows PC', 'Xbox One', 'Xbox Series'] ['Windows PC']
# ['Windows PC', 'Wii U', 'Xbox 360', 'PlayStation 4', 'iOS', 'PlayStation 3', 'Xbox One', 'PlayStation Vita', 'Nintendo Switch'] ['Windows PC']
# ['Windows PC'] ['Windows PC']
# ['Windows PC'] ['Windows PC']
# ['Windows PC', 'PlayStation 4', 'PlayStation 3', 'Xbox One', 'Nintendo Switch'] ['PlayStation 3', 'Xbox Series']
# ['Windows PC', 'PlayStation 4', 'Xbox One'] ['Windows PC', 'PlayStation 4', 'Xbox One']
# ['Windows PC', 'Nintendo 3DS'] ['Nintendo 3DS', 'Windows PC', 'PlayStation Vita']
# ['Windows PC', 'PlayStation 4', 'PlayStation 3', 'Arcade', 'Xbox One', 'PlayStation Vita'] ['PlayStation 4', 'Xbox One', 'PlayStation 3', 'PlayStation Vita', 'Windows PC']
# ['Windows PC', 'Mac', 'Linux', 'PlayStation 4', 'Xbox One', 'Nintendo Switch'] ['Windows PC']
# ['PlayStation Vita', 'PlayStation 4', 'Windows PC'] ['PlayStation Vita', 'PlayStation 4', 'Windows PC']
# ['Windows PC', 'Android', 'iOS', 'PlayStation Vita'] ['PlayStation Vita', 'Android', 'Mac', 'Windows PC']
# ['Arcade', 'SNES', 'Game Boy'] ['SNES', 'Game Boy']
# ['Windows PC', 'Android', 'Mac', 'Xbox 360', 'Linux', 'iOS', 'PlayStation 3', 'Sega Mega Drive/Genesis', 'Arcade', 'Wii'] ['Sega Mega Drive/Genesis', 'Sega Game Gear', 'Virtual Console', 'Xbox Live', 'Windows PC']
# ['Nintendo Switch'] ['Nintendo Switch']
# ['Windows PC', 'Mac', 'Linux'] ['Windows PC']
# ['Windows PC', 'PlayStation 4', 'Xbox One'] ['Xbox Series']
# ['PlayStation 4', 'Nintendo Switch'] ['PlayStation 4', 'Nintendo Switch']
# ['Windows PC', 'Android', 'PlayStation 4', 'Xbox One', 'Nintendo Switch'] ['Windows PC', 'Android', 'PlayStation 4', 'Xbox One', 'Nintendo Switch']
# ['Windows PC'] ['Windows PC']
# ['Windows PC', 'Mac', 'Xbox 360', 'PlayStation 4', 'iOS', 'PlayStation 3', 'Wii', 'Xbox One'] ['PlayStation 4', 'PlayStation 3', 'Wii', 'Xbox 360', 'Xbox One', 'Windows PC', 'PlayStation Network']
# ['Windows PC'] ['PlayStation 4', 'PlayStation Vita']
# ['Windows PC', 'Xbox One'] ['Windows PC', 'Xbox One']
# ['Windows PC', 'Mac', 'Xbox 360', 'Linux', 'PlayStation 3'] ['Xbox Live', 'Windows PC', 'PlayStation Network']
# ['Windows PC', 'Mac', 'Linux', 'PlayStation 4', 'Ouya', 'Xbox One', 'PlayStation Vita'] ['Windows PC']
# ['Windows PC', 'Android', 'Mac', 'Xbox 360', 'iOS', 'PlayStation 3', 'Wii', 'PlayStation Vita', 'PlayStation Portable'] ['Wii', 'Xbox 360', 'PlayStation 3', 'Nintendo DS', 'Nintendo 3DS', 'PlayStation Portable', 'Windows PC', 'PlayStation Vita', 'Mac']
# ['Windows PC', 'Mac', 'Linux', 'PlayStation 4'] ['Windows PC', 'PlayStation 4']
# ['Windows PC', 'PlayStation 2'] ['PlayStation 4', 'Nintendo Switch', 'PlayStation 2', 'Xbox One', 'Windows PC']
# ['Windows PC', 'Xbox One', 'Nintendo Switch', 'Xbox Series'] ['Xbox Series', 'Windows PC', 'Xbox One', 'Nintendo Switch']
# ['Windows PC'] ['Windows PC']
# ['PlayStation Network'] ['PlayStation Network']
# ['Windows PC', 'Xbox 360', 'PlayStation 3'] ['PlayStation 3', 'Xbox 360', 'Xbox Live', 'Windows PC']
# ['PlayStation 4', 'Windows PC'] ['PlayStation 4', 'Windows PC']
# ['Windows PC'] ['Windows PC']
# ['Windows PC', 'PlayStation 4', 'Nintendo Switch'] ['PlayStation 4', 'Windows PC', 'Nintendo Switch']
# ['Windows PC', 'N-Gage'] ['Windows PC', 'N-Gage']
# ['Windows PC', 'PlayStation 4', 'Xbox One'] ['Windows PC', 'Xbox One', 'PlayStation 4']
# ['Windows PC', 'Xbox 360'] ['Windows PC', 'Xbox 360']
# ['Windows PC'] ['Windows PC']
# ['Windows PC', 'PlayStation 5', 'Xbox Series'] ['PlayStation 3', 'Xbox 360', 'Windows PC', 'PlayStation Network', 'Xbox Series', 'Xbox Live']
# ['Windows PC', 'Mac', 'Xbox 360'] ['Xbox 360', 'Windows PC']
# ['Windows PC', 'PlayStation 4', 'PlayStation Vita', 'Nintendo Switch'] ['PlayStation 4', 'Nintendo Switch', 'PlayStation Vita', 'Windows PC']
# ['Windows PC', 'PlayStation 4', 'PlayStation 3', 'Xbox One', 'PlayStation Vita', 'Nintendo Switch'] ['PlayStation 4', 'PlayStation Vita', 'PlayStation 3', 'Windows PC', 'Nintendo Switch', 'Xbox One']
# ['Windows PC', 'Android', 'Mac', 'PlayStation 4', 'iOS', 'Xbox One', 'Nintendo Switch'] ['PlayStation 4']
# ['PlayStation 4'] ['PlayStation 4']
# ['Windows PC', 'PlayStation 4', 'Xbox One'] ['PlayStation 4', 'Xbox One', 'Windows PC']
# ['PlayStation 4'] ['PlayStation 4']
# ['Windows PC', 'PlayStation 4', 'Nintendo Switch'] []
# ['Windows PC'] ['Windows PC']
# ['Windows PC'] ['Windows PC']
# ['Windows PC', 'Mac', 'Linux', 'PlayStation 4', 'Xbox One', 'Nintendo Switch'] ['Windows PC', 'Mac', 'iOS', 'PlayStation 4', 'Xbox One']
# ['Windows PC'] ['Windows PC']
# ['Xbox One', 'Nintendo Switch', 'Windows PC', 'PlayStation 4'] ['Xbox One', 'Nintendo Switch', 'Windows PC', 'PlayStation 4']
# ['Mac', 'Windows PC'] ['Mac', 'Windows PC']
# ['Windows PC', 'Mac', 'Linux', 'iOS'] ['Windows PC', 'Linux', 'Mac']
# ['Windows PC', 'Nintendo Switch'] ['Nintendo Switch']
# ['Windows PC', 'PlayStation 4', 'Xbox One', 'Nintendo Switch'] ['PlayStation 4', 'Xbox One', 'Nintendo Switch', 'Windows PC']
# ['Windows PC', 'PlayStation 4', 'Xbox One', 'Nintendo Switch'] ['Xbox One', 'PlayStation 4', 'Nintendo Switch', 'Windows PC']
# ['Windows PC'] ['Windows PC']
# ['Windows PC', 'PlayStation 4', 'Nintendo Switch'] ['Windows PC', 'Nintendo Switch']
# ['Windows PC', 'Mac', 'Linux', 'PlayStation 4', 'Xbox One', 'Nintendo Switch'] ['PlayStation 4', 'Nintendo Switch', 'Windows PC', 'Linux', 'Xbox One']
# ['Windows PC', 'Mac', 'Linux', 'PlayStation 4', 'iOS', 'Nintendo Switch'] ['Linux', 'Windows PC']
# ['Nintendo Switch', 'Windows PC'] ['Nintendo Switch', 'Windows PC']
# ['Windows PC', 'PlayStation 4'] ['PlayStation 4', 'Windows PC', 'Xbox One']
# ['Windows PC', 'Android', 'Mac', 'Linux', 'PlayStation 4', 'iOS', 'Xbox One', 'Nintendo Switch'] ['Windows PC', 'Mac']
# ['Windows PC', 'Xbox 360', 'iOS', 'PlayStation 3'] ['Windows PC', 'Xbox Live', 'PlayStation Network']
# ['Linux', 'Mac', 'Windows PC', 'PlayStation 4', 'Xbox One'] ['Linux', 'Mac', 'Windows PC', 'PlayStation 4', 'Xbox One']
# ['Windows PC', 'Mac', 'Linux'] ['Windows PC']
# ['Windows PC', 'Xbox 360', 'PlayStation 4', 'PlayStation 3', 'Xbox One', 'Google Stadia'] ['PlayStation 4', 'Xbox One', 'PlayStation 3', 'Xbox 360', 'Windows PC']
# ['Windows PC', 'Nintendo DS', 'PlayStation 2', 'PlayStation Portable'] ['PlayStation 2', 'Nintendo DS', 'PlayStation Portable', 'Wii', 'Windows PC', 'PlayStation Network', 'NES']
# ['Windows PC'] ['Windows PC']
# ['PlayStation 2', 'Xbox', 'Nintendo GameCube', 'Xbox Live', 'Windows PC'] ['PlayStation 2', 'Xbox', 'Nintendo GameCube', 'Xbox Live', 'Windows PC']
# ['Xbox One', 'PlayStation 4', 'Windows PC'] ['Xbox One', 'PlayStation 4', 'Windows PC']
# ['Windows PC', 'PlayStation 4', 'Nintendo Switch'] ['Nintendo Switch', 'Windows PC', 'PlayStation 4']
# ['Windows PC', 'Mac', 'Linux', 'PlayStation 4', 'Xbox One', 'Nintendo Switch'] ['Nintendo Switch', 'Windows PC', 'PlayStation 4']
# ['Windows PC'] ['Windows PC']
# ['Windows PC', 'PlayStation 4', 'Xbox One', 'PlayStation 5', 'Nintendo Switch', 'Google Stadia', 'Xbox Series'] ['PlayStation 4', 'Xbox Series', 'Xbox One', 'Nintendo Switch', 'Windows PC', 'PlayStation 5']
# ['Windows PC', 'Xbox One', 'PlayStation 4', 'Nintendo Switch'] ['Windows PC', 'Xbox One', 'PlayStation 4', 'Nintendo Switch']
# ['Windows PC', 'Xbox 360', 'PlayStation 3'] ['Windows PC', 'PlayStation Network', 'Xbox Live']
# ['Windows PC', 'PlayStation 4', 'Xbox One', 'PlayStation 5', 'Google Stadia', 'Xbox Series'] ['PlayStation 4', 'Xbox One', 'Windows PC']
# ['Windows PC', 'Mac', 'Linux', 'PlayStation 4', 'Xbox One', 'PlayStation 5', 'Nintendo Switch', 'Xbox Series'] ['Windows PC']
# ['Windows PC', 'Mac', 'Xbox 360', 'Linux', 'PlayStation 3'] ['Mac', 'Windows PC']
# ['Windows PC'] ['Windows PC']
# ['Windows PC', 'Xbox One', 'Nintendo Switch', 'Google Stadia'] ['Xbox Series', 'Nintendo Switch', 'Windows PC']
# ['Windows PC', 'PlayStation 4', 'SteamVR', 'PlayStation VR', 'Xbox One', 'PlayStation 5', 'Nintendo Switch', 'Google Stadia', 'Oculus Quest', 'Oculus Quest 2', 'Oculus Rift', 'Playstation VR2'] ['PlayStation 4', 'Xbox One', 'Windows PC', 'iOS', 'Nintendo Switch']
# ['Nintendo Switch'] ['Nintendo Switch']
# ['PlayStation Vita', 'Windows PC', 'Nintendo Switch'] ['PlayStation Vita', 'Windows PC', 'Nintendo Switch']
# ['Windows PC', 'PlayStation 4', 'Xbox One', 'PlayStation 5', 'Google Stadia', 'Xbox Series'] ['PlayStation 4', 'Xbox One', 'Windows PC', 'PlayStation 5', 'Xbox Series']
# ['Windows PC'] ['PlayStation 3', 'Xbox 360', 'Windows PC']
# ['Windows PC', 'Nintendo Switch'] ['Nintendo Switch']
# ['Windows PC', 'Mac', 'Linux', 'PlayStation 4', 'Xbox One', 'PlayStation Vita', 'Nintendo Switch'] ['Nintendo Switch', 'PlayStation Vita', 'PlayStation 4', 'Windows PC']
# ['Windows PC', 'Mac', 'Linux'] ['Windows PC']
# ['Xbox One', 'Nintendo Switch', 'Windows PC'] ['Xbox One', 'Nintendo Switch', 'Windows PC']
# ['Windows PC', 'Android', 'Mac', 'Linux', 'PlayStation 4', 'iOS', 'Xbox One'] ['Windows PC', 'Xbox One', 'PlayStation 4', 'Xbox Series']
# ['Windows PC', 'Mac', 'Xbox 360', 'PlayStation 3', 'Nintendo DS', 'Wii'] ['Xbox 360', 'PlayStation 3', 'Windows PC', 'Wii', 'Nintendo DS', 'PlayStation Network', 'Xbox Live']
# ['Windows PC', 'Mac', 'Xbox', 'Xbox 360', 'PlayStation 3', 'Mobile', 'Xbox One'] ['Windows PC', 'Xbox Live']
# ['Windows PC', 'Android', 'Mac', 'Linux', 'PlayStation 4', 'PlayStation 3', 'Xbox One', 'PlayStation Vita', 'Nintendo Switch', 'Google Stadia'] ['Windows PC', 'Mac', 'PlayStation Vita', 'PlayStation 3', 'Linux', 'PlayStation 4']
# ['Windows PC', 'PlayStation 4', 'Xbox One', 'PlayStation 5', 'Xbox Series'] ['PlayStation 5', 'Xbox Series', 'Windows PC', 'PlayStation 4']
# ['Windows PC', 'Xbox 360', 'PlayStation 3'] ['Windows PC', 'Xbox 360', 'PlayStation 3']
# ['Windows PC', 'Mac', 'Linux'] ['Windows PC', 'Linux', 'Mac']
# ['Windows PC', 'Mac', 'Linux', 'PlayStation 4', 'PlayStation 3', 'Xbox One'] ['PlayStation 4', 'PlayStation 3', 'Linux', 'Mac', 'Windows PC']
# ['Windows PC', 'Xbox 360'] ['Xbox 360', 'Xbox Live', 'Windows PC']
# ['Windows PC', 'Xbox 360', 'PlayStation 3'] ['Xbox 360', 'PlayStation 3', 'Windows PC']
# ['Windows PC', 'PlayStation 4', 'PlayStation 5', 'Nintendo Switch'] ['Nintendo Switch', 'Windows PC']
# ['Windows PC', 'Xbox 360', 'PlayStation 3'] ['Xbox 360', 'PlayStation 3', 'Windows PC']
# ['Xbox One', 'PlayStation 4', 'Windows PC'] ['Xbox One', 'PlayStation 4', 'Windows PC']
# ['Xbox 360'] ['Sega Mega Drive/Genesis', 'Virtual Console', 'Windows PC', 'Xbox 360', 'Xbox Live']
# ['Windows PC', 'Mac', 'Linux', 'PlayStation 4', 'Mobile'] ['Windows PC', 'PlayStation 4']
# ['Windows PC', 'PlayStation 4', 'Xbox One', 'PlayStation 5', 'Google Stadia', 'Xbox Series'] ['Windows PC', 'PlayStation 4', 'Xbox One']
# ['Windows PC'] ['Windows PC']
# ['Windows PC'] ['Windows PC']
# ['Windows PC', 'Xbox'] ['Xbox', 'Windows PC']
# ['Windows PC'] ['Windows PC']
# ['Windows PC'] ['Windows PC']
# ['Windows PC'] ['Windows PC']
# ['PlayStation Vita', 'PlayStation 4', 'Windows PC'] ['PlayStation Vita', 'PlayStation 4', 'Windows PC']
# ['Windows PC', 'Mac'] ['Windows PC']
# ['Windows PC', 'Android', 'PlayStation 4', 'iOS', 'Xbox One', 'Nintendo Switch', 'Google Stadia', 'Xbox Series'] ['Xbox One', 'Nintendo Switch', 'Windows PC', 'PlayStation 4']
# ['Windows PC', 'PlayStation 4', 'Nintendo Switch'] ['PlayStation 4', 'Nintendo Switch']
# ['Windows PC', 'PlayStation 4', 'Xbox One', 'Nintendo Switch'] ['Nintendo Switch', 'Windows PC', 'PlayStation 4', 'Xbox One']
# ['Nintendo Switch', 'Windows PC'] ['Nintendo Switch', 'Windows PC']
# ['Windows PC'] ['Windows PC']
# ['Windows PC', 'PlayStation 4'] ['PlayStation 4', 'Windows PC']
# ['Windows PC', 'Android', 'Mac', 'Linux', 'PlayStation 4', 'iOS', 'Xbox One', 'Nintendo Switch'] ['Windows PC', 'PlayStation Vita', 'PlayStation 4', 'Xbox One', 'Nintendo Switch']
# ['Windows PC', 'PlayStation 4', 'Xbox One'] ['Xbox One', 'Windows PC', 'PlayStation 4']
# ['Windows PC', 'Oculus VR', 'SteamVR', 'Oculus Quest 2'] ['Windows PC']
# ['Windows PC', 'Android', 'Mac', 'Linux', 'PlayStation 4', 'iOS', 'Nintendo 3DS', 'Xbox One', 'Nintendo Switch'] ['Windows PC']
# ['Windows PC', 'Mac', 'Linux'] ['Windows PC']
# ['Windows PC'] ['Windows PC']
# ['Windows PC', 'PlayStation 4', 'PlayStation Vita'] ['PlayStation Vita', 'PlayStation 4']
# ['Xbox One', 'PlayStation 4', 'Windows PC', 'Nintendo Switch'] ['Xbox One', 'PlayStation 4', 'Windows PC', 'Nintendo Switch']
# ['Windows PC'] ['Windows PC']
# ['Windows PC', 'Mac'] ['Windows PC']
# ['Windows PC', 'Mac', 'Linux', 'PlayStation 4', 'Xbox One', 'Nintendo Switch'] ['PlayStation 4', 'Nintendo Switch', 'Windows PC', 'Linux', 'Mac']
# ['Windows PC', 'PlayStation 4'] ['Windows PC', 'PlayStation 4']
# ['Windows PC', 'Xbox 360', 'PlayStation 3'] ['Xbox 360', 'Windows PC', 'NES']
# ['Windows PC', 'Mac', 'PlayStation 4', 'Xbox One', 'Nintendo Switch'] ['Windows PC', 'Xbox One', 'Nintendo Switch', 'PlayStation 4', 'Xbox Series']
# ['Windows PC', 'PlayStation Portable'] ['PlayStation Portable', 'PlayStation Network']
# ['Windows PC', 'Mac'] ['Windows PC']
# ['Wii U'] ['Wii U']
# ['Windows PC', 'PlayStation 5', 'Xbox Series'] ['Windows PC', 'PlayStation 5', 'Xbox Series']
# ['PlayStation 2', 'Xbox', 'Windows PC'] ['PlayStation 2', 'Xbox', 'Windows PC']
# ['Windows PC', 'PlayStation 4', 'iOS', 'Xbox One', 'Nintendo Switch', 'Google Stadia', 'Xbox Series'] ['iOS', 'Windows PC', 'PlayStation 4', 'Nintendo Switch', 'Xbox One', 'Android']
# ['Windows PC', 'Mac', 'Xbox 360', 'PlayStation 3'] ['Xbox 360', 'PlayStation 3', 'Windows PC']
# ['Wii U', 'Windows PC', 'Mac'] ['Wii U', 'Windows PC', 'Mac']
# ['Windows PC', 'Wii U'] ['Wii U']
# ['Windows PC'] ['Windows PC']
# ['Windows PC', 'PlayStation 5'] ['PlayStation 5']
# ['Windows PC'] ['Windows PC']
# ['Xbox Series', 'Xbox One', 'PlayStation 5', 'PlayStation 4', 'Windows PC', 'Nintendo Switch'] ['Xbox Series', 'Xbox One', 'PlayStation 5', 'PlayStation 4', 'Windows PC', 'Nintendo Switch']
# ['Windows PC', 'Linux', 'PlayStation 4', 'Xbox One', 'Xbox Series'] ['PlayStation 4', 'Windows PC', 'PlayStation 5']
# ['Windows PC'] ['Windows PC']
# ['Windows PC', 'Mac', 'Linux', 'PlayStation 4', 'Web browser', 'Xbox One'] ['Windows PC']
# ['Windows PC', 'PlayStation 4', 'Xbox One', 'Nintendo Switch'] ['N-Gage']
# ['PlayStation 4', 'Xbox One', 'Windows PC'] ['PlayStation 4', 'Xbox One', 'Windows PC']
# ['Windows PC', 'Mac', 'Linux', 'PlayStation 3', 'PlayStation Portable'] ['Windows PC', 'PlayStation Network']
# ['PlayStation 4', 'Nintendo Switch'] ['PlayStation 4', 'Nintendo Switch']
# ['Windows PC', 'Mac', 'Linux', 'Nintendo Switch'] ['Nintendo Switch']
# ['Windows PC', 'PlayStation 4', 'Xbox One', 'Nintendo Switch', 'Google Stadia', 'Xbox Series'] ['Windows PC', 'PlayStation 4', 'Xbox One']
# ['Windows PC', 'Mac', 'Xbox 360', 'Linux'] ['Windows PC', 'Xbox Live', 'Linux']
# ['Android', 'Mac', 'Xbox 360', 'iOS', 'PlayStation 3', 'Atari ST/STE', 'Arcade', 'Sega CD', 'Amiga', 'Game Boy Color', 'Philips CD-i', 'PC DOS', '3DO Interactive Multiplayer', 'Atari Jaguar', 'Atari Jaguar CD'] ['Nintendo DS', 'PlayStation Network', 'NES', 'Sega CD', 'Nintendo DSi', 'Atari Jaguar', 'SNES', '3DO Interactive Multiplayer']
# ['Windows PC', 'Mac', 'Wii U', 'PlayStation 3'] ['Wii U', 'Mac', 'Windows PC', 'PlayStation 3']
# ['Windows PC', 'Mac', 'iOS', 'Windows Phone'] ['PlayStation Portable', 'Wii', 'Xbox', 'Windows PC', 'Xbox Live', 'PlayStation Network']
# ['Arcade', 'Neo Geo MVS', 'Neo Geo AES'] ['PlayStation Network']
# ['Windows PC', 'PlayStation 4', 'Xbox One', 'Nintendo Switch'] ['Xbox One', 'PlayStation 4', 'Windows PC', 'Nintendo Switch']
# ['Windows PC'] ['Windows PC']
# ['Windows PC', 'Xbox 360'] ['Xbox Live', 'Windows PC']
# ['Nintendo Switch'] ['Nintendo Switch']
# ['Windows PC', 'Mac', 'Linux'] ['Windows PC']
# ['Windows PC', 'Mac', 'Linux', 'PlayStation 4', 'Xbox One', 'Nintendo Switch'] ['Windows PC']
# ['Windows PC'] ['Windows PC']
# ['Windows PC'] ['Windows PC']
# ['Windows PC', 'Mac', 'Linux', 'PlayStation 4', 'Xbox One'] ['PlayStation 4', 'Xbox One', 'Windows PC']
# ['Windows PC', 'Mac', 'Linux', 'Xbox One', 'PlayStation 5', 'Nintendo Switch'] ['Nintendo Switch', 'Windows PC']
# ['Windows PC', 'PlayStation 4', 'Xbox One', 'Nintendo Switch'] ['Windows PC', 'Xbox One', 'Nintendo Switch', 'PlayStation 4']
# ['Windows PC', 'PlayStation 4'] ['PlayStation 4']
# ['Nintendo GameCube'] ['Nintendo GameCube', 'PlayStation 2']
# ['Windows PC', 'Android', 'Mac', 'Linux', 'iOS'] ['Mac', 'Windows PC']
# ['Windows PC', 'Mac', 'PlayStation 4', 'Nintendo Switch'] ['Nintendo Switch']
# ['Windows PC', 'Mac', 'PlayStation 4', 'Xbox One'] ['PlayStation 4', 'Xbox One', 'Nintendo Switch', 'Windows PC']
# ['Windows PC', 'Dreamcast'] ['Windows PC', 'Dreamcast']
# ['Windows PC', 'PlayStation Vita'] ['PlayStation Vita']
# ['Windows PC', 'Mac', 'PlayStation 4', 'Xbox One', 'PlayStation 5', 'Xbox Series'] ['PlayStation 4', 'PlayStation 5', 'Xbox One', 'Xbox Series', 'Windows PC', 'Nintendo Switch']
# ['Windows PC', 'Mac', 'Xbox 360', 'PlayStation 3'] ['Xbox 360', 'PlayStation 3', 'Windows PC', 'PlayStation Network']
# ['Windows PC', 'Mac', 'Xbox One'] ['Windows PC']
# ['Windows PC', 'PlayStation 4', 'Xbox One', 'Nintendo Switch'] ['Nintendo Switch', 'PlayStation 4', 'Xbox One']
# ['Windows PC', 'Mac', 'Linux', 'PlayStation 4', 'Xbox One', 'Nintendo Switch'] ['Windows PC', 'Nintendo Switch', 'Xbox One', 'PlayStation 4']
# ['PlayStation 4', 'Xbox One'] ['PlayStation 4', 'Xbox One']
# ['Windows PC', 'Mac', 'Linux'] ['Windows PC']
# ['Windows PC', 'Wii U', 'PlayStation 4', 'PlayStation 3', 'Xbox One'] ['Wii U', 'Windows PC', 'Xbox One', 'PlayStation 4']
# ['Windows PC', 'Xbox 360', 'PlayStation 3', 'PlayStation Vita', 'Google Stadia'] ['PlayStation 3', 'Xbox 360', 'Windows PC']
# ['Windows PC', 'Android', 'Mac', 'Linux', 'iOS', 'Nintendo Switch'] ['Nintendo Switch']
# ['Windows PC', 'Wii U', 'Xbox 360', 'PlayStation 3'] ['Windows PC', 'Wii U']
# ['Windows PC', 'Xbox 360', 'PlayStation 3'] ['PlayStation 3', 'Xbox 360', 'Windows PC']
# ['Windows PC', 'Xbox 360', 'PlayStation 3', 'Xbox One', 'Xbox Series'] ['PlayStation 3', 'Xbox 360', 'Windows PC']
# ['Windows PC', 'PlayStation 4', 'Xbox One', 'PlayStation 5', 'Nintendo Switch', 'Google Stadia'] ['Nintendo Switch', 'PlayStation 4', 'Xbox One']
# ['PlayStation 3', 'Xbox 360', 'Windows PC'] ['PlayStation 3', 'Xbox 360', 'Windows PC']
# ['Windows PC', 'PlayStation 4', 'Nintendo Switch'] ['PlayStation 4', 'Windows PC']
# ['Windows PC', 'PlayStation 4', 'Xbox One'] ['Windows PC', 'Xbox One']
# ['Windows PC'] ['Windows PC']
# ['Windows PC', 'Xbox 360', 'PlayStation 3', 'Wii', 'Xbox One'] ['Wii', 'PlayStation Network', 'Windows PC', 'Xbox Live']
# ['Windows PC', 'Mac', 'iOS', 'PlayStation 3', 'Mobile'] ['PlayStation Network']
# ['Windows PC', 'Xbox 360', 'Linux', 'PlayStation 3'] ['PlayStation 3', 'Xbox 360', 'PlayStation Portable', 'Wii', 'Nintendo DS', 'Windows PC', 'PlayStation Network', 'Xbox Live']
# ['Windows PC', 'PlayStation 4', 'Xbox One', 'Google Stadia'] ['Xbox One', 'PlayStation 4', 'Windows PC']
# ['Windows PC'] ['Windows PC']
# ['PlayStation 4', 'Nintendo Switch'] ['PlayStation 4', 'Nintendo Switch']
# ['Windows PC'] ['Windows PC']
# ['Windows PC', 'Linux'] ['Windows PC']
# ['Windows PC', 'PlayStation 4', 'Xbox One', 'Nintendo Switch'] ['PlayStation 4', 'Nintendo Switch', 'Xbox One', 'Windows PC']
# ['Windows PC', 'Android', 'Mac', 'Linux', 'PlayStation 4', 'iOS', 'Xbox One', 'Nintendo Switch', 'Google Stadia'] ['Xbox One', 'PlayStation 4', 'Windows PC', 'Nintendo Switch']
# ['Windows PC', 'PlayStation 4', 'Xbox One', 'Google Stadia'] ['PlayStation 4', 'Xbox One', 'Windows PC']
# ['Windows PC', 'Android', 'Linux', 'PlayStation 4', 'iOS', 'Xbox One', 'PlayStation 5', 'Nintendo Switch', 'Xbox Series'] ['Xbox One', 'PlayStation 4', 'Windows PC', 'Nintendo Switch']
# ['Windows PC', 'PlayStation 4', 'PlayStation 5', 'Xbox Series', 'Xbox One', 'Nintendo Switch'] ['Windows PC', 'PlayStation 4', 'PlayStation 5', 'Xbox Series', 'Xbox One', 'Nintendo Switch']
# ['PlayStation Vita'] ['PlayStation Vita', 'Windows PC']
# ['Windows PC', 'PlayStation 3', 'Nintendo Switch'] ['PlayStation 3', 'Windows PC']
# ['PlayStation 4', 'Windows PC', 'Oculus Rift'] ['PlayStation 4', 'Windows PC', 'Oculus Rift']
# ['Windows PC', 'Xbox 360', 'PlayStation 4', 'PlayStation 3', 'Xbox One'] ['PlayStation 4', 'Xbox One', 'PlayStation 3', 'Xbox 360', 'Windows PC']
# ['Windows PC'] ['Windows PC']
# ['Windows PC', 'Nintendo GameCube', 'Xbox', 'PlayStation 3', 'PlayStation 2'] ['PlayStation 2', 'Xbox', 'Nintendo GameCube', 'Game Boy Advance', 'Windows PC']
# ['Windows PC', 'Xbox 360'] ['Windows PC', 'Xbox Live']
# ['Windows PC'] ['Windows PC']
# ['Windows PC', 'Mac', 'Linux', 'PlayStation 4', 'Xbox One', 'Nintendo Switch'] ['Xbox One', 'PlayStation 4', 'Nintendo Switch', 'Windows PC']
# ['Windows PC', 'PlayStation 4', 'Xbox One', 'Nintendo Switch'] ['Windows PC', 'PlayStation 4', 'Xbox One', 'Nintendo Switch']
# ['Xbox One', 'Xbox Series', 'Nintendo Switch', 'Windows PC', 'PlayStation 4', 'PlayStation 5'] ['Xbox One', 'Xbox Series', 'Nintendo Switch', 'Windows PC', 'PlayStation 4', 'PlayStation 5']
# ['Windows PC', 'PlayStation 4', 'Xbox One', 'PlayStation Vita'] ['PlayStation 4', 'Xbox One', 'Windows PC']
# ['Nintendo DS'] ['Nintendo DS']
# ['Windows PC'] ['Windows PC']
# ['Windows PC', 'Mac', 'Linux', 'iOS', 'Nintendo Switch'] ['Windows PC']
# ['Windows PC', 'PlayStation 4', 'PlayStation VR', 'PlayStation 5', 'Playstation VR2'] ['Windows PC', 'PlayStation 4', 'PlayStation 5']
# ['Nintendo Switch'] ['Nintendo Switch']
# ['Windows PC'] ['Windows PC']
# ['Windows PC', 'Xbox 360', 'PlayStation 4', 'PlayStation 3', 'Arcade'] ['PlayStation 4', 'Windows PC', 'PlayStation 3', 'Xbox 360']
# ['Wii U', 'Windows PC', 'Android', 'Mac'] ['Wii U', 'Windows PC', 'Android', 'Mac']
# ['Windows PC', 'Mac', 'Xbox 360', 'Linux'] ['Windows PC', 'Xbox Series', 'Xbox Live']
# ['Windows PC', 'Android', 'Mac', 'Linux', 'PlayStation 3', 'PlayStation Vita'] ['Windows PC', 'PlayStation Vita', 'PlayStation 3', 'Mac', 'Linux']
# ['PlayStation Network', 'Windows PC', 'Xbox Live'] ['PlayStation Network', 'Windows PC', 'Xbox Live']
# ['Windows PC', 'Mac', 'PlayStation 4', 'Xbox One', 'Nintendo Switch'] ['Windows PC', 'PlayStation 4']
# ['Windows PC', 'Mac', 'Linux', 'PlayStation 4', 'Xbox One', 'Nintendo Switch'] ['Nintendo Switch']
# ['Windows PC', 'Android', 'Mac', 'Xbox', 'iOS', 'Nintendo Switch'] ['Xbox', 'Game Boy Advance', 'Windows PC', 'PlayStation Vita', 'PlayStation Network']
# ['PlayStation 4'] ['PlayStation 4']
# ['Windows PC', 'Mac', 'Linux'] ['Windows PC']
# ['Windows PC', 'PlayStation 4', 'Xbox One', 'PlayStation 5', 'Xbox Series'] ['Windows PC', 'PlayStation 4', 'Xbox One']
# ['PlayStation 2', 'Xbox', 'Windows PC', 'Xbox Live'] ['PlayStation 2', 'Xbox', 'Windows PC', 'Xbox Live']
# ['Windows PC', 'PlayStation 4', 'Xbox One'] ['PlayStation 4', 'Xbox One', 'Windows PC']
# ['Windows PC', 'Xbox 360', 'PlayStation 3'] ['PlayStation Network', 'Xbox Live', 'Windows PC']
# ['Windows PC', 'Mac', 'Linux', 'PlayStation 4', 'Xbox One'] ['PlayStation 4', 'Windows PC', 'Xbox One']
# ['Windows PC', 'Mac', 'Linux', 'PlayStation 4', 'Xbox One', 'PlayStation 5', 'Nintendo Switch', 'Xbox Series'] ['Windows PC']
# ['Windows PC', 'PlayStation 4', 'Xbox One', 'Nintendo Switch', 'Google Stadia'] ['Nintendo Switch', 'Windows PC', 'PlayStation 4', 'Xbox One']
# ['Windows PC', 'Android', 'Mac', 'Linux', 'PlayStation 4', 'iOS', 'Xbox One', 'Nintendo Switch', 'Google Stadia'] ['Nintendo Switch', 'PlayStation 4', 'Windows PC', 'Xbox One']
# ['Nintendo Switch', 'Windows PC', 'PlayStation 4', 'Xbox One'] ['Nintendo Switch', 'Windows PC', 'PlayStation 4', 'Xbox One']
# ['Windows PC', 'PlayStation 4', 'Xbox One', 'Nintendo Switch'] ['Nintendo Switch', 'Windows PC', 'Xbox One', 'PlayStation 4']
# ['PlayStation Vita', 'PlayStation 4', 'PlayStation 3', 'Windows PC'] ['PlayStation Vita', 'PlayStation 4', 'PlayStation 3', 'Windows PC']
# ['Windows PC', 'Xbox 360'] ['Xbox Live', 'Windows PC']
# ['Windows PC', 'PlayStation 4', 'Xbox One'] ['Windows PC', 'PlayStation 4', 'Xbox One']
# ['Windows PC', 'Mac', 'Linux', 'PlayStation 4', 'Xbox One', 'PlayStation 5', 'Nintendo Switch', 'Xbox Series'] ['PlayStation 4', 'Nintendo Switch', 'Windows PC', 'Xbox Series', 'Xbox One', 'PlayStation 5']
# ['Xbox One', 'PlayStation 4', 'PlayStation 5', 'Nintendo Switch', 'Windows PC', 'Xbox Series'] ['Xbox One', 'PlayStation 4', 'PlayStation 5', 'Nintendo Switch', 'Windows PC', 'Xbox Series']
# ['Windows PC', 'PlayStation 4', 'Xbox One', 'Nintendo Switch'] ['Windows PC', 'PlayStation 4', 'Xbox One', 'Nintendo Switch']
# ['PlayStation 3', 'Xbox 360', 'Wii', 'Windows PC'] ['PlayStation 3', 'Xbox 360', 'Wii', 'Windows PC']
# ['PlayStation Network', 'Windows PC'] ['PlayStation Network', 'Windows PC']
# ['Windows PC', 'Nintendo Switch'] ['Nintendo Switch', 'Windows PC']
# ['Windows PC', 'Mac', 'Wii', 'Nintendo 3DS', 'Nintendo Switch'] ['WiiWare']
# ['Windows PC', 'PlayStation 4', 'Nintendo Switch'] ['PlayStation 4']
# ['Windows PC'] ['PlayStation 4']
# ['Windows PC', 'PlayStation 4'] ['PlayStation 4']
# ['Windows PC', 'Mac', 'Wii U', 'Linux', 'PlayStation 4', 'Nintendo Switch'] ['Windows PC', 'Mac', 'Nintendo Switch', 'Linux', 'PlayStation 4', 'Wii U']
# ['Nintendo Switch'] ['Nintendo Switch']
# ['Windows PC', 'Xbox 360'] ['Windows PC', 'Xbox 360', 'PlayStation 3']
# ['Windows PC', 'Mac'] ['Windows PC']
# ['Windows PC', 'Mac', 'PlayStation 4', 'iOS', 'Xbox One', 'Nintendo Switch'] ['Windows PC']
# ['Windows PC', 'Xbox One', 'PlayStation 4', 'Nintendo Switch'] ['Windows PC', 'Xbox One', 'PlayStation 4', 'Nintendo Switch']
# ['Windows PC', 'Mac'] ['Windows PC', 'Mac']
# ['Windows PC', 'Mac', 'Xbox', 'Linux', 'Xbox One'] ['Xbox', 'Windows PC', 'iOS', 'Android', 'Xbox One', 'PlayStation 4', 'Nintendo Switch']
# ['Windows PC', 'Mac'] ['Windows PC']
# ['Nintendo Switch'] ['Nintendo Switch']
# ['Nintendo Switch'] ['Nintendo Switch', 'Game Boy', 'Atari 2600', 'NES', 'Nintendo DSi', 'WiiWare', 'PlayStation Network', 'PlayStation 2']
# ['Windows PC', 'Xbox'] ['Xbox', 'Windows PC']
# ['Windows PC', 'Mac', 'Linux', 'PlayStation 4', 'iOS', 'Xbox One', 'Nintendo Switch'] ['Windows PC', 'PlayStation 4', 'Xbox One', 'Mac', 'Linux']
# ['Xbox', 'Windows PC'] ['Xbox', 'Windows PC']
# ['Windows PC'] ['Windows PC']
# ['PlayStation 4', 'Xbox One', 'Nintendo Switch', 'Windows PC'] ['PlayStation 4', 'Xbox One', 'Nintendo Switch', 'Windows PC']
# ['Windows PC', 'Mac', 'Linux'] ['Windows PC', 'Mac', 'Linux']
# ['Windows PC', 'PlayStation 4', 'Xbox One', 'Nintendo Switch', 'Google Stadia'] ['Xbox One', 'Nintendo Switch', 'Windows PC', 'PlayStation 4']
# ['Windows PC', 'Mac', 'Xbox One', 'Nintendo Switch'] ['Nintendo Switch', 'Windows PC']
# ['Windows PC', 'Nintendo Switch', 'Google Stadia'] ['Windows PC', 'Nintendo Switch']
# ['Windows PC'] ['Windows PC']
# ['Windows PC', 'PlayStation 4', 'Xbox One', 'PlayStation 5', 'Google Stadia', 'Xbox Series'] ['PlayStation 4', 'Xbox One', 'Windows PC', 'PlayStation 5', 'Xbox Series']
# ['Windows PC'] ['Windows PC']
# ['Windows PC'] ['Windows PC']
# ['Windows PC', 'Mac', 'Xbox 360', 'PlayStation 3'] ['Xbox Live', 'PlayStation Network', 'Windows PC']
# ['Windows PC', 'Mac', 'Linux'] ['Windows PC']
# ['Windows PC', 'Mac', 'Linux'] ['Windows PC']
# ['Windows PC', 'PlayStation 4', 'Xbox One', 'Nintendo Switch'] ['PlayStation 4', 'Nintendo Switch', 'Xbox One', 'Windows PC']
# ['Windows PC', 'PlayStation 3', 'PlayStation Vita'] ['PlayStation Vita', 'PlayStation 3']
# ['Windows PC', 'Mac', 'PlayStation 4', 'Xbox One'] ['Windows PC', 'PlayStation 4', 'Xbox One']
# ['Xbox Live', 'Windows PC', 'PlayStation Network'] ['Xbox Live', 'Windows PC', 'PlayStation Network']
# ['Xbox', 'Windows PC', 'PlayStation 2'] ['Xbox', 'Windows PC', 'PlayStation 2']
# ['Windows PC'] ['Windows PC']
# ['Windows PC', 'PlayStation 4', 'Nintendo 3DS', 'Xbox One', 'Nintendo Switch', 'Xbox Series'] ['Nintendo Switch', 'Nintendo 3DS', 'PlayStation 4', 'Xbox One', 'Windows PC', 'Xbox Series']
# ['Windows PC'] ['Windows PC']
# ['Windows PC', 'PlayStation 4', 'Xbox One', 'PlayStation Vita'] ['PlayStation 4', 'Windows PC', 'Xbox One']
# ['Windows PC', 'Nintendo Switch'] ['Nintendo Switch']
# ['SteamVR', 'PlayStation VR', 'Windows Mixed Reality', 'Oculus Quest', 'Oculus Rift', 'Playstation VR2'] ['PlayStation 4']
# ['PlayStation 5', 'PlayStation 4', 'Windows PC', 'Xbox Series', 'Xbox One'] ['PlayStation 5', 'PlayStation 4', 'Windows PC', 'Xbox Series', 'Xbox One']
# ['Windows PC'] ['Windows PC']
# ['Windows PC', 'Mac', 'Xbox 360', 'PlayStation 3', 'Wii', 'PlayStation 2', 'PlayStation Portable'] ['Xbox 360', 'Wii', 'Nintendo DS', 'PlayStation 2', 'PlayStation Portable', 'PlayStation 3', 'Windows PC', 'PlayStation Network', 'Mac']
# ['Nintendo Switch', 'Xbox One', 'Windows PC'] ['Nintendo Switch', 'Xbox One', 'Windows PC']
# ['Windows PC', 'PlayStation 4', 'Xbox One'] ['PlayStation 2', 'Xbox', 'Windows PC', 'Xbox Series']
# ['Windows PC', 'Mac', 'Linux', 'Xbox One', 'Nintendo Switch', 'Xbox Series'] ['Windows PC']
# ['Windows PC', 'Xbox 360'] ['Xbox Live', 'Windows PC']
# ['Windows PC', 'PlayStation 4', 'Xbox One'] ['Xbox One', 'Nintendo Switch', 'Windows PC', 'PlayStation 4']
# ['Windows PC', 'PlayStation 4'] ['PlayStation 4', 'Windows PC']
# ['Windows PC'] ['Windows PC']
# ['PlayStation Vita', 'PlayStation 3', 'Windows PC'] ['PlayStation Vita', 'PlayStation 3', 'Windows PC']
# ['Windows PC', 'PlayStation 4', 'Xbox One'] ['Xbox One', 'PlayStation 4', 'Windows PC']
# ['Windows PC', 'Mac', 'Linux'] ['Windows PC']
# ['Nintendo Switch'] ['Windows PC']
# ['Windows PC', 'Wii U', 'Xbox 360', 'PlayStation 3'] ['PlayStation 3', 'Xbox 360', 'Windows PC', 'Wii U']
# ['Windows PC', 'Android', 'Mac', 'Wii U', 'Xbox 360', 'PlayStation 4', 'iOS', 'PlayStation 3', 'Xbox One', 'Nintendo Switch'] ['Xbox One', 'PlayStation 4', 'Xbox Series', 'Nintendo Switch', 'PlayStation 5', 'Windows PC', 'Wii U', 'Xbox 360', 'PlayStation 3', 'Mac']
# ['Windows PC', 'PlayStation 4', 'Xbox One'] ['PlayStation 4', 'Xbox One', 'Windows PC']
# ['Windows PC', 'Mac', 'PlayStation 4', 'iOS', 'Xbox One', 'PlayStation 5', 'Nintendo Switch', 'Xbox Series'] ['Windows PC', 'PlayStation 4', 'Nintendo Switch', 'Xbox One', 'Xbox Series']
# ['Nintendo Switch', 'Xbox One', 'PlayStation 4', 'Windows PC'] ['Nintendo Switch', 'Xbox One', 'PlayStation 4', 'Windows PC']
# ['PlayStation 4', 'Xbox One', 'Windows PC'] ['PlayStation 4', 'Xbox One', 'Windows PC']
# ['Nintendo Switch'] ['Nintendo Switch']
# ['PlayStation Network', 'Xbox Live', 'Windows PC'] ['PlayStation Network', 'Xbox Live', 'Windows PC']
# ['Windows PC', 'Mac', 'Xbox 360', 'PlayStation 3', 'Nintendo DS', 'Wii', 'Nintendo 3DS', 'PlayStation Portable'] ['Wii', 'Xbox 360', 'PlayStation 3', 'Nintendo DS', 'Nintendo 3DS', 'PlayStation Portable', 'Windows PC', 'PlayStation Network']
# ['Windows PC', 'PlayStation 4', 'Xbox One', 'PlayStation 5', 'Nintendo Switch', 'Xbox Series'] ['PlayStation 4', 'PlayStation 5', 'Xbox One', 'Xbox Series', 'Nintendo Switch', 'Windows PC']
# ['Windows PC'] ['Windows PC']
# ['Windows PC'] ['Windows PC']
# ['Windows PC'] ['Windows PC']
# ['PlayStation 4', 'Windows PC', 'Xbox One'] ['PlayStation 4', 'Windows PC', 'Xbox One']
# ['Windows PC', 'PlayStation 4', 'PlayStation 5', 'Nintendo Switch', 'Google Stadia'] ['Nintendo Switch', 'Windows PC', 'PlayStation 4']
# ['PlayStation 4'] ['PlayStation 4']
# ['Windows PC'] ['Windows PC']
# ['Windows PC', 'Mac', 'PlayStation 4', 'Xbox One', 'PlayStation 5', 'Xbox Series'] ['Windows PC', 'PlayStation 4', 'Xbox One', 'Mac']
# ['Windows PC', 'Xbox 360'] ['Xbox 360', 'Windows PC', 'Xbox Live', 'Nintendo Switch']
# ['Windows PC', 'Android', 'PlayStation 4', 'iOS', 'PlayStation 3', 'Wii', 'PlayStation Portable'] ['PlayStation 4']
# ['Windows PC', 'Windows Phone'] ['Windows PC', 'Windows Phone']
# ['Windows PC', 'PlayStation 4', 'Xbox One', 'PlayStation 5', 'Google Stadia', 'Xbox Series'] ['Windows PC', 'PlayStation 4', 'Xbox One', 'PlayStation 5', 'Xbox Series']
# ['Nintendo Switch'] ['Nintendo Switch']
# ['Windows PC', 'PlayStation 4'] ['PlayStation 4', 'Windows PC']
# ['Windows PC', 'Mac', 'PlayStation 4', 'Xbox One', 'PlayStation 5', 'Nintendo Switch', 'Xbox Series'] ['Xbox One', 'Xbox Series', 'Nintendo Switch', 'Windows PC', 'PlayStation 4', 'PlayStation 5']
# ['Windows PC', 'PlayStation 4', 'Xbox One', 'PlayStation 5', 'Nintendo Switch', 'Xbox Series'] ['Windows PC', 'Xbox One', 'Xbox Series']
# ['Windows PC', 'PlayStation 4', 'Nintendo Switch'] ['PlayStation 4', 'Nintendo Switch', 'Windows PC']
# ['Windows PC', 'Wii U', 'Xbox 360', 'PlayStation 3'] ['Xbox 360', 'PlayStation 3', 'Windows PC', 'Wii U']
# ['Windows PC', 'Mac', 'PlayStation 4', 'Xbox One', 'Nintendo Switch'] ['Windows PC', 'Xbox One', 'PlayStation 4', 'Nintendo Switch']
# ['Windows PC', 'Xbox', 'Xbox 360', 'PlayStation 2'] ['Xbox 360', 'PlayStation 2', 'Windows PC', 'Xbox', 'Xbox Series']
# ['Windows PC', 'Android', 'PlayStation 4', 'iOS', 'Xbox One', 'Nintendo Switch'] ['PlayStation 4']
# ['Nintendo Switch'] ['Nintendo Switch']
# ['Game Boy Advance', 'Nintendo GameCube', 'PlayStation 2', 'Windows PC'] ['Game Boy Advance', 'Nintendo GameCube', 'PlayStation 2', 'Windows PC']
# ['Windows PC', 'Mac', 'Linux', 'PlayStation 4', 'Xbox One', 'Nintendo Switch'] ['Xbox One', 'PlayStation 4', 'Windows PC', 'Nintendo Switch']
# ['Windows PC', 'Xbox Live'] ['Windows PC', 'Xbox Live']
# ['Windows PC', 'Xbox', 'PlayStation 4', 'PlayStation 2'] ['PlayStation 2', 'Xbox', 'Windows PC', 'Xbox Series']
# ['Windows PC', 'Linux', 'Mac'] ['Windows PC', 'Linux', 'Mac']
# ['Windows PC', 'Mac', 'Wii U', 'Linux', 'PlayStation 4', 'iOS', 'Nintendo 3DS', 'Xbox One', 'PlayStation Vita', 'New Nintendo 3DS'] ['Windows PC', 'Xbox One', 'Linux', 'Mac', 'PlayStation 4', 'Wii U', 'Nintendo 3DS', 'PlayStation Vita']
# ['PlayStation 3', 'Xbox 360', 'Windows PC'] ['PlayStation 3', 'Xbox 360', 'Windows PC']
# ['Windows PC', 'PlayStation 4', 'Nintendo Switch'] ['PlayStation 4', 'PlayStation 3', 'Windows PC', 'Nintendo Switch']
# ['Windows PC', 'Mac', 'Linux', 'Nintendo Switch'] ['Windows PC', 'Nintendo Switch']
# ['Windows PC', 'Android', 'Mac', 'iOS', 'PlayStation 5', 'Nintendo Switch'] ['Nintendo Switch', 'Windows PC', 'PlayStation 5', 'Xbox One', 'Xbox Series']
# ['Windows PC', 'Android', 'Mac', 'iOS', 'Nintendo Switch'] ['Nintendo Switch', 'Windows PC']
# ['Windows PC', 'Mac', 'Linux'] ['Windows PC']
# ['PlayStation 5', 'Xbox Series', 'Xbox One', 'Nintendo Switch', 'Windows PC', 'PlayStation 4'] ['PlayStation 5', 'Xbox Series', 'Xbox One', 'Nintendo Switch', 'Windows PC', 'PlayStation 4']
# ['Windows PC', 'Nintendo GameCube', 'Xbox', 'PlayStation 2'] ['PlayStation 2', 'Xbox', 'Nintendo GameCube', 'Windows PC']
# ['Windows PC', 'Mac', 'Linux', 'PlayStation 4', 'Xbox One'] ['PlayStation 4', 'Xbox One', 'Windows PC']
# ['Windows PC', 'Android', 'Mac', 'Linux', 'PlayStation 4', 'Xbox One', 'Nintendo Switch'] ['Nintendo Switch']
# ['Windows PC', 'PlayStation 4', 'Xbox One', 'Nintendo Switch'] ['Windows PC', 'Xbox One', 'PlayStation 4']
# ['Windows PC', 'PlayStation 4', 'Xbox One'] ['PlayStation 4', 'Windows PC', 'Xbox One']
# ['Windows PC', 'PlayStation 4', 'Nintendo Switch'] ['Windows PC', 'PlayStation 4', 'Nintendo Switch']
# ['Windows PC', 'PlayStation 4', 'Xbox One', 'PlayStation 5', 'Nintendo Switch', 'Xbox Series'] ['PlayStation 5', 'Xbox One', 'Xbox Series', 'Windows PC', 'PlayStation 4']
# ['SteamVR', 'Oculus Quest 2', 'Oculus Rift', 'Playstation VR2'] ['PlayStation 5', 'Windows PC']
# ['Windows PC', 'Android', 'Mac', 'Linux', 'iOS', 'Nintendo Switch'] ['Windows PC']
# ['Windows PC', 'PlayStation 4', 'Xbox One', 'PlayStation 5', 'Nintendo Switch', 'Google Stadia', 'Xbox Series'] []
# ['Windows PC', 'Mac', 'Linux', 'PlayStation 4', 'Xbox One'] ['PlayStation 4', 'Xbox One', 'Windows PC']
# ['PlayStation'] ['Nintendo Switch']
# ['Windows PC', 'PlayStation 4', 'Xbox One'] ['Windows PC', 'Xbox One', 'PlayStation 4']
# ['Windows PC', 'Mac'] ['Windows PC', 'Mac']
# ['Windows PC', 'Android', 'Mac', 'Xbox 360', 'iOS'] ['Xbox 360', 'Windows PC', 'Nintendo DS']
# ['PlayStation 2', 'Xbox', 'Wii', 'Windows PC'] ['PlayStation 2', 'Xbox', 'Wii', 'Windows PC']
# ['Windows PC', 'Mac', 'Xbox 360', 'Linux', 'PlayStation 4', 'Xbox One'] ['PlayStation 4', 'Windows PC', 'Xbox 360', 'Xbox One', 'Mac', 'Linux']
# ['Windows PC', 'Xbox 360', 'PlayStation 3', 'Xbox One'] ['PlayStation 3', 'Xbox 360']
# ['Windows PC', 'PlayStation 4', 'Xbox One'] ['PlayStation', 'Game Boy Advance', 'Windows PC', 'Xbox Live', 'Sega Saturn', 'Atari Jaguar', 'SNES', '3DO Interactive Multiplayer', 'PlayStation 4', 'Xbox One', 'Android', 'Nintendo Switch', 'iOS']
# ['Windows PC', 'Mac', 'Xbox 360', 'PlayStation 3', 'Nintendo Switch'] ['Xbox 360', 'PlayStation 3', 'Windows PC']
# ['Windows PC'] ['Windows PC']
# ['PlayStation 3', 'Xbox 360', 'Windows PC'] ['PlayStation 3', 'Xbox 360', 'Windows PC']
# ['Nintendo DS', 'PlayStation Portable', 'Windows PC', 'PlayStation Network', 'PlayStation 2'] ['Nintendo DS', 'PlayStation Portable', 'Windows PC', 'PlayStation Network', 'PlayStation 2']
# ['Windows PC', 'Mac', 'Linux', 'PlayStation 4', 'Xbox One', 'Nintendo Switch'] ['PlayStation 4', 'Windows PC', 'Xbox One', 'Nintendo Switch']
# ['Windows PC', 'PlayStation 4', 'Xbox One'] ['Xbox One', 'PlayStation 4', 'Windows PC']
# ['Windows PC'] ['Windows PC']
# ['Windows PC', 'Mac', 'Linux', 'PlayStation 4', 'Xbox One'] ['Windows PC', 'Xbox One', 'PlayStation 4']
# ['Windows PC', 'PlayStation 4', 'Xbox One', 'PlayStation 5', 'Xbox Series'] ['Windows PC', 'PlayStation 4', 'Xbox One']
# ['WiiWare'] ['WiiWare']
# ['PlayStation 4'] ['PlayStation 4']
# ['Windows PC', 'PlayStation 3', 'PlayStation Vita'] ['PlayStation Network']
# ['Windows PC', 'Mac', 'PlayStation 4', 'Xbox One', 'PlayStation 5', 'Nintendo Switch'] ['Xbox Series', 'Nintendo Switch', 'PlayStation 4', 'PlayStation 5', 'Windows PC', 'Xbox One']
# ['Windows PC', 'Wii U', 'PlayStation 4', 'Xbox One', 'Nintendo Switch'] ['PlayStation 4', 'Xbox One', 'Wii U', 'Windows PC', 'Nintendo Switch']
# ['Windows PC'] ['Windows PC']
# ['Windows PC', 'Xbox 360'] ['Windows PC', 'Xbox Live']
# ['Windows PC', 'Xbox 360', 'PlayStation 4', 'PlayStation 3', 'Xbox One'] ['PlayStation 4', 'Xbox One', 'Xbox 360', 'Windows PC', 'PlayStation 3']
# ['Xbox One', 'Nintendo Switch', 'PlayStation 4', 'Windows PC'] ['Xbox One', 'Nintendo Switch', 'PlayStation 4', 'Windows PC']
# ['PlayStation 2', 'Xbox'] ['PlayStation 2', 'Xbox']
# ['Windows PC', 'PlayStation 4', 'Xbox One', 'Nintendo Switch', 'Google Stadia'] ['Xbox One', 'Nintendo Switch', 'Windows PC', 'PlayStation 4']
# ['Windows PC', 'PlayStation 4', 'Xbox One', 'PlayStation 5', 'Nintendo Switch', 'Xbox Series'] ['PlayStation 4', 'Nintendo Switch', 'PlayStation 5', 'Xbox Series', 'Windows PC', 'Xbox One']
# ['PlayStation 2'] ['PlayStation 2']
# ['Windows PC'] ['Windows PC']
# ['Windows PC', 'Nintendo Switch'] ['Windows PC', 'Nintendo Switch']
# ['Windows PC', 'Xbox 360', 'PlayStation 3'] ['PlayStation 3', 'Xbox 360', 'Wii', 'Windows PC', 'Xbox Live', 'PlayStation Network']
# ['Windows PC', 'PlayStation Vita'] ['PlayStation Vita', 'Windows PC']
# ['Windows PC', 'Mac', 'Linux', 'PlayStation 4', 'Xbox One', 'Nintendo Switch'] ['Nintendo Switch']
# ['Windows PC', 'Mac', 'PlayStation 4', 'Xbox One', 'Nintendo Switch'] ['Windows PC', 'Mac', 'PlayStation 4', 'Xbox One']
# ['Windows PC', 'Mac', 'Xbox 360', 'Wii', 'OnLive Game System', 'PlayStation 2', 'PlayStation Portable'] ['Wii', 'PlayStation Portable', 'PlayStation 2', 'Xbox 360', 'Windows PC', 'PlayStation Network', 'Xbox Live']
# ['Windows PC', 'PlayStation 4', 'Xbox One', 'Nintendo Switch', 'Google Stadia'] ['Xbox One', 'PlayStation 4', 'Nintendo Switch', 'Windows PC']
# ['Windows PC', 'Android', 'PlayStation 4', 'iOS', 'Xbox One', 'Nintendo Switch'] ['Nintendo Switch', 'PlayStation 4', 'Xbox One', 'Windows PC']
# ['Windows PC', 'Mac', 'Wii U', 'Linux', 'PlayStation 4', 'Xbox One', 'PlayStation Vita', 'Nintendo Switch'] ['Nintendo Switch', 'Wii U', 'Windows PC']
# ['Windows PC', 'Android', 'Mac', 'iOS', 'Xbox One', 'Nintendo Switch'] ['Windows PC']
# ['Windows PC', 'PlayStation Vita'] ['PlayStation Vita', 'PlayStation 4']
# ['Windows PC'] ['Windows PC']
# ['Windows PC', 'Mac', 'PlayStation 4', 'SteamVR', 'PlayStation VR', 'Xbox One', 'PlayStation 5', 'Xbox Series', 'Oculus Rift', 'Playstation VR2'] ['PlayStation 4', 'Xbox One', 'Windows PC', 'Xbox Series', 'Nintendo Switch', 'PlayStation 5']
# ['Windows PC', 'PlayStation 4', 'Xbox One', 'PlayStation 5', 'Xbox Series'] ['Windows PC', 'PlayStation 4', 'PlayStation 5', 'Xbox One', 'Xbox Series']
# ['Windows PC', 'PlayStation 4', 'Xbox One'] ['Xbox One', 'PlayStation 4', 'Windows PC']
# ['Windows PC', 'PlayStation 4', 'Xbox One'] ['PlayStation 4', 'Xbox One', 'Windows PC']
# ['Windows PC'] ['Windows PC', 'Nintendo DS']
# ['PlayStation 3', 'Xbox 360', 'Windows PC'] ['PlayStation 3', 'Xbox 360', 'Windows PC']
# ['Windows PC', 'PlayStation 4', 'SteamVR', 'PlayStation VR', 'Xbox One', 'Oculus Rift'] ['Windows PC', 'PlayStation 4']
# ['Windows PC', 'PlayStation 4', 'Xbox One'] ['PlayStation 4', 'Xbox One', 'Windows PC']
# ['Windows PC', 'PlayStation 4', 'Xbox One', 'PlayStation 5', 'Xbox Series'] ['Xbox One', 'Xbox Series', 'Windows PC', 'PlayStation 4', 'PlayStation 5']
# ['Windows PC', 'Xbox 360', 'PlayStation 3'] ['PlayStation 3', 'Xbox 360', 'PlayStation Portable', 'Nintendo DS', 'Windows PC']
# ['Windows PC', 'PlayStation 4'] ['PlayStation 4', 'Windows PC']
# ['Windows PC', 'Mac', 'Linux', 'PlayStation 4', 'Xbox One', 'Nintendo Switch'] ['Windows PC']
# ['Windows PC', 'PlayStation 4', 'Xbox One', 'Nintendo Switch'] ['Nintendo Switch']
# ['Windows PC', 'Mac', 'Xbox 360', 'Linux'] ['Windows PC', 'Xbox Live']
# ['PlayStation 4'] ['PlayStation 4']
# ['Windows PC'] ['Windows PC']
# ['Windows PC'] ['Windows PC']
# ['Windows PC', 'Mac', 'Linux'] ['Windows PC', 'Linux']
# ['Windows PC', 'PlayStation 4'] ['Windows PC', 'PlayStation 4']
# ['Windows PC', 'Mac', 'Nintendo GameCube', 'Xbox', 'PlayStation 2'] ['Xbox', 'PlayStation 2', 'Nintendo GameCube', 'Game Boy Advance', 'Windows PC', 'Xbox Series']
# ['Game Boy Advance'] ['Game Boy Advance']
# ['Windows PC'] ['Windows PC']
# ['Windows PC', 'Xbox', 'Wii', 'PlayStation 2'] ['PlayStation 2', 'Xbox', 'Windows PC']
# ['Windows PC', 'Mac', 'Xbox', 'Linux'] ['Mac', 'Windows PC']
# ['Windows PC', 'Mac', 'Linux', 'PlayStation 4', 'Xbox One'] ['Windows PC', 'Linux', 'Mac', 'Xbox One']
# ['Windows PC', 'Linux', 'PlayStation 4', 'Xbox One', 'Nintendo Switch'] ['PlayStation 4', 'Nintendo Switch', 'Windows PC']
# ['PlayStation Network'] ['PlayStation Network']
# ['Windows PC', 'PlayStation 4', 'Nintendo Switch'] ['Windows PC', 'PlayStation 4', 'Nintendo Switch']
# ['PlayStation 4', 'Xbox One', 'Windows PC'] ['PlayStation 4', 'Xbox One', 'Windows PC']
# ['Windows PC', 'Mac', 'Linux', 'PlayStation 4', 'Xbox One', 'Nintendo Switch'] ['PlayStation 4', 'Windows PC', 'Xbox One', 'Nintendo Switch']
# ['Windows PC'] ['Windows PC']
# ['Nintendo Switch', 'Windows PC', 'PlayStation 4', 'Xbox One'] ['Nintendo Switch', 'Windows PC', 'PlayStation 4', 'Xbox One']
# ['Windows PC', 'Mac', 'Linux'] ['Mac', 'Linux', 'Windows PC']
# ...
# ['Windows PC', 'Xbox 360', 'Linux', 'PlayStation 3'] ['Windows PC', 'Xbox Live', 'PlayStation Network']
# ['Windows PC', 'PlayStation 4', 'Xbox One'] ['PlayStation 4', 'Xbox One', 'Windows PC']
# ['Windows PC', 'Android', 'Mac', 'Xbox 360', 'iOS', 'PlayStation 3', 'Nintendo Switch'] ['PlayStation 3', 'Xbox 360', 'Windows PC', 'Nintendo Switch']
# ['Windows PC', 'Wii U', 'Xbox 360', 'PlayStation 3'] ['Wii U', 'Xbox 360', 'Windows PC', 'PlayStation 3']
# ['Windows PC', 'Xbox 360', 'PlayStation 3'] ['Xbox 360', 'PlayStation 3', 'Windows PC']
# ['Windows PC', 'Mac', 'PlayStation 4', 'PlayStation 3', 'Xbox One'] ['PlayStation 3', 'PlayStation 4']
# ['Windows PC', 'Wii U', 'Xbox 360', 'PlayStation 3', 'Nintendo 3DS'] ['Nintendo 3DS', 'Xbox 360', 'PlayStation 3', 'Wii U', 'Windows PC']
# ['Xbox Series', 'Nintendo Switch', 'Windows PC', 'PlayStation 4', 'PlayStation 5', 'Xbox One'] ['Xbox Series', 'Nintendo Switch', 'Windows PC', 'PlayStation 4', 'PlayStation 5', 'Xbox One']
# ['Windows PC', 'PlayStation 4', 'Xbox One', 'PlayStation 5', 'Xbox Series'] ['Xbox One', 'Xbox Series', 'Windows PC', 'PlayStation 4', 'PlayStation 5']
# ['Windows PC', 'Nintendo Switch'] ['Xbox One', 'Xbox Series', 'Nintendo Switch', 'Windows PC', 'PlayStation 4', 'PlayStation 5']
# ['PlayStation 5', 'PlayStation 4', 'Windows PC'] ['PlayStation 5', 'PlayStation 4', 'Windows PC']
# ['Windows PC', 'PlayStation 4', 'Xbox One', 'PlayStation 5', 'Nintendo Switch', 'Xbox Series'] ['Xbox One', 'Windows PC', 'Xbox Series', 'Nintendo Switch', 'PlayStation 4', 'PlayStation 5']
# ['Xbox One', 'Xbox Series', 'Windows PC', 'PlayStation 4', 'PlayStation 5'] ['Xbox One', 'Xbox Series', 'Windows PC', 'PlayStation 4', 'PlayStation 5']
# ['Xbox Series', 'Nintendo Switch', 'Windows PC', 'PlayStation 4', 'PlayStation 5', 'Xbox One'] ['Xbox Series', 'Nintendo Switch', 'Windows PC', 'PlayStation 4', 'PlayStation 5', 'Xbox One']
# ['Xbox Series', 'Windows PC', 'PlayStation 5'] ['Xbox Series', 'Windows PC', 'PlayStation 5']
# ['Windows PC', 'Nintendo Switch'] ['Windows PC', 'Nintendo Switch']
# ['Windows PC', 'Xbox Series'] ['Xbox', 'Windows PC', 'Xbox Series']
# ['Arcade', 'Sega Saturn'] ['Sega Saturn', 'Xbox Live']
# ['PlayStation 5', 'Xbox One', 'Xbox Series', 'Windows PC', 'PlayStation 4'] ['PlayStation 5', 'Xbox One', 'Xbox Series', 'Windows PC', 'PlayStation 4']
# ['Windows PC', 'PlayStation 4', 'Xbox One', 'PlayStation 5', 'Xbox Series'] ['PlayStation 5', 'Xbox One', 'Xbox Series', 'Windows PC', 'PlayStation 4']
# ['Windows PC', 'PlayStation 4', 'Xbox One', 'PlayStation 5', 'Xbox Series'] ['Xbox Series', 'Windows PC', 'PlayStation 5']
# ['Windows PC', 'PlayStation 4', 'PlayStation 5'] ['Windows PC', 'PlayStation 4', 'PlayStation 5']
# ['Game Boy Advance'] ['Game Boy Advance']
# ['Nintendo Switch', 'Windows PC'] ['Nintendo Switch', 'Windows PC']
# ['Xbox One', 'Xbox Series', 'Nintendo Switch', 'Windows PC', 'PlayStation 4', 'PlayStation 5'] ['Xbox One', 'Xbox Series', 'Nintendo Switch', 'Windows PC', 'PlayStation 4', 'PlayStation 5']
# ['Windows PC', 'Mac', 'PlayStation 4', 'Xbox One', 'PlayStation 5', 'Nintendo Switch'] ['Nintendo Switch']
# ['Windows PC', 'PlayStation 4', 'Xbox One', 'PlayStation 5', 'Nintendo Switch', 'Xbox Series'] ['Xbox Series', 'Nintendo Switch', 'Windows PC', 'PlayStation 4', 'PlayStation 5', 'Xbox One']
# ['PlayStation 4', 'PlayStation 5', 'Nintendo Switch', 'Windows PC'] ['PlayStation 4', 'PlayStation 5', 'Nintendo Switch', 'Windows PC']
# ['Windows PC', 'Xbox Series'] ['Windows PC', 'Xbox Series', 'Xbox Live']
# ['Windows PC', 'Xbox One', 'Xbox Series'] ['Windows PC', 'Xbox One', 'Xbox Series']
# ['Windows PC', 'Nintendo Switch'] ['Nintendo Switch', 'Windows PC']
# ['Windows PC', 'Mac'] ['Windows PC']
# ['Windows PC', 'PlayStation 4', 'Xbox One', 'PlayStation 5', 'Google Stadia', 'Xbox Series'] ['Xbox 360', 'Xbox Live', 'Xbox Series']
# ['Windows PC'] ['Windows PC', 'PlayStation 4', 'Xbox One']
# ['Windows PC', 'PlayStation 4', 'Xbox One', 'PlayStation 5', 'Xbox Series'] ['Windows PC', 'PlayStation 4', 'PlayStation 5', 'Xbox One', 'Xbox Series']
# ['Windows PC', 'PlayStation 5', 'Nintendo Switch', 'Xbox Series'] ['Nintendo Switch', 'Windows PC', 'PlayStation 5', 'Xbox Series']
# ['Windows PC'] ['Windows PC']
# ['Windows PC', 'PlayStation 5', 'Xbox Series'] ['Windows PC', 'PlayStation 5', 'Xbox Series']
# ['Windows PC', 'PlayStation 4', 'Xbox One', 'PlayStation 5', 'Nintendo Switch', 'Xbox Series'] ['PlayStation 5', 'Windows PC', 'Nintendo Switch', 'Xbox One', 'PlayStation 4', 'Xbox Series']
# ['Windows PC', 'PlayStation 4', 'Xbox One', 'PlayStation 5', 'Nintendo Switch', 'Xbox Series'] ['Xbox One', 'Xbox Series', 'Nintendo Switch', 'Windows PC', 'PlayStation 4', 'PlayStation 5']
# ['Windows PC', 'PlayStation 4', 'Xbox One'] ['Windows PC', 'PlayStation 4', 'Xbox One']
# ['Xbox Series', 'Windows PC', 'PlayStation 5'] ['Xbox Series', 'Windows PC', 'PlayStation 5']
# ['Nintendo Switch'] ['Nintendo Switch']
# ['Xbox Series', 'PlayStation 5', 'Windows PC'] ['Xbox Series', 'PlayStation 5', 'Windows PC']
# ['Windows PC', 'PlayStation 5', 'Xbox Series'] ['Windows PC', 'Xbox Series', 'PlayStation 5']
# ['PlayStation 5', 'Nintendo Switch', 'Windows PC', 'PlayStation 4'] ['PlayStation 5', 'Nintendo Switch', 'Windows PC', 'PlayStation 4']
# ['Windows PC', 'PlayStation 4', 'Xbox One', 'PlayStation 5', 'Xbox Series'] ['PlayStation 5', 'Xbox One', 'Xbox Series', 'Windows PC', 'PlayStation 4']
# ['Windows PC', 'PlayStation 4', 'Xbox One', 'PlayStation 5', 'Nintendo Switch', 'Xbox Series'] ['Windows PC']
# ['Windows PC', 'Xbox One', 'Xbox Series'] ['PlayStation 5', 'Xbox One', 'Xbox Series', 'Nintendo Switch', 'Windows PC', 'PlayStation 4']
# ['Windows PC', 'PlayStation 5', 'Xbox Series'] ['Windows PC', 'PlayStation 5', 'Xbox Series']
# ['Windows PC'] ['Windows PC']
# ['Xbox Series', 'Nintendo Switch', 'Windows PC', 'PlayStation 4', 'PlayStation 5', 'Xbox One'] ['Xbox Series', 'Nintendo Switch', 'Windows PC', 'PlayStation 4', 'PlayStation 5', 'Xbox One']
# ['Windows PC'] ['Windows PC']
# ['Windows PC', 'Nintendo Switch'] ['Windows PC', 'Nintendo Switch']
# ['Windows PC', 'Xbox One', 'Nintendo Switch', 'Xbox Series'] ['Windows PC', 'Xbox One']
# ['Windows PC', 'PlayStation 4', 'Xbox One', 'PlayStation 5', 'Xbox Series'] ['Windows PC', 'PlayStation 4', 'Xbox One', 'PlayStation 5', 'Xbox Series']
# ['PlayStation 4', 'Nintendo Switch'] ['Nintendo Switch', 'PlayStation 4']
# ['Windows PC', 'PlayStation 5', 'Nintendo Switch', 'Xbox Series'] ['Windows PC', 'Nintendo Switch']
# ['Windows PC', 'PlayStation 4', 'Xbox One', 'PlayStation 5', 'Nintendo Switch', 'Xbox Series'] ['Windows PC', 'Xbox One', 'PlayStation 4']
# ['Windows PC', 'PlayStation 4', 'Xbox One', 'PlayStation 5', 'Nintendo Switch', 'Xbox Series'] ['Windows PC', 'PlayStation 4', 'PlayStation 5', 'Xbox One', 'Xbox Series', 'Nintendo Switch']
# ['Windows PC', 'PlayStation 5', 'Nintendo Switch', 'Xbox Series'] ['Nintendo Switch', 'Windows PC', 'PlayStation 5', 'Xbox Series']
# ['PlayStation 5', 'Nintendo Switch', 'Windows PC', 'iOS', 'Xbox Series'] ['PlayStation 5', 'Nintendo Switch', 'Windows PC', 'iOS', 'Xbox Series']
# [] ['Nintendo Switch', 'Windows PC', 'PlayStation 4', 'PlayStation 5']
# ['Windows PC', 'Xbox One', 'Xbox Series'] ['Windows PC', 'Xbox One', 'Xbox Series']
# ['Windows PC', 'PlayStation 4', 'Xbox One', 'PlayStation 5', 'Nintendo Switch', 'Xbox Series'] ['Xbox Series', 'Nintendo Switch', 'Windows PC', 'PlayStation 4', 'PlayStation 5', 'Xbox One']
# ['PlayStation 4', 'PlayStation 5', 'Xbox One', 'Xbox Series', 'Nintendo Switch', 'Windows PC'] ['PlayStation 4', 'PlayStation 5', 'Xbox One', 'Xbox Series', 'Nintendo Switch', 'Windows PC']
# ['Nintendo Switch', 'Windows PC', 'PlayStation 4', 'PlayStation 5', 'Xbox One', 'Xbox Series'] ['Nintendo Switch', 'Windows PC', 'PlayStation 4', 'PlayStation 5', 'Xbox One', 'Xbox Series']
# ['PlayStation 4', 'PlayStation Vita', 'Nintendo Switch'] ['PlayStation 4', 'PlayStation Vita', 'Nintendo Switch']
# ['Windows PC'] ['Windows PC']
# ['Windows PC'] ['Windows PC']
# ['Windows PC', 'PlayStation 4', 'Xbox One', 'Nintendo Switch'] ['PlayStation 4', 'Xbox One', 'Xbox Series', 'Nintendo Switch', 'Windows PC']
# ['PlayStation 5', 'Xbox One', 'Xbox Series', 'Nintendo Switch', 'Windows PC', 'PlayStation 4'] ['PlayStation 5', 'Xbox One', 'Xbox Series', 'Nintendo Switch', 'Windows PC', 'PlayStation 4']
# ['Windows PC', 'PlayStation 5', 'Xbox Series'] ['Windows PC', 'PlayStation 5', 'Xbox Series']
# ['Xbox One', 'Xbox Series', 'Nintendo Switch', 'Windows PC', 'PlayStation 4', 'PlayStation 5'] ['Xbox One', 'Xbox Series', 'Nintendo Switch', 'Windows PC', 'PlayStation 4', 'PlayStation 5']
# ['Windows PC', 'PlayStation 5', 'Xbox Series'] ['Windows PC', 'PlayStation 5', 'Xbox Series']
# ['Windows PC', 'PlayStation 5', 'Xbox Series'] ['Windows PC', 'PlayStation 5', 'Xbox Series']
# ['PlayStation 5', 'Xbox One', 'Xbox Series', 'Windows PC'] ['PlayStation 5', 'Xbox One', 'Xbox Series', 'Windows PC']
# ['Windows PC', 'PlayStation 4', 'Xbox One', 'PlayStation 5', 'Nintendo Switch', 'Xbox Series'] ['PlayStation 5', 'Xbox One', 'Xbox Series', 'Nintendo Switch', 'Windows PC', 'PlayStation 4']
# ['Windows PC', 'PlayStation 5', 'Xbox Series'] ['Windows PC', 'PlayStation 5', 'Xbox Series']
# ['Windows PC', 'Nintendo Switch'] ['Nintendo Switch', 'Windows PC']
# ['Xbox Series', 'Nintendo Switch', 'Windows PC', 'PlayStation 4', 'PlayStation 5', 'Xbox One'] ['Xbox Series', 'Nintendo Switch', 'Windows PC', 'PlayStation 4', 'PlayStation 5', 'Xbox One']
# ['PlayStation 5', 'Windows PC'] ['PlayStation 5', 'Windows PC']
# ['Windows PC', 'PlayStation 5', 'Xbox Series'] ['Windows PC', 'PlayStation 5', 'Xbox Series']
# ['Windows PC', 'PlayStation 5', 'Xbox Series'] ['Windows PC', 'PlayStation 5', 'Xbox Series']
# [] ['Windows PC', 'PlayStation 4', 'PlayStation 5']
# ['Windows PC'] ['PlayStation Vita']
# ['Windows PC'] ['Windows PC']
# ['Windows PC', 'PlayStation 5', 'Xbox Series'] ['Xbox Series', 'Windows PC', 'PlayStation 5']
# ['Windows PC'] ['Windows PC']
# ['Xbox One', 'Xbox Series', 'Nintendo Switch', 'Windows PC'] ['Xbox One', 'Xbox Series', 'Nintendo Switch', 'Windows PC']
# ['Windows PC', 'PlayStation 5', 'Xbox Series'] ['PlayStation 5', 'Xbox Series', 'Windows PC']
# ['Windows PC', 'PlayStation 4', 'Xbox One', 'Nintendo Switch'] ['Nintendo Switch', 'Windows PC', 'PlayStation 4', 'Xbox One']
# ['Windows PC', 'PlayStation 4', 'Xbox One', 'PlayStation 5', 'Xbox Series'] ['Xbox One', 'Xbox Series', 'Windows PC', 'PlayStation 4', 'PlayStation 5']
# ['Windows PC', 'PlayStation 4', 'PlayStation 5', 'Nintendo Switch'] ['Windows PC', 'PlayStation 4', 'PlayStation 5', 'Nintendo Switch']
# ['PlayStation 5', 'Xbox One', 'Xbox Series', 'Nintendo Switch', 'Windows PC', 'PlayStation 4'] ['PlayStation 5', 'Xbox One', 'Xbox Series', 'Nintendo Switch', 'Windows PC', 'PlayStation 4']
# ['Windows PC', 'PlayStation 4', 'Xbox One', 'PlayStation 5', 'Xbox Series'] ['Windows PC', 'Xbox One', 'PlayStation 4', 'Xbox Series', 'PlayStation 5']
# ['Windows PC', 'PlayStation 4', 'PlayStation 5'] ['Windows PC', 'PlayStation 5', 'PlayStation 4']
# ['Xbox Series', 'PlayStation 5', 'Windows PC'] ['Xbox Series', 'PlayStation 5', 'Windows PC']
# ['Windows PC', 'PlayStation 4', 'PlayStation 5', 'Xbox One', 'Xbox Series', 'Nintendo Switch'] ['Windows PC', 'PlayStation 4', 'PlayStation 5', 'Xbox One', 'Xbox Series', 'Nintendo Switch']
# ['Windows PC', 'PlayStation 5'] ['Windows PC', 'PlayStation 5']
# ['Windows PC', 'PlayStation 4', 'PlayStation 5'] ['Windows PC', 'PlayStation 4', 'PlayStation 5']
# ['Xbox Series'] ['Xbox Series']
# ['Nintendo Switch', 'Windows PC', 'PlayStation 4'] ['Nintendo Switch', 'Windows PC', 'PlayStation 4']
# ['Windows PC'] ['Windows PC']
# ['Windows PC', 'PlayStation 5'] ['Windows PC', 'PlayStation 5']
# ['Windows PC', 'PlayStation 4', 'PlayStation 5', 'Xbox One', 'Xbox Series', 'Nintendo Switch'] ['Windows PC', 'PlayStation 4', 'PlayStation 5', 'Xbox One', 'Xbox Series', 'Nintendo Switch']
# ['Windows PC', 'Nintendo Switch'] ['Windows PC', 'Nintendo Switch']
# ['PlayStation 5', 'Xbox Series', 'Windows PC'] ['PlayStation 5', 'Xbox Series', 'Windows PC']
# ['Xbox Series', 'Nintendo Switch', 'Windows PC', 'PlayStation 4', 'PlayStation 5', 'Xbox One'] ['Xbox Series', 'Nintendo Switch', 'Windows PC', 'PlayStation 4', 'PlayStation 5', 'Xbox One']
# ['Windows PC', 'Xbox 360', 'PlayStation 3'] ['Xbox 360', 'PlayStation 3', 'Windows PC']
# ['Xbox One', 'Xbox Series', 'Nintendo Switch', 'Windows PC', 'PlayStation 4', 'PlayStation 5'] ['Xbox One', 'Xbox Series', 'Nintendo Switch', 'Windows PC', 'PlayStation 4', 'PlayStation 5']
# ['Windows PC', 'PlayStation 5', 'Xbox Series'] ['Windows PC', 'PlayStation 5', 'Xbox Series']
# ['PlayStation 4', 'PlayStation 5', 'Xbox One', 'Xbox Series', 'Windows PC'] ['PlayStation 4', 'PlayStation 5', 'Xbox One', 'Xbox Series', 'Windows PC']
# ['Windows PC'] ['Windows PC']
# ['Windows PC'] ['Windows PC']
# ['Windows PC', 'PlayStation 5', 'Xbox Series'] ['Windows PC', 'PlayStation 5', 'Xbox Series']
# ['Windows PC', 'PlayStation 4', 'PlayStation 5'] ['Windows PC', 'PlayStation 4', 'PlayStation 5']
# ['PlayStation 5', 'Xbox One', 'Xbox Series', 'Nintendo Switch', 'Windows PC', 'PlayStation 4'] ['PlayStation 5', 'Xbox One', 'Xbox Series', 'Nintendo Switch', 'Windows PC', 'PlayStation 4']
# ['PlayStation 4', 'PlayStation 5', 'Xbox One', 'Xbox Series', 'Windows PC'] ['PlayStation 4', 'PlayStation 5', 'Xbox One', 'Xbox Series', 'Windows PC']
# ['Xbox Series', 'PlayStation 5', 'Windows PC'] ['Xbox Series', 'PlayStation 5', 'Windows PC']
# ['Windows PC'] ['Windows PC']
# ['Windows PC'] ['Windows PC']
# ['Windows PC', 'Nintendo Switch'] ['Xbox Series', 'Nintendo Switch', 'Windows PC', 'Xbox One']
# ['Windows PC', 'PlayStation 4', 'Xbox One', 'Nintendo Switch'] ['Xbox One', 'Xbox Series', 'Windows PC', 'PlayStation 4', 'PlayStation 5']
# ['Windows PC', 'PlayStation 4', 'Xbox One', 'PlayStation 5', 'Xbox Series'] ['Windows PC', 'PlayStation 4', 'PlayStation 5', 'Xbox One', 'Xbox Series']
# ['Windows PC', 'PlayStation 4', 'PlayStation 5', 'Xbox Series'] ['PlayStation 4', 'PlayStation 5', 'Xbox One', 'Xbox Series', 'Windows PC']
# ['Nintendo Switch', 'Windows PC', 'PlayStation 4', 'PlayStation 5'] ['Nintendo Switch', 'Windows PC', 'PlayStation 4', 'PlayStation 5']
# ['Dreamcast', 'Xbox Live'] ['Dreamcast', 'Xbox Live']
# ['Windows PC', 'PlayStation 4', 'PlayStation 5', 'Xbox One', 'Xbox Series', 'Nintendo Switch'] ['Windows PC', 'PlayStation 4', 'PlayStation 5', 'Xbox One', 'Xbox Series', 'Nintendo Switch']
# ['Windows PC', 'PlayStation 4', 'Xbox One', 'PlayStation 5', 'Xbox Series'] ['PlayStation 4', 'Xbox One', 'Windows PC', 'Xbox Series', 'PlayStation 5']
# ['Windows PC'] ['Windows PC']
# ['PlayStation 4', 'Nintendo Switch'] ['PlayStation 4', 'Nintendo Switch']
# ['PlayStation 4', 'PlayStation 5'] ['PlayStation 4', 'PlayStation 5']
# ['PlayStation 4', 'PlayStation 5', 'Xbox One', 'Xbox Series', 'Windows PC'] ['PlayStation 4', 'PlayStation 5', 'Xbox One', 'Xbox Series', 'Windows PC']
# ['Android', 'iOS', 'Nintendo 3DS'] ['Nintendo 3DS']
# ['Windows PC', 'PlayStation 5', 'Xbox Series'] ['Windows PC', 'PlayStation 5', 'Xbox Series']
# ['Windows PC', 'Xbox Series'] ['Windows PC', 'PlayStation 5', 'Xbox Series']
# ['Windows PC', 'PlayStation 5', 'Xbox Series'] ['Windows PC', 'Xbox Series', 'PlayStation 5']
# ['PlayStation 5', 'Xbox One', 'Xbox Series', 'Nintendo Switch', 'Windows PC', 'PlayStation 4'] ['PlayStation 5', 'Xbox One', 'Xbox Series', 'Nintendo Switch', 'Windows PC', 'PlayStation 4']
# ['Windows PC', 'Xbox Series'] ['Windows PC', 'Xbox Series']
# ['Windows PC', 'PlayStation 4', 'PlayStation 5'] ['Windows PC', 'PlayStation 4', 'PlayStation 5']
# ['Windows PC', 'PlayStation 4', 'Xbox One', 'PlayStation 5', 'Xbox Series'] ['Xbox Series', 'Windows PC', 'PlayStation 4', 'PlayStation 5', 'Xbox One']
# ['WonderSwan', 'Game Boy Advance', 'PlayStation Portable'] ['Game Boy Advance', 'PlayStation Portable', 'PlayStation Network']
# ['Nintendo GameCube', 'PlayStation 4', 'PlayStation 3', 'PlayStation 2'] ['PlayStation 2', 'Nintendo GameCube']
# ['Windows PC', 'PlayStation 5', 'Xbox Series'] ['Xbox Series', 'Windows PC', 'PlayStation 5']

# %%
new_platforms_1_2_list = list()
for elem, elem_2 in zip(df['platforms'].values, df['platforms_2'].values):
    if isinstance(elem, list) and isinstance(elem_2, list):
        new_platforms_1_2_list.append(list(set(elem + elem_2)))
    else:
        new_platforms_1_2_list.append(elem)

# %%
new_platforms_1_2_list
# Out:
# [['Xbox One', 'PlayStation 4', 'Nintendo Switch', 'Windows PC'],
#  ['PlayStation Network',
#   'PlayStation 3',
#   'Xbox Live',
#   'Xbox 360',
#   'Linux',
#   'Windows PC'],
#  ['PlayStation 3', 'Xbox 360', 'Windows PC'],
#  ['Google Stadia', 'Xbox One', 'PlayStation 4', 'Windows PC'],
#  ['Xbox One', 'Xbox Series', 'Windows PC'],
#  ['PlayStation 3',
#   'PlayStation 4',
#   'Xbox Series',
#   'Xbox Live',
#   'Xbox 360',
#   'Xbox',
#   'Mac',
#   'Android',
#   'PlayStation 2',
#   'Game Boy Advance',
#   'iOS',
#   'Windows PC'],
#  nan,
#  ['Linux', 'Mac', 'Windows PC'],
#  ['PlayStation 3',
#   'PlayStation 4',
#   'Nintendo Switch',
#   'Xbox One',
#   'PlayStation Vita',
#   'Wii U',
#   'Nintendo 3DS',
#   'Windows PC'],
#  ['Xbox One', 'PlayStation 4', 'Windows PC'],
#  ['Oculus Quest 2',
#   'Oculus VR',
#   'Oculus Quest',
#   'SteamVR',
#   'Windows PC',
#   'Playstation VR2'],
#  ['Windows PC',
#   'PlayStation 4',
#   'Xbox One',
#   'PlayStation Vita',
#   'Nintendo Switch'],
#  ['PlayStation 3',
#   'PlayStation Network',
#   'Xbox Live',
#   'Xbox 360',
#   'Mac',
#   'Nintendo DS',
#   'Wii',
#   'Windows PC'],
#  ['Xbox Live'],
#  ['PlayStation Network',
#   'PlayStation 3',
#   'PlayStation 4',
#   'Windows PC',
#   'iOS'],
#  nan,
#  ['PlayStation Vita', 'PlayStation 3', 'PlayStation 4', 'Windows PC'],
#  ['Windows PC'],
#  ['PlayStation 4',
#   'Nintendo Switch',
#   'Xbox One',
#   'Google Stadia',
#   'Windows PC'],
#  ['PlayStation 4',
#   'Nintendo Switch',
#   'Xbox Series',
#   'Xbox One',
#   'PlayStation 5',
#   'Google Stadia',
#   'Windows PC'],
#  ['PlayStation 4',
#   'Nintendo Switch',
#   'Xbox One',
#   'Mac',
#   'PlayStation 5',
#   'Linux',
#   'Windows PC'],
#  ['Xbox One', 'PlayStation 4', 'Nintendo Switch', 'Windows PC'],
#  ['PlayStation 4', 'Nintendo Switch', 'Mac', 'Linux', 'Windows PC'],
#  ['Windows PC'],
#  ['PlayStation Vita', 'Windows PC'],
#  nan,
#  ['Windows PC'],
#  ['Mac',
#   'Nintendo DS',
#   'Tapwave Zodiac',
#   'Windows Phone',
#   'Windows PC',
#   'iOS'],
#  ['Windows PC'],
#  nan,
#  ['PlayStation 4', 'Windows PC'],
#  ['Windows PC', 'PlayStation 4', 'Xbox One'],
#  ['Nintendo Switch', 'Mac', 'Linux', 'Android', 'Windows PC', 'iOS'],
#  nan,
#  nan,
#  ['PlayStation 4', 'Xbox One', 'PlayStation 5', 'Google Stadia', 'Windows PC'],
#  ['Xbox One', 'PlayStation 4', 'Windows PC'],
#  nan,
#  [],
#  nan,
#  ['Wii', 'Windows PC', 'PlayStation 3', 'Xbox 360'],
#  ['Windows PC', 'Mac', 'Linux', 'Nintendo Switch'],
#  ['PlayStation 4',
#   'Nintendo Switch',
#   'Xbox Series',
#   'Xbox Live',
#   'WiiWare',
#   'Xbox 360',
#   'PlayStation Vita',
#   'Mac',
#   'Wii U',
#   'Linux',
#   'Windows PC'],
#  ['Linux', 'Mac', 'Windows PC'],
#  ['PlayStation 4',
#   'Nintendo Switch',
#   'Xbox Series',
#   'Xbox One',
#   'PlayStation 5',
#   'Windows PC'],
#  ['Nintendo Switch'],
#  nan,
#  nan,
#  ['PlayStation Vita', 'PlayStation 4', 'Windows PC'],
#  ['Linux', 'Mac', 'Windows PC'],
#  ['PlayStation 3', 'Xbox 360', 'Linux', 'Windows PC'],
#  ['PlayStation 4', 'Nintendo Switch', 'Windows PC'],
#  nan,
#  ['Windows PC'],
#  ['Nintendo Switch'],
#  ['Windows PC', 'PlayStation 4', 'Xbox One', 'Nintendo Switch'],
#  ['Windows PC', 'PlayStation 4', 'Xbox One'],
#  nan,
#  ['PlayStation 3', 'Xbox 360', 'Windows PC'],
#  ['Xbox One', 'PlayStation 4', 'Nintendo Switch', 'Windows PC'],
#  ['Nintendo Switch', 'Windows PC'],
#  nan,
#  ['PlayStation 4',
#   'Nintendo Switch',
#   'Xbox One',
#   'Mac',
#   'Android',
#   'Windows PC',
#   'iOS'],
#  ['Windows PC', 'Mac', 'Linux', 'Xbox One', 'Nintendo Switch', 'Xbox Series'],
#  ['Nintendo 3DS', 'PlayStation Vita', 'Windows PC'],
#  ['Xbox One', 'PlayStation 4', 'Windows PC'],
#  nan,
#  ['Xbox One', 'PlayStation 4', 'Nintendo Switch', 'Windows PC'],
#  ['Windows PC', 'Mac', 'PlayStation 4', 'PlayStation 5', 'Nintendo Switch'],
#  ['Windows PC', 'PlayStation 4', 'Xbox One', 'Nintendo Switch'],
#  nan,
#  ['Xbox One', 'PlayStation 4', 'Windows PC'],
#  ['PlayStation 4',
#   'Nintendo Switch',
#   'Xbox Series',
#   'Xbox One',
#   'PlayStation 5',
#   'Windows PC',
#   'iOS'],
#  nan,
#  nan,
#  ['PlayStation Network',
#   'PlayStation 3',
#   'Xbox Live',
#   'Xbox 360',
#   'Windows PC'],
#  ['Xbox One', 'PlayStation 4', 'Windows PC'],
#  ['PlayStation 3', 'Xbox 360', 'Windows PC'],
#  ['Windows PC', 'Mac', 'Linux'],
#  ['PlayStation 4', 'Nintendo Switch', 'Windows PC'],
#  ['PlayStation 4', 'Nintendo Switch', 'Windows PC'],
#  ['PlayStation Network',
#   'Nintendo Switch',
#   'Xbox Live',
#   'Nintendo DSi',
#   'WiiWare',
#   'PlayStation',
#   'PlayStation 2',
#   'Game Boy',
#   'Windows PC'],
#  ['Windows PC',
#   'Mac',
#   'Linux',
#   'PlayStation 4',
#   'Xbox One',
#   'Nintendo Switch'],
#  nan,
#  ['Xbox One', 'Xbox Series', 'Windows PC'],
#  ['PlayStation 3',
#   'PlayStation 4',
#   'Nintendo Switch',
#   'Xbox One',
#   'Xbox 360',
#   'PlayStation Vita',
#   'Wii U',
#   'Windows PC',
#   'iOS'],
#  ['Windows PC', 'Mac'],
#  ['Windows PC'],
#  ['Windows PC'],
#  ['PlayStation 3',
#   'PlayStation 4',
#   'Nintendo Switch',
#   'Xbox Series',
#   'Xbox One',
#   'Windows PC'],
#  ['Xbox One', 'PlayStation 4', 'Windows PC'],
#  ['Nintendo 3DS', 'PlayStation Vita', 'Windows PC'],
#  ['PlayStation 3',
#   'PlayStation 4',
#   'Arcade',
#   'Xbox One',
#   'PlayStation Vita',
#   'Windows PC'],
#  ['PlayStation 4',
#   'Nintendo Switch',
#   'Xbox One',
#   'Mac',
#   'Linux',
#   'Windows PC'],
#  ['PlayStation Vita', 'Windows PC', 'PlayStation 4'],
#  ['PlayStation Vita', 'Mac', 'Android', 'Windows PC', 'iOS'],
#  nan,
#  ['Game Boy', 'SNES', 'Arcade'],
#  nan,
#  ['Virtual Console',
#   'PlayStation 3',
#   'Arcade',
#   'Xbox Live',
#   'Xbox 360',
#   'Sega Game Gear',
#   'Mac',
#   'Wii',
#   'Linux',
#   'Android',
#   'Sega Mega Drive/Genesis',
#   'iOS',
#   'Windows PC'],
#  ['Windows PC', 'PlayStation 4', 'Xbox One', 'Nintendo Switch'],
#  ['Nintendo Switch'],
#  ['Linux', 'Mac', 'Windows PC'],
#  ['Windows PC', 'Mac', 'Linux', 'Nintendo Switch'],
#  ['Xbox One', 'PlayStation 4', 'Windows PC', 'Xbox Series'],
#  ['PlayStation 4', 'Nintendo Switch'],
#  ['PlayStation 4', 'Nintendo Switch', 'Xbox One', 'Android', 'Windows PC'],
#  ['Windows PC'],
#  ['PlayStation 3',
#   'PlayStation 4',
#   'PlayStation Network',
#   'Xbox One',
#   'Xbox 360',
#   'Mac',
#   'Wii',
#   'Windows PC',
#   'iOS'],
#  ['PlayStation Vita', 'PlayStation 4', 'Windows PC'],
#  ['Windows PC', 'Mac', 'iOS', 'Nintendo Switch'],
#  ['Xbox One', 'Windows PC'],
#  ['PlayStation 3',
#   'PlayStation Network',
#   'Xbox Live',
#   'Xbox 360',
#   'Mac',
#   'Linux',
#   'Windows PC'],
#  ['Windows PC', 'Mac', 'Nintendo Switch'],
#  ['PlayStation 4',
#   'Ouya',
#   'Xbox One',
#   'PlayStation Vita',
#   'Mac',
#   'Linux',
#   'Windows PC'],
#  ['PlayStation 3',
#   'Xbox 360',
#   'PlayStation Vita',
#   'Mac',
#   'Nintendo DS',
#   'Wii',
#   'Nintendo 3DS',
#   'Android',
#   'PlayStation Portable',
#   'Windows PC',
#   'iOS'],
#  nan,
#  ['Linux', 'PlayStation 4', 'Mac', 'Windows PC'],
#  ['PlayStation 4',
#   'Nintendo Switch',
#   'Xbox One',
#   'PlayStation 2',
#   'Windows PC'],
#  nan,
#  ['Xbox One', 'Xbox Series', 'Nintendo Switch', 'Windows PC'],
#  ['Windows PC'],
#  ['PlayStation Network'],
#  ['PlayStation 3', 'Xbox 360', 'Windows PC', 'Xbox Live'],
#  nan,
#  ['Windows PC', 'PlayStation 4', 'Xbox One', 'Google Stadia'],
#  ['Windows PC', 'Android', 'iOS', 'Xbox One', 'Nintendo Switch'],
#  nan,
#  ['PlayStation 4', 'Windows PC'],
#  ['Windows PC', 'Mac', 'PlayStation 4', 'Xbox One', 'Nintendo Switch'],
#  ['Windows PC'],
#  ['PlayStation 4', 'Nintendo Switch', 'Windows PC'],
#  ['N-Gage', 'Windows PC'],
#  ['Xbox One', 'PlayStation 4', 'Windows PC'],
#  ['Xbox 360', 'Windows PC'],
#  ['Windows PC'],
#  ['PlayStation 3',
#   'PlayStation Network',
#   'Xbox Series',
#   'Xbox Live',
#   'Xbox 360',
#   'PlayStation 5',
#   'Windows PC'],
#  ['Xbox 360', 'Mac', 'Windows PC'],
#  nan,
#  ['Windows PC',
#   'PlayStation 4',
#   'iOS',
#   'PlayStation 5',
#   'Nintendo Switch',
#   'Xbox Series'],
#  ['PlayStation Vita', 'PlayStation 4', 'Nintendo Switch', 'Windows PC'],
#  nan,
#  ['PlayStation 3',
#   'PlayStation 4',
#   'Nintendo Switch',
#   'Xbox One',
#   'PlayStation Vita',
#   'Windows PC'],
#  ['PlayStation 4',
#   'Nintendo Switch',
#   'Xbox One',
#   'Mac',
#   'Android',
#   'Windows PC',
#   'iOS'],
#  ['PlayStation 4'],
#  ['Xbox One', 'PlayStation 4', 'Windows PC'],
#  ['PlayStation 4'],
#  ['PlayStation 4', 'Nintendo Switch', 'Windows PC'],
#  ['Windows PC'],
#  ['Windows PC'],
#  nan,
#  ['PlayStation 4',
#   'Nintendo Switch',
#   'Xbox One',
#   'Mac',
#   'Linux',
#   'iOS',
#   'Windows PC'],
#  ['Windows PC'],
#  ['Xbox One', 'PlayStation 4', 'Nintendo Switch', 'Windows PC'],
#  ['Windows PC', 'Mac', 'Nintendo Switch'],
#  ['Mac', 'Windows PC'],
#  ['iOS', 'Linux', 'Mac', 'Windows PC'],
#  ['Nintendo Switch', 'Windows PC'],
#  ['Xbox One', 'PlayStation 4', 'Nintendo Switch', 'Windows PC'],
#  ['Xbox One', 'PlayStation 4', 'Nintendo Switch', 'Windows PC'],
#  ['Windows PC',
#   'Mac',
#   'Linux',
#   'PlayStation 4',
#   'Xbox One',
#   'Nintendo Switch'],
#  ['Windows PC'],
#  nan,
#  ['PlayStation 4', 'Nintendo Switch', 'Windows PC'],
#  ['PlayStation 4',
#   'Nintendo Switch',
#   'Xbox One',
#   'Mac',
#   'Linux',
#   'Windows PC'],
#  nan,
#  ['PlayStation 4', 'Nintendo Switch', 'Mac', 'Linux', 'Windows PC', 'iOS'],
#  ['Nintendo Switch', 'Windows PC'],
#  ['Xbox One', 'PlayStation 4', 'Windows PC'],
#  ['Windows PC', 'Mac', 'Linux'],
#  ['PlayStation 4',
#   'Nintendo Switch',
#   'Xbox One',
#   'Mac',
#   'Linux',
#   'Android',
#   'iOS',
#   'Windows PC'],
#  ['Windows PC',
#   'Mac',
#   'Wii U',
#   'Linux',
#   'PlayStation 4',
#   'PlayStation 3',
#   'PlayStation Vita',
#   'Nintendo Switch'],
#  nan,
#  ['Windows PC',
#   'Wii U',
#   'Xbox 360',
#   'PlayStation 4',
#   'Xbox One',
#   'Nintendo Switch'],
#  ['PlayStation 3',
#   'PlayStation Network',
#   'Xbox Live',
#   'Xbox 360',
#   'Windows PC',
#   'iOS'],
#  ['PlayStation 4', 'Xbox One', 'Mac', 'Linux', 'Windows PC'],
#  ['Linux', 'Mac', 'Windows PC'],
#  ['PlayStation 3',
#   'PlayStation 4',
#   'Xbox One',
#   'Xbox 360',
#   'Google Stadia',
#   'Windows PC'],
#  ['PlayStation Network',
#   'NES',
#   'Nintendo DS',
#   'Wii',
#   'PlayStation Portable',
#   'PlayStation 2',
#   'Windows PC'],
#  ['Windows PC'],
#  ['Xbox Live', 'Xbox', 'Nintendo GameCube', 'PlayStation 2', 'Windows PC'],
#  ['Xbox One', 'PlayStation 4', 'Windows PC'],
#  ['PlayStation 4', 'Nintendo Switch', 'Windows PC'],
#  nan,
#  nan,
#  ['PlayStation 4',
#   'Nintendo Switch',
#   'Xbox One',
#   'Mac',
#   'Linux',
#   'Windows PC'],
#  ['Windows PC'],
#  ['PlayStation 4',
#   'Nintendo Switch',
#   'Xbox Series',
#   'Xbox One',
#   'PlayStation 5',
#   'Google Stadia',
#   'Windows PC'],
#  ['Windows PC'],
#  ['Windows PC', 'Mac'],
#  ['Xbox One', 'PlayStation 4', 'Nintendo Switch', 'Windows PC'],
#  nan,
#  nan,
#  ['PlayStation Network',
#   'PlayStation 3',
#   'Xbox Live',
#   'Xbox 360',
#   'Windows PC'],
#  ['PlayStation 4',
#   'Xbox Series',
#   'Xbox One',
#   'PlayStation 5',
#   'Google Stadia',
#   'Windows PC'],
#  ['PlayStation 4',
#   'Nintendo Switch',
#   'Xbox Series',
#   'Xbox One',
#   'Mac',
#   'PlayStation 5',
#   'Linux',
#   'Windows PC'],
#  ['PlayStation 3', 'Xbox 360', 'Mac', 'Linux', 'Windows PC'],
#  ['Windows PC'],
#  ['Nintendo Switch', 'Xbox Series', 'Xbox One', 'Google Stadia', 'Windows PC'],
#  ['Oculus Quest 2',
#   'PlayStation 4',
#   'Nintendo Switch',
#   'Oculus Rift',
#   'PlayStation VR',
#   'Xbox One',
#   'PlayStation 5',
#   'Oculus Quest',
#   'Playstation VR2',
#   'SteamVR',
#   'Google Stadia',
#   'iOS',
#   'Windows PC'],
#  nan,
#  ['Nintendo Switch'],
#  ['PlayStation Vita', 'Nintendo Switch', 'Windows PC'],
#  ['PlayStation 4',
#   'Xbox Series',
#   'Xbox One',
#   'PlayStation 5',
#   'Google Stadia',
#   'Windows PC'],
#  nan,
#  ['Xbox 360', 'PlayStation 3', 'Windows PC'],
#  ['Nintendo Switch', 'Windows PC'],
#  ['Windows PC', 'Mac', 'Linux', 'Xbox One', 'Nintendo Switch'],
#  ['PlayStation 4',
#   'Nintendo Switch',
#   'Xbox One',
#   'PlayStation Vita',
#   'Mac',
#   'Linux',
#   'Windows PC'],
#  ['Windows PC', 'PlayStation 4', 'PlayStation Vita', 'Nintendo Switch'],
#  ['Linux', 'Mac', 'Windows PC'],
#  nan,
#  ['Xbox One', 'Nintendo Switch', 'Windows PC'],
#  ['PlayStation 4',
#   'Xbox Series',
#   'Xbox One',
#   'Mac',
#   'Linux',
#   'Android',
#   'iOS',
#   'Windows PC'],
#  nan,
#  ['PlayStation 3',
#   'PlayStation Network',
#   'Xbox Live',
#   'Xbox 360',
#   'Mac',
#   'Nintendo DS',
#   'Wii',
#   'Windows PC'],
#  ['Mobile',
#   'PlayStation 3',
#   'Xbox Live',
#   'Xbox One',
#   'Xbox 360',
#   'Xbox',
#   'Mac',
#   'Windows PC'],
#  ['Windows PC', 'PlayStation 4'],
#  ['PlayStation 3',
#   'PlayStation 4',
#   'Nintendo Switch',
#   'Xbox One',
#   'PlayStation Vita',
#   'Mac',
#   'Linux',
#   'Android',
#   'Google Stadia',
#   'Windows PC'],
#  nan,
#  nan,
#  ['Windows PC',
#   'PlayStation 4',
#   'Xbox One',
#   'PlayStation 5',
#   'Nintendo Switch',
#   'Xbox Series'],
#  ['PlayStation 4', 'Xbox Series', 'Xbox One', 'PlayStation 5', 'Windows PC'],
#  ['Windows PC', 'Mac', 'PlayStation 4', 'Xbox One'],
#  nan,
#  ['PlayStation 3', 'Xbox 360', 'Windows PC'],
#  ['Windows PC', 'Android', 'Mac', 'Linux', 'iOS'],
#  nan,
#  ['Linux', 'Mac', 'Windows PC'],
#  nan,
#  ['PlayStation 3', 'PlayStation 4', 'Xbox One', 'Mac', 'Linux', 'Windows PC'],
#  ['Xbox 360', 'Windows PC', 'Xbox Live'],
#  ['PlayStation 3', 'Xbox 360', 'Windows PC'],
#  ['PlayStation 4', 'Nintendo Switch', 'Windows PC', 'PlayStation 5'],
#  ['PlayStation 3', 'Xbox 360', 'Windows PC'],
#  ['Xbox One', 'PlayStation 4', 'Windows PC'],
#  ['Windows PC', 'PlayStation 4', 'PlayStation 5'],
#  ['Windows PC',
#   'Mac',
#   'Linux',
#   'PlayStation 4',
#   'Ouya',
#   'PlayStation Vita',
#   'Nintendo Switch'],
#  ['Virtual Console',
#   'Xbox Live',
#   'Xbox 360',
#   'Sega Mega Drive/Genesis',
#   'Windows PC'],
#  nan,
#  ['Mobile', 'PlayStation 4', 'Mac', 'Linux', 'Windows PC'],
#  ['Windows PC', 'PlayStation 4', 'Xbox One', 'Nintendo Switch'],
#  ['PlayStation 4',
#   'Xbox Series',
#   'Xbox One',
#   'PlayStation 5',
#   'Google Stadia',
#   'Windows PC'],
#  nan,
#  nan,
#  ['Windows PC'],
#  nan,
#  ['Windows PC'],
#  ['Xbox', 'Windows PC'],
#  ['Windows PC'],
#  ['Windows PC'],
#  ['Windows PC'],
#  ['Windows PC', 'Mac'],
#  ['PlayStation Vita', 'Windows PC', 'PlayStation 4'],
#  ['Mac', 'Windows PC'],
#  ['PlayStation 4',
#   'Nintendo Switch',
#   'Xbox Series',
#   'Xbox One',
#   'Android',
#   'Windows PC',
#   'Google Stadia',
#   'iOS'],
#  ['PlayStation 4', 'Nintendo Switch', 'Windows PC'],
#  nan,
#  nan,
#  ['Xbox One', 'PlayStation 4', 'Nintendo Switch', 'Windows PC'],
#  ['Nintendo Switch', 'Windows PC'],
#  ['Windows PC'],
#  ['PlayStation 4', 'Windows PC'],
#  ['PlayStation 4',
#   'Nintendo Switch',
#   'Xbox One',
#   'PlayStation Vita',
#   'Mac',
#   'Linux',
#   'Android',
#   'iOS',
#   'Windows PC'],
#  ['Xbox One', 'PlayStation 4', 'Windows PC'],
#  ['SteamVR', 'Oculus Quest 2', 'Oculus VR', 'Windows PC'],
#  ['PlayStation 4',
#   'Nintendo Switch',
#   'Xbox One',
#   'Mac',
#   'Nintendo 3DS',
#   'Linux',
#   'Android',
#   'iOS',
#   'Windows PC'],
#  ['Windows PC', 'Nintendo 3DS'],
#  ['Linux', 'Mac', 'Windows PC'],
#  ['Windows PC'],
#  ['PlayStation Vita', 'PlayStation 4', 'Windows PC'],
#  ['Xbox One', 'PlayStation 4', 'Nintendo Switch', 'Windows PC'],
#  ['Windows PC'],
#  ['Mac', 'Windows PC'],
#  ['PlayStation 4',
#   'Nintendo Switch',
#   'Xbox One',
#   'Mac',
#   'Linux',
#   'Windows PC'],
#  nan,
#  ['PlayStation 4', 'Windows PC'],
#  ['PlayStation 3', 'Xbox 360', 'NES', 'Windows PC'],
#  ['PlayStation 4',
#   'Nintendo Switch',
#   'Xbox Series',
#   'Xbox One',
#   'Mac',
#   'Windows PC'],
#  ['PlayStation Network', 'PlayStation Portable', 'Windows PC'],
#  ['Mac', 'Windows PC'],
#  ['Wii U'],
#  ['Xbox Series', 'Windows PC', 'PlayStation 5'],
#  ['Xbox', 'PlayStation 2', 'Windows PC'],
#  ['PlayStation 4',
#   'Nintendo Switch',
#   'Xbox Series',
#   'Xbox One',
#   'Android',
#   'Windows PC',
#   'Google Stadia',
#   'iOS'],
#  ['PlayStation 3', 'Xbox 360', 'Mac', 'Windows PC'],
#  ['Mac', 'Wii U', 'Windows PC'],
#  ['Wii U', 'Windows PC'],
#  nan,
#  ['Windows PC'],
#  ['Windows PC', 'PlayStation 5'],
#  ['Windows PC'],
#  ['PlayStation 4',
#   'Nintendo Switch',
#   'Xbox Series',
#   'Xbox One',
#   'PlayStation 5',
#   'Windows PC'],
#  ['PlayStation 4',
#   'Xbox Series',
#   'Xbox One',
#   'PlayStation 5',
#   'Linux',
#   'Windows PC'],
#  ['Windows PC'],
#  ['Web browser', 'PlayStation 4', 'Xbox One', 'Mac', 'Linux', 'Windows PC'],
#  ['PlayStation 4', 'Nintendo Switch', 'Xbox One', 'N-Gage', 'Windows PC'],
#  nan,
#  ['Xbox One', 'PlayStation 4', 'Windows PC'],
#  ['PlayStation 3',
#   'PlayStation Network',
#   'Mac',
#   'Linux',
#   'PlayStation Portable',
#   'Windows PC'],
#  ['Windows PC', 'Mac', 'Nintendo Switch'],
#  ['PlayStation 4', 'Nintendo Switch'],
#  ['Linux', 'Mac', 'Windows PC', 'Nintendo Switch'],
#  ['PlayStation 4',
#   'Nintendo Switch',
#   'Xbox Series',
#   'Xbox One',
#   'Google Stadia',
#   'Windows PC'],
#  ['Xbox Live', 'Xbox 360', 'Mac', 'Linux', 'Windows PC'],
#  ['PC DOS',
#   'Game Boy Color',
#   'NES',
#   'Philips CD-i',
#   'Atari Jaguar CD',
#   'SNES',
#   'PlayStation Network',
#   'Mac',
#   'Nintendo DS',
#   'PlayStation 3',
#   '3DO Interactive Multiplayer',
#   'Arcade',
#   'Sega CD',
#   'Nintendo DSi',
#   'Xbox 360',
#   'Android',
#   'Atari Jaguar',
#   'Atari ST/STE',
#   'iOS',
#   'Amiga'],
#  ['Windows PC', 'PlayStation 4', 'Xbox One', 'Nintendo Switch'],
#  ['PlayStation 3', 'Mac', 'Windows PC', 'Wii U'],
#  ['PlayStation Network',
#   'Xbox Live',
#   'Xbox',
#   'Mac',
#   'Wii',
#   'PlayStation Portable',
#   'Windows Phone',
#   'Windows PC',
#   'iOS'],
#  ['Neo Geo AES', 'PlayStation Network', 'Neo Geo MVS', 'Arcade'],
#  ['Xbox One', 'PlayStation 4', 'Nintendo Switch', 'Windows PC'],
#  ['Windows PC'],
#  ['Windows PC'],
#  ['Xbox 360', 'Windows PC', 'Xbox Live'],
#  ['Nintendo Switch'],
#  ['Windows PC',
#   'PlayStation 4',
#   'PlayStation VR',
#   'Xbox One',
#   'PlayStation 5',
#   'Google Stadia',
#   'Xbox Series'],
#  ['Linux', 'Mac', 'Windows PC'],
#  ['PlayStation 4',
#   'Nintendo Switch',
#   'Xbox One',
#   'Mac',
#   'Linux',
#   'Windows PC'],
#  ['Windows PC'],
#  ['Windows PC'],
#  ['PlayStation 4', 'Xbox One', 'Mac', 'Linux', 'Windows PC'],
#  ['Nintendo Switch',
#   'Xbox One',
#   'Mac',
#   'PlayStation 5',
#   'Linux',
#   'Windows PC'],
#  ['Xbox One', 'PlayStation 4', 'Nintendo Switch', 'Windows PC'],
#  ['PlayStation 4', 'Windows PC'],
#  nan,
#  ['Nintendo GameCube', 'PlayStation 2'],
#  ['Windows PC',
#   'Mac',
#   'Linux',
#   'PlayStation 4',
#   'iOS',
#   'Xbox One',
#   'Nintendo Switch'],
#  ['Mac', 'Linux', 'Android', 'Windows PC', 'iOS'],
#  ['PlayStation 4', 'Mac', 'Windows PC', 'Nintendo Switch'],
#  nan,
#  ['PlayStation 4', 'Nintendo Switch', 'Xbox One', 'Mac', 'Windows PC'],
#  ['Dreamcast', 'Windows PC'],
#  ['PlayStation Vita', 'Windows PC'],
#  ['Windows PC', 'PlayStation 4', 'Xbox One'],
#  ['PlayStation 4',
#   'Nintendo Switch',
#   'Xbox Series',
#   'Xbox One',
#   'Mac',
#   'PlayStation 5',
#   'Windows PC'],
#  ['PlayStation Network', 'PlayStation 3', 'Xbox 360', 'Mac', 'Windows PC'],
#  ['Xbox One', 'Mac', 'Windows PC'],
#  ['Windows PC',
#   'PlayStation 4',
#   'Xbox One',
#   'Nintendo Switch',
#   'Google Stadia'],
#  nan,
#  ['Xbox One', 'PlayStation 4', 'Nintendo Switch', 'Windows PC'],
#  ['PlayStation 4',
#   'Nintendo Switch',
#   'Xbox One',
#   'Mac',
#   'Linux',
#   'Windows PC'],
#  ['Xbox One', 'PlayStation 4'],
#  nan,
#  ['Linux', 'Mac', 'Windows PC'],
#  ['PlayStation 3', 'PlayStation 4', 'Xbox One', 'Wii U', 'Windows PC'],
#  ['Windows PC'],
#  ['PlayStation 3',
#   'Xbox 360',
#   'PlayStation Vita',
#   'Google Stadia',
#   'Windows PC'],
#  ['Nintendo Switch', 'Mac', 'Linux', 'Android', 'Windows PC', 'iOS'],
#  nan,
#  ['PlayStation 3', 'Xbox 360', 'Wii U', 'Windows PC'],
#  ['PlayStation 3', 'Xbox 360', 'Windows PC'],
#  ['Windows PC', 'Mac', 'Nintendo Switch'],
#  ['PlayStation 3', 'Xbox Series', 'Xbox One', 'Xbox 360', 'Windows PC'],
#  ['PlayStation 4',
#   'Nintendo Switch',
#   'Xbox One',
#   'PlayStation 5',
#   'Google Stadia',
#   'Windows PC'],
#  ['Windows PC', 'PlayStation 3', 'Xbox 360'],
#  nan,
#  ['PlayStation 4', 'Nintendo Switch', 'Windows PC'],
#  ['Xbox One', 'PlayStation 4', 'Windows PC'],
#  ['Windows PC'],
#  ['Windows PC', 'Mac', 'Linux', 'PlayStation 4'],
#  nan,
#  ['PlayStation 3',
#   'PlayStation Network',
#   'Xbox Live',
#   'Xbox One',
#   'Xbox 360',
#   'Wii',
#   'Windows PC'],
#  ['Mobile',
#   'PlayStation 3',
#   'PlayStation Network',
#   'Mac',
#   'Windows PC',
#   'iOS'],
#  ['PlayStation 3',
#   'PlayStation Network',
#   'Xbox Live',
#   'Xbox 360',
#   'Nintendo DS',
#   'Wii',
#   'Linux',
#   'PlayStation Portable',
#   'Windows PC'],
#  ['Google Stadia', 'Xbox One', 'PlayStation 4', 'Windows PC'],
#  ['Windows PC'],
#  nan,
#  ['PlayStation 4', 'Nintendo Switch'],
#  ['Windows PC'],
#  nan,
#  ['Linux', 'Windows PC'],
#  ['Xbox One', 'PlayStation 4', 'Nintendo Switch', 'Windows PC'],
#  ['PlayStation 4',
#   'Nintendo Switch',
#   'Xbox One',
#   'Mac',
#   'Linux',
#   'Android',
#   'Google Stadia',
#   'iOS',
#   'Windows PC'],
#  nan,
#  ['Google Stadia', 'Xbox One', 'PlayStation 4', 'Windows PC'],
#  ['PlayStation 4',
#   'Nintendo Switch',
#   'Xbox Series',
#   'Xbox One',
#   'PlayStation 5',
#   'Linux',
#   'Android',
#   'Windows PC',
#   'iOS'],
#  ['PlayStation 4',
#   'Nintendo Switch',
#   'Xbox Series',
#   'Xbox One',
#   'PlayStation 5',
#   'Windows PC'],
#  ['PlayStation Vita', 'Windows PC'],
#  ['PlayStation 3', 'Nintendo Switch', 'Windows PC'],
#  ['Oculus Rift', 'PlayStation 4', 'Windows PC'],
#  nan,
#  ['PlayStation 3', 'PlayStation 4', 'Xbox One', 'Xbox 360', 'Windows PC'],
#  ['Windows PC'],
#  ['PlayStation 3',
#   'Xbox',
#   'Nintendo GameCube',
#   'PlayStation 2',
#   'Game Boy Advance',
#   'Windows PC'],
#  nan,
#  ['Xbox 360', 'Windows PC', 'Xbox Live'],
#  ['Windows PC'],
#  ['PlayStation 4',
#   'Nintendo Switch',
#   'Xbox One',
#   'Mac',
#   'Linux',
#   'Windows PC'],
#  ['Xbox One', 'PlayStation 4', 'Nintendo Switch', 'Windows PC'],
#  ['Windows PC', 'Mac', 'Linux'],
#  ['PlayStation 4',
#   'Nintendo Switch',
#   'Xbox Series',
#   'Xbox One',
#   'PlayStation 5',
#   'Windows PC'],
#  ['Windows PC'],
#  ['PlayStation Vita', 'Xbox One', 'PlayStation 4', 'Windows PC'],
#  ['Nintendo DS'],
#  ['Windows PC'],
#  ['Nintendo Switch', 'Mac', 'Linux', 'Windows PC', 'iOS'],
#  ['PlayStation 4',
#   'PlayStation VR',
#   'PlayStation 5',
#   'Windows PC',
#   'Playstation VR2'],
#  ['Nintendo Switch'],
#  ['Windows PC'],
#  ['Windows PC', 'PlayStation 4', 'Xbox One', 'Nintendo Switch'],
#  ['Windows PC', 'Wii U', 'Xbox 360', 'PlayStation 3', 'PlayStation Vita'],
#  ['PlayStation 3', 'PlayStation 4', 'Arcade', 'Xbox 360', 'Windows PC'],
#  ['Mac', 'Android', 'Wii U', 'Windows PC'],
#  ['Xbox Series', 'Xbox Live', 'Xbox 360', 'Mac', 'Linux', 'Windows PC'],
#  ['Windows PC', 'PlayStation 4', 'Xbox One', 'Nintendo Switch'],
#  ['PlayStation 3',
#   'PlayStation Vita',
#   'Mac',
#   'Linux',
#   'Android',
#   'Windows PC'],
#  nan,
#  ['PlayStation Network', 'Windows PC', 'Xbox Live'],
#  ['PlayStation 4', 'Nintendo Switch', 'Xbox One', 'Mac', 'Windows PC'],
#  ['Windows PC',
#   'Android',
#   'Mac',
#   'Linux',
#   'PlayStation 4',
#   'iOS',
#   'Xbox One',
#   'Nintendo Switch'],
#  ['PlayStation 4',
#   'Nintendo Switch',
#   'Xbox One',
#   'Mac',
#   'Linux',
#   'Windows PC'],
#  ['Windows PC', 'Xbox One'],
#  nan,
#  ['PlayStation Network',
#   'Nintendo Switch',
#   'Xbox',
#   'Mac',
#   'PlayStation Vita',
#   'Android',
#   'Game Boy Advance',
#   'Windows PC',
#   'iOS'],
#  ['PlayStation 4'],
#  ['Linux', 'Mac', 'Windows PC'],
#  ['PlayStation 4', 'Xbox Series', 'Xbox One', 'PlayStation 5', 'Windows PC'],
#  ['Xbox', 'PlayStation 2', 'Windows PC', 'Xbox Live'],
#  ['Xbox One', 'PlayStation 4', 'Windows PC'],
#  ['PlayStation Network',
#   'PlayStation 3',
#   'Xbox Live',
#   'Xbox 360',
#   'Windows PC'],
#  nan,
#  ['PlayStation 4', 'Xbox One', 'Mac', 'Linux', 'Windows PC'],
#  ['PlayStation 4',
#   'Nintendo Switch',
#   'Xbox Series',
#   'Xbox One',
#   'Mac',
#   'PlayStation 5',
#   'Linux',
#   'Windows PC'],
#  ['PlayStation 4',
#   'Nintendo Switch',
#   'Xbox One',
#   'Google Stadia',
#   'Windows PC'],
#  ['Windows PC', 'PlayStation 4', 'Xbox One'],
#  ['PlayStation 4',
#   'Nintendo Switch',
#   'Xbox One',
#   'Mac',
#   'Linux',
#   'Android',
#   'Google Stadia',
#   'iOS',
#   'Windows PC'],
#  ['Xbox One', 'PlayStation 4', 'Nintendo Switch', 'Windows PC'],
#  ['Xbox One', 'PlayStation 4', 'Nintendo Switch', 'Windows PC'],
#  ['PlayStation 3', 'PlayStation Vita', 'Windows PC', 'PlayStation 4'],
#  ['Xbox 360', 'Windows PC', 'Xbox Live'],
#  ['Xbox One', 'PlayStation 4', 'Windows PC'],
#  ['PlayStation 4',
#   'Nintendo Switch',
#   'Xbox Series',
#   'Xbox One',
#   'Mac',
#   'PlayStation 5',
#   'Linux',
#   'Windows PC'],
#  ['PlayStation 4',
#   'Nintendo Switch',
#   'Xbox Series',
#   'Xbox One',
#   'PlayStation 5',
#   'Windows PC'],
#  ['Xbox One', 'PlayStation 4', 'Nintendo Switch', 'Windows PC'],
#  ['Wii', 'Windows PC', 'PlayStation 3', 'Xbox 360'],
#  ['PlayStation Network', 'Windows PC'],
#  ['Nintendo Switch', 'Windows PC'],
#  ['Nintendo Switch', 'WiiWare', 'Mac', 'Wii', 'Nintendo 3DS', 'Windows PC'],
#  ['PlayStation 4', 'Nintendo Switch', 'Windows PC'],
#  ['PlayStation 4', 'Windows PC'],
#  nan,
#  ['PlayStation 4', 'Windows PC'],
#  ['Windows PC',
#   'Mac',
#   'Linux',
#   'PlayStation 4',
#   'Xbox One',
#   'Nintendo Switch'],
#  ['PlayStation 4', 'Nintendo Switch', 'Mac', 'Wii U', 'Linux', 'Windows PC'],
#  ['Windows PC',
#   'Linux',
#   'PlayStation 4',
#   'iOS',
#   'Xbox One',
#   'Nintendo Switch'],
#  nan,
#  ['Nintendo Switch'],
#  ['PlayStation 3', 'Xbox 360', 'Windows PC'],
#  nan,
#  ['Mac', 'Windows PC'],
#  ['PlayStation 4', 'Nintendo Switch', 'Xbox One', 'Mac', 'Windows PC', 'iOS'],
#  ['Xbox One', 'PlayStation 4', 'Nintendo Switch', 'Windows PC'],
#  ['Mac', 'Windows PC'],
#  ['PlayStation 4',
#   'Nintendo Switch',
#   'Xbox One',
#   'Xbox',
#   'Mac',
#   'Linux',
#   'Android',
#   'iOS',
#   'Windows PC'],
#  ['Windows PC', 'Linux', 'PlayStation 4', 'PlayStation Vita'],
#  ['Mac', 'Windows PC'],
#  ['Nintendo Switch'],
#  nan,
#  nan,
#  ['PlayStation Network',
#   'Nintendo Switch',
#   'Nintendo DSi',
#   'WiiWare',
#   'NES',
#   'Atari 2600',
#   'PlayStation 2',
#   'Game Boy'],
#  ['Xbox', 'Windows PC'],
#  ['PlayStation 4',
#   'Nintendo Switch',
#   'Xbox One',
#   'Mac',
#   'Linux',
#   'Windows PC',
#   'iOS'],
#  nan,
#  nan,
#  nan,
#  ['Xbox', 'Windows PC'],
#  ['Windows PC'],
#  ['Xbox One', 'PlayStation 4', 'Nintendo Switch', 'Windows PC'],
#  ['Linux', 'Mac', 'Windows PC'],
#  nan,
#  ['Windows PC', 'Nintendo Switch'],
#  nan,
#  ['Windows PC', 'Mac', 'Linux'],
#  ['PlayStation 4',
#   'Nintendo Switch',
#   'Xbox One',
#   'Google Stadia',
#   'Windows PC'],
#  nan,
#  ['Xbox One', 'Mac', 'Windows PC', 'Nintendo Switch'],
#  ['Google Stadia', 'Nintendo Switch', 'Windows PC'],
#  ['Windows PC'],
#  ['Windows PC', 'Mac', 'Linux'],
#  ['PlayStation 4',
#   'Xbox Series',
#   'Xbox One',
#   'PlayStation 5',
#   'Google Stadia',
#   'Windows PC'],
#  ['Windows PC'],
#  ['Windows PC'],
#  ['Windows PC', 'Mac'],
#  ['PlayStation 3',
#   'PlayStation Network',
#   'Xbox Live',
#   'Xbox 360',
#   'Mac',
#   'Windows PC'],
#  ['Windows PC',
#   'Mac',
#   'PlayStation 4',
#   'Xbox One',
#   'PlayStation 5',
#   'Google Stadia',
#   'Xbox Series',
#   'Playstation VR2'],
#  ['Linux', 'Mac', 'Windows PC'],
#  ['Linux', 'Mac', 'Windows PC'],
#  ['Xbox One', 'PlayStation 4', 'Nintendo Switch', 'Windows PC'],
#  ['PlayStation 3', 'PlayStation Vita', 'Windows PC'],
#  ['Windows PC', 'PlayStation 4', 'Xbox One'],
#  ['Xbox One', 'PlayStation 4', 'Mac', 'Windows PC'],
#  ['PlayStation Network', 'Windows PC', 'Xbox Live'],
#  ['Xbox', 'PlayStation 2', 'Windows PC'],
#  ['Windows PC'],
#  ['PlayStation 4',
#   'Nintendo Switch',
#   'Xbox Series',
#   'Xbox One',
#   'Nintendo 3DS',
#   'Windows PC'],
#  ['Windows PC'],
#  ['PlayStation Vita', 'Xbox One', 'PlayStation 4', 'Windows PC'],
#  ['Windows PC', 'Xbox One', 'PlayStation 5', 'Nintendo Switch', 'Xbox Series'],
#  ['Nintendo Switch', 'Windows PC'],
#  ['Oculus Rift',
#   'PlayStation 4',
#   'PlayStation VR',
#   'Oculus Quest',
#   'SteamVR',
#   'Windows Mixed Reality',
#   'Playstation VR2'],
#  ['PlayStation 4', 'Xbox Series', 'Xbox One', 'PlayStation 5', 'Windows PC'],
#  ['Windows PC'],
#  ['PlayStation 3',
#   'PlayStation Network',
#   'Xbox 360',
#   'Mac',
#   'Nintendo DS',
#   'Wii',
#   'PlayStation Portable',
#   'PlayStation 2',
#   'Windows PC'],
#  ['Xbox One', 'Nintendo Switch', 'Windows PC'],
#  ['PlayStation 4',
#   'Xbox Series',
#   'Xbox One',
#   'Xbox',
#   'PlayStation 2',
#   'Windows PC'],
#  ['Windows PC'],
#  ['Nintendo Switch', 'Xbox Series', 'Xbox One', 'Mac', 'Linux', 'Windows PC'],
#  nan,
#  nan,
#  ['Xbox 360', 'Windows PC', 'Xbox Live'],
#  ['Xbox One', 'PlayStation 4', 'Nintendo Switch', 'Windows PC'],
#  ['PlayStation 4', 'Windows PC'],
#  ['Windows PC'],
#  nan,
#  ['PlayStation 3', 'PlayStation Vita', 'Windows PC'],
#  ['Xbox One', 'PlayStation 4', 'Windows PC'],
#  nan,
#  ['Linux', 'Mac', 'Windows PC'],
#  ['Nintendo Switch', 'Windows PC'],
#  ['PlayStation 3', 'Xbox 360', 'Wii U', 'Windows PC'],
#  ['PlayStation 3',
#   'PlayStation 4',
#   'Nintendo Switch',
#   'Xbox Series',
#   'Xbox One',
#   'Xbox 360',
#   'Mac',
#   'Wii U',
#   'PlayStation 5',
#   'Android',
#   'iOS',
#   'Windows PC'],
#  ['Xbox One', 'PlayStation 4', 'Windows PC'],
#  ['PlayStation 4',
#   'Nintendo Switch',
#   'Xbox Series',
#   'Xbox One',
#   'Mac',
#   'PlayStation 5',
#   'Windows PC',
#   'iOS'],
#  ['Xbox One', 'PlayStation 4', 'Nintendo Switch', 'Windows PC'],
#  ['Xbox One', 'PlayStation 4', 'Windows PC'],
#  ['Nintendo Switch'],
#  ['PlayStation Network', 'Windows PC', 'Xbox Live'],
#  ['PlayStation 3',
#   'PlayStation Network',
#   'Xbox 360',
#   'Mac',
#   'Nintendo DS',
#   'Wii',
#   'Nintendo 3DS',
#   'PlayStation Portable',
#   'Windows PC'],
#  ['PlayStation 4',
#   'Nintendo Switch',
#   'Xbox Series',
#   'Xbox One',
#   'PlayStation 5',
#   'Windows PC'],
#  ['Windows PC'],
#  ['Windows PC'],
#  ['Windows PC'],
#  ['Xbox One', 'PlayStation 4', 'Windows PC'],
#  ['Windows PC', 'Mac', 'PlayStation 4', 'Xbox One'],
#  ['Windows PC',
#   'PlayStation 4',
#   'Xbox One',
#   'PlayStation 5',
#   'Nintendo Switch',
#   'Xbox Series'],
#  ['PlayStation 4',
#   'Nintendo Switch',
#   'PlayStation 5',
#   'Google Stadia',
#   'Windows PC'],
#  ['PlayStation 4'],
#  ['Windows PC'],
#  ['PlayStation 4',
#   'Xbox Series',
#   'Xbox One',
#   'Mac',
#   'PlayStation 5',
#   'Windows PC'],
#  ['Xbox 360', 'Nintendo Switch', 'Windows PC', 'Xbox Live'],
#  nan,
#  nan,
#  ['PlayStation 3',
#   'PlayStation 4',
#   'Wii',
#   'Android',
#   'PlayStation Portable',
#   'Windows PC',
#   'iOS'],
#  ['Windows PC',
#   'Mac',
#   'Linux',
#   'PlayStation 4',
#   'Xbox One',
#   'Nintendo Switch'],
#  ['Windows Phone', 'Windows PC'],
#  nan,
#  nan,
#  ['PlayStation 4',
#   'Xbox Series',
#   'Xbox One',
#   'PlayStation 5',
#   'Google Stadia',
#   'Windows PC'],
#  ['Nintendo Switch'],
#  ['PlayStation 4', 'Windows PC'],
#  ['PlayStation 4',
#   'Nintendo Switch',
#   'Xbox Series',
#   'Xbox One',
#   'Mac',
#   'PlayStation 5',
#   'Windows PC'],
#  ['PlayStation 4',
#   'Nintendo Switch',
#   'Xbox Series',
#   'Xbox One',
#   'PlayStation 5',
#   'Windows PC'],
#  ['Windows PC',
#   'Mac',
#   'Linux',
#   'PlayStation 4',
#   'Xbox One',
#   'Nintendo Switch'],
#  nan,
#  ['PlayStation 4', 'Nintendo Switch', 'Windows PC'],
#  nan,
#  ['PlayStation 3', 'Xbox 360', 'Wii U', 'Windows PC'],
#  ['PlayStation 4', 'Nintendo Switch', 'Xbox One', 'Mac', 'Windows PC'],
#  ['Xbox Series', 'Xbox 360', 'Xbox', 'PlayStation 2', 'Windows PC'],
#  ['PlayStation 4',
#   'Nintendo Switch',
#   'Xbox One',
#   'Android',
#   'Windows PC',
#   'iOS'],
#  nan,
#  nan,
#  ['Nintendo Switch'],
#  ['Game Boy Advance', 'Nintendo GameCube', 'PlayStation 2', 'Windows PC'],
#  nan,
#  ['PlayStation 4',
#   'Nintendo Switch',
#   'Xbox One',
#   'Mac',
#   'Linux',
#   'Windows PC'],
#  ['Windows PC', 'Mac', 'Nintendo Switch'],
#  ['Windows PC', 'Xbox Live'],
#  nan,
#  ['Windows PC', 'Mac', 'Linux'],
#  ['PlayStation 4', 'Xbox Series', 'Xbox', 'PlayStation 2', 'Windows PC'],
#  ['Linux', 'Mac', 'Windows PC'],
#  [],
#  ['PlayStation 4',
#   'Xbox One',
#   'PlayStation Vita',
#   'Mac',
#   'Wii U',
#   'Nintendo 3DS',
#   'Linux',
#   'New Nintendo 3DS',
#   'iOS',
#   'Windows PC'],
#  nan,
#  nan,
#  ['Windows PC', 'PlayStation 3', 'Xbox 360'],
#  ['Windows PC', 'PlayStation VR'],
#  nan,
#  ['Windows PC',
#   'PlayStation 4',
#   'Xbox One',
#   'PlayStation 5',
#   'Nintendo Switch',
#   'Xbox Series'],
#  ['PlayStation 3', 'PlayStation 4', 'Nintendo Switch', 'Windows PC'],
#  ['Linux', 'Mac', 'Windows PC', 'Nintendo Switch'],
#  ['Nintendo Switch',
#   'Xbox Series',
#   'Xbox One',
#   'Mac',
#   'PlayStation 5',
#   'Android',
#   'Windows PC',
#   'iOS'],
#  ['Nintendo Switch', 'Mac', 'Android', 'Windows PC', 'iOS'],
#  ['Linux', 'Mac', 'Windows PC'],
#  ['PlayStation 4',
#   'Nintendo Switch',
#   'Xbox Series',
#   'Xbox One',
#   'PlayStation 5',
#   'Windows PC'],
#  ['Nintendo GameCube', 'Xbox', 'PlayStation 2', 'Windows PC'],
#  ['PlayStation 4', 'Xbox One', 'Mac', 'Linux', 'Windows PC'],
#  ['PlayStation 4',
#   'Nintendo Switch',
#   'Xbox One',
#   'Mac',
#   'Linux',
#   'Android',
#   'Windows PC'],
#  nan,
#  ['Xbox One', 'PlayStation 4', 'Nintendo Switch', 'Windows PC'],
#  ['Xbox One', 'PlayStation 4', 'Windows PC'],
#  ['PlayStation 4', 'Nintendo Switch', 'Windows PC'],
#  ['PlayStation 4',
#   'Nintendo Switch',
#   'Xbox Series',
#   'Xbox One',
#   'PlayStation 5',
#   'Windows PC'],
#  ['Oculus Quest 2',
#   'Oculus Rift',
#   'PlayStation 5',
#   'SteamVR',
#   'Windows PC',
#   'Playstation VR2'],
#  ['Nintendo Switch', 'Mac', 'Linux', 'Android', 'Windows PC', 'iOS'],
#  ['PlayStation 4',
#   'Nintendo Switch',
#   'Xbox Series',
#   'Xbox One',
#   'PlayStation 5',
#   'Google Stadia',
#   'Windows PC'],
#  ['PlayStation 4', 'Xbox One', 'Mac', 'Linux', 'Windows PC'],
#  ['PlayStation', 'Nintendo Switch'],
#  ['Xbox One', 'PlayStation 4', 'Windows PC'],
#  ['Windows PC',
#   'Android',
#   'Mac',
#   'PlayStation 4',
#   'iOS',
#   'Xbox One',
#   'Nintendo Switch',
#   'Google Stadia'],
#  ['Mac', 'Windows PC'],
#  ['Xbox 360', 'Mac', 'Nintendo DS', 'Android', 'Windows PC', 'iOS'],
#  ['Wii', 'Xbox', 'PlayStation 2', 'Windows PC'],
#  nan,
#  ['PlayStation 4', 'Xbox One', 'Xbox 360', 'Mac', 'Linux', 'Windows PC'],
#  ['PlayStation 3', 'Xbox 360', 'Xbox One', 'Windows PC'],
#  ['Atari Jaguar',
#   'PlayStation 4',
#   '3DO Interactive Multiplayer',
#   'Nintendo Switch',
#   'Xbox Live',
#   'Xbox One',
#   'PlayStation',
#   'Sega Saturn',
#   'SNES',
#   'Android',
#   'Game Boy Advance',
#   'iOS',
#   'Windows PC'],
#  ['PlayStation 3', 'Nintendo Switch', 'Xbox 360', 'Mac', 'Windows PC'],
#  ['Windows PC'],
#  ['Windows PC', 'PlayStation 3', 'Xbox 360'],
#  nan,
#  ['Windows PC', 'Xbox 360', 'PlayStation 3'],
#  nan,
#  ['PlayStation Network',
#   'Nintendo DS',
#   'PlayStation Portable',
#   'PlayStation 2',
#   'Windows PC'],
#  ['PlayStation 4',
#   'Nintendo Switch',
#   'Xbox One',
#   'Mac',
#   'Linux',
#   'Windows PC'],
#  nan,
#  nan,
#  ['Xbox One', 'PlayStation 4', 'Windows PC'],
#  ['Windows PC'],
#  ['Windows PC', 'PlayStation 4'],
#  ['Windows PC', 'Mac', 'iOS'],
#  nan,
#  ['PlayStation 4', 'Xbox One', 'Mac', 'Linux', 'Windows PC'],
#  ['PlayStation 4', 'Xbox Series', 'Xbox One', 'PlayStation 5', 'Windows PC'],
#  ['WiiWare'],
#  ['PlayStation 4'],
#  nan,
#  ['PlayStation Network', 'PlayStation 3', 'PlayStation Vita', 'Windows PC'],
#  nan,
#  ['PlayStation 4',
#   'Nintendo Switch',
#   'Xbox Series',
#   'Xbox One',
#   'Mac',
#   'PlayStation 5',
#   'Windows PC'],
#  ['Windows PC', 'PlayStation 4', 'Xbox One', 'PlayStation 5'],
#  ['PlayStation 4', 'Nintendo Switch', 'Xbox One', 'Wii U', 'Windows PC'],
#  nan,
#  ['Windows PC'],
#  ['Windows PC', 'PlayStation 4', 'Xbox One', 'Nintendo Switch'],
#  ['Xbox 360', 'Windows PC', 'Xbox Live'],
#  ['PlayStation 3', 'PlayStation 4', 'Xbox One', 'Xbox 360', 'Windows PC'],
#  ['Xbox One', 'PlayStation 4', 'Nintendo Switch', 'Windows PC'],
#  ['Xbox', 'PlayStation 2'],
#  ['PlayStation 4',
#   'Nintendo Switch',
#   'Xbox One',
#   'Google Stadia',
#   'Windows PC'],
#  ['Windows PC',
#   'Mac',
#   'Linux',
#   'PlayStation 4',
#   'Xbox One',
#   'Nintendo Switch'],
#  ['PlayStation 4',
#   'Nintendo Switch',
#   'Xbox Series',
#   'Xbox One',
#   'PlayStation 5',
#   'Windows PC'],
#  ['PlayStation 2'],
#  ['Windows PC'],
#  ['Nintendo Switch', 'Windows PC'],
#  ['PlayStation 3',
#   'PlayStation Network',
#   'Xbox Live',
#   'Xbox 360',
#   'Wii',
#   'Windows PC'],
#  ['PlayStation Vita', 'Windows PC'],
#  ['PlayStation 4',
#   'Nintendo Switch',
#   'Xbox One',
#   'Mac',
#   'Linux',
#   'Windows PC'],
#  ['PlayStation 4', 'Nintendo Switch', 'Xbox One', 'Mac', 'Windows PC'],
#  ['PlayStation Network',
#   'Xbox Live',
#   'Xbox 360',
#   'Mac',
#   'Wii',
#   'PlayStation Portable',
#   'PlayStation 2',
#   'OnLive Game System',
#   'Windows PC'],
#  nan,
#  ['PlayStation 4',
#   'Nintendo Switch',
#   'Xbox One',
#   'Google Stadia',
#   'Windows PC'],
#  ['PlayStation 4',
#   'Nintendo Switch',
#   'Xbox One',
#   'Android',
#   'Windows PC',
#   'iOS'],
#  ['PlayStation 4',
#   'Nintendo Switch',
#   'Xbox One',
#   'PlayStation Vita',
#   'Mac',
#   'Wii U',
#   'Linux',
#   'Windows PC'],
#  ['Nintendo Switch', 'Xbox One', 'Mac', 'Android', 'Windows PC', 'iOS'],
#  ['PlayStation Vita', 'Windows PC', 'PlayStation 4'],
#  ['Windows PC'],
#  ['PlayStation 4',
#   'Oculus Rift',
#   'Xbox Series',
#   'Nintendo Switch',
#   'PlayStation VR',
#   'Xbox One',
#   'Mac',
#   'PlayStation 5',
#   'Playstation VR2',
#   'SteamVR',
#   'Windows PC'],
#  ['PlayStation 4', 'Xbox Series', 'Xbox One', 'PlayStation 5', 'Windows PC'],
#  ['Xbox One', 'PlayStation 4', 'Windows PC'],
#  ['Xbox One', 'PlayStation 4', 'Windows PC'],
#  ['Nintendo DS', 'Windows PC'],
#  ['Windows PC', 'PlayStation 3', 'Xbox 360'],
#  ['PlayStation 4',
#   'Oculus Rift',
#   'PlayStation VR',
#   'Xbox One',
#   'SteamVR',
#   'Windows PC'],
#  ['Xbox One', 'PlayStation 4', 'Windows PC'],
#  ['PlayStation 4', 'Xbox Series', 'Xbox One', 'PlayStation 5', 'Windows PC'],
#  ['PlayStation 3',
#   'Xbox 360',
#   'Nintendo DS',
#   'PlayStation Portable',
#   'Windows PC'],
#  nan,
#  ['PlayStation 4', 'Windows PC'],
#  ['PlayStation 4',
#   'Nintendo Switch',
#   'Xbox One',
#   'Mac',
#   'Linux',
#   'Windows PC'],
#  ['Xbox One', 'PlayStation 4', 'Nintendo Switch', 'Windows PC'],
#  nan,
#  nan,
#  ['Xbox Live', 'Xbox 360', 'Mac', 'Linux', 'Windows PC'],
#  ['PlayStation 4'],
#  ['Windows PC'],
#  nan,
#  ['Windows PC'],
#  ['Linux', 'Mac', 'Windows PC'],
#  ['PlayStation 4', 'Windows PC'],
#  ['Xbox Series',
#   'Xbox',
#   'Mac',
#   'Nintendo GameCube',
#   'PlayStation 2',
#   'Game Boy Advance',
#   'Windows PC'],
#  ['Game Boy Advance'],
#  ['Windows PC'],
#  ['Wii', 'Xbox', 'PlayStation 2', 'Windows PC'],
#  ['Windows PC', 'Mac', 'PlayStation 4', 'Xbox One', 'Nintendo Switch'],
#  ['Linux', 'Xbox', 'Mac', 'Windows PC'],
#  ['PlayStation 4', 'Xbox One', 'Mac', 'Linux', 'Windows PC'],
#  nan,
#  ['PlayStation 4', 'Nintendo Switch', 'Xbox One', 'Linux', 'Windows PC'],
#  ['PlayStation Network'],
#  ['PlayStation 4', 'Nintendo Switch', 'Windows PC'],
#  ['Xbox One', 'PlayStation 4', 'Windows PC'],
#  ['PlayStation 4',
#   'Nintendo Switch',
#   'Xbox One',
#   'Mac',
#   'Linux',
#   'Windows PC'],
#  ['Windows PC'],
#  nan,
#  ['Xbox One', 'PlayStation 4', 'Nintendo Switch', 'Windows PC'],
#  ['Linux', 'Mac', 'Windows PC'],
#  ['PlayStation 4',
#   'Xbox Series',
#   'Xbox One',
#   'PlayStation 5',
#   'Google Stadia',
#   'Windows PC'],
#  ['PlayStation 4',
#   'Nintendo Switch',
#   'Xbox Live',
#   'Xbox 360',
#   'Mac',
#   'Linux',
#   'iOS',
#   'Windows PC'],
#  nan,
#  nan,
#  ['Xbox One', 'PlayStation 4', 'Nintendo Switch', 'Windows PC'],
#  ['Xbox One', 'PlayStation 4', 'Nintendo Switch', 'Windows PC'],
#  ['Xbox One', 'PlayStation 4', 'Nintendo Switch', 'Windows PC'],
#  ['Windows PC', 'PlayStation 3', 'Xbox 360'],
#  nan,
#  ['Windows PC', 'PlayStation 4', 'Xbox One'],
#  nan,
#  ['PlayStation 4',
#   'Nintendo Switch',
#   'Xbox One',
#   'Mac',
#   'Linux',
#   'Windows PC'],
#  ['PlayStation 3', 'Xbox 360', 'Nintendo Switch', 'Windows PC'],
#  ['PlayStation 4',
#   'Nintendo Switch',
#   'Xbox One',
#   'Google Stadia',
#   'Windows PC'],
#  nan,
#  ['PlayStation 3', 'Xbox 360', 'Windows PC'],
#  ['Xbox Live'],
#  ['Mac', 'Windows PC'],
#  ['Nintendo Switch'],
#  ['PlayStation 4',
#   'Xbox One',
#   'PlayStation 5',
#   'Nintendo Switch',
#   'Xbox Series'],
#  ['PlayStation 4', 'Xbox Series', 'Xbox One', 'PlayStation 5', 'Windows PC'],
#  ['PlayStation 4',
#   'Nintendo Switch',
#   'Xbox One',
#   'Mac',
#   'Linux',
#   'Windows PC'],
#  ['Oculus VR', 'PlayStation VR', 'Oculus Quest 2'],
#  ['PlayStation 3',
#   'PlayStation 4',
#   'Nintendo Switch',
#   'Xbox One',
#   'Xbox 360',
#   'Nintendo DS',
#   'Wii',
#   'Windows PC'],
#  ['Windows PC'],
#  nan,
#  ['PlayStation 4',
#   'Nintendo Switch',
#   'Xbox One',
#   'PlayStation Vita',
#   'Windows PC'],
#  nan,
#  ['Linux', 'Mac', 'Windows PC'],
#  ['PlayStation 4', 'Nintendo Switch', 'Windows PC'],
#  ['PlayStation 3', 'Xbox 360', 'Xbox Series', 'Windows PC'],
#  ['Xbox One', 'PlayStation 4', 'Windows PC'],
#  ['Windows PC'],
#  nan,
#  ['Ouya', 'Xbox One', 'Mac', 'Linux', 'Windows PC'],
#  nan,
#  ['Windows PC', 'Android', 'PlayStation 4', 'Xbox One', 'Nintendo Switch'],
#  ['Windows PC'],
#  nan,
#  ['Xbox One', 'PlayStation 4', 'Nintendo Switch', 'Windows PC'],
#  ['PlayStation 3',
#   'PlayStation 4',
#   'Nintendo Switch',
#   'Xbox One',
#   'Xbox 360',
#   'Mac',
#   'Wii U',
#   'Linux',
#   'iOS',
#   'Windows PC'],
#  ['PlayStation 4',
#   'Nintendo Switch',
#   'Xbox Series',
#   'Xbox One',
#   'Mac',
#   'Windows PC'],
#  ['Windows PC', 'Mac', 'PlayStation 4'],
#  ['SteamVR', 'PlayStation VR', 'Oculus Rift'],
#  nan,
#  ['Nintendo Switch'],
#  ['PlayStation 4',
#   'Nintendo Switch',
#   'Xbox Series',
#   'Xbox One',
#   'Mac',
#   'PlayStation 5',
#   'Linux',
#   'Android',
#   'iOS',
#   'Windows PC'],
#  ['PlayStation 4',
#   'Nintendo Switch',
#   'Xbox Series',
#   'Xbox One',
#   'PlayStation 5',
#   'Windows PC'],
#  ['Windows PC', 'Mac', 'PlayStation 4', 'Xbox One'],
#  ['Windows PC', 'Mac', 'PlayStation 4', 'Xbox One'],
#  ['Windows PC'],
#  ['Windows PC'],
#  ['PlayStation 3', 'Xbox 360', 'Nintendo Switch', 'Windows PC'],
#  ['PlayStation 3',
#   'PlayStation 4',
#   'Nintendo Switch',
#   'Xbox One',
#   'PlayStation Vita',
#   'Mac',
#   'Wii U',
#   'Linux',
#   'Android',
#   'iOS',
#   'Windows PC'],
#  nan,
#  nan,
#  ['Windows PC'],
#  ['Xbox One', 'PlayStation 4', 'Windows PC', 'PlayStation 5'],
#  ['Windows PC'],
#  ['Nintendo Switch', 'Mac', 'Android', 'Windows PC', 'iOS'],
#  ['Linux', 'Mac', 'Windows PC'],
#  ['Xbox One', 'PlayStation 4', 'Nintendo Switch', 'Windows PC'],
#  ['PlayStation Vita', 'Xbox One', 'PlayStation 4', 'Windows PC'],
#  ['PlayStation 4',
#   'Nintendo Switch',
#   'Xbox Series',
#   'Xbox One',
#   'Mac',
#   'PlayStation 5',
#   'Linux',
#   'Windows PC'],
#  ['Windows PC', 'Xbox One', 'Nintendo Switch'],
#  ['PlayStation 4',
#   'Nintendo Switch',
#   'Xbox One',
#   'Google Stadia',
#   'Windows PC'],
#  ['PlayStation 3',
#   'Xbox Live',
#   'Xbox 360',
#   'PlayStation Vita',
#   'Mac',
#   'Linux',
#   'Android',
#   'Windows Phone',
#   'PlayStation Portable',
#   'iOS',
#   'Windows PC'],
#  ['PlayStation 3',
#   'Xbox Live',
#   'Xbox 360',
#   'Mac',
#   'Nintendo DS',
#   'Wii',
#   'Windows PC'],
#  ['Windows PC', 'Nintendo GameCube', 'Xbox', 'PlayStation 2'],
#  ['PlayStation Portable', 'PlayStation 3', 'PlayStation Vita', 'Windows PC'],
#  ['PlayStation 4',
#   'Nintendo Switch',
#   'Xbox One',
#   'Google Stadia',
#   'Windows PC'],
#  ['PlayStation 4'],
#  ['PlayStation Vita', 'Windows PC'],
#  ['Xbox One', 'PlayStation 4', 'Nintendo Switch', 'Windows PC'],
#  nan,
#  ['Windows PC'],
#  ['PlayStation 3',
#   'PlayStation 4',
#   'Nintendo Switch',
#   'Xbox One',
#   'PlayStation Vita',
#   'Mac',
#   'Nintendo DS',
#   'Wii',
#   'Nintendo 3DS',
#   'Linux',
#   'Android',
#   'iOS',
#   'Windows PC'],
#  ['PlayStation 4', 'Windows PC'],
#  ['Windows PC', 'PlayStation 5'],
#  ['Windows PC'],
#  nan,
#  ['PlayStation 4', 'Mac', 'Windows PC', 'PlayStation 5'],
#  ['Windows PC'],
#  ['Windows PC'],
#  ['PlayStation 4', 'Nintendo Switch'],
#  nan,
#  ['Windows PC'],
#  ['Windows PC', 'Android', 'Mac', 'iOS'],
#  ['PlayStation Network',
#   'PlayStation 3',
#   'Xbox Live',
#   'Xbox 360',
#   'Android',
#   'iOS'],
#  ['Xbox One', 'PlayStation 4', 'Nintendo Switch', 'Windows PC'],
#  nan,
#  nan,
#  ['Xbox One', 'Windows PC'],
#  ['PlayStation 4', 'Nintendo Switch', 'Windows PC'],
#  nan,
#  ['Wii', 'PlayStation Vita', 'Windows PC'],
#  nan,
#  ['PlayStation 4',
#   'Nintendo Switch',
#   'Xbox One',
#   'PlayStation Vita',
#   'Mac',
#   'Wii U',
#   'Linux',
#   'Android',
#   'iOS',
#   'Windows PC'],
#  ['Windows PC'],
#  ['PlayStation 4', 'Nintendo Switch', 'Windows PC'],
#  ['PlayStation 3'],
#  ['Windows PC',
#   'PlayStation 4',
#   'Xbox One',
#   'PlayStation 5',
#   'Nintendo Switch',
#   'Xbox Series'],
#  ['Windows PC'],
#  ['Xbox One', 'Nintendo Switch', 'Windows PC'],
#  nan,
#  ['Windows PC',
#   'PlayStation 4',
#   'Web browser',
#   'Xbox One',
#   'PlayStation 5',
#   'Xbox Series'],
#  nan,
#  ['PlayStation 4', 'Mac', 'Linux', 'PlayStation', 'Windows PC'],
#  nan,
#  ['Windows PC', 'PlayStation 4'],
#  ['PlayStation 4',
#   'Nintendo Switch',
#   'Xbox One',
#   'Mac',
#   'Linux',
#   'Windows PC'],
#  nan,
#  ['PlayStation 4', 'PlayStation Vita', 'Wii U', 'Nintendo 3DS', 'Windows PC'],
#  ['PlayStation 4', 'Windows PC'],
#  nan,
#  ['Nintendo Switch'],
#  nan,
#  ['iOS', 'Nintendo Switch'],
#  ['PlayStation 3',
#   'PlayStation 4',
#   'Nintendo Switch',
#   'Xbox One',
#   'PlayStation Vita',
#   'Mac',
#   'Linux',
#   'Google Stadia',
#   'Windows PC'],
#  ['Oculus Quest 2',
#   'Daydream',
#   'PlayStation 4',
#   'Nintendo Switch',
#   'Oculus Rift',
#   'Gear VR',
#   'PlayStation VR',
#   'Xbox One',
#   'Mac',
#   'Oculus Quest',
#   'Linux',
#   'Android',
#   'SteamVR',
#   'Windows Mixed Reality',
#   'iOS',
#   'Windows PC'],
#  nan,
#  ['Mac', 'PlayStation', 'Sega Saturn', 'Windows PC', 'iOS'],
#  ['Xbox One', 'PlayStation 4', 'Nintendo Switch', 'Windows PC'],
#  ['Windows PC', 'PlayStation 4', 'Xbox One'],
#  ['Xbox One', 'PlayStation 4', 'Nintendo Switch', 'Windows PC'],
#  nan,
#  ['Windows PC'],
#  ['Xbox One', 'PlayStation 4', 'Nintendo Switch', 'Windows PC'],
#  ['PlayStation Vita', 'Windows PC'],
#  ['PlayStation 3',
#   'PlayStation Network',
#   'Xbox Live',
#   'Xbox 360',
#   'PlayStation Portable',
#   'Windows PC'],
#  ['Nintendo Switch'],
#  nan,
#  ['Xbox One', 'Linux', 'PlayStation 4', 'Windows PC'],
#  ['PlayStation 4', 'Xbox Series', 'Xbox One', 'PlayStation 5', 'Windows PC'],
#  ['Windows PC'],
#  ['Windows PC'],
#  ['Xbox One', 'PlayStation 4', 'Windows PC'],
#  ['PlayStation 3', 'Xbox 360', 'Windows PC'],
#  ['Xbox', 'PlayStation 2', 'Windows PC', 'Xbox Series'],
#  ['Windows PC', 'Nintendo Switch'],
#  ['Xbox One', 'Xbox 360', 'PlayStation 4', 'Windows PC'],
#  ['Linux', 'Mac', 'Windows PC'],
#  ['Windows PC', 'PlayStation 5', 'Xbox Series'],
#  ['Xbox One', 'Xbox 360', 'PlayStation 4', 'Windows PC'],
#  ['PlayStation 3',
#   'Xbox Live',
#   'Xbox 360',
#   'Mac',
#   'Nintendo DS',
#   'Wii',
#   'Android',
#   'Windows PC',
#   'iOS'],
#  ['Xbox One', 'PlayStation 4', 'Windows PC'],
#  nan,
#  ['Xbox One', 'Xbox Series', 'Windows PC'],
#  ['Windows PC', 'Mac', 'Linux'],
#  ['Windows PC', 'Xbox Live'],
#  ['Windows PC', 'Mac', 'Linux', 'PlayStation 4'],
#  ['PlayStation 3',
#   'PlayStation 4',
#   'Xbox One',
#   'PlayStation Vita',
#   'Mac',
#   'Wii U',
#   'Linux',
#   'Windows PC'],
#  ['Windows PC'],
#  ['PlayStation 3',
#   'PlayStation 4',
#   'Xbox Series',
#   'Xbox One',
#   'Xbox 360',
#   'Mac',
#   'Linux',
#   'Windows PC'],
#  ['PlayStation 4', 'Xbox One', 'Mac', 'Linux', 'Windows PC'],
#  ['Nintendo Switch', 'Xbox', 'Mac', 'Linux', 'Android', 'Windows PC', 'iOS'],
#  nan,
#  ['PlayStation Vita', 'Mac', 'Linux', 'Android', 'Windows PC', 'iOS'],
#  ['PlayStation 3',
#   'PlayStation Network',
#   'Nintendo Switch',
#   'PlayStation 4',
#   'Xbox One',
#   'PlayStation Vita',
#   'PlayStation Portable',
#   'PlayStation',
#   'Android',
#   'iOS',
#   'Windows PC'],
#  ['Windows PC', 'Oculus VR', 'SteamVR', 'PlayStation VR'],
#  ['Xbox One', 'PlayStation 4', 'Windows PC'],
#  ['PlayStation 3',
#   'PlayStation 4',
#   'Nintendo Switch',
#   'PlayStation Network',
#   'Xbox One',
#   'PlayStation Vita',
#   'Mac',
#   'Linux',
#   'Android',
#   'iOS',
#   'Windows PC'],
#  ['PlayStation 4', 'Nintendo Switch', 'Mac', 'Linux', 'Windows PC'],
#  nan,
#  ['PlayStation 4',
#   'Nintendo Switch',
#   'Xbox One',
#   'PlayStation 5',
#   'Google Stadia',
#   'Windows PC'],
#  nan,
#  nan,
#  ['PlayStation Network', 'PlayStation Portable', 'Windows PC', 'Xbox Live'],
#  ['PlayStation 4', 'Xbox Series', 'Xbox One', 'PlayStation 5', 'Windows PC'],
#  ['PlayStation 2', 'Xbox', 'Mac', 'Windows PC'],
#  nan,
#  ['Windows PC'],
#  nan,
#  ['PlayStation 4', 'Windows PC'],
#  nan,
#  ['Windows PC', 'PlayStation 3', 'Xbox 360'],
#  ['PlayStation 3',
#   'PlayStation 4',
#   'Xbox One',
#   'Xbox 360',
#   'Mac',
#   'Wii U',
#   'Linux',
#   'Windows PC'],
#  ['PlayStation 4',
#   'Nintendo Switch',
#   'Xbox One',
#   'PlayStation Vita',
#   'Windows PC'],
#  ['Windows PC', 'Mac', 'Linux'],
#  ['Windows PC'],
#  ['PlayStation 4',
#   'Nintendo Switch',
#   'Xbox One',
#   'Google Stadia',
#   'Windows PC'],
#  ['Xbox One', 'PlayStation 4', 'Nintendo Switch', 'Windows PC'],
#  ['Sega Mega Drive/Genesis', 'Wii', 'PlayStation 4'],
#  nan,
#  ['PlayStation 4',
#   'Nintendo Switch',
#   'Xbox One',
#   'Google Stadia',
#   'Windows PC'],
#  ['Windows PC'],
#  ['PlayStation 4',
#   'Nintendo Switch',
#   'Xbox Series',
#   'Xbox One',
#   'PlayStation 5',
#   'Windows PC'],
#  ['PlayStation 3',
#   'PlayStation 4',
#   'Nintendo Switch',
#   'Xbox One',
#   'PlayStation Vita',
#   'Mac',
#   'Linux',
#   'Windows PC'],
#  ['Xbox One', 'PlayStation 4', 'Windows PC'],
#  ['Xbox One', 'PlayStation 4', 'Windows PC'],
#  ['PlayStation 3', 'Xbox 360', 'Xbox One', 'Windows PC'],
#  ['Windows PC', 'Nintendo Switch'],
#  ['Windows PC'],
#  ['Windows PC'],
#  ['Windows PC'],
#  ['Windows PC', 'Nintendo Switch'],
#  nan,
#  ['PlayStation 4',
#   'Xbox Series',
#   'Xbox One',
#   'PlayStation 5',
#   'Google Stadia',
#   'Windows PC'],
#  ['PlayStation 3',
#   'PlayStation Network',
#   'Xbox Live',
#   'Ouya',
#   'Xbox 360',
#   'PlayStation Vita',
#   'Android',
#   'Windows PC',
#   'iOS'],
#  ['Xbox 360', 'Windows PC', 'Xbox Live'],
#  nan,
#  ['Nintendo Switch', 'Windows PC'],
#  nan,
#  ['Xbox One', 'PlayStation 4', 'Nintendo Switch', 'Windows PC'],
#  ['Mac', 'Windows PC'],
#  ['Windows PC', 'Mac', 'Linux'],
#  ['Windows PC'],
#  ['PlayStation Vita', 'PlayStation 4', 'iOS', 'Windows PC'],
#  ['PlayStation 3', 'PlayStation Vita', 'Windows PC', 'PlayStation 4'],
#  ['PlayStation 4',
#   'Nintendo Switch',
#   'Xbox One',
#   'Wii U',
#   'PlayStation 5',
#   'Nintendo 3DS',
#   'Google Stadia',
#   'Windows PC'],
#  ['Windows PC', 'PlayStation 4', 'PlayStation 5', 'Nintendo Switch'],
#  nan,
#  ['Windows PC', 'Mac', 'iOS', 'Nintendo Switch'],
#  ['Windows PC', 'Mac', 'Linux', 'Nintendo Switch'],
#  ['PlayStation 3', 'Xbox 360', 'OnLive Game System', 'Windows PC'],
#  ['Windows PC', 'Mac', 'Linux', 'PlayStation 4', 'Xbox One'],
#  nan,
#  ['Windows PC'],
#  ['Xbox One', 'PlayStation 4', 'Nintendo Switch', 'Windows PC'],
#  ['PlayStation 4',
#   'Nintendo Switch',
#   'Xbox Series',
#   'Xbox One',
#   'PlayStation 5',
#   'Windows PC'],
#  nan,
#  ['Windows PC'],
#  ['Mac', 'Windows PC'],
#  ['Windows PC', 'PlayStation 3', 'Xbox 360'],
#  ['Windows PC', 'PlayStation 4', 'PlayStation Vita'],
#  ['Xbox One', 'PlayStation 4', 'Nintendo Switch', 'Windows PC'],
#  ['Xbox One', 'PlayStation 4', 'Nintendo Switch', 'Windows PC'],
#  nan,
#  ['Windows PC'],
#  nan,
#  ['Windows PC', 'PlayStation 3', 'PlayStation Vita', 'Xbox 360'],
#  nan,
#  ['Xbox One', 'PlayStation 4', 'Nintendo Switch', 'Windows PC'],
#  nan,
#  nan,
#  ['PlayStation 3', 'Xbox 360', 'Windows PC'],
#  nan,
#  ['PlayStation Vita', 'PlayStation 4', 'Nintendo Switch', 'Windows PC'],
#  ['Linux', 'Mac', 'Windows PC'],
#  nan,
#  ['PlayStation 4',
#   'Nintendo Switch',
#   'Xbox Series',
#   'Xbox One',
#   'Mac',
#   'Linux',
#   'Android',
#   'Google Stadia',
#   'iOS',
#   'Windows PC'],
#  ['Nintendo Switch', 'Mac', 'Linux', 'Google Stadia', 'Windows PC'],
#  ['Windows PC', 'Mac'],
#  ['Xbox One', 'PlayStation 4', 'Nintendo Switch', 'Windows PC'],
#  ['Xbox One', 'Nintendo Switch', 'Windows PC'],
#  ['PlayStation 4', 'Xbox One', 'PlayStation Vita', 'Wii U', 'Windows PC'],
#  ['Mac', 'Windows PC'],
#  ['Windows PC'],
#  ['PlayStation 3',
#   'PlayStation 4',
#   'PC DOS',
#   'PlayStation Network',
#   'PlayStation Vita',
#   'PlayStation 5',
#   'PlayStation',
#   'PlayStation Portable',
#   'Game Boy',
#   'Windows PC'],
#  ['PlayStation 4',
#   'Nintendo Switch',
#   'Xbox Series',
#   'Xbox One',
#   'PlayStation 5',
#   'Google Stadia',
#   'Windows PC'],
#  nan,
#  ['Windows PC', 'Nintendo Switch'],
#  ['PlayStation 3', 'Xbox 360', 'PlayStation Vita', 'Windows PC'],
#  ['PlayStation 3',
#   'PlayStation 4',
#   'Xbox Live',
#   'Xbox One',
#   'Xbox 360',
#   'Xbox',
#   'Mac',
#   'Linux',
#   'PlayStation 2',
#   'Windows PC'],
#  ['Xbox One', 'PlayStation 4', 'Nintendo Switch', 'Windows PC'],
#  ['PlayStation 4',
#   'Nintendo Switch',
#   'Xbox Series',
#   'Xbox One',
#   'Mac',
#   'PlayStation 5',
#   'Windows PC'],
#  ['Windows PC'],
#  ['Nintendo Switch', 'Windows PC'],
#  ['Web browser',
#   'PlayStation 3',
#   'PlayStation 4',
#   'PlayStation Network',
#   'PlayStation Vita',
#   'PlayStation Portable'],
#  ['Windows PC', 'Mac', 'Linux', 'PlayStation 4', 'Xbox One'],
#  ['PlayStation Network'],
#  ['PlayStation 4',
#   'Xbox One',
#   'Xbox 360',
#   'Mac',
#   'Linux',
#   'Google Stadia',
#   'Windows PC'],
#  ['PlayStation 4',
#   'Nintendo Switch',
#   'Xbox Series',
#   'Xbox One',
#   'Mac',
#   'PlayStation 5',
#   'Android',
#   'Windows PC',
#   'iOS'],
#  ['Nintendo Switch', 'Xbox Series', 'Xbox One', 'PlayStation 5', 'Windows PC'],
#  ['Windows PC', 'Xbox 360', 'PlayStation 4', 'Xbox One'],
#  ['PlayStation 4',
#   'Arcade',
#   'Xbox Series',
#   'Xbox One',
#   'PlayStation 5',
#   'Windows PC'],
#  ['Xbox One', 'PlayStation 4', 'Nintendo Switch', 'Windows PC'],
#  nan,
#  ['PlayStation 4', 'Xbox One', 'Mac', 'Wii U', 'Linux', 'Windows PC'],
#  ['Windows PC'],
#  ['PlayStation 4', 'Nintendo Switch', 'Xbox One', 'Wii U', 'Windows PC'],
#  ['Xbox One', 'PlayStation 4', 'Nintendo Switch', 'Windows PC'],
#  nan,
#  ['Nintendo Switch'],
#  ['PlayStation 4',
#   'Nintendo Switch',
#   'Xbox One',
#   'Google Stadia',
#   'Windows PC'],
#  ['Nintendo Switch', 'Windows PC'],
#  ['PlayStation Portable', 'PlayStation 3', 'PlayStation', 'Windows PC'],
#  ['Xbox Series', 'Windows PC', 'PlayStation 5'],
#  nan,
#  ['PlayStation 3', 'Xbox 360', 'PlayStation Vita', 'Wii U', 'Windows PC'],
#  ['PlayStation Network', 'PlayStation 3', 'Mac', 'Linux', 'Windows PC'],
#  ['Windows PC', 'iOS'],
#  ['PlayStation Vita', 'Windows PC'],
#  ['Windows PC'],
#  ['Windows PC', 'PlayStation 5', 'Xbox Series'],
#  nan,
#  ['Windows PC'],
#  ['Xbox', 'Windows PC'],
#  ['Xbox One', 'PlayStation 4', 'Nintendo Switch', 'Windows PC'],
#  ['PlayStation Network',
#   'Xbox Live',
#   'Nintendo DSi',
#   'Nintendo DS',
#   'PlayStation Portable',
#   'Windows PC'],
#  ['PlayStation 4', 'Windows PC'],
#  ['Xbox One', 'PlayStation 4', 'Nintendo Switch', 'Windows PC'],
#  ['Xbox One', 'PlayStation 4', 'Windows PC'],
#  ['PlayStation', 'Windows PC', 'Android'],
#  nan,
#  nan,
#  ['Xbox One', 'PlayStation 4', 'Nintendo Switch', 'Windows PC'],
#  nan,
#  nan,
#  ['Xbox Series', 'iOS', 'Windows PC'],
#  nan,
#  nan,
#  ...]

# %%
df['platforms'] = new_platforms_1_2_list

# %% [markdown]
# `platforms_2` is now useless and can be dropped

# %%
df.drop(columns='platforms_2', inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5061 entries, 0 to 5060
# Data columns (total 51 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   appid                     5061 non-null   int64
#  1   normalized_name           5061 non-null   object
#  2   name                      5061 non-null   object
#  3   release_date              5061 non-null   datetime64[ns]
#  4   peak_ccu                  5061 non-null   float64
#  5   required_age              5061 non-null   int64
#  6   dlc_count                 5061 non-null   int64
#  7   about_the_game            5045 non-null   object
#  8   summary                   3021 non-null   object
#  9   supported_languages       5061 non-null   object
#  10  full_audio_languages      5061 non-null   object
#  11  some_reviews              2248 non-null   object
#  12  reviews_total             5061 non-null   float64
#  13  reviews_score_fancy       5061 non-null   object
#  14  header_image              5061 non-null   object
#  15  windows                   5061 non-null   bool
#  16  mac                       5061 non-null   bool
#  17  linux                     5061 non-null   bool
#  18  metacritic_url            5061 non-null   object
#  19  achievements              5061 non-null   int64
#  20  recommendations           5061 non-null   int64
#  21  notes                     591 non-null    object
#  22  developers                5061 non-null   object
#  23  publishers                5037 non-null   object
#  24  categories                5059 non-null   object
#  25  genres                    5057 non-null   object
#  26  tags                      5031 non-null   object
#  27  screenshots               5061 non-null   object
#  28  movies                    4500 non-null   object
#  29  steam_page                5061 non-null   object
#  30  platforms                 4088 non-null   object
#  31  infos_per_platform        3384 non-null   object
#  32  revenue_estimated         4583 non-null   object
#  33  meta_critic_score         5061 non-null   float64
#  34  new_positive              5061 non-null   float64
#  35  new_negative              5061 non-null   float64
#  36  new_min_estimated_owners  5061 non-null   float64
#  37  new_max_estimated_owners  5061 non-null   float64
#  38  new_average_forever       5061 non-null   float64
#  39  new_median_forever        5061 non-null   float64
#  40  new_price                 4936 non-null   float64
#  41  new_initialprice          4583 non-null   float64
#  42  new_discount              4583 non-null   float64
#  43  metacritic_user_score     4743 non-null   float64
#  44  plays_backloggd           5058 non-null   float64
#  45  playing_backloggd         5058 non-null   float64
#  46  backlogs_backloggd        5058 non-null   float64
#  47  wishlist_backloggd        5058 non-null   float64
#  48  lists_backloggd           5058 non-null   float64
#  49  reviews_backloggd         5058 non-null   float64
#  50  likes_backloggd           4525 non-null   float64
# dtypes: bool(3), datetime64[ns](1), float64(20), int64(5), object(22)
# memory usage: 1.9+ MB

# %%
df[df['infos_per_platform'].notna()]['infos_per_platform'][0]
# Out:
# "{'XOne': {'critic_score': nan, 'total_sales': nan, 'na_sales': nan, 'jp_sales': nan, 'pal_sales': nan, 'other_sales': nan, 'release_date': '2020-10-02', 'last_update': '2020-09-11'}, 'NS': {'critic_score': nan, 'total_sales': nan, 'na_sales': nan, 'jp_sales': nan, 'pal_sales': nan, 'other_sales': nan, 'release_date': '2020-10-01', 'last_update': '2020-09-11'}, 'PC': {'critic_score': nan, 'total_sales': nan, 'na_sales': nan, 'jp_sales': nan, 'pal_sales': nan, 'other_sales': nan, 'release_date': '2019-10-02', 'last_update': '2020-09-11'}, 'PS4': {'critic_score': nan, 'total_sales': nan, 'na_sales': nan, 'jp_sales': nan, 'pal_sales': nan, 'other_sales': nan, 'release_date': '2020-09-29', 'last_update': '2020-09-11'}}"

# %%
info_list = list()
for elem in df['infos_per_platform'].values:
    if isinstance(elem, str):
        info_list.append(eval(elem, {"nan": np.nan}))
    else:
        info_list.append(elem)

# %%
df['infos_per_platform'] = info_list

# %%
df[df['infos_per_platform'].notna()]['infos_per_platform']
# Out:
# 0       {'XOne': {'critic_score': nan, 'total_sales': ...
# 1       {'PSN': {'critic_score': 6.5, 'total_sales': n...
# 2       {'X360': {'critic_score': nan, 'total_sales': ...
# 3       {'PS4': {'critic_score': 7.9, 'total_sales': 3...
# 4       {'XOne': {'critic_score': 9.2, 'total_sales': ...
#                               ...
# 5037    {'All': {'critic_score': nan, 'total_sales': n...
# 5040    {'XS': {'critic_score': nan, 'total_sales': na...
# 5041    {'GBA': {'critic_score': 8.7, 'total_sales': 0...
# 5046    {'PS2': {'critic_score': nan, 'total_sales': 1...
# 5052    {'XS': {'critic_score': nan, 'total_sales': na...
# Name: infos_per_platform, Length: 3384, dtype: object

# %%
new_infos_per_platform_list = list()
for i, row in df.iterrows():
    temp_dict = dict()
    if isinstance(row['infos_per_platform'], dict):
        for console, infos in row['infos_per_platform'].items():
            new_console = platforms_2_mapping.get(console, console)
            temp_dict[new_console] = infos
        new_infos_per_platform_list.append(temp_dict)
    else:
        new_infos_per_platform_list.append(row['infos_per_platform'])

# %%
new_infos_per_platform_list
# Out:
# [{'Xbox One': {'critic_score': nan,
#    'total_sales': nan,
#    'na_sales': nan,
#    'jp_sales': nan,
#    'pal_sales': nan,
#    'other_sales': nan,
#    'release_date': '2020-10-02',
#    'last_update': '2020-09-11'},
#   'Nintendo Switch': {'critic_score': nan,
#    'total_sales': nan,
#    'na_sales': nan,
#    'jp_sales': nan,
#    'pal_sales': nan,
#    'other_sales': nan,
#    'release_date': '2020-10-01',
#    'last_update': '2020-09-11'},
#   'Windows PC': {'critic_score': nan,
#    'total_sales': nan,
#    'na_sales': nan,
#    'jp_sales': nan,
#    'pal_sales': nan,
#    'other_sales': nan,
#    'release_date': '2019-10-02',
#    'last_update': '2020-09-11'},
#   'PlayStation 4': {'critic_score': nan,
#    'total_sales': nan,
#    'na_sales': nan,
#    'jp_sales': nan,
#    'pal_sales': nan,
#    'other_sales': nan,
#    'release_date': '2020-09-29',
#    'last_update': '2020-09-11'}},
#  {'PlayStation Network': {'critic_score': 6.5,
#    'total_sales': nan,
#    'na_sales': nan,
#    'jp_sales': nan,
#    'pal_sales': nan,
#    'other_sales': nan,
#    'release_date': '2011-02-22',
#    'last_update': nan},
#   'Xbox Live': {'critic_score': 6.8,
#    'total_sales': nan,
#    'na_sales': nan,
#    'jp_sales': nan,
#    'pal_sales': nan,
#    'other_sales': nan,
#    'release_date': '2010-11-17',
#    'last_update': nan},
#   'Windows PC': {'critic_score': 6.8,
#    'total_sales': nan,
#    'na_sales': nan,
#    'jp_sales': nan,
#    'pal_sales': nan,
#    'other_sales': nan,
#    'release_date': '2010-11-17',
#    'last_update': nan}},
#  {'Xbox 360': {'critic_score': nan,
#    'total_sales': 0.01,
#    'na_sales': nan,
#    'jp_sales': nan,
#    'pal_sales': 0.01,
#    'other_sales': 0.0,
#    'release_date': '2013-07-01',
#    'last_update': '2019-04-29'},
#   'Windows PC': {'critic_score': nan,
#    'total_sales': nan,
#    'na_sales': nan,
#    'jp_sales': nan,
#    'pal_sales': nan,
#    'other_sales': nan,
#    'release_date': '2013-11-15',
#    'last_update': '2019-04-29'},
#   'PlayStation 3': {'critic_score': nan,
#    'total_sales': nan,
#    'na_sales': nan,
#    'jp_sales': nan,
#    'pal_sales': nan,
#    'other_sales': nan,
#    'release_date': '2014-10-28',
#    'last_update': '2019-04-29'}},
#  {'PlayStation 4': {'critic_score': 7.9,
#    'total_sales': 3.95,
#    'na_sales': 1.44,
#    'jp_sales': 0.15,
#    'pal_sales': 1.73,
#    'other_sales': 0.62,
#    'release_date': '2018-03-27',
#    'last_update': '2018-02-28'},
#   'Xbox One': {'critic_score': 7.2,
#    'total_sales': 1.78,
#    'na_sales': 1.14,
#    'jp_sales': nan,
#    'pal_sales': 0.47,
#    'other_sales': 0.17,
#    'release_date': '2018-03-27',
#    'last_update': '2018-02-28'},
#   'Windows PC': {'critic_score': 6.3,
#    'total_sales': 0.07,
#    'na_sales': nan,
#    'jp_sales': nan,
#    'pal_sales': 0.07,
#    'other_sales': 0.0,
#    'release_date': '2018-02-27',
#    'last_update': '2018-07-19'},
#   'All': {'critic_score': nan,
#    'total_sales': nan,
#    'na_sales': nan,
#    'jp_sales': nan,
#    'pal_sales': nan,
#    'other_sales': nan,
#    'release_date': '2018-03-27',
#    'last_update': '2020-10-28'}},
#  {'Xbox One': {'critic_score': 9.2,
#    'total_sales': 1.84,
#    'na_sales': 0.74,
#    'jp_sales': 0.01,
#    'pal_sales': 0.95,
#    'other_sales': 0.15,
#    'release_date': '2018-10-02',
#    'last_update': '2018-10-01'},
#   'Windows PC': {'critic_score': 10.0,
#    'total_sales': nan,
#    'na_sales': nan,
#    'jp_sales': nan,
#    'pal_sales': nan,
#    'other_sales': nan,
#    'release_date': '2018-10-02',
#    'last_update': '2018-06-11'},
#   'Xbox Series': {'critic_score': nan,
#    'total_sales': nan,
#    'na_sales': nan,
#    'jp_sales': nan,
#    'pal_sales': nan,
#    'other_sales': nan,
#    'release_date': '2020-11-10',
#    'last_update': '2020-09-19'}},
#  {'PlayStation 2': {'critic_score': 8.1,
#    'total_sales': 3.31,
#    'na_sales': 1.99,
#    'jp_sales': 0.05,
#    'pal_sales': 1.05,
#    'other_sales': 0.22,
#    'release_date': '2001-12-06',
#    'last_update': nan},
#   'Xbox': {'critic_score': 8.6,
#    'total_sales': 1.22,
#    'na_sales': 0.98,
#    'jp_sales': nan,
#    'pal_sales': 0.19,
#    'other_sales': 0.05,
#    'release_date': '2001-12-12',
#    'last_update': nan},
#   'Game Boy Advance': {'critic_score': 7.8,
#    'total_sales': 0.03,
#    'na_sales': 0.02,
#    'jp_sales': nan,
#    'pal_sales': 0.01,
#    'other_sales': 0.0,
#    'release_date': '2003-12-18',
#    'last_update': nan},
#   'Windows PC': {'critic_score': 9.2,
#    'total_sales': 0.02,
#    'na_sales': nan,
#    'jp_sales': nan,
#    'pal_sales': 0.02,
#    'other_sales': 0.0,
#    'release_date': '2001-07-23',
#    'last_update': nan},
#   'Xbox Series': {'critic_score': nan,
#    'total_sales': nan,
#    'na_sales': nan,
#    'jp_sales': nan,
#    'pal_sales': nan,
#    'other_sales': nan,
#    'release_date': '2001-07-23',
#    'last_update': '2020-11-06'},
#   'All': {'critic_score': nan,
#    'total_sales': nan,
#    'na_sales': nan,
#    'jp_sales': nan,
#    'pal_sales': nan,
#    'other_sales': nan,
#    'release_date': '2001-07-23',
#    'last_update': '2021-03-13'},
#   'Xbox Live': {'critic_score': nan,
#    'total_sales': nan,
#    'na_sales': nan,
#    'jp_sales': nan,
#    'pal_sales': nan,
#    'other_sales': nan,
#    'release_date': '2009-04-27',
#    'last_update': nan}},
#  nan,
#  {'Windows PC': {'critic_score': nan,
#    'total_sales': nan,
#    'na_sales': nan,
#    'jp_sales': nan,
#    'pal_sales': nan,
#    'other_sales': nan,
#    'release_date': '2019-07-29',
#    'last_update': '2019-05-19'}},
#  {'Nintendo 3DS': {'critic_score': nan,
#    'total_sales': 0.11,
#    'na_sales': nan,
#    'jp_sales': 0.11,
#    'pal_sales': nan,
#    'other_sales': nan,
#    'release_date': '2014-02-06',
#    'last_update': '2018-07-04'},
#   'PlayStation 4': {'critic_score': nan,
#    'total_sales': 0.1,
#    'na_sales': 0.05,
#    'jp_sales': nan,
#    'pal_sales': 0.03,
#    'other_sales': 0.02,
#    'release_date': '2017-04-25',
#    'last_update': '2018-07-04'},
#   'PlayStation Vita': {'critic_score': nan,
#    'total_sales': 0.06,
#    'na_sales': nan,
#    'jp_sales': 0.06,
#    'pal_sales': nan,
#    'other_sales': nan,
#    'release_date': '2014-02-06',
#    'last_update': '2018-07-04'},
#   'PlayStation 3': {'critic_score': nan,
#    'total_sales': 0.05,
#    'na_sales': nan,
#    'jp_sales': 0.05,
#    'pal_sales': nan,
#    'other_sales': nan,
#    'release_date': '2014-02-06',
#    'last_update': '2018-07-04'},
#   'Wii U': {'critic_score': nan,
#    'total_sales': 0.02,
#    'na_sales': nan,
#    'jp_sales': 0.02,
#    'pal_sales': nan,
#    'other_sales': nan,
#    'release_date': '2014-02-06',
#    'last_update': '2018-07-04'},
#   'All': {'critic_score': nan,
#    'total_sales': nan,
#    'na_sales': nan,
#    'jp_sales': nan,
#    'pal_sales': nan,
#    'other_sales': nan,
#    'release_date': '2017-04-25',
#    'last_update': '2021-05-12'},
#   'Nintendo Switch': {'critic_score': 8.3,
#    'total_sales': nan,
#    'na_sales': nan,
#    'jp_sales': nan,
#    'pal_sales': nan,
#    'other_sales': nan,
#    'release_date': '2017-04-25',
#    'last_update': '2018-07-04'},
#   'Xbox One': {'critic_score': nan,
#    'total_sales': nan,
#    'na_sales': nan,
#    'jp_sales': nan,
#    'pal_sales': nan,
#    'other_sales': nan,
#    'release_date': '2014-12-04',
#    'last_update': '2018-07-04'}},
#  {'PlayStation 4': {'critic_score': nan,
#    'total_sales': 0.37,
#    'na_sales': 0.1,
#    'jp_sales': 0.17,
#    'pal_sales': 0.06,
#    'other_sales': 0.03,
#    'release_date': '2018-02-13',
#    'last_update': '2017-12-31'},
#   'Xbox One': {'critic_score': nan,
#    'total_sales': 0.08,
#    'na_sales': 0.06,
#    'jp_sales': nan,
#    'pal_sales': 0.01,
#    'other_sales': 0.01,
#    'release_date': '2018-02-13',
#    'last_update': '2017-12-31'},
#   'All': {'critic_score': nan,
#    'total_sales': nan,
#    'na_sales': nan,
#    'jp_sales': nan,
#    'pal_sales': nan,
#    'other_sales': nan,
#    'release_date': '2018-02-13',
#    'last_update': '2020-10-17'},
#   'Windows PC': {'critic_score': nan,
#    'total_sales': nan,
#    'na_sales': nan,
#    'jp_sales': nan,
#    'pal_sales': nan,
#    'other_sales': nan,
#    'release_date': '2018-02-13',
#    'last_update': '2017-12-31'}},
#  {'Windows PC': {'critic_score': nan,
#    'total_sales': nan,
#    'na_sales': nan,
#    'jp_sales': nan,
#    'pal_sales': nan,
#    'other_sales': nan,
#    'release_date': nan,
#    'last_update': '2022-02-09'}},
#  nan,
#  {'Xbox 360': {'critic_score': 9.6,
#    'total_sales': 9.41,
#    'na_sales': 5.98,
#    'jp_sales': 0.13,
#    'pal_sales': 2.39,
#    'other_sales': 0.91,
#    'release_date': '2007-11-05',
#    'last_update': nan},
#   'PlayStation 3': {'critic_score': 9.5,
#    'total_sales': 6.72,
#    'na_sales': 3.13,
#    'jp_sales': 0.28,
#    'pal_sales': 2.27,
#    'other_sales': 1.04,
#    'release_date': '2007-11-05',
#    'last_update': nan},
#   'Windows PC': {'critic_score': 9.3,
#    'total_sales': 1.15,
#    'na_sales': nan,
#    'jp_sales': nan,
#    'pal_sales': 1.12,
#    'other_sales': 0.03,
#    'release_date': '2007-11-05',
#    'last_update': nan},
#   'Nintendo DS': {'critic_score': 7.3,
#    'total_sales': 1.05,
#    'na_sales': 0.95,
#    'jp_sales': 0.01,
#    'pal_sales': 0.02,
#    'other_sales': 0.08,
#    'release_date': '2007-11-05',
#    'last_update': nan},
#   'All': {'critic_score': nan,
#    'total_sales': nan,
#    'na_sales': nan,
#    'jp_sales': nan,
#    'pal_sales': nan,
#    'other_sales': nan,
#    'release_date': '2007-11-05',
#    'last_update': '2020-10-14'},
#   'PlayStation Network': {'critic_score': nan,
#    'total_sales': nan,
#    'na_sales': nan,
#    'jp_sales': nan,
#    'pal_sales': nan,
#    'other_sales': nan,
#    'release_date': '2011-11-22',
#    'last_update': nan},
#   'Xbox Live': {'critic_score': nan,
#    'total_sales': nan,
#    'na_sales': nan,
#    'jp_sales': nan,
#    'pal_sales': nan,
#    'other_sales': nan,
#    'release_date': '2010-05-25',
#    'last_update': nan}},
#  {'Xbox Live': {'critic_score': 7.1,
#    'total_sales': nan,
#    'na_sales': nan,
#    'jp_sales': nan,
#    'pal_sales': nan,
#    'other_sales': nan,
#    'release_date': '2005-11-22',
#    'last_update': nan}},
#  {'PlayStation Network': {'critic_score': nan,
#    'total_sales': 0.17,
#    'na_sales': 0.04,
#    'jp_sales': nan,
#    'pal_sales': 0.11,
#    'other_sales': 0.01,
#    'release_date': '2012-08-28',
#    'last_update': '2018-09-23'},
#   'Windows PC': {'critic_score': nan,
#    'total_sales': nan,
#    'na_sales': nan,
#    'jp_sales': nan,
#    'pal_sales': nan,
#    'other_sales': nan,
#    'release_date': '2020-06-11',
#    'last_update': '2019-03-26'},
#   'PlayStation 4': {'critic_score': nan,
#    'total_sales': nan,
#    'na_sales': nan,
#    'jp_sales': nan,
#    'pal_sales': nan,
#    'other_sales': nan,
#    'release_date': '2015-07-21',
#    'last_update': '2018-09-23'}},
#  nan,
#  {'PlayStation Vita': {'critic_score': nan,
#    'total_sales': 0.26,
#    'na_sales': 0.06,
#    'jp_sales': 0.13,
#    'pal_sales': 0.04,
#    'other_sales': 0.03,
#    'release_date': '2016-09-06',
#    'last_update': '2018-10-29'},
#   'PlayStation 3': {'critic_score': nan,
#    'total_sales': 0.22,
#    'na_sales': 0.05,
#    'jp_sales': 0.11,
#    'pal_sales': 0.04,
#    'other_sales': 0.02,
#    'release_date': '2016-09-06',
#    'last_update': '2018-10-29'}},
#  {'Windows PC': {'critic_score': nan,
#    'total_sales': nan,
#    'na_sales': nan,
#    'jp_sales': nan,
#    'pal_sales': nan,
#    'other_sales': nan,
#    'release_date': '2015-12-02',
#    'last_update': '2019-03-27'}},
#  {'Nintendo Switch': {'critic_score': nan,
#    'total_sales': nan,
#    'na_sales': nan,
#    'jp_sales': nan,
#    'pal_sales': nan,
#    'other_sales': nan,
#    'release_date': nan,
#    'last_update': '2021-01-28'},
#   'PlayStation 4': {'critic_score': nan,
#    'total_sales': nan,
#    'na_sales': nan,
#    'jp_sales': nan,
#    'pal_sales': nan,
#    'other_sales': nan,
#    'release_date': nan,
#    'last_update': '2021-01-28'},
#   'Xbox One': {'critic_score': nan,
#    'total_sales': nan,
#    'na_sales': nan,
#    'jp_sales': nan,
#    'pal_sales': nan,
#    'other_sales': nan,
#    'release_date': nan,
#    'last_update': '2021-01-28'},
#   'Windows PC': {'critic_score': nan,
#    'total_sales': nan,
#    'na_sales': nan,
#    'jp_sales': nan,
#    'pal_sales': nan,
#    'other_sales': nan,
#    'release_date': '2020-02-04',
#    'last_update': '2021-01-28'}},
#  {'Nintendo Switch': {'critic_score': nan,
#    'total_sales': nan,
#    'na_sales': nan,
#    'jp_sales': nan,
#    'pal_sales': nan,
#    'other_sales': nan,
#    'release_date': nan,
#    'last_update': '2021-07-23'},
#   'Windows PC': {'critic_score': nan,
#    'total_sales': nan,
#    'na_sales': nan,
#    'jp_sales': nan,
#    'pal_sales': nan,
#    'other_sales': nan,
#    'release_date': nan,
#    'last_update': '2021-07-23'},
#   'PlayStation 4': {'critic_score': nan,
#    'total_sales': nan,
#    'na_sales': nan,
#    'jp_sales': nan,
#    'pal_sales': nan,
#    'other_sales': nan,
#    'release_date': nan,
#    'last_update': '2021-07-23'},
#   'PlayStation 5': {'critic_score': nan,
#    'total_sales': nan,
#    'na_sales': nan,
#    'jp_sales': nan,
#    'pal_sales': nan,
#    'other_sales': nan,
#    'release_date': nan,
#    'last_update': '2021-07-23'},
#   'Xbox One': {'critic_score': nan,
#    'total_sales': nan,
#    'na_sales': nan,
#    'jp_sales': nan,
#    'pal_sales': nan,
#    'other_sales': nan,
#    'release_date': nan,
#    'last_update': '2021-07-23'},
#   'Xbox Series': {'critic_score': nan,
#    'total_sales': nan,
#    'na_sales': nan,
#    'jp_sales': nan,
#    'pal_sales': nan,
#    'other_sales': nan,
#    'release_date': nan,
#    'last_update': '2021-07-23'}},
#  {'PlayStation 4': {'critic_score': nan,
#    'total_sales': nan,
#    'na_sales': nan,
#    'jp_sales': nan,
#    'pal_sales': nan,
#    'other_sales': nan,
#    'release_date': '2019-10-04',
#    'last_update': '2019-06-11'},
#   'Xbox One': {'critic_score': nan,
#    'total_sales': nan,
#    'na_sales': nan,
#    'jp_sales': nan,
#    'pal_sales': nan,
#    'other_sales': nan,
#    'release_date': '2019-10-04',
#    'last_update': '2019-06-11'},
#   'Nintendo Switch': {'critic_score': nan,
#    'total_sales': nan,
#    'na_sales': nan,
#    'jp_sales': nan,
#    'pal_sales': nan,
#    'other_sales': nan,
#    'release_date': '2019-10-04',
#    'last_update': '2019-06-11'},
#   'Windows PC': {'critic_score': nan,
#    'total_sales': nan,
#    'na_sales': nan,
#    'jp_sales': nan,
#    'pal_sales': nan,
#    'other_sales': nan,
#    'release_date': '2016-10-20',
#    'last_update': '2019-06-11'}},
#  {'Nintendo Switch': {'critic_score': nan,
#    'total_sales': 0.09,
#    'na_sales': 0.05,
#    'jp_sales': 0.01,
#    'pal_sales': 0.01,
#    'other_sales': 0.01,
#    'release_date': '2018-07-10',
#    'last_update': '2018-09-15'},
#   'PlayStation 4': {'critic_score': nan,
#    'total_sales': 0.08,
#    'na_sales': 0.03,
#    'jp_sales': 0.04,
#    'pal_sales': 0.01,
#    'other_sales': 0.01,
#    'release_date': '2018-07-10',
#    'last_update': '2018-09-15'},
#   'Xbox One': {'critic_score': nan,
#    'total_sales': 0.03,
#    'na_sales': 0.02,
#    'jp_sales': nan,
#    'pal_sales': nan,
#    'other_sales': 0.0,
#    'release_date': '2018-07-10',
#    'last_update': '2018-09-15'},
#   'Windows PC': {'critic_score': nan,
#    'total_sales': nan,
#    'na_sales': nan,
#    'jp_sales': nan,
#    'pal_sales': nan,
#    'other_sales': nan,
#    'release_date': '2018-12-31',
#    'last_update': '2018-02-21'}},
#  {'Windows PC': {'critic_score': nan,
#    'total_sales': nan,
#    'na_sales': nan,
#    'jp_sales': nan,
#    'pal_sales': nan,
#    'other_sales': nan,
#    'release_date': nan,
#    'last_update': '2019-03-31'},
#   'Nintendo Switch': {'critic_score': nan,
#    'total_sales': nan,
#    'na_sales': nan,
#    'jp_sales': nan,
#    'pal_sales': nan,
#    'other_sales': nan,
#    'release_date': '2018-08-30',
#    'last_update': '2019-03-31'}},
#  {'Windows PC': {'critic_score': nan,
#    'total_sales': nan,
#    'na_sales': nan,
#    'jp_sales': nan,
#    'pal_sales': nan,
#    'other_sales': nan,
#    'release_date': '2006-08-24',
#    'last_update': nan}},
#  {'PlayStation Vita': {'critic_score': nan,
#    'total_sales': 0.06,
#    'na_sales': 0.01,
#    'jp_sales': 0.04,
#    'pal_sales': 0.0,
#    'other_sales': 0.01,
#    'release_date': '2017-09-19',
#    'last_update': '2018-09-22'},
#   'Windows PC': {'critic_score': nan,
#    'total_sales': nan,
#    'na_sales': nan,
#    'jp_sales': nan,
#    'pal_sales': nan,
#    'other_sales': nan,
#    'release_date': nan,
#    'last_update': '2018-06-28'}},
#  nan,
#  {'Windows PC': {'critic_score': nan,
#    'total_sales': nan,
#    'na_sales': nan,
#    'jp_sales': nan,
#    'pal_sales': nan,
#    'other_sales': nan,
#    'release_date': '2014-05-21',
#    'last_update': '2019-04-17'}},
#  {'Nintendo DS': {'critic_score': nan,
#    'total_sales': 0.26,
#    'na_sales': 0.24,
#    'jp_sales': nan,
#    'pal_sales': 0.0,
#    'other_sales': 0.02,
#    'release_date': '2007-10-16',
#    'last_update': nan}},
#  {'Windows PC': {'critic_score': nan,
#    'total_sales': nan,
#    'na_sales': nan,
#    'jp_sales': nan,
#    'pal_sales': nan,
#    'other_sales': nan,
#    'release_date': '2013-05-30',
#    'last_update': '2019-04-21'}},
#  nan,
#  {'PlayStation 4': {'critic_score': nan,
#    'total_sales': 0.08,
#    'na_sales': 0.05,
#    'jp_sales': nan,
#    'pal_sales': 0.02,
#    'other_sales': 0.01,
#    'release_date': '2015-12-08',
#    'last_update': '2018-04-26'},
#   'Windows PC': {'critic_score': nan,
#    'total_sales': nan,
#    'na_sales': nan,
#    'jp_sales': nan,
#    'pal_sales': nan,
#    'other_sales': nan,
#    'release_date': '2016-07-18',
#    'last_update': nan}},
#  nan,
#  {'Nintendo Switch': {'critic_score': nan,
#    'total_sales': nan,
#    'na_sales': nan,
#    'jp_sales': nan,
#    'pal_sales': nan,
#    'other_sales': nan,
#    'release_date': '2018-03-01',
#    'last_update': '2019-04-21'}},
#  nan,
#  nan,
#  {'PlayStation 4': {'critic_score': nan,
#    'total_sales': nan,
#    'na_sales': nan,
#    'jp_sales': nan,
#    'pal_sales': nan,
#    'other_sales': nan,
#    'release_date': '2020-12-01',
#    'last_update': '2019-12-02'},
#   'Windows PC': {'critic_score': nan,
#    'total_sales': nan,
#    'na_sales': nan,
#    'jp_sales': nan,
#    'pal_sales': nan,
#    'other_sales': nan,
#    'release_date': '2019-12-03',
#    'last_update': '2019-04-08'},
#   'Xbox One': {'critic_score': nan,
#    'total_sales': nan,
#    'na_sales': nan,
#    'jp_sales': nan,
#    'pal_sales': nan,
#    'other_sales': nan,
#    'release_date': '2020-12-01',
#    'last_update': '2019-04-08'}},
#  {'Windows PC': {'critic_score': nan,
#    'total_sales': nan,
#    'na_sales': nan,
#    'jp_sales': nan,
#    'pal_sales': nan,
#    'other_sales': nan,
#    'release_date': '2020-09-25',
#    'last_update': '2020-10-23'},
#   'PlayStation 4': {'critic_score': nan,
#    'total_sales': nan,
#    'na_sales': nan,
#    'jp_sales': nan,
#    'pal_sales': nan,
#    'other_sales': nan,
#    'release_date': nan,
#    'last_update': '2020-10-23'},
#   'Xbox One': {'critic_score': nan,
#    'total_sales': nan,
#    'na_sales': nan,
#    'jp_sales': nan,
#    'pal_sales': nan,
#    'other_sales': nan,
#    'release_date': nan,
#    'last_update': '2020-10-23'}},
#  nan,
#  {'All': {'critic_score': nan,
#    'total_sales': nan,
#    'na_sales': nan,
#    'jp_sales': nan,
#    'pal_sales': nan,
#    'other_sales': nan,
#    'release_date': '2019-09-19',
#    'last_update': '2021-12-07'}},
#  nan,
#  {'Wii': {'critic_score': nan,
#    'total_sales': 1.05,
#    'na_sales': 0.66,
#    'jp_sales': nan,
#    'pal_sales': 0.28,
#    'other_sales': 0.1,
#    'release_date': '2011-10-25',
#    'last_update': nan},
#   'PlayStation 3': {'critic_score': 7.4,
#    'total_sales': 0.62,
#    'na_sales': 0.3,
#    'jp_sales': nan,
#    'pal_sales': 0.23,
#    'other_sales': 0.09,
#    'release_date': '2011-10-25',
#    'last_update': nan},
#   'Xbox 360': {'critic_score': 6.7,
#    'total_sales': 0.57,
#    'na_sales': 0.37,
#    'jp_sales': nan,
#    'pal_sales': 0.14,
#    'other_sales': 0.05,
#    'release_date': '2011-10-25',
#    'last_update': nan},
#   'Windows PC': {'critic_score': nan,
#    'total_sales': 0.01,
#    'na_sales': 0.01,
#    'jp_sales': nan,
#    'pal_sales': nan,
#    'other_sales': 0.0,
#    'release_date': '2011-10-25',
#    'last_update': nan}},
#  nan,
#  {'PlayStation 4': {'critic_score': nan,
#    'total_sales': 0.01,
#    'na_sales': nan,
#    'jp_sales': nan,
#    'pal_sales': 0.0,
#    'other_sales': 0.0,
#    'release_date': '2016-04-29',
#    'last_update': '2018-09-21'},
#   'Windows PC': {'critic_score': 9.2,
#    'total_sales': nan,
#    'na_sales': nan,
#    'jp_sales': nan,
#    'pal_sales': nan,
#    'other_sales': nan,
#    'release_date': '2010-11-30',
#    'last_update': nan},
#   'Xbox Live': {'critic_score': 9.0,
#    'total_sales': nan,
#    'na_sales': nan,
#    'jp_sales': nan,
#    'pal_sales': nan,
#    'other_sales': nan,
#    'release_date': '2010-10-20',
#    'last_update': nan},
#   'WiiWare': {'critic_score': nan,
#    'total_sales': nan,
#    'na_sales': nan,
#    'jp_sales': nan,
#    'pal_sales': nan,
#    'other_sales': nan,
#    'release_date': nan,
#    'last_update': nan},
#   'Nintendo Switch': {'critic_score': nan,
#    'total_sales': nan,
#    'na_sales': nan,
#    'jp_sales': nan,
#    'pal_sales': nan,
#    'other_sales': nan,
#    'release_date': '2018-01-11',
#    'last_update': '2018-03-25'},
#   'Xbox Series': {'critic_score': nan,
#    'total_sales': nan,
#    'na_sales': nan,
#    'jp_sales': nan,
#    'pal_sales': nan,
#    'other_sales': nan,
#    'release_date': '2010-10-20',
#    'last_update': '2020-03-19'}},
#  {'Windows PC': {'critic_score': 8.5,
#    'total_sales': nan,
#    'na_sales': nan,
#    'jp_sales': nan,
#    'pal_sales': nan,
#    'other_sales': nan,
#    'release_date': '2013-11-07',
#    'last_update': '2019-04-17'}},
#  {'Nintendo Switch': {'critic_score': nan,
#    'total_sales': nan,
#    'na_sales': nan,
#    'jp_sales': nan,
#    'pal_sales': nan,
#    'other_sales': nan,
#    'release_date': '2020-12-01',
#    'last_update': '2020-06-19'},
#   'PlayStation 4': {'critic_score': nan,
#    'total_sales': nan,
#    'na_sales': nan,
#    'jp_sales': nan,
#    'pal_sales': nan,
#    'other_sales': nan,
#    'release_date': '2019-02-04',
#    'last_update': '2019-03-15'},
#   'Windows PC': {'critic_score': nan,
#    'total_sales': nan,
#    'na_sales': nan,
#    'jp_sales': nan,
#    'pal_sales': nan,
#    'other_sales': nan,
#    'release_date': '2019-02-04',
#    'last_update': '2019-03-15'},
#   'Xbox One': {'critic_score': nan,
#    'total_sales': nan,
#    'na_sales': nan,
#    'jp_sales': nan,
#    'pal_sales': nan,
#    'other_sales': nan,
#    'release_date': '2019-02-04',
#    'last_update': '2019-03-15'}},
#  {'Nintendo Switch': {'critic_score': nan,
#    'total_sales': nan,
#    'na_sales': nan,
#    'jp_sales': nan,
#    'pal_sales': nan,
#    'other_sales': nan,
#    'release_date': '2018-09-13',
#    'last_update': '2018-10-27'}},
#  nan,
#  nan,
#  {'PlayStation Vita': {'critic_score': nan,
#    'total_sales': 0.44,
#    'na_sales': nan,
#    'jp_sales': 0.38,
#    'pal_sales': 0.05,
#    'other_sales': 0.01,
#    'release_date': '2016-10-01',
#    'last_update': '2018-07-04'},
#   'PlayStation 4': {'critic_score': nan,
#    'total_sales': 0.12,
#    'na_sales': nan,
#    'jp_sales': 0.11,
#    'pal_sales': 0.01,
#    'other_sales': 0.0,
#    'release_date': '2015-02-26',
#    'last_update': '2018-07-04'},
#   'Windows PC': {'critic_score': nan,
#    'total_sales': nan,
#    'na_sales': nan,
#    'jp_sales': nan,
#    'pal_sales': nan,
#    'other_sales': nan,
#    'release_date': '2016-10-01',
#    'last_update': '2018-07-04'}},
#  {'Windows PC': {'critic_score': nan,
#    'total_sales': 0.09,
#    'na_sales': nan,
#    'jp_sales': nan,
#    'pal_sales': 0.09,
#    'other_sales': 0.01,
#    'release_date': '2016-02-02',
#    'last_update': '2018-11-29'}},
#  {'PlayStation 3': {'critic_score': 6.6,
#    'total_sales': 0.95,
#    'na_sales': 0.29,
#    'jp_sales': 0.2,
#    'pal_sales': 0.34,
#    'other_sales': 0.12,
#    'release_date': '2010-05-11',
#    'last_update': nan},
#   'Xbox 360': {'critic_score': 6.5,
#    'total_sales': 0.76,
#    'na_sales': 0.38,
#    'jp_sales': 0.08,
#    'pal_sales': 0.24,
#    'other_sales': 0.06,
#    'release_date': '2010-05-11',
#    'last_update': nan},
#   'Windows PC': {'critic_score': nan,
#    'total_sales': 0.03,
#    'na_sales': nan,
#    'jp_sales': nan,
#    'pal_sales': 0.02,
#    'other_sales': 0.0,
#    'release_date': '2010-10-15',
#    'last_update': nan},
#   'All': {'critic_score': nan,
#    'total_sales': nan,
#    'na_sales': nan,
#    'jp_sales': nan,
#    'pal_sales': nan,
#    'other_sales': nan,
#    'release_date': '2010-05-11',
#    'last_update': '2020-10-13'}},
#  {'Windows PC': {'critic_score': nan,
#    'total_sales': nan,
#    'na_sales': nan,
#    'jp_sales': nan,
#    'pal_sales': nan,
#    'other_sales': nan,
#    'release_date': nan,
#    'last_update': '2021-04-15'},
#   'PlayStation 4': {'critic_score': nan,
#    'total_sales': nan,
#    'na_sales': nan,
#    'jp_sales': nan,
#    'pal_sales': nan,
#    'other_sales': nan,
#    'release_date': nan,
#    'last_update': '2021-04-15'},
#   'Nintendo Switch': {'critic_score': nan,
#    'total_sales': nan,
#    'na_sales': nan,
#    'jp_sales': nan,
#    'pal_sales': nan,
#    'other_sales': nan,
#    'release_date': nan,
#    'last_update': '2021-04-15'}},
#  nan,
#  {'Windows PC': {'critic_score': nan,
#    'total_sales': nan,
#    'na_sales': nan,
#    'jp_sales': nan,
#    'pal_sales': nan,
#    'other_sales': nan,
#    'release_date': '2008-09-20',
#    'last_update': nan}},
#  {'Nintendo Switch': {'critic_score': nan,
#    'total_sales': nan,
#    'na_sales': nan,
#    'jp_sales': nan,
#    'pal_sales': nan,
#    'other_sales': nan,
#    'release_date': '2018-08-02',
#    'last_update': '2018-08-01'}},
#  nan,
#  nan,
#  nan,
#  {'Xbox 360': {'critic_score': 8.2,
#    'total_sales': 4.08,
#    'na_sales': 2.67,
#    'jp_sales': 0.04,
#    'pal_sales': 1.03,
#    'other_sales': 0.34,
#    'release_date': '2010-10-19',
#    'last_update': nan},
#   'PlayStation 3': {'critic_score': 8.2,
#    'total_sales': 3.17,
#    'na_sales': 1.54,
#    'jp_sales': 0.1,
#    'pal_sales': 1.04,
#    'other_sales': 0.49,
#    'release_date': '2010-10-19',
#    'last_update': nan},
#   'Windows PC': {'critic_score': 8.3,
#    'total_sales': nan,
#    'na_sales': nan,
#    'jp_sales': nan,
#    'pal_sales': nan,
#    'other_sales': nan,
#    'release_date': '2010-10-19',
#    'last_update': nan},
#   'All': {'critic_score': nan,
#    'total_sales': nan,
#    'na_sales': nan,
#    'jp_sales': nan,
#    'pal_sales': nan,
#    'other_sales': nan,
#    'release_date': '2010-10-19',
#    'last_update': '2020-10-30'}},
#  {'Nintendo Switch': {'critic_score': nan,
#    'total_sales': nan,
#    'na_sales': nan,
#    'jp_sales': nan,
#    'pal_sales': nan,
#    'other_sales': nan,
#    'release_date': '2020-02-14',
#    'last_update': '2019-06-08'},
#   'Windows PC': {'critic_score': nan,
#    'total_sales': nan,
#    'na_sales': nan,
#    'jp_sales': nan,
#    'pal_sales': nan,
#    'other_sales': nan,
#    'release_date': '2020-12-05',
#    'last_update': '2019-06-08'},
#   'Xbox One': {'critic_score': nan,
#    'total_sales': nan,
#    'na_sales': nan,
#    'jp_sales': nan,
#    'pal_sales': nan,
#    'other_sales': nan,
#    'release_date': '2020-02-14',
#    'last_update': '2019-06-08'},
#   'PlayStation 4': {'critic_score': nan,
#    'total_sales': nan,
#    'na_sales': nan,
#    'jp_sales': nan,
#    'pal_sales': nan,
#    'other_sales': nan,
#    'release_date': '2020-02-14',
#    'last_update': '2019-06-08'}},
#  {'Nintendo Switch': {'critic_score': nan,
#    'total_sales': nan,
#    'na_sales': nan,
#    'jp_sales': nan,
#    'pal_sales': nan,
#    'other_sales': nan,
#    'release_date': nan,
#    'last_update': '2022-11-18'},
#   'Windows PC': {'critic_score': nan,
#    'total_sales': nan,
#    'na_sales': nan,
#    'jp_sales': nan,
#    'pal_sales': nan,
#    'other_sales': nan,
#    'release_date': nan,
#    'last_update': '2022-11-18'}},
#  nan,
#  {'Nintendo Switch': {'critic_score': nan,
#    'total_sales': nan,
#    'na_sales': nan,
#    'jp_sales': nan,
#    'pal_sales': nan,
#    'other_sales': nan,
#    'release_date': '2018-01-01',
#    'last_update': '2018-03-25'}},
#  nan,
#  {'PlayStation Vita': {'critic_score': nan,
#    'total_sales': 0.18,
#    'na_sales': 0.11,
#    'jp_sales': 0.04,
#    'pal_sales': nan,
#    'other_sales': 0.04,
#    'release_date': '2014-04-15',
#    'last_update': '2019-01-14'},
#   'Nintendo 3DS': {'critic_score': nan,
#    'total_sales': 0.12,
#    'na_sales': 0.09,
#    'jp_sales': 0.03,
#    'pal_sales': nan,
#    'other_sales': 0.01,
#    'release_date': '2014-04-15',
#    'last_update': '2019-01-14'},
#   'Windows PC': {'critic_score': nan,
#    'total_sales': nan,
#    'na_sales': nan,
#    'jp_sales': nan,
#    'pal_sales': nan,
#    'other_sales': nan,
#    'release_date': '2016-08-16',
#    'last_update': '2019-01-14'}},
#  {'PlayStation 4': {'critic_score': nan,
#    'total_sales': 2.04,
#    'na_sales': 0.82,
#    'jp_sales': 0.06,
#    'pal_sales': 0.84,
#    'other_sales': 0.33,
#    'release_date': '2017-10-10',
#    'last_update': '2018-01-10'},
#   'Xbox One': {'critic_score': nan,
#    'total_sales': 1.15,
#    'na_sales': 0.75,
#    'jp_sales': nan,
#    'pal_sales': 0.29,
#    'other_sales': 0.11,
#    'release_date': '2017-10-10',
#    'last_update': '2018-01-10'},
#   'Windows PC': {'critic_score': nan,
#    'total_sales': 0.07,
#    'na_sales': 0.03,
#    'jp_sales': nan,
#    'pal_sales': 0.04,
#    'other_sales': 0.01,
#    'release_date': '2017-10-10',
#    'last_update': '2018-01-10'},
#   'All': {'critic_score': nan,
#    'total_sales': nan,
#    'na_sales': nan,
#    'jp_sales': nan,
#    'pal_sales': nan,
#    'other_sales': nan,
#    'release_date': '2017-10-10',
#    'last_update': '2021-08-30'}},
#  nan,
#  {'Nintendo Switch': {'critic_score': nan,
#    'total_sales': nan,
#    'na_sales': nan,
#    'jp_sales': nan,
#    'pal_sales': nan,
#    'other_sales': nan,
#    'release_date': '2017-12-05',
#    'last_update': '2018-03-23'}},
#  nan,
#  nan,
#  nan,
#  {'Xbox One': {'critic_score': nan,
#    'total_sales': nan,
#    'na_sales': nan,
#    'jp_sales': nan,
#    'pal_sales': nan,
#    'other_sales': nan,
#    'release_date': '2020-07-14',
#    'last_update': '2020-06-19'},
#   'PlayStation 4': {'critic_score': nan,
#    'total_sales': nan,
#    'na_sales': nan,
#    'jp_sales': nan,
#    'pal_sales': nan,
#    'other_sales': nan,
#    'release_date': '2020-07-14',
#    'last_update': '2020-06-19'},
#   'Windows PC': {'critic_score': nan,
#    'total_sales': nan,
#    'na_sales': nan,
#    'jp_sales': nan,
#    'pal_sales': nan,
#    'other_sales': nan,
#    'release_date': '2020-07-14',
#    'last_update': '2020-06-19'}},
#  {'iOS': {'critic_score': nan,
#    'total_sales': nan,
#    'na_sales': nan,
#    'jp_sales': nan,
#    'pal_sales': nan,
#    'other_sales': nan,
#    'release_date': nan,
#    'last_update': '2022-03-03'},
#   'Windows PC': {'critic_score': nan,
#    'total_sales': nan,
#    'na_sales': nan,
#    'jp_sales': nan,
#    'pal_sales': nan,
#    'other_sales': nan,
#    'release_date': nan,
#    'last_update': '2022-03-03'},
#   'PlayStation 4': {'critic_score': nan,
#    'total_sales': nan,
#    'na_sales': nan,
#    'jp_sales': nan,
#    'pal_sales': nan,
#    'other_sales': nan,
#    'release_date': nan,
#    'last_update': '2022-03-03'},
#   'PlayStation 5': {'critic_score': nan,
#    'total_sales': nan,
#    'na_sales': nan,
#    'jp_sales': nan,
#    'pal_sales': nan,
#    'other_sales': nan,
#    'release_date': nan,
#    'last_update': '2022-03-03'},
#   'Nintendo Switch': {'critic_score': nan,
#    'total_sales': nan,
#    'na_sales': nan,
#    'jp_sales': nan,
#    'pal_sales': nan,
#    'other_sales': nan,
#    'release_date': nan,
#    'last_update': '2022-03-03'},
#   'Xbox One': {'critic_score': nan,
#    'total_sales': nan,
#    'na_sales': nan,
#    'jp_sales': nan,
#    'pal_sales': nan,
#    'other_sales': nan,
#    'release_date': nan,
#    'last_update': '2022-03-03'},
#   'Xbox Series': {'critic_score': nan,
#    'total_sales': nan,
#    'na_sales': nan,
#    'jp_sales': nan,
#    'pal_sales': nan,
#    'other_sales': nan,
#    'release_date': nan,
#    'last_update': '2022-03-03'},
#   'All': {'critic_score': nan,
#    'total_sales': nan,
#    'na_sales': nan,
#    'jp_sales': nan,
#    'pal_sales': nan,
#    'other_sales': nan,
#    'release_date': nan,
#    'last_update': '2022-07-15'}},
#  nan,
#  nan,
#  {'All': {'critic_score': nan,
#    'total_sales': nan,
#    'na_sales': nan,
#    'jp_sales': nan,
#    'pal_sales': nan,
#    'other_sales': nan,
#    'release_date': '2008-08-14',
#    'last_update': '2021-02-14'},
#   'Xbox Live': {'critic_score': 8.7,
#    'total_sales': nan,
#    'na_sales': nan,
#    'jp_sales': nan,
#    'pal_sales': nan,
#    'other_sales': nan,
#    'release_date': '2008-08-13',
#    'last_update': nan},
#   'Windows PC': {'critic_score': 8.0,
#    'total_sales': nan,
#    'na_sales': nan,
#    'jp_sales': nan,
#    'pal_sales': nan,
#    'other_sales': nan,
#    'release_date': '2008-08-14',
#    'last_update': nan},
#   'PlayStation Network': {'critic_score': 8.0,
#    'total_sales': nan,
#    'na_sales': nan,
#    'jp_sales': nan,
#    'pal_sales': nan,
#    'other_sales': nan,
#    'release_date': '2008-08-14',
#    'last_update': nan}},
#  {'Xbox One': {'critic_score': nan,
#    'total_sales': nan,
#    'na_sales': nan,
#    'jp_sales': nan,
#    'pal_sales': nan,
#    'other_sales': nan,
#    'release_date': '2019-02-05',
#    'last_update': '2018-09-11'},
#   'PlayStation 4': {'critic_score': nan,
#    'total_sales': nan,
#    'na_sales': nan,
#    'jp_sales': nan,
#    'pal_sales': nan,
#    'other_sales': nan,
#    'release_date': '2019-02-05',
#    'last_update': '2018-09-11'}},
#  {'Windows PC': {'critic_score': nan,
#    'total_sales': nan,
#    'na_sales': nan,
#    'jp_sales': nan,
#    'pal_sales': nan,
#    'other_sales': nan,
#    'release_date': '2014-01-01',
#    'last_update': nan},
#   'PlayStation 3': {'critic_score': nan,
#    'total_sales': nan,
#    'na_sales': nan,
#    'jp_sales': nan,
#    'pal_sales': nan,
#    'other_sales': nan,
#    'release_date': '2014-01-01',
#    'last_update': nan},
#   'Xbox 360': {'critic_score': nan,
#    'total_sales': nan,
#    'na_sales': nan,
#    'jp_sales': nan,
#    'pal_sales': nan,
#    'other_sales': nan,
#    'release_date': '2014-01-01',
#    'last_update': nan}},
#  nan,
#  {'Windows PC': {'critic_score': nan,
#    'total_sales': nan,
#    'na_sales': nan,
#    'jp_sales': nan,
#    'pal_sales': nan,
#    'other_sales': nan,
#    'release_date': nan,
#    'last_update': '2019-03-29'}},
#  {'Nintendo Switch': {'critic_score': nan,
#    'total_sales': 0.07,
#    'na_sales': 0.06,
#    'jp_sales': nan,
#    'pal_sales': nan,
#    'other_sales': 0.01,
#    'release_date': '2018-04-17',
#    'last_update': '2019-02-16'},
#   'Windows PC': {'critic_score': nan,
#    'total_sales': nan,
#    'na_sales': nan,
#    'jp_sales': nan,
#    'pal_sales': nan,
#    'other_sales': nan,
#    'release_date': nan,
#    'last_update': '2019-02-15'},
#   'PlayStation 4': {'critic_score': nan,
#    'total_sales': nan,
#    'na_sales': nan,
#    'jp_sales': nan,
#    'pal_sales': nan,
#    'other_sales': nan,
#    'release_date': '2017-01-18',
#    'last_update': '2019-02-16'}},
#  {'Nintendo Switch': {'critic_score': nan,
#    'total_sales': nan,
#    'na_sales': nan,
#    'jp_sales': nan,
#    'pal_sales': nan,
#    'other_sales': nan,
#    'release_date': '2017-11-07',
#    'last_update': '2018-03-26'},
#   'Xbox Live': {'critic_score': 8.0,
#    'total_sales': nan,
#    'na_sales': nan,
#    'jp_sales': nan,
#    'pal_sales': nan,
#    'other_sales': nan,
#    'release_date': '2006-05-09',
#    'last_update': nan},
#   'Game Boy': {'critic_score': 7.5,
#    'total_sales': nan,
#    'na_sales': nan,
#    'jp_sales': nan,
#    'pal_sales': nan,
#    'other_sales': nan,
#    'release_date': '1999-12-16',
#    'last_update': nan},
#   'Nintendo DSi': {'critic_score': nan,
#    'total_sales': nan,
#    'na_sales': nan,
#    'jp_sales': nan,
#    'pal_sales': nan,
#    'other_sales': nan,
#    'release_date': '2009-12-21',
#    'last_update': nan},
#   'WiiWare': {'critic_score': nan,
#    'total_sales': nan,
#    'na_sales': nan,
#    'jp_sales': nan,
#    'pal_sales': nan,
#    'other_sales': nan,
#    'release_date': '2010-01-25',
#    'last_update': nan},
#   'PlayStation Network': {'critic_score': 7.5,
#    'total_sales': nan,
#    'na_sales': nan,
#    'jp_sales': nan,
#    'pal_sales': nan,
#    'other_sales': nan,
#    'release_date': '2009-10-01',
#    'last_update': nan},
#   'PlayStation': {'critic_score': nan,
#    'total_sales': nan,
#    'na_sales': nan,
#    'jp_sales': nan,
#    'pal_sales': nan,
#    'other_sales': nan,
#    'release_date': '1998-04-02',
#    'last_update': nan},
#   'PlayStation 2': {'critic_score': nan,
#    'total_sales': nan,
#    'na_sales': nan,
#    'jp_sales': nan,
#    'pal_sales': nan,
#    'other_sales': nan,
#    'release_date': '2004-03-11',
#    'last_update': nan},
#   'Windows PC': {'critic_score': nan,
#    'total_sales': nan,
#    'na_sales': nan,
#    'jp_sales': nan,
#    'pal_sales': nan,
#    'other_sales': nan,
#    'release_date': '2000-12-01',
#    'last_update': nan}},
#  nan,
#  nan,
#  {'Windows PC': {'critic_score': nan,
#    'total_sales': nan,
#    'na_sales': nan,
#    'jp_sales': nan,
#    'pal_sales': nan,
#    'other_sales': nan,
#    'release_date': nan,
#    'last_update': '2021-06-14'}},
#  {'Windows PC': {'critic_score': nan,
#    'total_sales': nan,
#    'na_sales': nan,
#    'jp_sales': nan,
#    'pal_sales': nan,
#    'other_sales': nan,
#    'release_date': nan,
#    'last_update': '2019-03-12'}},
#  nan,
#  {'Windows PC': {'critic_score': nan,
#    'total_sales': 0.0,
#    'na_sales': nan,
#    'jp_sales': nan,
#    'pal_sales': 0.0,
#    'other_sales': 0.0,
#    'release_date': '2008-04-14',
#    'last_update': nan}},
#  {'Windows PC': {'critic_score': nan,
#    'total_sales': nan,
#    'na_sales': nan,
#    'jp_sales': nan,
#    'pal_sales': nan,
#    'other_sales': nan,
#    'release_date': '2014-10-01',
#    'last_update': nan}},
#  {'PlayStation 3': {'critic_score': 7.8,
#    'total_sales': 1.07,
#    'na_sales': 0.49,
#    'jp_sales': 0.09,
#    'pal_sales': 0.34,
#    'other_sales': 0.15,
#    'release_date': '2008-11-04',
#    'last_update': nan},
#   'Xbox Series': {'critic_score': nan,
#    'total_sales': nan,
#    'na_sales': nan,
#    'jp_sales': nan,
#    'pal_sales': nan,
#    'other_sales': nan,
#    'release_date': '2008-11-04',
#    'last_update': '2020-10-17'},
#   'All': {'critic_score': nan,
#    'total_sales': nan,
#    'na_sales': nan,
#    'jp_sales': nan,
#    'pal_sales': nan,
#    'other_sales': nan,
#    'release_date': '2008-11-04',
#    'last_update': '2020-11-16'}},
#  {'Windows PC': {'critic_score': nan,
#    'total_sales': nan,
#    'na_sales': nan,
#    'jp_sales': nan,
#    'pal_sales': nan,
#    'other_sales': nan,
#    'release_date': '2020-04-14',
#    'last_update': '2020-02-13'},
#   'PlayStation 4': {'critic_score': nan,
#    'total_sales': nan,
#    'na_sales': nan,
#    'jp_sales': nan,
#    'pal_sales': nan,
#    'other_sales': nan,
#    'release_date': '2020-04-14',
#    'last_update': '2020-02-13'},
#   'Xbox One': {'critic_score': nan,
#    'total_sales': nan,
#    'na_sales': nan,
#    'jp_sales': nan,
#    'pal_sales': nan,
#    'other_sales': nan,
#    'release_date': '2020-04-14',
#    'last_update': '2020-02-13'}},
#  {'Nintendo 3DS': {'critic_score': nan,
#    'total_sales': 0.03,
#    'na_sales': nan,
#    'jp_sales': 0.03,
#    'pal_sales': nan,
#    'other_sales': nan,
#    'release_date': '2014-03-20',
#    'last_update': '2019-04-26'},
#   'Windows PC': {'critic_score': nan,
#    'total_sales': nan,
#    'na_sales': nan,
#    'jp_sales': nan,
#    'pal_sales': nan,
#    'other_sales': nan,
#    'release_date': '2015-10-06',
#    'last_update': '2019-04-26'},
#   'PlayStation Vita': {'critic_score': nan,
#    'total_sales': nan,
#    'na_sales': nan,
#    'jp_sales': nan,
#    'pal_sales': nan,
#    'other_sales': nan,
#    'release_date': '2015-04-21',
#    'last_update': '2019-04-26'}},
#  {'PlayStation 4': {'critic_score': nan,
#    'total_sales': 0.16,
#    'na_sales': 0.08,
#    'jp_sales': 0.02,
#    'pal_sales': 0.04,
#    'other_sales': 0.02,
#    'release_date': '2015-06-30',
#    'last_update': '2018-07-09'},
#   'Xbox One': {'critic_score': nan,
#    'total_sales': 0.08,
#    'na_sales': 0.06,
#    'jp_sales': nan,
#    'pal_sales': 0.01,
#    'other_sales': 0.01,
#    'release_date': '2015-06-30',
#    'last_update': '2018-06-03'},
#   'PlayStation 3': {'critic_score': nan,
#    'total_sales': 0.04,
#    'na_sales': nan,
#    'jp_sales': 0.04,
#    'pal_sales': nan,
#    'other_sales': nan,
#    'release_date': '2015-06-30',
#    'last_update': '2018-06-03'},
#   'PlayStation Vita': {'critic_score': nan,
#    'total_sales': 0.03,
#    'na_sales': nan,
#    'jp_sales': nan,
#    'pal_sales': 0.02,
#    'other_sales': 0.01,
#    'release_date': '2015-06-30',
#    'last_update': '2018-06-03'},
#   'Windows PC': {'critic_score': nan,
#    'total_sales': nan,
#    'na_sales': nan,
#    'jp_sales': nan,
#    'pal_sales': nan,
#    'other_sales': nan,
#    'release_date': '2016-03-02',
#    'last_update': '2019-04-08'}},
#  {'Windows PC': {'critic_score': nan,
#    'total_sales': nan,
#    'na_sales': nan,
#    'jp_sales': nan,
#    'pal_sales': nan,
#    'other_sales': nan,
#    'release_date': nan,
#    'last_update': '2019-02-15'}},
#  {'PlayStation Vita': {'critic_score': nan,
#    'total_sales': 0.06,
#    'na_sales': nan,
#    'jp_sales': 0.01,
#    'pal_sales': 0.03,
#    'other_sales': 0.01,
#    'release_date': '2016-08-02',
#    'last_update': '2018-03-04'},
#   'PlayStation 4': {'critic_score': nan,
#    'total_sales': 0.01,
#    'na_sales': nan,
#    'jp_sales': 0.01,
#    'pal_sales': nan,
#    'other_sales': nan,
#    'release_date': '2016-08-02',
#    'last_update': '2018-05-04'},
#   'All': {'critic_score': nan,
#    'total_sales': nan,
#    'na_sales': nan,
#    'jp_sales': nan,
#    'pal_sales': nan,
#    'other_sales': nan,
#    'release_date': '2016-08-02',
#    'last_update': '2021-01-30'},
#   'Windows PC': {'critic_score': nan,
#    'total_sales': nan,
#    'na_sales': nan,
#    'jp_sales': nan,
#    'pal_sales': nan,
#    'other_sales': nan,
#    'release_date': '2016-09-27',
#    'last_update': '2018-04-28'}},
#  {'PlayStation Vita': {'critic_score': nan,
#    'total_sales': nan,
#    'na_sales': nan,
#    'jp_sales': nan,
#    'pal_sales': nan,
#    'other_sales': nan,
#    'release_date': '2013-09-17',
#    'last_update': nan},
#   'Android': {'critic_score': nan,
#    'total_sales': nan,
#    'na_sales': nan,
#    'jp_sales': nan,
#    'pal_sales': nan,
#    'other_sales': nan,
#    'release_date': '2013-03-13',
#    'last_update': nan},
#   'Mac': {'critic_score': nan,
#    'total_sales': nan,
#    'na_sales': nan,
#    'jp_sales': nan,
#    'pal_sales': nan,
#    'other_sales': nan,
#    'release_date': '2014-02-27',
#    'last_update': nan},
#   'Windows PC': {'critic_score': nan,
#    'total_sales': nan,
#    'na_sales': nan,
#    'jp_sales': nan,
#    'pal_sales': nan,
#    'other_sales': nan,
#    'release_date': '2014-07-02',
#    'last_update': '2019-04-16'}},
#  nan,
#  {'SNES': {'critic_score': nan,
#    'total_sales': nan,
#    'na_sales': nan,
#    'jp_sales': nan,
#    'pal_sales': nan,
#    'other_sales': nan,
#    'release_date': '1995-08-01',
#    'last_update': nan},
#   'Game Boy': {'critic_score': nan,
#    'total_sales': nan,
#    'na_sales': nan,
#    'jp_sales': nan,
#    'pal_sales': nan,
#    'other_sales': nan,
#    'release_date': '1995-11-01',
#    'last_update': nan}},
#  nan,
#  {'Sega Mega Drive/Genesis': {'critic_score': nan,
#    'total_sales': nan,
#    'na_sales': nan,
#    'jp_sales': nan,
#    'pal_sales': nan,
#    'other_sales': nan,
#    'release_date': '1992-12-20',
#    'last_update': nan},
#   'Sega Game Gear': {'critic_score': nan,
#    'total_sales': nan,
#    'na_sales': nan,
#    'jp_sales': nan,
#    'pal_sales': nan,
#    'other_sales': nan,
#    'release_date': '1993-01-01',
#    'last_update': nan},
#   'Virtual Console': {'critic_score': nan,
#    'total_sales': nan,
#    'na_sales': nan,
#    'jp_sales': nan,
#    'pal_sales': nan,
#    'other_sales': nan,
#    'release_date': '2007-05-21',
#    'last_update': nan},
#   'Xbox Live': {'critic_score': nan,
#    'total_sales': nan,
#    'na_sales': nan,
#    'jp_sales': nan,
#    'pal_sales': nan,
#    'other_sales': nan,
#    'release_date': '2007-08-29',
#    'last_update': nan},
#   'Windows PC': {'critic_score': nan,
#    'total_sales': nan,
#    'na_sales': nan,
#    'jp_sales': nan,
#    'pal_sales': nan,
#    'other_sales': nan,
#    'release_date': '2011-01-26',
#    'last_update': nan}},
#  nan,
#  {'Nintendo Switch': {'critic_score': nan,
#    'total_sales': nan,
#    'na_sales': nan,
#    'jp_sales': nan,
#    'pal_sales': nan,
#    'other_sales': nan,
#    'release_date': '2018-01-01',
#    'last_update': '2018-01-07'}},
#  {'Windows PC': {'critic_score': nan,
#    'total_sales': nan,
#    'na_sales': nan,
#    'jp_sales': nan,
#    'pal_sales': nan,
#    'other_sales': nan,
#    'release_date': nan,
#    'last_update': '2021-08-02'}},
#  nan,
#  {'Xbox Series': {'critic_score': nan,
#    'total_sales': nan,
#    'na_sales': nan,
#    'jp_sales': nan,
#    'pal_sales': nan,
#    'other_sales': nan,
#    'release_date': '1994-08-31',
#    'last_update': '2020-02-24'}},
#  {'PlayStation 4': {'critic_score': nan,
#    'total_sales': 0.06,
#    'na_sales': 0.01,
#    'jp_sales': 0.05,
#    'pal_sales': nan,
#    'other_sales': 0.0,
#    'release_date': '2018-06-05',
#    'last_update': '2018-07-30'},
#   'Nintendo Switch': {'critic_score': nan,
#    'total_sales': 0.01,
#    'na_sales': nan,
#    'jp_sales': 0.01,
#    'pal_sales': nan,
#    'other_sales': nan,
#    'release_date': '2017-11-30',
#    'last_update': '2018-07-30'},
#   'All': {'critic_score': nan,
#    'total_sales': nan,
#    'na_sales': nan,
#    'jp_sales': nan,
#    'pal_sales': nan,
#    'other_sales': nan,
#    'release_date': '2017-11-30',
#    'last_update': '2020-10-17'}},
#  {'Windows PC': {'critic_score': nan,
#    'total_sales': nan,
#    'na_sales': nan,
#    'jp_sales': nan,
#    'pal_sales': nan,
#    'other_sales': nan,
#    'release_date': '2020-12-26',
#    'last_update': nan},
#   'Android': {'critic_score': nan,
#    'total_sales': nan,
#    'na_sales': nan,
#    'jp_sales': nan,
#    'pal_sales': nan,
#    'other_sales': nan,
#    'release_date': '2020-12-26',
#    'last_update': nan},
#   'PlayStation 4': {'critic_score': nan,
#    'total_sales': nan,
#    'na_sales': nan,
#    'jp_sales': nan,
#    'pal_sales': nan,
#    'other_sales': nan,
#    'release_date': '2020-12-26',
#    'last_update': '2019-04-01'},
#   'Xbox One': {'critic_score': nan,
#    'total_sales': nan,
#    'na_sales': nan,
#    'jp_sales': nan,
#    'pal_sales': nan,
#    'other_sales': nan,
#    'release_date': '2020-12-26',
#    'last_update': '2019-04-01'},
#   'Nintendo Switch': {'critic_score': nan,
#    'total_sales': nan,
#    'na_sales': nan,
#    'jp_sales': nan,
#    'pal_sales': nan,
#    'other_sales': nan,
#    'release_date': '2020-12-26',
#    'last_update': '2018-02-13'}},
#  {'Windows PC': {'critic_score': nan,
#    'total_sales': nan,
#    'na_sales': nan,
#    'jp_sales': nan,
#    'pal_sales': nan,
#    'other_sales': nan,
#    'release_date': '2014-06-05',
#    'last_update': nan}},
#  {'PlayStation 4': {'critic_score': nan,
#    'total_sales': 0.18,
#    'na_sales': 0.1,
#    'jp_sales': nan,
#    'pal_sales': 0.05,
#    'other_sales': 0.03,
#    'release_date': '2015-10-13',
#    'last_update': '2018-04-23'},
#   'PlayStation 3': {'critic_score': nan,
#    'total_sales': 0.09,
#    'na_sales': 0.07,
#    'jp_sales': nan,
#    'pal_sales': 0.01,
#    'other_sales': 0.01,
#    'release_date': '2011-10-25',
#    'last_update': '2018-04-23'},
#   'Wii': {'critic_score': 7.0,
#    'total_sales': 0.05,
#    'na_sales': 0.05,
#    'jp_sales': nan,
#    'pal_sales': 0.0,
#    'other_sales': 0.0,
#    'release_date': '2011-10-25',
#    'last_update': '2018-04-23'},
#   'Xbox 360': {'critic_score': nan,
#    'total_sales': 0.02,
#    'na_sales': 0.02,
#    'jp_sales': nan,
#    'pal_sales': 0.0,
#    'other_sales': 0.0,
#    'release_date': '2015-10-13',
#    'last_update': '2018-04-23'},
#   'Xbox One': {'critic_score': nan,
#    'total_sales': 0.02,
#    'na_sales': nan,
#    'jp_sales': nan,
#    'pal_sales': 0.02,
#    'other_sales': 0.0,
#    'release_date': '2015-10-13',
#    'last_update': '2018-04-23'},
#   'Windows PC': {'critic_score': 8.1,
#    'total_sales': 0.0,
#    'na_sales': nan,
#    'jp_sales': nan,
#    'pal_sales': 0.0,
#    'other_sales': 0.0,
#    'release_date': '2010-12-23',
#    'last_update': '2018-04-23'},
#   'PlayStation Network': {'critic_score': nan,
#    'total_sales': nan,
#    'na_sales': nan,
#    'jp_sales': nan,
#    'pal_sales': nan,
#    'other_sales': nan,
#    'release_date': '2011-02-15',
#    'last_update': '2018-04-23'}},
#  {'PlayStation 4': {'critic_score': nan,
#    'total_sales': 0.04,
#    'na_sales': 0.03,
#    'jp_sales': nan,
#    'pal_sales': nan,
#    'other_sales': 0.01,
#    'release_date': '2018-10-09',
#    'last_update': nan},
#   'PlayStation Vita': {'critic_score': nan,
#    'total_sales': nan,
#    'na_sales': nan,
#    'jp_sales': nan,
#    'pal_sales': nan,
#    'other_sales': nan,
#    'release_date': '2016-01-01',
#    'last_update': nan}},
#  nan,
#  {'Windows PC': {'critic_score': nan,
#    'total_sales': nan,
#    'na_sales': nan,
#    'jp_sales': nan,
#    'pal_sales': nan,
#    'other_sales': nan,
#    'release_date': '2020-09-17',
#    'last_update': '2020-09-04'},
#   'Xbox One': {'critic_score': nan,
#    'total_sales': nan,
#    'na_sales': nan,
#    'jp_sales': nan,
#    'pal_sales': nan,
#    'other_sales': nan,
#    'release_date': '2020-09-17',
#    'last_update': '2020-09-04'}},
#  {'Xbox Live': {'critic_score': 7.1,
#    'total_sales': nan,
#    'na_sales': nan,
#    'jp_sales': nan,
#    'pal_sales': nan,
#    'other_sales': nan,
#    'release_date': '2010-08-25',
#    'last_update': nan},
#   'Windows PC': {'critic_score': 6.7,
#    'total_sales': nan,
#    'na_sales': nan,
#    'jp_sales': nan,
#    'pal_sales': nan,
#    'other_sales': nan,
#    'release_date': '2010-10-26',
#    'last_update': nan},
#   'PlayStation Network': {'critic_score': 6.9,
#    'total_sales': nan,
#    'na_sales': nan,
# ...
#    'na_sales': nan,
#    'jp_sales': nan,
#    'pal_sales': nan,
#    'other_sales': nan,
#    'release_date': '2018-12-13',
#    'last_update': '2021-02-12'},
#   'Nintendo Switch': {'critic_score': nan,
#    'total_sales': nan,
#    'na_sales': nan,
#    'jp_sales': nan,
#    'pal_sales': nan,
#    'other_sales': nan,
#    'release_date': '2018-12-13',
#    'last_update': '2018-11-10'},
#   'iOS': {'critic_score': nan,
#    'total_sales': nan,
#    'na_sales': nan,
#    'jp_sales': nan,
#    'pal_sales': nan,
#    'other_sales': nan,
#    'release_date': '2019-08-21',
#    'last_update': '2019-11-27'},
#   'Windows PC': {'critic_score': nan,
#    'total_sales': nan,
#    'na_sales': nan,
#    'jp_sales': nan,
#    'pal_sales': nan,
#    'other_sales': nan,
#    'release_date': '2018-12-13',
#    'last_update': '2019-11-27'},
#   'PlayStation 4': {'critic_score': nan,
#    'total_sales': nan,
#    'na_sales': nan,
#    'jp_sales': nan,
#    'pal_sales': nan,
#    'other_sales': nan,
#    'release_date': '2019-11-26',
#    'last_update': '2019-11-27'}},
#  {'Nintendo Switch': {'critic_score': 7.0,
#    'total_sales': 0.02,
#    'na_sales': 0.01,
#    'jp_sales': nan,
#    'pal_sales': nan,
#    'other_sales': 0.0,
#    'release_date': '2018-05-29',
#    'last_update': '2018-04-24'}},
#  nan,
#  {'All': {'critic_score': nan,
#    'total_sales': nan,
#    'na_sales': nan,
#    'jp_sales': nan,
#    'pal_sales': nan,
#    'other_sales': nan,
#    'release_date': '2021-06-11',
#    'last_update': '2021-06-15'},
#   'PlayStation 4': {'critic_score': nan,
#    'total_sales': nan,
#    'na_sales': nan,
#    'jp_sales': nan,
#    'pal_sales': nan,
#    'other_sales': nan,
#    'release_date': '2020-12-31',
#    'last_update': '2019-11-24'},
#   'Windows PC': {'critic_score': nan,
#    'total_sales': nan,
#    'na_sales': nan,
#    'jp_sales': nan,
#    'pal_sales': nan,
#    'other_sales': nan,
#    'release_date': nan,
#    'last_update': '2021-03-04'},
#   'PlayStation 5': {'critic_score': nan,
#    'total_sales': nan,
#    'na_sales': nan,
#    'jp_sales': nan,
#    'pal_sales': nan,
#    'other_sales': nan,
#    'release_date': nan,
#    'last_update': '2021-03-04'}},
#  {'Nintendo Switch': {'critic_score': nan,
#    'total_sales': nan,
#    'na_sales': nan,
#    'jp_sales': nan,
#    'pal_sales': nan,
#    'other_sales': nan,
#    'release_date': '2018-09-04',
#    'last_update': '2019-04-20'},
#   'PlayStation 4': {'critic_score': nan,
#    'total_sales': nan,
#    'na_sales': nan,
#    'jp_sales': nan,
#    'pal_sales': nan,
#    'other_sales': nan,
#    'release_date': '2018-09-04',
#    'last_update': '2019-04-20'},
#   'Xbox One': {'critic_score': nan,
#    'total_sales': nan,
#    'na_sales': nan,
#    'jp_sales': nan,
#    'pal_sales': nan,
#    'other_sales': nan,
#    'release_date': '2018-09-04',
#    'last_update': '2019-04-20'},
#   'Windows PC': {'critic_score': nan,
#    'total_sales': nan,
#    'na_sales': nan,
#    'jp_sales': nan,
#    'pal_sales': nan,
#    'other_sales': nan,
#    'release_date': '2018-09-04',
#    'last_update': '2019-04-20'}},
#  nan,
#  {'Windows PC': {'critic_score': nan,
#    'total_sales': nan,
#    'na_sales': nan,
#    'jp_sales': nan,
#    'pal_sales': nan,
#    'other_sales': nan,
#    'release_date': '2014-07-31',
#    'last_update': '2018-08-08'},
#   'Linux': {'critic_score': nan,
#    'total_sales': nan,
#    'na_sales': nan,
#    'jp_sales': nan,
#    'pal_sales': nan,
#    'other_sales': nan,
#    'release_date': '2014-07-31',
#    'last_update': '2018-08-08'},
#   'Mac': {'critic_score': nan,
#    'total_sales': nan,
#    'na_sales': nan,
#    'jp_sales': nan,
#    'pal_sales': nan,
#    'other_sales': nan,
#    'release_date': '2014-07-31',
#    'last_update': '2018-08-08'},
#   'PlayStation 4': {'critic_score': nan,
#    'total_sales': nan,
#    'na_sales': nan,
#    'jp_sales': nan,
#    'pal_sales': nan,
#    'other_sales': nan,
#    'release_date': '2016-04-05',
#    'last_update': '2018-08-08'},
#   'Wii U': {'critic_score': nan,
#    'total_sales': nan,
#    'na_sales': nan,
#    'jp_sales': nan,
#    'pal_sales': nan,
#    'other_sales': nan,
#    'release_date': '2016-04-05',
#    'last_update': '2018-08-08'},
#   'Xbox One': {'critic_score': nan,
#    'total_sales': nan,
#    'na_sales': nan,
#    'jp_sales': nan,
#    'pal_sales': nan,
#    'other_sales': nan,
#    'release_date': '2016-01-08',
#    'last_update': '2018-08-08'}},
#  nan,
#  {'PlayStation 4': {'critic_score': 8.0,
#    'total_sales': 0.75,
#    'na_sales': 0.17,
#    'jp_sales': 0.01,
#    'pal_sales': 0.46,
#    'other_sales': 0.12,
#    'release_date': '2017-04-04',
#    'last_update': '2018-05-24'},
#   'Nintendo Switch': {'critic_score': 8.0,
#    'total_sales': 0.65,
#    'na_sales': 0.23,
#    'jp_sales': 0.03,
#    'pal_sales': 0.33,
#    'other_sales': 0.05,
#    'release_date': '2017-04-04',
#    'last_update': '2018-02-24'},
#   'Xbox One': {'critic_score': nan,
#    'total_sales': 0.3,
#    'na_sales': 0.15,
#    'jp_sales': nan,
#    'pal_sales': 0.12,
#    'other_sales': 0.03,
#    'release_date': '2017-04-04',
#    'last_update': '2018-05-24'},
#   'Wii U': {'critic_score': 7.5,
#    'total_sales': nan,
#    'na_sales': nan,
#    'jp_sales': nan,
#    'pal_sales': nan,
#    'other_sales': nan,
#    'release_date': '2013-03-18',
#    'last_update': '2018-03-20'}},
#  {'Nintendo Switch': {'critic_score': nan,
#    'total_sales': nan,
#    'na_sales': nan,
#    'jp_sales': nan,
#    'pal_sales': nan,
#    'other_sales': nan,
#    'release_date': '2020-10-13',
#    'last_update': '2020-09-25'},
#   'Windows PC': {'critic_score': nan,
#    'total_sales': nan,
#    'na_sales': nan,
#    'jp_sales': nan,
#    'pal_sales': nan,
#    'other_sales': nan,
#    'release_date': '2020-10-13',
#    'last_update': '2020-09-25'},
#   'PlayStation 4': {'critic_score': nan,
#    'total_sales': nan,
#    'na_sales': nan,
#    'jp_sales': nan,
#    'pal_sales': nan,
#    'other_sales': nan,
#    'release_date': '2020-10-13',
#    'last_update': '2020-09-25'},
#   'Xbox One': {'critic_score': nan,
#    'total_sales': nan,
#    'na_sales': nan,
#    'jp_sales': nan,
#    'pal_sales': nan,
#    'other_sales': nan,
#    'release_date': '2020-10-13',
#    'last_update': '2020-09-25'}},
#  nan,
#  {'Nintendo Switch': {'critic_score': nan,
#    'total_sales': nan,
#    'na_sales': nan,
#    'jp_sales': nan,
#    'pal_sales': nan,
#    'other_sales': nan,
#    'release_date': '2017-11-21',
#    'last_update': '2018-03-11'}},
#  {'Xbox One': {'critic_score': nan,
#    'total_sales': nan,
#    'na_sales': nan,
#    'jp_sales': nan,
#    'pal_sales': nan,
#    'other_sales': nan,
#    'release_date': '2019-02-26',
#    'last_update': '2019-01-25'},
#   'Windows PC': {'critic_score': nan,
#    'total_sales': nan,
#    'na_sales': nan,
#    'jp_sales': nan,
#    'pal_sales': nan,
#    'other_sales': nan,
#    'release_date': '2019-02-26',
#    'last_update': '2019-01-25'},
#   'Nintendo Switch': {'critic_score': nan,
#    'total_sales': nan,
#    'na_sales': nan,
#    'jp_sales': nan,
#    'pal_sales': nan,
#    'other_sales': nan,
#    'release_date': '2019-02-26',
#    'last_update': '2019-01-25'},
#   'PlayStation 4': {'critic_score': nan,
#    'total_sales': nan,
#    'na_sales': nan,
#    'jp_sales': nan,
#    'pal_sales': nan,
#    'other_sales': nan,
#    'release_date': '2019-02-26',
#    'last_update': '2019-01-25'}},
#  {'Windows PC': {'critic_score': nan,
#    'total_sales': nan,
#    'na_sales': nan,
#    'jp_sales': nan,
#    'pal_sales': nan,
#    'other_sales': nan,
#    'release_date': '2020-07-30',
#    'last_update': '2020-07-27'},
#   'Nintendo Switch': {'critic_score': nan,
#    'total_sales': nan,
#    'na_sales': nan,
#    'jp_sales': nan,
#    'pal_sales': nan,
#    'other_sales': nan,
#    'release_date': '2020-09-15',
#    'last_update': '2020-07-27'}},
#  {'PlayStation': {'critic_score': nan,
#    'total_sales': 0.02,
#    'na_sales': 0.01,
#    'jp_sales': nan,
#    'pal_sales': 0.01,
#    'other_sales': 0.0,
#    'release_date': '2000-08-05',
#    'last_update': nan},
#   'Windows PC': {'critic_score': nan,
#    'total_sales': 0.0,
#    'na_sales': nan,
#    'jp_sales': nan,
#    'pal_sales': 0.0,
#    'other_sales': 0.0,
#    'release_date': '2000-10-03',
#    'last_update': nan},
#   'PlayStation 3': {'critic_score': nan,
#    'total_sales': nan,
#    'na_sales': nan,
#    'jp_sales': nan,
#    'pal_sales': nan,
#    'other_sales': nan,
#    'release_date': '2013-03-19',
#    'last_update': nan},
#   'PlayStation Portable': {'critic_score': nan,
#    'total_sales': nan,
#    'na_sales': nan,
#    'jp_sales': nan,
#    'pal_sales': nan,
#    'other_sales': nan,
#    'release_date': '2013-03-19',
#    'last_update': nan}},
#  {'PlayStation 5': {'critic_score': nan,
#    'total_sales': nan,
#    'na_sales': nan,
#    'jp_sales': nan,
#    'pal_sales': nan,
#    'other_sales': nan,
#    'release_date': '2021-12-01',
#    'last_update': '2020-06-12'},
#   'Windows PC': {'critic_score': nan,
#    'total_sales': nan,
#    'na_sales': nan,
#    'jp_sales': nan,
#    'pal_sales': nan,
#    'other_sales': nan,
#    'release_date': '2021-12-01',
#    'last_update': '2019-06-09'}},
#  nan,
#  {'Windows PC': {'critic_score': nan,
#    'total_sales': nan,
#    'na_sales': nan,
#    'jp_sales': nan,
#    'pal_sales': nan,
#    'other_sales': nan,
#    'release_date': '2013-10-28',
#    'last_update': nan}},
#  {'PlayStation Network': {'critic_score': 8.5,
#    'total_sales': nan,
#    'na_sales': nan,
#    'jp_sales': nan,
#    'pal_sales': nan,
#    'other_sales': nan,
#    'release_date': '2009-12-10',
#    'last_update': nan},
#   'Windows PC': {'critic_score': nan,
#    'total_sales': nan,
#    'na_sales': nan,
#    'jp_sales': nan,
#    'pal_sales': nan,
#    'other_sales': nan,
#    'release_date': nan,
#    'last_update': '2019-03-29'}},
#  nan,
#  {'PlayStation Vita': {'critic_score': nan,
#    'total_sales': 0.13,
#    'na_sales': 0.04,
#    'jp_sales': 0.07,
#    'pal_sales': 0.01,
#    'other_sales': 0.02,
#    'release_date': '2016-03-29',
#    'last_update': '2018-11-12'}},
#  nan,
#  nan,
#  nan,
#  nan,
#  {'Xbox': {'critic_score': nan,
#    'total_sales': 0.02,
#    'na_sales': 0.02,
#    'jp_sales': nan,
#    'pal_sales': 0.01,
#    'other_sales': 0.0,
#    'release_date': '2005-09-27',
#    'last_update': nan},
#   'Windows PC': {'critic_score': nan,
#    'total_sales': nan,
#    'na_sales': nan,
#    'jp_sales': nan,
#    'pal_sales': nan,
#    'other_sales': nan,
#    'release_date': '2005-09-27',
#    'last_update': nan}},
#  {'PlayStation 4': {'critic_score': 9.0,
#    'total_sales': 1.36,
#    'na_sales': 0.55,
#    'jp_sales': 0.01,
#    'pal_sales': 0.58,
#    'other_sales': 0.22,
#    'release_date': '2017-10-27',
#    'last_update': '2018-05-10'},
#   'Xbox One': {'critic_score': nan,
#    'total_sales': 0.7,
#    'na_sales': 0.45,
#    'jp_sales': nan,
#    'pal_sales': 0.19,
#    'other_sales': 0.07,
#    'release_date': '2017-10-27',
#    'last_update': nan},
#   'Nintendo Switch': {'critic_score': 8.3,
#    'total_sales': 0.11,
#    'na_sales': 0.05,
#    'jp_sales': nan,
#    'pal_sales': 0.05,
#    'other_sales': 0.01,
#    'release_date': '2018-06-29',
#    'last_update': '2018-07-28'},
#   'Windows PC': {'critic_score': nan,
#    'total_sales': nan,
#    'na_sales': nan,
#    'jp_sales': nan,
#    'pal_sales': nan,
#    'other_sales': nan,
#    'release_date': '2017-10-27',
#    'last_update': nan}},
#  {'PlayStation Portable': {'critic_score': 6.5,
#    'total_sales': 0.1,
#    'na_sales': 0.08,
#    'jp_sales': nan,
#    'pal_sales': 0.0,
#    'other_sales': 0.02,
#    'release_date': '2010-02-02',
#    'last_update': nan},
#   'Nintendo DS': {'critic_score': nan,
#    'total_sales': 0.02,
#    'na_sales': 0.02,
#    'jp_sales': nan,
#    'pal_sales': 0.0,
#    'other_sales': 0.0,
#    'release_date': '2010-02-02',
#    'last_update': nan},
#   'Windows PC': {'critic_score': nan,
#    'total_sales': nan,
#    'na_sales': nan,
#    'jp_sales': nan,
#    'pal_sales': nan,
#    'other_sales': nan,
#    'release_date': '2010-04-22',
#    'last_update': nan},
#   'Xbox Live': {'critic_score': nan,
#    'total_sales': nan,
#    'na_sales': nan,
#    'jp_sales': nan,
#    'pal_sales': nan,
#    'other_sales': nan,
#    'release_date': '2010-04-21',
#    'last_update': nan},
#   'Nintendo DSi': {'critic_score': nan,
#    'total_sales': nan,
#    'na_sales': nan,
#    'jp_sales': nan,
#    'pal_sales': nan,
#    'other_sales': nan,
#    'release_date': '2010-02-02',
#    'last_update': nan},
#   'PlayStation Network': {'critic_score': nan,
#    'total_sales': nan,
#    'na_sales': nan,
#    'jp_sales': nan,
#    'pal_sales': nan,
#    'other_sales': nan,
#    'release_date': '2010-04-22',
#    'last_update': nan}},
#  {'PlayStation 4': {'critic_score': nan,
#    'total_sales': nan,
#    'na_sales': nan,
#    'jp_sales': nan,
#    'pal_sales': nan,
#    'other_sales': nan,
#    'release_date': nan,
#    'last_update': '2020-03-23'},
#   'Windows PC': {'critic_score': nan,
#    'total_sales': nan,
#    'na_sales': nan,
#    'jp_sales': nan,
#    'pal_sales': nan,
#    'other_sales': nan,
#    'release_date': nan,
#    'last_update': '2020-03-23'}},
#  {'Nintendo Switch': {'critic_score': 8.0,
#    'total_sales': 0.36,
#    'na_sales': 0.29,
#    'jp_sales': 0.03,
#    'pal_sales': nan,
#    'other_sales': 0.03,
#    'release_date': '2018-10-02',
#    'last_update': '2018-09-12'},
#   'PlayStation 4': {'critic_score': nan,
#    'total_sales': 0.17,
#    'na_sales': 0.09,
#    'jp_sales': 0.03,
#    'pal_sales': 0.03,
#    'other_sales': 0.03,
#    'release_date': '2018-10-02',
#    'last_update': '2018-06-04'},
#   'Xbox One': {'critic_score': nan,
#    'total_sales': 0.06,
#    'na_sales': 0.06,
#    'jp_sales': nan,
#    'pal_sales': nan,
#    'other_sales': 0.01,
#    'release_date': '2018-10-02',
#    'last_update': '2018-06-04'},
#   'All': {'critic_score': nan,
#    'total_sales': nan,
#    'na_sales': nan,
#    'jp_sales': nan,
#    'pal_sales': nan,
#    'other_sales': nan,
#    'release_date': '2018-10-02',
#    'last_update': '2020-10-12'}},
#  {'Xbox One': {'critic_score': nan,
#    'total_sales': 0.3,
#    'na_sales': 0.26,
#    'jp_sales': nan,
#    'pal_sales': 0.01,
#    'other_sales': 0.03,
#    'release_date': '2018-10-19',
#    'last_update': '2018-11-07'},
#   'All': {'critic_score': nan,
#    'total_sales': nan,
#    'na_sales': nan,
#    'jp_sales': nan,
#    'pal_sales': nan,
#    'other_sales': nan,
#    'release_date': '2018-10-19',
#    'last_update': '2021-07-21'},
#   'PlayStation 4': {'critic_score': nan,
#    'total_sales': nan,
#    'na_sales': nan,
#    'jp_sales': nan,
#    'pal_sales': nan,
#    'other_sales': nan,
#    'release_date': '2018-10-19',
#    'last_update': '2018-11-07'},
#   'Windows PC': {'critic_score': nan,
#    'total_sales': nan,
#    'na_sales': nan,
#    'jp_sales': nan,
#    'pal_sales': nan,
#    'other_sales': nan,
#    'release_date': '2018-10-19',
#    'last_update': '2018-11-07'}},
#  {'PlayStation': {'critic_score': 6.7,
#    'total_sales': 0.66,
#    'na_sales': 0.37,
#    'jp_sales': nan,
#    'pal_sales': 0.25,
#    'other_sales': 0.04,
#    'release_date': '2001-01-28',
#    'last_update': nan},
#   'Windows PC': {'critic_score': 7.5,
#    'total_sales': 0.0,
#    'na_sales': nan,
#    'jp_sales': nan,
#    'pal_sales': 0.0,
#    'other_sales': nan,
#    'release_date': '1999-07-13',
#    'last_update': nan},
#   'Android': {'critic_score': nan,
#    'total_sales': nan,
#    'na_sales': nan,
#    'jp_sales': nan,
#    'pal_sales': nan,
#    'other_sales': nan,
#    'release_date': '2014-03-20',
#    'last_update': nan}},
#  nan,
#  nan,
#  {'Nintendo Switch': {'critic_score': nan,
#    'total_sales': nan,
#    'na_sales': nan,
#    'jp_sales': nan,
#    'pal_sales': nan,
#    'other_sales': nan,
#    'release_date': '2018-08-30',
#    'last_update': '2018-03-26'},
#   'Windows PC': {'critic_score': nan,
#    'total_sales': nan,
#    'na_sales': nan,
#    'jp_sales': nan,
#    'pal_sales': nan,
#    'other_sales': nan,
#    'release_date': '2018-08-30',
#    'last_update': '2022-05-24'},
#   'Xbox One': {'critic_score': nan,
#    'total_sales': nan,
#    'na_sales': nan,
#    'jp_sales': nan,
#    'pal_sales': nan,
#    'other_sales': nan,
#    'release_date': nan,
#    'last_update': '2022-05-24'},
#   'PlayStation 4': {'critic_score': nan,
#    'total_sales': nan,
#    'na_sales': nan,
#    'jp_sales': nan,
#    'pal_sales': nan,
#    'other_sales': nan,
#    'release_date': '2019-03-19',
#    'last_update': '2022-05-24'}},
#  nan,
#  nan,
#  {'Xbox Series': {'critic_score': nan,
#    'total_sales': nan,
#    'na_sales': nan,
#    'jp_sales': nan,
#    'pal_sales': nan,
#    'other_sales': nan,
#    'release_date': '2000-11-16',
#    'last_update': '2021-03-06'},
#   'Windows PC': {'critic_score': 8.7,
#    'total_sales': nan,
#    'na_sales': nan,
#    'jp_sales': nan,
#    'pal_sales': nan,
#    'other_sales': nan,
#    'release_date': '2000-11-16',
#    'last_update': nan}},
#  nan,
#  nan,
#  ...]

# %%
count = 0
for elem in new_infos_per_platform_list:
    if isinstance(elem, dict):
        for console in list(elem.keys()):
            if console in ['Sega 32X', 'TurboGrafx-16', 'NEC PC-FX']:
                count += 1
print(count)
# Out:
# 3

# %%
for elem in new_infos_per_platform_list:
    if isinstance(elem, dict):
        for console in list(elem.keys()):
            if console in ['Sega 32X', 'TurboGrafx-16', 'NEC PC-FX']:
                del elem[console]

# %%
count = 0
for elem in new_infos_per_platform_list:
    if isinstance(elem, dict):
        for console in list(elem.keys()):
            if console in ['Sega 32X', 'TurboGrafx-16', 'NEC PC-FX']:
                count += 1
print(count)
# Out:
# 0

# %%
df['infos_per_platform'] = new_infos_per_platform_list

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5061 entries, 0 to 5060
# Data columns (total 51 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   appid                     5061 non-null   int64
#  1   normalized_name           5061 non-null   object
#  2   name                      5061 non-null   object
#  3   release_date              5061 non-null   datetime64[ns]
#  4   peak_ccu                  5061 non-null   float64
#  5   required_age              5061 non-null   int64
#  6   dlc_count                 5061 non-null   int64
#  7   about_the_game            5045 non-null   object
#  8   summary                   3021 non-null   object
#  9   supported_languages       5061 non-null   object
#  10  full_audio_languages      5061 non-null   object
#  11  some_reviews              2248 non-null   object
#  12  reviews_total             5061 non-null   float64
#  13  reviews_score_fancy       5061 non-null   object
#  14  header_image              5061 non-null   object
#  15  windows                   5061 non-null   bool
#  16  mac                       5061 non-null   bool
#  17  linux                     5061 non-null   bool
#  18  metacritic_url            5061 non-null   object
#  19  achievements              5061 non-null   int64
#  20  recommendations           5061 non-null   int64
#  21  notes                     591 non-null    object
#  22  developers                5061 non-null   object
#  23  publishers                5037 non-null   object
#  24  categories                5059 non-null   object
#  25  genres                    5057 non-null   object
#  26  tags                      5031 non-null   object
#  27  screenshots               5061 non-null   object
#  28  movies                    4500 non-null   object
#  29  steam_page                5061 non-null   object
#  30  platforms                 4088 non-null   object
#  31  infos_per_platform        3384 non-null   object
#  32  revenue_estimated         4583 non-null   object
#  33  meta_critic_score         5061 non-null   float64
#  34  new_positive              5061 non-null   float64
#  35  new_negative              5061 non-null   float64
#  36  new_min_estimated_owners  5061 non-null   float64
#  37  new_max_estimated_owners  5061 non-null   float64
#  38  new_average_forever       5061 non-null   float64
#  39  new_median_forever        5061 non-null   float64
#  40  new_price                 4936 non-null   float64
#  41  new_initialprice          4583 non-null   float64
#  42  new_discount              4583 non-null   float64
#  43  metacritic_user_score     4743 non-null   float64
#  44  plays_backloggd           5058 non-null   float64
#  45  playing_backloggd         5058 non-null   float64
#  46  backlogs_backloggd        5058 non-null   float64
#  47  wishlist_backloggd        5058 non-null   float64
#  48  lists_backloggd           5058 non-null   float64
#  49  reviews_backloggd         5058 non-null   float64
#  50  likes_backloggd           4525 non-null   float64
# dtypes: bool(3), datetime64[ns](1), float64(20), int64(5), object(22)
# memory usage: 1.9+ MB

# %%
df['revenue_estimated']
# Out:
# 0           $11 203,33
# 1            $3 076,92
# 2           $23 548,22
# 3        $7 708 595,02
# 4       $10 485 712,09
#              ...
# 5056               NaN
# 5057               NaN
# 5058               NaN
# 5059               NaN
# 5060               NaN
# Name: revenue_estimated, Length: 5061, dtype: object

# %%
df['revenue_estimated'] = df['revenue_estimated'].str.replace('\xa0', '', regex=True).str.replace('$' , '').str.replace(',' , '.').values.astype(float)

# %%
df['revenue_estimated']
# Out:
# 0          11203.33
# 1           3076.92
# 2          23548.22
# 3        7708595.02
# 4       10485712.09
#            ...
# 5056            NaN
# 5057            NaN
# 5058            NaN
# 5059            NaN
# 5060            NaN
# Name: revenue_estimated, Length: 5061, dtype: float64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5061 entries, 0 to 5060
# Data columns (total 51 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   appid                     5061 non-null   int64
#  1   normalized_name           5061 non-null   object
#  2   name                      5061 non-null   object
#  3   release_date              5061 non-null   datetime64[ns]
#  4   peak_ccu                  5061 non-null   float64
#  5   required_age              5061 non-null   int64
#  6   dlc_count                 5061 non-null   int64
#  7   about_the_game            5045 non-null   object
#  8   summary                   3021 non-null   object
#  9   supported_languages       5061 non-null   object
#  10  full_audio_languages      5061 non-null   object
#  11  some_reviews              2248 non-null   object
#  12  reviews_total             5061 non-null   float64
#  13  reviews_score_fancy       5061 non-null   object
#  14  header_image              5061 non-null   object
#  15  windows                   5061 non-null   bool
#  16  mac                       5061 non-null   bool
#  17  linux                     5061 non-null   bool
#  18  metacritic_url            5061 non-null   object
#  19  achievements              5061 non-null   int64
#  20  recommendations           5061 non-null   int64
#  21  notes                     591 non-null    object
#  22  developers                5061 non-null   object
#  23  publishers                5037 non-null   object
#  24  categories                5059 non-null   object
#  25  genres                    5057 non-null   object
#  26  tags                      5031 non-null   object
#  27  screenshots               5061 non-null   object
#  28  movies                    4500 non-null   object
#  29  steam_page                5061 non-null   object
#  30  platforms                 4088 non-null   object
#  31  infos_per_platform        3384 non-null   object
#  32  revenue_estimated         4583 non-null   float64
#  33  meta_critic_score         5061 non-null   float64
#  34  new_positive              5061 non-null   float64
#  35  new_negative              5061 non-null   float64
#  36  new_min_estimated_owners  5061 non-null   float64
#  37  new_max_estimated_owners  5061 non-null   float64
#  38  new_average_forever       5061 non-null   float64
#  39  new_median_forever        5061 non-null   float64
#  40  new_price                 4936 non-null   float64
#  41  new_initialprice          4583 non-null   float64
#  42  new_discount              4583 non-null   float64
#  43  metacritic_user_score     4743 non-null   float64
#  44  plays_backloggd           5058 non-null   float64
#  45  playing_backloggd         5058 non-null   float64
#  46  backlogs_backloggd        5058 non-null   float64
#  47  wishlist_backloggd        5058 non-null   float64
#  48  lists_backloggd           5058 non-null   float64
#  49  reviews_backloggd         5058 non-null   float64
#  50  likes_backloggd           4525 non-null   float64
# dtypes: bool(3), datetime64[ns](1), float64(21), int64(5), object(21)
# memory usage: 1.9+ MB

# %%
df[['name', 'new_initialprice', 'new_discount','new_price']]
# Out:
#                              name  new_initialprice  new_discount  new_price
# 0                          WARSAW             23.99           0.0       0.00
# 1          Alien Breed 3: Descent              9.99           0.0       9.99
# 2             Deadfall Adventures             19.99           0.0      19.99
# 3                      Far Cry® 5             59.99           0.0      59.99
# 4                 Forza Horizon 4             59.99           0.0       0.00
# ...                           ...               ...           ...        ...
# 5056                   Deathbound               NaN           NaN      26.99
# 5057             F1® Manager 2024               NaN           NaN      34.99
# 5058          SteamWorld Heist II               NaN           NaN      29.99
# 5059                Cat Quest III               NaN           NaN      19.99
# 5060  Thank Goodness You're Here!               NaN           NaN      19.99
#
# [5061 rows x 4 columns]

# %%
# Notation: 
# NaN = X, NotNull = V

# %%
((df['new_initialprice'].notna()) & (df['new_price'].notna()) & (df['new_discount'].notna())).value_counts()
# Out:
# True     4583
# False     478
# Name: count, dtype: int64

# %%
# Case 1: 
# new_initialprice = V | new_price = V | new_discount = V
count = 0
for i, row in df.iterrows():
    if pd.notna(row['new_initialprice']) and pd.notna(row['new_price']) and pd.notna(row['new_discount']):
        if abs(int(row['new_initialprice']*(1 - row['new_discount']/100)*100)/100 - row['new_price']) > 0.1:
            count += 1
            print(row['new_initialprice'], row['new_discount'], '------->', int(row['new_initialprice']*(1 - row['new_discount']/100)*100)/100, 'VS', row['new_price'])
print(count)
# Out:
# 23.99 0.0 -------> 23.99 VS 0.0
# 59.99 0.0 -------> 59.99 VS 0.0
# 19.99 0.0 -------> 19.98 VS 0.0
# 4.99 0.0 -------> 4.99 VS 0.0
# 9.99 0.0 -------> 9.99 VS 0.0
# 19.99 0.0 -------> 19.98 VS 0.0
# 39.99 0.0 -------> 39.99 VS 0.0
# 0.99 0.0 -------> 0.99 VS 0.0
# 19.99 0.0 -------> 19.98 VS 0.0
# 14.99 0.0 -------> 14.99 VS 0.0
# 19.99 0.0 -------> 19.98 VS 0.0
# 19.99 0.0 -------> 19.98 VS 0.0
# 0.99 0.0 -------> 0.99 VS 0.0
# 29.99 0.0 -------> 29.99 VS 0.0
# 29.99 0.0 -------> 29.99 VS 0.0
# 29.99 0.0 -------> 29.99 VS 0.0
# 19.99 0.0 -------> 19.98 VS 0.0
# 19.99 0.0 -------> 19.98 VS 0.0
# 3.99 0.0 -------> 3.99 VS 0.0
# 59.99 0.0 -------> 59.99 VS 0.0
# 34.99 0.0 -------> 34.99 VS 0.0
# 49.99 0.0 -------> 49.99 VS 0.0
# 39.99 0.0 -------> 39.99 VS 0.0
# 59.99 0.0 -------> 59.99 VS 0.0
# 59.99 0.0 -------> 59.99 VS 0.0
# 34.99 0.0 -------> 34.99 VS 0.0
# 19.99 0.0 -------> 19.98 VS 0.0
# 19.99 0.0 -------> 19.98 VS 0.0
# 59.99 0.0 -------> 59.99 VS 0.0
# 39.99 0.0 -------> 39.99 VS 0.0
# 17.99 0.0 -------> 17.98 VS 0.0
# 24.99 0.0 -------> 24.99 VS 0.0
# 14.99 0.0 -------> 14.99 VS 0.0
# 19.99 0.0 -------> 19.98 VS 0.0
# 19.99 0.0 -------> 19.98 VS 0.0
# 14.99 0.0 -------> 14.99 VS 0.0
# 14.99 0.0 -------> 14.99 VS 0.0
# 19.99 0.0 -------> 19.98 VS 0.0
# 19.99 0.0 -------> 19.98 VS 0.0
# 59.99 0.0 -------> 59.99 VS 0.0
# 19.99 0.0 -------> 19.98 VS 0.0
# 9.99 0.0 -------> 9.99 VS 0.0
# 0.99 0.0 -------> 0.99 VS 0.0
# 29.99 0.0 -------> 29.99 VS 0.0
# 24.99 0.0 -------> 24.99 VS 0.0
# 29.99 0.0 -------> 29.99 VS 0.0
# 49.99 0.0 -------> 49.99 VS 0.0
# 19.99 0.0 -------> 19.98 VS 0.0
# 29.99 0.0 -------> 29.99 VS 0.0
# 6.99 0.0 -------> 6.99 VS 0.0
# 19.99 0.0 -------> 19.98 VS 0.0
# 29.99 0.0 -------> 29.99 VS 0.0
# 14.99 0.0 -------> 14.99 VS 0.0
# 14.99 0.0 -------> 14.99 VS 0.0
# 12.99 0.0 -------> 12.99 VS 0.0
# 59.99 0.0 -------> 59.99 VS 0.0
# 59.99 0.0 -------> 59.99 VS 0.0
# 19.99 0.0 -------> 19.98 VS 0.0
# 14.99 0.0 -------> 14.99 VS 0.0
# 10.99 0.0 -------> 10.99 VS 0.0
# 29.99 0.0 -------> 29.99 VS 0.0
# 29.99 0.0 -------> 29.99 VS 0.0
# 14.99 0.0 -------> 14.99 VS 0.0
# 4.99 0.0 -------> 4.99 VS 0.0
# 19.99 0.0 -------> 19.98 VS 0.0
# 59.99 0.0 -------> 59.99 VS 0.0
# 59.99 0.0 -------> 59.99 VS 0.0
# 24.99 0.0 -------> 24.99 VS 0.0
# 49.99 0.0 -------> 49.99 VS 0.0
# 19.99 0.0 -------> 19.98 VS 0.0
# 39.99 0.0 -------> 39.99 VS 0.0
# 29.99 0.0 -------> 29.99 VS 0.0
# 39.99 0.0 -------> 39.99 VS 0.0
# 19.99 0.0 -------> 19.98 VS 0.0
# 14.99 0.0 -------> 14.99 VS 0.0
# 59.99 0.0 -------> 59.99 VS 0.0
# 19.99 0.0 -------> 19.98 VS 0.0
# 4.99 0.0 -------> 4.99 VS 0.0
# 9.99 0.0 -------> 9.99 VS 0.0
# 59.99 0.0 -------> 59.99 VS 0.0
# 59.99 0.0 -------> 59.99 VS 0.0
# 9.99 0.0 -------> 9.99 VS 0.0
# 14.99 0.0 -------> 14.99 VS 0.0
# 14.99 0.0 -------> 14.99 VS 0.0
# 14.99 0.0 -------> 14.99 VS 0.0
# 19.99 0.0 -------> 19.98 VS 0.0
# 29.99 0.0 -------> 29.99 VS 0.0
# 18.99 0.0 -------> 18.98 VS 0.0
# 12.99 0.0 -------> 12.99 VS 0.0
# 59.99 0.0 -------> 59.99 VS 0.0
# 14.99 0.0 -------> 14.99 VS 0.0
# 9.99 0.0 -------> 9.99 VS 0.0
# 19.99 0.0 -------> 19.98 VS 0.0
# 9.99 0.0 -------> 9.99 VS 0.0
# 29.99 0.0 -------> 29.99 VS 0.0
# 49.99 0.0 -------> 49.99 VS 0.0
# 29.99 0.0 -------> 29.99 VS 0.0
# 11.99 0.0 -------> 11.99 VS 0.0
# 49.99 0.0 -------> 49.99 VS 0.0
# 19.99 0.0 -------> 19.98 VS 0.0
# 19.99 0.0 -------> 19.98 VS 0.0
# 29.99 0.0 -------> 29.99 VS 0.0
# 49.99 0.0 -------> 49.99 VS 0.0
# 4.99 0.0 -------> 4.99 VS 0.0
# 29.99 0.0 -------> 29.99 VS 0.0
# 12.99 0.0 -------> 12.99 VS 0.0
# 9.99 0.0 -------> 9.99 VS 0.0
# 39.99 0.0 -------> 39.99 VS 0.0
# 19.99 0.0 -------> 19.98 VS 0.0
# 19.99 0.0 -------> 19.98 VS 0.0
# 29.99 0.0 -------> 29.99 VS 0.0
# 29.99 0.0 -------> 29.99 VS 0.0
# 0.99 0.0 -------> 0.99 VS 0.0
# 11.99 0.0 -------> 11.99 VS 0.0
# 39.99 0.0 -------> 39.99 VS 0.0
# 9.99 0.0 -------> 9.99 VS 0.0
# 14.99 0.0 -------> 14.99 VS 0.0
# 19.99 0.0 -------> 19.98 VS 0.0
# 59.99 0.0 -------> 59.99 VS 0.0
# 29.99 0.0 -------> 29.99 VS 0.0
# 19.99 0.0 -------> 19.98 VS 0.0
# 4.99 0.0 -------> 4.99 VS 0.0
# 19.99 0.0 -------> 19.98 VS 0.0
# 14.99 0.0 -------> 14.99 VS 0.0
# 14.99 0.0 -------> 14.99 VS 0.0
# 29.99 0.0 -------> 29.99 VS 0.0
# 29.99 0.0 -------> 29.99 VS 0.0
# 19.99 0.0 -------> 19.98 VS 0.0
# 12.99 0.0 -------> 12.99 VS 0.0
# 29.99 0.0 -------> 29.99 VS 0.0
# 59.99 0.0 -------> 59.99 VS 0.0
# 29.99 0.0 -------> 29.99 VS 0.0
# 49.99 0.0 -------> 49.99 VS 0.0
# 29.99 0.0 -------> 29.99 VS 0.0
# 59.99 0.0 -------> 59.99 VS 0.0
# 29.99 0.0 -------> 29.99 VS 0.0
# 54.99 0.0 -------> 54.99 VS 0.0
# 19.99 0.0 -------> 19.98 VS 0.0
# 34.99 0.0 -------> 34.99 VS 0.0
# 29.99 0.0 -------> 29.99 VS 0.0
# 19.99 0.0 -------> 19.98 VS 0.0
# 59.99 0.0 -------> 59.99 VS 0.0
# 39.99 0.0 -------> 39.99 VS 0.0
# 19.99 0.0 -------> 19.98 VS 0.0
# 19.99 0.0 -------> 19.98 VS 0.0
# 9.99 0.0 -------> 9.99 VS 0.0
# 49.99 0.0 -------> 49.99 VS 0.0
# 49.99 0.0 -------> 49.99 VS 0.0
# 4.99 0.0 -------> 4.99 VS 0.0
# 19.99 0.0 -------> 19.98 VS 0.0
# 14.99 0.0 -------> 14.99 VS 0.0
# 2.99 0.0 -------> 2.99 VS 0.0
# 29.99 0.0 -------> 29.99 VS 0.0
# 29.99 0.0 -------> 29.99 VS 0.0
# 29.99 0.0 -------> 29.99 VS 0.0
# 14.99 0.0 -------> 14.99 VS 0.0
# 29.99 0.0 -------> 29.99 VS 0.0
# 14.99 0.0 -------> 14.99 VS 0.0
# 19.99 0.0 -------> 19.98 VS 0.0
# 29.99 0.0 -------> 29.99 VS 0.0
# 9.99 0.0 -------> 9.99 VS 0.0
# 19.99 0.0 -------> 19.98 VS 0.0
# 59.99 0.0 -------> 59.99 VS 0.0
# 14.99 0.0 -------> 14.99 VS 0.0
# 19.99 0.0 -------> 19.98 VS 0.0
# 29.99 0.0 -------> 29.99 VS 0.0
# 19.99 0.0 -------> 19.98 VS 0.0
# 7.99 0.0 -------> 7.99 VS 0.0
# 59.99 0.0 -------> 59.99 VS 0.0
# 39.99 0.0 -------> 39.99 VS 0.0
# 59.99 0.0 -------> 59.99 VS 0.0
# 29.99 0.0 -------> 29.99 VS 0.0
# 54.99 0.0 -------> 54.99 VS 0.0
# 59.99 0.0 -------> 59.99 VS 0.0
# 59.99 0.0 -------> 59.99 VS 0.0
# 4.99 0.0 -------> 4.99 VS 0.0
# 99.99 0.0 -------> 99.99 VS 0.0
# 9.99 0.0 -------> 9.99 VS 0.0
# 4.99 0.0 -------> 4.99 VS 0.0
# 39.99 0.0 -------> 39.99 VS 0.0
# 69.99 0.0 -------> 69.98 VS 0.0
# 14.99 0.0 -------> 14.99 VS 0.0
# 9.99 0.0 -------> 9.99 VS 0.0
# 9.99 0.0 -------> 9.99 VS 0.0
# 59.99 0.0 -------> 59.99 VS 0.0
# 14.99 0.0 -------> 14.99 VS 0.0
# 9.99 0.0 -------> 9.99 VS 0.0
# 14.99 0.0 -------> 14.99 VS 0.0
# 9.99 0.0 -------> 9.99 VS 0.0
# 49.99 0.0 -------> 49.99 VS 0.0
# 19.99 0.0 -------> 19.98 VS 0.0
# 9.99 0.0 -------> 9.99 VS 0.0
# 49.99 0.0 -------> 49.99 VS 0.0
# 59.99 0.0 -------> 59.99 VS 0.0
# 4.99 0.0 -------> 4.99 VS 0.0
# 59.99 0.0 -------> 59.99 VS 0.0
# 49.99 0.0 -------> 49.99 VS 0.0
# 5.99 0.0 -------> 5.99 VS 0.0
# 39.99 0.0 -------> 39.99 VS 0.0
# 9.99 0.0 -------> 9.99 VS 0.0
# 59.99 0.0 -------> 59.99 VS 0.0
# 54.99 0.0 -------> 54.99 VS 0.0
# 14.99 0.0 -------> 14.99 VS 0.0
# 9.99 0.0 -------> 9.99 VS 0.0
# 19.99 0.0 -------> 19.98 VS 0.0
# 19.99 0.0 -------> 19.98 VS 0.0
# 44.99 0.0 -------> 44.99 VS 0.0
# 29.99 0.0 -------> 29.99 VS 0.0
# 14.99 0.0 -------> 14.99 VS 0.0
# 14.99 0.0 -------> 14.99 VS 0.0
# 49.99 0.0 -------> 49.99 VS 0.0
# 39.99 0.0 -------> 39.99 VS 0.0
# 9.99 0.0 -------> 9.99 VS 0.0
# 59.99 0.0 -------> 59.99 VS 0.0
# 29.99 0.0 -------> 29.99 VS 0.0
# 59.99 0.0 -------> 59.99 VS 0.0
# 19.99 0.0 -------> 19.98 VS 0.0
# 14.99 0.0 -------> 14.99 VS 0.0
# 19.99 0.0 -------> 19.98 VS 0.0
# 59.99 0.0 -------> 59.99 VS 0.0
# 29.99 0.0 -------> 29.99 VS 0.0
# 14.99 0.0 -------> 14.99 VS 0.0
# 9.99 0.0 -------> 9.99 VS 0.0
# 59.99 0.0 -------> 59.99 VS 0.0
# 4.99 0.0 -------> 4.99 VS 0.0
# 19.99 0.0 -------> 19.98 VS 0.0
# 19.99 0.0 -------> 19.98 VS 0.0
# 69.99 0.0 -------> 69.98 VS 0.0
# 19.99 0.0 -------> 19.98 VS 0.0
# 29.99 0.0 -------> 29.99 VS 0.0
# 9.99 0.0 -------> 9.99 VS 0.0
# 59.99 0.0 -------> 59.99 VS 0.0
# 59.99 0.0 -------> 59.99 VS 0.0
# 19.99 0.0 -------> 19.98 VS 0.0
# 4.99 0.0 -------> 4.99 VS 0.0
# 19.99 0.0 -------> 19.98 VS 0.0
# 19.99 0.0 -------> 19.98 VS 0.0
# 24.99 0.0 -------> 24.99 VS 0.0
# 19.99 0.0 -------> 19.98 VS 0.0
# 19.99 0.0 -------> 19.98 VS 0.0
# 240

# %%
((df['new_discount'] == 0) & (df['new_price'] == 0)).value_counts()
# Out:
# False    4821
# True      240
# Name: count, dtype: int64

# %%
df[((df['new_discount'] == 0) & (df['new_price'] == 0))]['name']
# Out:
# 0                            WARSAW
# 4                   Forza Horizon 4
# 50                   Lost Planet® 2
# 71                     Rocket Arena
# 77                         God Mode
#                    ...
# 4705    Stranger Things 3: The Game
# 4706                    Velocity 2X
# 4707           Frozen Synapse Prime
# 4708                    Titanfall­™
# 4709                Darkest of Days
# Name: name, Length: 240, dtype: object

# %% [markdown]
# The game that have both `discount` and `new_price` equal to $0$ have high chance to be not more available on Steam

# %%
((df['new_initialprice'] == 0) & (df['new_discount'] == 0) & (df['new_price'] == 0)).value_counts()
# Out:
# False    5061
# Name: count, dtype: int64

# %%
((df['new_initialprice'].isna()) & (df['new_price'].notna()) & (df['new_discount'].notna())).value_counts()
# Out:
# False    5061
# Name: count, dtype: int64

# %%
((df['new_initialprice'].notna()) & (df['new_price'].isna()) & (df['new_discount'].notna())).value_counts()
# Out:
# False    5061
# Name: count, dtype: int64

# %%
((df['new_initialprice'].notna()) & (df['new_price'].notna()) & (df['new_discount'].isna())).value_counts()
# Out:
# False    5061
# Name: count, dtype: int64

# %%
((df['new_initialprice'].isna()) & (df['new_price'].isna()) & (df['new_discount'].notna())).value_counts()
# Out:
# False    5061
# Name: count, dtype: int64

# %%
((df['new_initialprice'].isna()) & (df['new_price'].notna()) & (df['new_discount'].isna())).value_counts()
# Out:
# False    4708
# True      353
# Name: count, dtype: int64

# %%
((df['new_initialprice'].isna()) & (df['new_price'].notna())).value_counts()
# Out:
# False    4708
# True      353
# Name: count, dtype: int64

# %%
df[(df['new_initialprice'].isna()) & (df['new_price'].notna())]['name']
# Out:
# 45          Wasteland 2: Director's Cut
# 195                            One Shot
# 203     Tom Clancy's Rainbow Six® Siege
# 205                            F.E.A.R.
# 215            Call of Duty®: Black Ops
#                      ...
# 5056                         Deathbound
# 5057                   F1® Manager 2024
# 5058                SteamWorld Heist II
# 5059                      Cat Quest III
# 5060        Thank Goodness You're Here!
# Name: name, Length: 353, dtype: object

# %%
# Case 2:
# new_initialprice = X | new_price = V | new_discount = X

for i, row in df.iterrows():
    if pd.isna(row['new_initialprice']) and pd.notna(row['new_price']):
        df.at[i, 'new_initialprice'] = row['new_price']
        df.at[i, 'new_discount'] = float(0)

# %%
df[['new_initialprice', 'new_discount', 'new_price']]
# Out:
#       new_initialprice  new_discount  new_price
# 0                23.99           0.0       0.00
# 1                 9.99           0.0       9.99
# 2                19.99           0.0      19.99
# 3                59.99           0.0      59.99
# 4                59.99           0.0       0.00
# ...                ...           ...        ...
# 5056             26.99           0.0      26.99
# 5057             34.99           0.0      34.99
# 5058             29.99           0.0      29.99
# 5059             19.99           0.0      19.99
# 5060             19.99           0.0      19.99
#
# [5061 rows x 3 columns]

# %%
((df['new_initialprice'].notna()) & (df['new_price'].isna()) & (df['new_discount'].isna())).value_counts()
# Out:
# False    5061
# Name: count, dtype: int64

# %%
((df['new_initialprice'].isna()) & (df['new_price'].isna()) & (df['new_discount'].isna())).value_counts()
# Out:
# False    4936
# True      125
# Name: count, dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5061 entries, 0 to 5060
# Data columns (total 51 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   appid                     5061 non-null   int64
#  1   normalized_name           5061 non-null   object
#  2   name                      5061 non-null   object
#  3   release_date              5061 non-null   datetime64[ns]
#  4   peak_ccu                  5061 non-null   float64
#  5   required_age              5061 non-null   int64
#  6   dlc_count                 5061 non-null   int64
#  7   about_the_game            5045 non-null   object
#  8   summary                   3021 non-null   object
#  9   supported_languages       5061 non-null   object
#  10  full_audio_languages      5061 non-null   object
#  11  some_reviews              2248 non-null   object
#  12  reviews_total             5061 non-null   float64
#  13  reviews_score_fancy       5061 non-null   object
#  14  header_image              5061 non-null   object
#  15  windows                   5061 non-null   bool
#  16  mac                       5061 non-null   bool
#  17  linux                     5061 non-null   bool
#  18  metacritic_url            5061 non-null   object
#  19  achievements              5061 non-null   int64
#  20  recommendations           5061 non-null   int64
#  21  notes                     591 non-null    object
#  22  developers                5061 non-null   object
#  23  publishers                5037 non-null   object
#  24  categories                5059 non-null   object
#  25  genres                    5057 non-null   object
#  26  tags                      5031 non-null   object
#  27  screenshots               5061 non-null   object
#  28  movies                    4500 non-null   object
#  29  steam_page                5061 non-null   object
#  30  platforms                 4088 non-null   object
#  31  infos_per_platform        3384 non-null   object
#  32  revenue_estimated         4583 non-null   float64
#  33  meta_critic_score         5061 non-null   float64
#  34  new_positive              5061 non-null   float64
#  35  new_negative              5061 non-null   float64
#  36  new_min_estimated_owners  5061 non-null   float64
#  37  new_max_estimated_owners  5061 non-null   float64
#  38  new_average_forever       5061 non-null   float64
#  39  new_median_forever        5061 non-null   float64
#  40  new_price                 4936 non-null   float64
#  41  new_initialprice          4936 non-null   float64
#  42  new_discount              4936 non-null   float64
#  43  metacritic_user_score     4743 non-null   float64
#  44  plays_backloggd           5058 non-null   float64
#  45  playing_backloggd         5058 non-null   float64
#  46  backlogs_backloggd        5058 non-null   float64
#  47  wishlist_backloggd        5058 non-null   float64
#  48  lists_backloggd           5058 non-null   float64
#  49  reviews_backloggd         5058 non-null   float64
#  50  likes_backloggd           4525 non-null   float64
# dtypes: bool(3), datetime64[ns](1), float64(21), int64(5), object(21)
# memory usage: 1.9+ MB

# %%
df = df.rename(columns={'meta_critic_score': 'metacritic_score ', 'new_positive': 'positive', 'new_negative': 'negative', 'new_min_estimated_owners': 'min_estimated_owners', 
                        'new_max_estimated_owners': 'max_estimated_owners', 'new_average_forever': 'average_forever', 'new_median_forever': 'median_forever',
                        'new_price': 'current_price', 'new_initialprice': 'initial_price', 'new_discount': 'discount_percentage'})

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5061 entries, 0 to 5060
# Data columns (total 51 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   appid                  5061 non-null   int64
#  1   normalized_name        5061 non-null   object
#  2   name                   5061 non-null   object
#  3   release_date           5061 non-null   datetime64[ns]
#  4   peak_ccu               5061 non-null   float64
#  5   required_age           5061 non-null   int64
#  6   dlc_count              5061 non-null   int64
#  7   about_the_game         5045 non-null   object
#  8   summary                3021 non-null   object
#  9   supported_languages    5061 non-null   object
#  10  full_audio_languages   5061 non-null   object
#  11  some_reviews           2248 non-null   object
#  12  reviews_total          5061 non-null   float64
#  13  reviews_score_fancy    5061 non-null   object
#  14  header_image           5061 non-null   object
#  15  windows                5061 non-null   bool
#  16  mac                    5061 non-null   bool
#  17  linux                  5061 non-null   bool
#  18  metacritic_url         5061 non-null   object
#  19  achievements           5061 non-null   int64
#  20  recommendations        5061 non-null   int64
#  21  notes                  591 non-null    object
#  22  developers             5061 non-null   object
#  23  publishers             5037 non-null   object
#  24  categories             5059 non-null   object
#  25  genres                 5057 non-null   object
#  26  tags                   5031 non-null   object
#  27  screenshots            5061 non-null   object
#  28  movies                 4500 non-null   object
#  29  steam_page             5061 non-null   object
#  30  platforms              4088 non-null   object
#  31  infos_per_platform     3384 non-null   object
#  32  revenue_estimated      4583 non-null   float64
#  33  metacritic_score       5061 non-null   float64
#  34  positive               5061 non-null   float64
#  35  negative               5061 non-null   float64
#  36  min_estimated_owners   5061 non-null   float64
#  37  max_estimated_owners   5061 non-null   float64
#  38  average_forever        5061 non-null   float64
#  39  median_forever         5061 non-null   float64
#  40  current_price          4936 non-null   float64
#  41  initial_price          4936 non-null   float64
#  42  discount_percentage    4936 non-null   float64
#  43  metacritic_user_score  4743 non-null   float64
#  44  plays_backloggd        5058 non-null   float64
#  45  playing_backloggd      5058 non-null   float64
#  46  backlogs_backloggd     5058 non-null   float64
#  47  wishlist_backloggd     5058 non-null   float64
#  48  lists_backloggd        5058 non-null   float64
#  49  reviews_backloggd      5058 non-null   float64
#  50  likes_backloggd        4525 non-null   float64
# dtypes: bool(3), datetime64[ns](1), float64(21), int64(5), object(21)
# memory usage: 1.9+ MB

# %%
df.to_csv('steam_games.csv', index=False)

# %%
temp_df = df[['appid', 'infos_per_platform']].copy(deep=True)

# %%
records = []

for _, row in temp_df.iterrows():
    appid = row['appid']
    platform_data = row['infos_per_platform']

    if isinstance(platform_data, dict):
        for platform, info in platform_data.items():
            flat_row = {'appid': appid, 'platform': platform}
            flat_row.update(info)
            records.append(flat_row)
    else:
        records.append({'appid': appid, 'platform': None})

# Create the long-form DataFrame
long_temp_df = pd.DataFrame(records)

# %%
long_temp_df
# Out:
#          appid             platform  critic_score  total_sales  na_sales  \
# 0      1026420             Xbox One           NaN          NaN       NaN
# 1      1026420      Nintendo Switch           NaN          NaN       NaN
# 2      1026420           Windows PC           NaN          NaN       NaN
# 3      1026420        PlayStation 4           NaN          NaN       NaN
# 4        22670  PlayStation Network           6.5          NaN       NaN
# ...        ...                  ...           ...          ...       ...
# 12012  1277130                 None           NaN          NaN       NaN
# 12013  2591280                 None           NaN          NaN       NaN
# 12014  2396240                 None           NaN          NaN       NaN
# 12015  2305840                 None           NaN          NaN       NaN
# 12016  2366980                 None           NaN          NaN       NaN
#
#        jp_sales  pal_sales  other_sales release_date last_update
# 0           NaN        NaN          NaN   2020-10-02  2020-09-11
# 1           NaN        NaN          NaN   2020-10-01  2020-09-11
# 2           NaN        NaN          NaN   2019-10-02  2020-09-11
# 3           NaN        NaN          NaN   2020-09-29  2020-09-11
# 4           NaN        NaN          NaN   2011-02-22         NaN
# ...         ...        ...          ...          ...         ...
# 12012       NaN        NaN          NaN          NaN         NaN
# 12013       NaN        NaN          NaN          NaN         NaN
# 12014       NaN        NaN          NaN          NaN         NaN
# 12015       NaN        NaN          NaN          NaN         NaN
# 12016       NaN        NaN          NaN          NaN         NaN
#
# [12017 rows x 10 columns]

# %%
long_temp_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12017 entries, 0 to 12016
# Data columns (total 10 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   appid         12017 non-null  int64
#  1   platform      10340 non-null  object
#  2   critic_score  1265 non-null   float64
#  3   total_sales   2361 non-null   float64
#  4   na_sales      1817 non-null   float64
#  5   jp_sales      722 non-null    float64
#  6   pal_sales     1899 non-null   float64
#  7   other_sales   2229 non-null   float64
#  8   release_date  7725 non-null   object
#  9   last_update   7377 non-null   object
# dtypes: float64(6), int64(1), object(3)
# memory usage: 939.0+ KB

# %%
long_temp_df['release_date'] = pd.to_datetime(long_temp_df['release_date'])
long_temp_df['last_update'] = pd.to_datetime(long_temp_df['last_update'])

# %%
long_temp_df.columns
# Out:
# Index(['appid', 'platform', 'critic_score', 'total_sales', 'na_sales',
#        'jp_sales', 'pal_sales', 'other_sales', 'release_date', 'last_update'],
#       dtype='object')

# %%
long_temp_df = long_temp_df.rename(columns={'critic_score' : 'critic_score_pp', 'total_sales' : 'total_sales_pp', 'na_sales' : 'na_sales_pp',
       'jp_sales' : 'jp_sales_pp', 'pal_sales' : 'pal_sales_pp', 'other_sales' : 'other_sales_pp', 'release_date' : 'release_date_pp', 'last_update' : 'last_update_pp'})

# %%
long_temp_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12017 entries, 0 to 12016
# Data columns (total 10 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   appid            12017 non-null  int64
#  1   platform         10340 non-null  object
#  2   critic_score_pp  1265 non-null   float64
#  3   total_sales_pp   2361 non-null   float64
#  4   na_sales_pp      1817 non-null   float64
#  5   jp_sales_pp      722 non-null    float64
#  6   pal_sales_pp     1899 non-null   float64
#  7   other_sales_pp   2229 non-null   float64
#  8   release_date_pp  7725 non-null   datetime64[ns]
#  9   last_update_pp   7377 non-null   datetime64[ns]
# dtypes: datetime64[ns](2), float64(6), int64(1), object(1)
# memory usage: 939.0+ KB

# %%
long_df = df.merge(long_temp_df, left_on='appid', right_on='appid', how='right')

# %%
long_df.drop(columns='infos_per_platform', inplace=True)

# %%
long_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12017 entries, 0 to 12016
# Data columns (total 59 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   appid                  12017 non-null  int64
#  1   normalized_name        12017 non-null  object
#  2   name                   12017 non-null  object
#  3   release_date           12017 non-null  datetime64[ns]
#  4   peak_ccu               12017 non-null  float64
#  5   required_age           12017 non-null  int64
#  6   dlc_count              12017 non-null  int64
#  7   about_the_game         11978 non-null  object
#  8   summary                8400 non-null   object
#  9   supported_languages    12017 non-null  object
#  10  full_audio_languages   12017 non-null  object
#  11  some_reviews           4884 non-null   object
#  12  reviews_total          12017 non-null  float64
#  13  reviews_score_fancy    12017 non-null  object
#  14  header_image           12017 non-null  object
#  15  windows                12017 non-null  bool
#  16  mac                    12017 non-null  bool
#  17  linux                  12017 non-null  bool
#  18  metacritic_url         12017 non-null  object
#  19  achievements           12017 non-null  int64
#  20  recommendations        12017 non-null  int64
#  21  notes                  1329 non-null   object
#  22  developers             12017 non-null  object
#  23  publishers             11975 non-null  object
#  24  categories             12014 non-null  object
#  25  genres                 12002 non-null  object
#  26  tags                   11972 non-null  object
#  27  screenshots            12017 non-null  object
#  28  movies                 10496 non-null  object
#  29  steam_page             12017 non-null  object
#  30  platforms              11044 non-null  object
#  31  revenue_estimated      10989 non-null  float64
#  32  metacritic_score       12017 non-null  float64
#  33  positive               12017 non-null  float64
#  34  negative               12017 non-null  float64
#  35  min_estimated_owners   12017 non-null  float64
#  36  max_estimated_owners   12017 non-null  float64
#  37  average_forever        12017 non-null  float64
#  38  median_forever         12017 non-null  float64
#  39  current_price          11722 non-null  float64
#  40  initial_price          11722 non-null  float64
#  41  discount_percentage    11722 non-null  float64
#  42  metacritic_user_score  11543 non-null  float64
#  43  plays_backloggd        12011 non-null  float64
#  44  playing_backloggd      12011 non-null  float64
#  45  backlogs_backloggd     12011 non-null  float64
#  46  wishlist_backloggd     12011 non-null  float64
#  47  lists_backloggd        12011 non-null  float64
#  48  reviews_backloggd      12011 non-null  float64
#  49  likes_backloggd        11074 non-null  float64
#  50  platform               10340 non-null  object
#  51  critic_score_pp        1265 non-null   float64
#  52  total_sales_pp         2361 non-null   float64
#  53  na_sales_pp            1817 non-null   float64
#  54  jp_sales_pp            722 non-null    float64
#  55  pal_sales_pp           1899 non-null   float64
#  56  other_sales_pp         2229 non-null   float64
#  57  release_date_pp        7725 non-null   datetime64[ns]
#  58  last_update_pp         7377 non-null   datetime64[ns]
# dtypes: bool(3), datetime64[ns](3), float64(27), int64(5), object(21)
# memory usage: 5.2+ MB

# %%
long_df.head()
# Out:
#      appid     normalized_name                    name release_date  peak_ccu  \
# 0  1026420              warsaw                  WARSAW   2019-10-01       5.0
# 1  1026420              warsaw                  WARSAW   2019-10-01       5.0
# 2  1026420              warsaw                  WARSAW   2019-10-01       5.0
# 3  1026420              warsaw                  WARSAW   2019-10-01       5.0
# 4    22670  alienbreed3descent  Alien Breed 3: Descent   2010-11-01       3.0
#
#    required_age  dlc_count                                     about_the_game  \
# 0             0          0  Use everything at your disposal to help a team...
# 1             0          0  Use everything at your disposal to help a team...
# 2             0          0  Use everything at your disposal to help a team...
# 3             0          0  Use everything at your disposal to help a team...
# 4             0          0  Alien Breed™ 3: Descent is the final explosive...
#
#                                              summary  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4  Alien Breed 3: Descent is the final explosive ...
#
#                                  supported_languages  ... likes_backloggd  \
# 0         [English, French, German, Polish, Russian]  ...             0.0
# 1         [English, French, German, Polish, Russian]  ...             0.0
# 2         [English, French, German, Polish, Russian]  ...             0.0
# 3         [English, French, German, Polish, Russian]  ...             0.0
# 4  [English, French, German, Italian, Japanese, S...  ...             0.0
#
#               platform  critic_score_pp total_sales_pp na_sales_pp  \
# 0             Xbox One              NaN            NaN         NaN
# 1      Nintendo Switch              NaN            NaN         NaN
# 2           Windows PC              NaN            NaN         NaN
# 3        PlayStation 4              NaN            NaN         NaN
# 4  PlayStation Network              6.5            NaN         NaN
#
#    jp_sales_pp  pal_sales_pp  other_sales_pp release_date_pp  last_update_pp
# 0          NaN           NaN             NaN      2020-10-02      2020-09-11
# 1          NaN           NaN             NaN      2020-10-01      2020-09-11
# 2          NaN           NaN             NaN      2019-10-02      2020-09-11
# 3          NaN           NaN             NaN      2020-09-29      2020-09-11
# 4          NaN           NaN             NaN      2011-02-22             NaT
#
# [5 rows x 59 columns]

# %%
long_df.to_csv('steam_games_long.csv', index=False)

# %%
import pandas as pd
import numpy as np
from data_type_fix import data_type_fix

# %%
df = pd.read_csv('steam_games.csv')
df = data_type_fix(df)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5061 entries, 0 to 5060
# Data columns (total 51 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   appid                  5061 non-null   int64
#  1   normalized_name        5061 non-null   object
#  2   name                   5061 non-null   object
#  3   release_date           5061 non-null   datetime64[ns]
#  4   peak_ccu               5061 non-null   float64
#  5   required_age           5061 non-null   int64
#  6   dlc_count              5061 non-null   int64
#  7   about_the_game         5045 non-null   object
#  8   summary                3021 non-null   object
#  9   supported_languages    5061 non-null   object
#  10  full_audio_languages   5061 non-null   object
#  11  some_reviews           2248 non-null   object
#  12  reviews_total          5061 non-null   float64
#  13  reviews_score_fancy    5028 non-null   float64
#  14  header_image           5061 non-null   object
#  15  windows                5061 non-null   bool
#  16  mac                    5061 non-null   bool
#  17  linux                  5061 non-null   bool
#  18  metacritic_url         5061 non-null   object
#  19  achievements           5061 non-null   int64
#  20  recommendations        5061 non-null   int64
#  21  notes                  591 non-null    object
#  22  developers             5061 non-null   object
#  23  publishers             5037 non-null   object
#  24  categories             5059 non-null   object
#  25  genres                 5057 non-null   object
#  26  tags                   5031 non-null   object
#  27  screenshots            5061 non-null   object
#  28  movies                 4500 non-null   object
#  29  steam_page             5061 non-null   object
#  30  platforms              4088 non-null   object
#  31  infos_per_platform     3384 non-null   object
#  32  revenue_estimated      4583 non-null   float64
#  33  metacritic_score       5061 non-null   float64
#  34  positive               5061 non-null   float64
#  35  negative               5061 non-null   float64
#  36  min_estimated_owners   5061 non-null   float64
#  37  max_estimated_owners   5061 non-null   float64
#  38  average_forever        5061 non-null   float64
#  39  median_forever         5061 non-null   float64
#  40  current_price          4936 non-null   float64
#  41  initial_price          4936 non-null   float64
#  42  discount_percentage    4936 non-null   float64
#  43  metacritic_user_score  4743 non-null   float64
#  44  plays_backloggd        5058 non-null   float64
#  45  playing_backloggd      5058 non-null   float64
#  46  backlogs_backloggd     5058 non-null   float64
#  47  wishlist_backloggd     5058 non-null   float64
#  48  lists_backloggd        5058 non-null   float64
#  49  reviews_backloggd      5058 non-null   float64
#  50  likes_backloggd        4525 non-null   float64
# dtypes: bool(3), datetime64[ns](1), float64(22), int64(5), object(20)
# memory usage: 1.9+ MB

# %%
df[['appid', 'name', 'metacritic_url', 'steam_page', 'header_image']].to_csv('games_list.csv', index=False)

# %%
df1 = pd.read_csv('games_list.csv')
df1.head()
# Out:
#      appid                    name  \
# 0  1026420                  WARSAW
# 1    22670  Alien Breed 3: Descent
# 2   231330     Deadfall Adventures
# 3   552520              Far Cry® 5
# 4  1293830         Forza Horizon 4
#
#                                       metacritic_url  \
# 0  https://www.metacritic.com/game/pc/warsaw?ftag...
# 1  https://www.metacritic.com/game/pc/alien-breed...
# 2  https://www.metacritic.com/game/pc/deadfall-ad...
# 3  https://www.metacritic.com/game/pc/far-cry-5?f...
# 4  https://www.metacritic.com/game/pc/forza-horiz...
#
#                                    steam_page  \
# 0  https://store.steampowered.com/app/1026420
# 1    https://store.steampowered.com/app/22670
# 2   https://store.steampowered.com/app/231330
# 3   https://store.steampowered.com/app/552520
# 4  https://store.steampowered.com/app/1293830
#
#                                         header_image
# 0  https://cdn.akamai.steamstatic.com/steam/apps/...
# 1  https://cdn.akamai.steamstatic.com/steam/apps/...
# 2  https://cdn.akamai.steamstatic.com/steam/apps/...
# 3  https://cdn.akamai.steamstatic.com/steam/apps/...
# 4  https://cdn.akamai.steamstatic.com/steam/apps/...

# %%
df1['metacritic_url'].values
# Out:
# array(['https://www.metacritic.com/game/pc/warsaw?ftag=MCD-06-10aaa1f',
#        'https://www.metacritic.com/game/pc/alien-breed-3-descent?ftag=MCD-06-10aaa1f',
#        'https://www.metacritic.com/game/pc/deadfall-adventures?ftag=MCD-06-10aaa1f',
#        ...,
#        'https://www.metacritic.com/game/pc/steamworld-heist-ii?ftag=MCD-06-10aaa1f',
#        'https://www.metacritic.com/game/pc/cat-quest-iii?ftag=MCD-06-10aaa1f',
#        'https://www.metacritic.com/game/pc/thank-goodness-youre-here!?ftag=MCD-06-10aaa1f'],
#       dtype=object)

# %%
import requests
from bs4 import BeautifulSoup
import time
import random
import pandas as pd

# Inserisci qui i tuoi 5000 AppID
app_ids = df['appid'].values.astype(str)  # <-- Lista completa qui

# Configura la dimensione dei batch
batch_size = 100

# Genera i batch
batches = [app_ids[i:i + batch_size] for i in range(0, len(app_ids), batch_size)]

# User-Agent per sembrare un browser reale
headers = {
    "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) "
                  "AppleWebKit/537.36 (KHTML, like Gecko) "
                  "Chrome/114.0.0.0 Safari/537.36"
}

def get_all_time_peak(app_id):
    url = f"https://steamcharts.com/app/{app_id}"
    try:
        response = requests.get(url, headers=headers, timeout=15)
        response.raise_for_status()
        soup = BeautifulSoup(response.text, "html.parser")
        stat_divs = soup.find_all("div", class_="app-stat")
        if len(stat_divs) >= 3:
            peak_text = stat_divs[2].find("span", class_="num").text.strip().replace(',', '')
            return int(peak_text)
        else:
            print(f"Struttura cambiata per app_id {app_id}", end = '\r')
            return None 
    except requests.exceptions.RequestException as e:
        print(f"Errore rete con app_id {app_id}: {e}", end = '\r')
        return None
    except Exception as e:
        print(f"Errore imprevisto con app_id {app_id}: {e}", end = '\r')
        return None

def run_batch(batch_index):
    if batch_index >= len(batches):
        print("Batch index fuori dal range.")
        return

    batch_app_ids = batches[batch_index]
    peak_list = []

    print(f"\nAvvio batch {batch_index + 1}/{len(batches)} con {len(batch_app_ids)} app_id...\n")
    for app_id in batch_app_ids:
        peak = get_all_time_peak(app_id)
        peak_list.append(peak)
        print(f"{app_id} → {peak}", end = '\r')
        time.sleep(random.uniform(1, 3))  # Ritardo random per evitare blocchi

    # Salvataggio su CSV
    df = pd.DataFrame({"AppID": batch_app_ids, "AllTimePeak": peak_list})
    df.to_csv(f"steam_peak_batch_{batch_index}.csv", index=False)
    print(f"\nBatch {batch_index} completato e salvato come 'steam_peak_batch_{batch_index}.csv'.")

# Esempio di uso manuale:
# run_batch(0)  # Esegui il primo batch
# run_batch(1)  # Esegui il secondo quando vuoi
# Out:
# '\nimport requests\nfrom bs4 import BeautifulSoup\nimport time\nimport random\nimport pandas as pd\n\n# Inserisci qui i tuoi 5000 AppID\napp_ids = df[\'appid\'].values.astype(str)  # <-- Lista completa qui\n\n# Configura la dimensione dei batch\nbatch_size = 100\n\n# Genera i batch\nbatches = [app_ids[i:i + batch_size] for i in range(0, len(app_ids), batch_size)]\n\n# User-Agent per sembrare un browser reale\nheaders = {\n    "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) "\n                  "AppleWebKit/537.36 (KHTML, like Gecko) "\n                  "Chrome/114.0.0.0 Safari/537.36"\n}\n\ndef get_all_time_peak(app_id):\n    url = f"https://steamcharts.com/app/{app_id}"\n    try:\n        response = requests.get(url, headers=headers, timeout=15)\n        response.raise_for_status()\n        soup = BeautifulSoup(response.text, "html.parser")\n        stat_divs = soup.find_all("div", class_="app-stat")\n        if len(stat_divs) >= 3:\n            peak_text = stat_divs[2].find("span", class_="num").text.strip().replace(\',\', \'\')\n            return int(peak_text)\n        else:\n            print(f"Struttura cambiata per app_id {app_id}", end = \'\r\')\n            return None \n    except requests.exceptions.RequestException as e:\n        print(f"Errore rete con app_id {app_id}: {e}", end = \'\r\')\n        return None\n    except Exception as e:\n        print(f"Errore imprevisto con app_id {app_id}: {e}", end = \'\r\')\n        return None\n\ndef run_batch(batch_index):\n    if batch_index >= len(batches):\n        print("Batch index fuori dal range.")\n        return\n\n    batch_app_ids = batches[batch_index]\n    peak_list = []\n\n    print(f"\nAvvio batch {batch_index + 1}/{len(batches)} con {len(batch_app_ids)} app_id...\n")\n    for app_id in batch_app_ids:\n        peak = get_all_time_peak(app_id)\n        peak_list.append(peak)\n        print(f"{app_id} → {peak}", end = \'\r\')\n        time.sleep(random.uniform(1, 3))  # Ritardo random per evitare blocchi\n\n    # Salvataggio su CSV\n    df = pd.DataFrame({"AppID": batch_app_ids, "AllTimePeak": peak_list})\n    df.to_csv(f"steam_peak_batch_{batch_index}.csv", index=False)\n    print(f"\nBatch {batch_index} completato e salvato come \'steam_peak_batch_{batch_index}.csv\'.")\n\n# Esempio di uso manuale:\n# run_batch(0)  # Esegui il primo batch\n# run_batch(1)  # Esegui il secondo quando vuoi\n'

# %%
'''
for i in range(41,50+1):
    run_batch(i)
    time.sleep(30)
'''
# Out:
# '\nfor i in range(41,50+1):\n    run_batch(i)\n    time.sleep(30)\n'

# %%
import glob

# Trova tutti i CSV che seguono il pattern dei batch
csv_files = glob.glob("steam_peak_batch_*.csv")

# Legge e concatena tutti i CSV
df_list = [pd.read_csv(file) for file in csv_files]
df_all = pd.concat(df_list, ignore_index=True)

# Salva il risultato finale
df_all.to_csv("steam_peak_all.csv", index=False)

print(f"Unito {len(csv_files)} file. Totale AppID: {len(df_all)}")
# Out:
# '\nimport glob\n\n# Trova tutti i CSV che seguono il pattern dei batch\ncsv_files = glob.glob("steam_peak_batch_*.csv")\n\n# Legge e concatena tutti i CSV\ndf_list = [pd.read_csv(file) for file in csv_files]\ndf_all = pd.concat(df_list, ignore_index=True)\n\n# Salva il risultato finale\ndf_all.to_csv("steam_peak_all.csv", index=False)\n\nprint(f"Unito {len(csv_files)} file. Totale AppID: {len(df_all)}")\n'

# %%
df_all = pd.read_csv('steam_peak_all.csv')

# %%
df = df.merge(df_all, how='left', left_on='appid', right_on='AppID')

# %%
df.drop(columns='AppID', inplace = True)

# %%
col = df.pop('AllTimePeak')
df.insert(5, 'AllTimePeak', col)

# %%
df.rename(columns={'AllTimePeak': 'all_time_peak_ccu', 'peak_ccu': '24h_peak_ccu'}, inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5061 entries, 0 to 5060
# Data columns (total 52 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   appid                  5061 non-null   int64
#  1   normalized_name        5061 non-null   object
#  2   name                   5061 non-null   object
#  3   release_date           5061 non-null   datetime64[ns]
#  4   24h_peak_ccu           5061 non-null   float64
#  5   all_time_peak_ccu      3386 non-null   float64
#  6   required_age           5061 non-null   int64
#  7   dlc_count              5061 non-null   int64
#  8   about_the_game         5045 non-null   object
#  9   summary                3021 non-null   object
#  10  supported_languages    5061 non-null   object
#  11  full_audio_languages   5061 non-null   object
#  12  some_reviews           2248 non-null   object
#  13  reviews_total          5061 non-null   float64
#  14  reviews_score_fancy    5028 non-null   float64
#  15  header_image           5061 non-null   object
#  16  windows                5061 non-null   bool
#  17  mac                    5061 non-null   bool
#  18  linux                  5061 non-null   bool
#  19  metacritic_url         5061 non-null   object
#  20  achievements           5061 non-null   int64
#  21  recommendations        5061 non-null   int64
#  22  notes                  591 non-null    object
#  23  developers             5061 non-null   object
#  24  publishers             5037 non-null   object
#  25  categories             5059 non-null   object
#  26  genres                 5057 non-null   object
#  27  tags                   5031 non-null   object
#  28  screenshots            5061 non-null   object
#  29  movies                 4500 non-null   object
#  30  steam_page             5061 non-null   object
#  31  platforms              4088 non-null   object
#  32  infos_per_platform     3384 non-null   object
#  33  revenue_estimated      4583 non-null   float64
#  34  metacritic_score       5061 non-null   float64
#  35  positive               5061 non-null   float64
#  36  negative               5061 non-null   float64
#  37  min_estimated_owners   5061 non-null   float64
#  38  max_estimated_owners   5061 non-null   float64
#  39  average_forever        5061 non-null   float64
#  40  median_forever         5061 non-null   float64
#  41  current_price          4936 non-null   float64
#  42  initial_price          4936 non-null   float64
#  43  discount_percentage    4936 non-null   float64
#  44  metacritic_user_score  4743 non-null   float64
#  45  plays_backloggd        5058 non-null   float64
#  46  playing_backloggd      5058 non-null   float64
#  47  backlogs_backloggd     5058 non-null   float64
#  48  wishlist_backloggd     5058 non-null   float64
#  49  lists_backloggd        5058 non-null   float64
#  50  reviews_backloggd      5058 non-null   float64
#  51  likes_backloggd        4525 non-null   float64
# dtypes: bool(3), datetime64[ns](1), float64(23), int64(5), object(20)
# memory usage: 1.9+ MB

# %%
df.to_csv('steam_games.csv', index=False)
